# %% [markdown]
# # Del problema al algoritmo
# ### Semana 2 · Unidad 2 · Fundamentos para la solución de problemas
#
# Esta semana aprendes a decir lo mismo en tres idiomas: **pseudocódigo** (para
# pensar), **diagrama de flujo** (para ver) y **Python** (para ejecutar).
#
# Y hay algo que quizá no te esperas: el pseudocódigo de este cuadernillo **se
# ejecuta de verdad**. Lo escribes en español, oprimes un botón y corre.
#
# **Empieza ejecutando la celda de abajo**: haz clic sobre ella y presiona
# `Shift+Enter`. Después avanza celda por celda, sin saltarte ninguna.

# %%
# Motor del cuadernillo: barra de progreso, pistas y verificadores.
# No necesitas leer este codigo. Ejecutalo una vez (Shift+Enter) y sigue.
# Codigo fuente legible en el repositorio del curso:
#   notebook/cuadernillos/**/ava_motor.py
#   notebook/cuadernillos/**/pseudo_uis.py
#   notebook/cuadernillos/**/contenido.py
import base64, zlib
exec(zlib.decompress(base64.b64decode("...")).decode("utf-8"))
exec(zlib.decompress(base64.b64decode("...")).decode("utf-8"))
exec(zlib.decompress(base64.b64decode("...")).decode("utf-8"))

ava = Motor(titulo='Del problema al algoritmo', meta_xp=80, insignia='Traductora / Traductor de algoritmos')
quiz, ordenar, comprobar, pista = ava.quiz, ava.ordenar, ava.comprobar, ava.pista

# Pistas de los ejercicios. Van comprimidas para no destriparlas:
# se piden una a una con pista("E1"), o con el boton Pista.
import json as _json
for _c, _p in _json.loads(zlib.decompress(base64.b64decode("...")).decode("utf-8")).items():
    ava.registrar_pistas(_c, _p)

ava.barra()
esconder_entrada()

# %%
portada()

# %% [markdown]
# ## Al terminar este cuadernillo vas a poder…
#
# 1. Leer un problema en español y decir en voz alta **qué datos entran, qué se
#    hace con ellos y qué sale** — sin escribir una sola línea de código.
# 2. Distinguir una **variable** de una **constante** y de una **restricción**, y
#    ponerle a cada una un nombre que se entienda.
# 3. Escribir un algoritmo en **pseudocódigo en español** y **ejecutarlo aquí
#    mismo** para ver si hace lo que creías.
# 4. Dibujar el **diagrama de flujo** de ese algoritmo usando los cinco símbolos
#    correctos, y reconocer cuándo un diagrama está mal armado.
# 5. Hacer una **prueba de escritorio**: seguir tu propio algoritmo con lápiz y
#    papel, instrucción por instrucción, anotando cuánto vale cada variable.
# 6. Traducir el mismo algoritmo a **Python**, sabiendo que `input()` siempre te
#    entrega **texto** y que tú decides con `int()` o `float()` en qué se
#    convierte.
# 7. Explicar por qué `x = x + 2` no es una ecuación mentirosa. 🙂
#
# ### Este cuadernillo se hace en dos sentadas
#
# Son 165 minutos y cubre las dos clases de la semana. No intentes hacerlo de una:
#
# | | Cuándo | Qué trae |
# |---|---|---|
# | **Parte A** | después de la **Clase 1** | secciones 1, 2 y 3 — plantear, analizar, variables y E-P-S |
# | **Parte B** | después de la **Clase 2** | secciones 4 a 8 — pseudocódigo, diagramas, memoria, tipos, `input()` y los ocho ejercicios |
#
# Hay una tarjeta que marca el corte cuando llegues.
#
# > **Dos marcadores distintos, no los confundas.** Los **XP** son del juego: los
# > ganas con los quices y los ensayos. Los **puntos** son tu nota: salen solo de
# > los ocho ejercicios y viajan solos a Moodle.
# >
# > Este cuadernillo tiene **80 puntos** y **80 XP**. La insignia se llama
# > «Traductora / Traductor de algoritmos».

# %% [markdown]
# ---
#
# ## 1. Calentamiento · 10 min
#
# Cuatro preguntas rápidas de la semana pasada. No tienen nota: dan XP y te
# dicen si estás listo para lo de hoy.
#
# Si algo aquí se te atasca, **esa es la señal**: vuelve al cuadernillo de la
# Semana 1 antes de seguir. Lo de hoy se apoya en eso.

# %%
quiz_hardware()

# %%
quiz_niveles()

# %%
# Esta línea está rota, igual que la de la semana pasada.
# Quítale el # del principio, arréglala y ejecútala.
# print("Buenos días, Bucaramanga)

# %%
orden_errores()

# %% [markdown]
# El tercero es el peligroso. Un error de sintaxis lo ve Python; un error de
# lógica solo lo ves **tú**, y solo si haces una prueba de escritorio. Ese es,
# casualmente, uno de los temas de hoy.

# %% [markdown]
# ---
#
# ## 2. ¿A qué hora tengo que salir de la casa? · 8 min
#
# Vives en **Girón**. Tu primera clase en la UIS es a las **6:00 a. m.** y el
# profesor cierra la puerta en punto.
#
# - De tu casa a la parada: **8 minutos** caminando.
# - De la parada a la UIS en bus: **45 minutos** (si el tráfico se porta bien).
# - De la portería al salón: **10 minutos**.
# - Y quieres un **colchón de 15 minutos**, porque el bus no siempre se porta
#   bien.
#
# ¿A qué hora suena el despertador?

# %%
grafica_madrugada()

# %% [markdown]
# **Las 4:42.** Ese cálculo lo hiciste de cabeza en veinte segundos.
#
# Ahora hazlo para los **30.000 estudiantes de la UIS**: cada uno vive en un
# barrio distinto, toma rutas distintas y tiene clase a horas distintas. Ahí ya no
# alcanza la cabeza ni la calculadora. Ahí se necesita **un algoritmo**: una
# receta que sirva para todos, escrita una sola vez.
#
# Ejecuta la celda de abajo. No es Python.

# %%
CODIGO_GANCHO = """Algoritmo AQueHoraSalgo
    Definir hora_clase_min, minutos_bus, minutos_caminata Como Entero
    Definir trayecto, salida_min Como Entero
    Constante PORTERIA <- 10
    Constante COLCHON  <- 15

    Escribir "¿A qué hora es tu clase? (en minutos desde medianoche)"
    Leer hora_clase_min
    Escribir "¿Cuántos minutos de bus?"
    Leer minutos_bus
    Escribir "¿Cuántos minutos caminando hasta la parada?"
    Leer minutos_caminata

    trayecto <- minutos_bus + minutos_caminata + PORTERIA
    salida_min <- hora_clase_min - trayecto - COLCHON

    Escribir "Debes salir a los ", salida_min, " minutos desde medianoche"
FinAlgoritmo"""

ps.ejecutar_pseudo(CODIGO_GANCHO, entradas=["360", "45", "8"]).imprimir()
display(HTML(ps.diagrama(CODIGO_GANCHO)))   # el diagrama se dibuja SOLO

# %% [markdown]
# Lo que acabas de ver **no es Python**. Es **pseudocódigo**: español con reglas.
# Y sin embargo se ejecutó, y sin embargo el computador dibujó su diagrama de
# flujo sin que nadie lo dibujara.
#
# Eso es lo que vas a saber hacer al final de esta sesión: **escribir un algoritmo
# en español, verlo correr, verlo dibujado y traducirlo a Python** — que es
# exactamente lo que se hace en la vida real antes de programar cualquier cosa
# seria.

# %% [markdown]
# ---
#
# ## 3. Concepto en corto · 30 min
#
# Antes de escribir nada hay que pensar. Esta sección es la parte del oficio que
# se hace **sin computador**, y es la que el 90 % de los novatos se salta.

# %%
# Diagrama: s02_d1_cadv
ava.figura('<svg xmlns="http://www.w3.org/2000/svg" id="dia-s02_d1_cadv" width="100%" aria-roledescription="flowchart-v2" class="flowchart" role="graphics-document document" style="max-width:1173.73px;background-color:transparent" viewBox="0 0 1173.734 167.75"><style>#dia-s02_d1_cadv{font-family:system-ui,-apple-system,&apos;Segoe UI&apos;,Roboto,sans-serif;font-size:15px;fill:#000000;}@keyframes edge-animation-frame{from{stroke-dashoffset:0;}}@keyframes dash{to{stroke-dashoffset:0;}}#dia-s02_d1_cadv .edge-animation-slow{stroke-dasharray:9,5!important;stroke-dashoffset:900;animation:dash 50s linear infinite;stroke-linecap:round;}#dia-s02_d1_cadv .edge-animation-fast{stroke-dasharray:9,5!important;stroke-dashoffset:900;animation:dash 20s linear infinite;stroke-linecap:round;}#dia-s02_d1_cadv .error-icon{fill:#552222;}#dia-s02_d1_cadv .error-text{fill:#552222;stroke:#552222;}#dia-s02_d1_cadv .edge-thickness-normal{stroke-width:1px;}#dia-s02_d1_cadv .edge-thickness-thick{stroke-width:3.5px;}#dia-s02_d1_cadv .edge-pattern-solid{stroke-dasharray:0;}#dia-s02_d1_cadv .edge-thickness-invisible{stroke-width:0;fill:none;}#dia-s02_d1_cadv .edge-pattern-dashed{stroke-dasharray:3;}#dia-s02_d1_cadv .edge-pattern-dotted{stroke-dasharray:2;}#dia-s02_d1_cadv .marker{fill:#52514e;stroke:#52514e;}#dia-s02_d1_cadv .marker.cross{stroke:#52514e;}#dia-s02_d1_cadv svg{font-family:system-ui,-apple-system,&apos;Segoe UI&apos;,Roboto,sans-serif;font-size:15px;}#dia-s02_d1_cadv p{margin:0;}#dia-s02_d1_cadv .label{font-family:system-ui,-apple-system,&apos;Segoe UI&apos;,Roboto,sans-serif;color:#000000;}#dia-s02_d1_cadv .cluster-label text{fill:#333;}#dia-s02_d1_cadv .cluster-label span{color:#333;}#dia-s02_d1_cadv .cluster-label span p{background-color:transparent;}#dia-s02_d1_cadv .label text,#dia-s02_d1_cadv span{fill:#000000;color:#000000;}#dia-s02_d1_cadv .node rect,#dia-s02_d1_cadv .node circle,#dia-s02_d1_cadv .node ellipse,#dia-s02_d1_cadv .node polygon,#dia-s02_d1_cadv .node path{fill:#eee;stroke:#999;stroke-width:1px;}#dia-s02_d1_cadv .rough-node .label text,#dia-s02_d1_cadv .node .label text,#dia-s02_d1_cadv .image-shape .label,#dia-s02_d1_cadv .icon-shape .label{text-anchor:middle;}#dia-s02_d1_cadv .node .katex path{fill:#000;stroke:#000;stroke-width:1px;}#dia-s02_d1_cadv .rough-node .label,#dia-s02_d1_cadv .node .label,#dia-s02_d1_cadv .image-shape .label,#dia-s02_d1_cadv .icon-shape .label{text-align:center;}#dia-s02_d1_cadv .node.clickable{cursor:pointer;}#dia-s02_d1_cadv .root .anchor path{fill:#52514e!important;stroke-width:0;stroke:#52514e;}#dia-s02_d1_cadv .arrowheadPath{fill:#333333;}#dia-s02_d1_cadv .edgePath .path{stroke:#52514e;stroke-width:1px;}#dia-s02_d1_cadv .flowchart-link{stroke:#52514e;fill:none;}#dia-s02_d1_cadv .edgeLabel{background-color:white;text-align:center;}#dia-s02_d1_cadv .edgeLabel p{background-color:white;}#dia-s02_d1_cadv .edgeLabel rect{opacity:0.5;background-color:white;fill:white;}#dia-s02_d1_cadv .labelBkg{background-color:rgba(255, 255, 255, 0.5);}#dia-s02_d1_cadv .cluster rect{fill:hsl(0, 0%, 98.9215686275%);stroke:#707070;stroke-width:1px;}#dia-s02_d1_cadv .cluster text{fill:#333;}#dia-s02_d1_cadv .cluster span{color:#333;}#dia-s02_d1_cadv div.mermaidTooltip{position:absolute;text-align:center;max-width:200px;padding:2px;font-family:system-ui,-apple-system,&apos;Segoe UI&apos;,Roboto,sans-serif;font-size:12px;background:#fdf6e3;border:1px solid #707070;border-radius:2px;pointer-events:none;z-index:100;}#dia-s02_d1_cadv .flowchartTitleText{text-anchor:middle;font-size:18px;fill:#000000;}#dia-s02_d1_cadv rect.text{fill:none;stroke-width:0;}#dia-s02_d1_cadv .icon-shape,#dia-s02_d1_cadv .image-shape{background-color:white;text-align:center;}#dia-s02_d1_cadv .icon-shape p,#dia-s02_d1_cadv .image-shape p{background-color:white;padding:2px;}#dia-s02_d1_cadv .icon-shape .label rect,#dia-s02_d1_cadv .image-shape .label rect{opacity:0.5;background-color:white;fill:white;}#dia-s02_d1_cadv .label-icon{display:inline-block;height:1em;overflow:visible;vertical-align:-0.125em;}#dia-s02_d1_cadv .node .label-icon path{fill:currentColor;stroke:revert;stroke-width:revert;}#dia-s02_d1_cadv .node .neo-node{stroke:#999;}#dia-s02_d1_cadv [data-look=&quot;neo&quot;].node rect,#dia-s02_d1_cadv [data-look=&quot;neo&quot;].cluster rect,#dia-s02_d1_cadv [data-look=&quot;neo&quot;].node polygon{stroke:url(#dia-s02_d1_cadv-gradient);filter:drop-shadow( 1px 2px 2px rgba(185,185,185,1));}#dia-s02_d1_cadv [data-look=&quot;neo&quot;].swimlane.cluster rect{filter:none;}#dia-s02_d1_cadv [data-look=&quot;neo&quot;].node path{stroke:url(#dia-s02_d1_cadv-gradient);stroke-width:1px;}#dia-s02_d1_cadv [data-look=&quot;neo&quot;].node .outer-path{filter:drop-shadow( 1px 2px 2px rgba(185,185,185,1));}#dia-s02_d1_cadv [data-look=&quot;neo&quot;].node .neo-line path{stroke:#999;filter:none;}#dia-s02_d1_cadv [data-look=&quot;neo&quot;].node circle{stroke:url(#dia-s02_d1_cadv-gradient);filter:drop-shadow( 1px 2px 2px rgba(185,185,185,1));}#dia-s02_d1_cadv [data-look=&quot;neo&quot;].node circle .state-start{fill:#000000;}#dia-s02_d1_cadv [data-look=&quot;neo&quot;].icon-shape .icon{fill:url(#dia-s02_d1_cadv-gradient);filter:drop-shadow( 1px 2px 2px rgba(185,185,185,1));}#dia-s02_d1_cadv [data-look=&quot;neo&quot;].icon-shape .icon-neo path{stroke:url(#dia-s02_d1_cadv-gradient);filter:drop-shadow( 1px 2px 2px rgba(185,185,185,1));}#dia-s02_d1_cadv :root{--mermaid-font-family:&quot;trebuchet ms&quot;,verdana,arial,sans-serif;}</style><marker id="dia-s02_d1_cadv_flowchart-v2-pointEnd" class="marker flowchart-v2" markerHeight="8" markerUnits="userSpaceOnUse" markerWidth="8" orient="auto" refX="5" refY="5" viewBox="0 0 10 10"><path d="m0 0 10 5-10 5z" class="arrowMarkerPath" style="stroke-width:1;stroke-dasharray:1,0"/></marker><marker id="dia-s02_d1_cadv_flowchart-v2-pointStart" class="marker flowchart-v2" markerHeight="8" markerUnits="userSpaceOnUse" markerWidth="8" orient="auto" refX="4.5" refY="5" viewBox="0 0 10 10"><path d="m0 5 10 5V0z" class="arrowMarkerPath" style="stroke-width:1;stroke-dasharray:1,0"/></marker><marker id="dia-s02_d1_cadv_flowchart-v2-pointEnd-margin" class="marker flowchart-v2" markerHeight="14" markerUnits="userSpaceOnUse" markerWidth="10.5" orient="auto" refX="11.5" refY="7" viewBox="0 0 11.5 14"><path d="m0 0 11.5 7L0 14z" class="arrowMarkerPath" style="stroke-width:0;stroke-dasharray:1,0"/></marker><marker id="dia-s02_d1_cadv_flowchart-v2-pointStart-margin" class="marker flowchart-v2" markerHeight="14" markerUnits="userSpaceOnUse" markerWidth="11.5" orient="auto" refX="1" refY="7" viewBox="0 0 11.5 14"><polygon points="0,7 11.5,14 11.5,0" class="arrowMarkerPath" style="stroke-width:0;stroke-dasharray:1,0"/></marker><marker id="dia-s02_d1_cadv_flowchart-v2-circleEnd" class="marker flowchart-v2" markerHeight="11" markerUnits="userSpaceOnUse" markerWidth="11" orient="auto" refX="11" refY="5" viewBox="0 0 10 10"><circle cx="5" cy="5" r="5" class="arrowMarkerPath" style="stroke-width:1;stroke-dasharray:1,0"/></marker><marker id="dia-s02_d1_cadv_flowchart-v2-circleStart" class="marker flowchart-v2" markerHeight="11" markerUnits="userSpaceOnUse" markerWidth="11" orient="auto" refX="-1" refY="5" viewBox="0 0 10 10"><circle cx="5" cy="5" r="5" class="arrowMarkerPath" style="stroke-width:1;stroke-dasharray:1,0"/></marker><marker id="dia-s02_d1_cadv_flowchart-v2-circleEnd-margin" class="marker flowchart-v2" markerHeight="14" markerUnits="userSpaceOnUse" markerWidth="14" orient="auto" refX="12.25" refY="5" viewBox="0 0 10 10"><circle cx="5" cy="5" r="5" class="arrowMarkerPath" style="stroke-width:0;stroke-dasharray:1,0"/></marker><marker id="dia-s02_d1_cadv_flowchart-v2-circleStart-margin" class="marker flowchart-v2" markerHeight="14" markerUnits="userSpaceOnUse" markerWidth="14" orient="auto" refX="-2" refY="5" viewBox="0 0 10 10"><circle cx="5" cy="5" r="5" class="arrowMarkerPath" style="stroke-width:0;stroke-dasharray:1,0"/></marker><marker id="dia-s02_d1_cadv_flowchart-v2-crossEnd" class="marker cross flowchart-v2" markerHeight="11" markerUnits="userSpaceOnUse" markerWidth="11" orient="auto" refX="12" refY="5.2" viewBox="0 0 11 11"><path d="m1 1 9 9m0-9-9 9" class="arrowMarkerPath" style="stroke-width:2;stroke-dasharray:1,0"/></marker><marker id="dia-s02_d1_cadv_flowchart-v2-crossStart" class="marker cross flowchart-v2" markerHeight="11" markerUnits="userSpaceOnUse" markerWidth="11" orient="auto" refX="-1" refY="5.2" viewBox="0 0 11 11"><path d="m1 1 9 9m0-9-9 9" class="arrowMarkerPath" style="stroke-width:2;stroke-dasharray:1,0"/></marker><marker id="dia-s02_d1_cadv_flowchart-v2-crossEnd-margin" class="marker cross flowchart-v2" markerHeight="12" markerUnits="userSpaceOnUse" markerWidth="12" orient="auto" refX="17.7" refY="7.5" viewBox="0 0 15 15"><path d="m1 1 13 13M1 14 14 1" class="arrowMarkerPath" style="stroke-width:2.5"/></marker><marker id="dia-s02_d1_cadv_flowchart-v2-crossStart-margin" class="marker cross flowchart-v2" markerHeight="12" markerUnits="userSpaceOnUse" markerWidth="12" orient="auto" refX="-3.5" refY="7.5" viewBox="0 0 15 15"><path d="m1 1 13 13M1 14 14 1" class="arrowMarkerPath" style="stroke-width:2.5;stroke-dasharray:1,0"/></marker><g class="root"><g class="edgePaths"><path id="dia-s02_d1_cadv-L_A_B_0" marker-end="url(#dia-s02_d1_cadv_flowchart-v2-pointEnd)" d="m256.813 63.757 4.166-1.168c4.167-1.168 12.5-3.503 20.167-4.671s14.667-1.168 18.167-1.168h3.5" class="edge-thickness-normal edge-pattern-solid edge-thickness-normal edge-pattern-solid flowchart-link" data-edge="true" data-et="edge" data-id="L_A_B_0" data-look="classic" data-points="W3sieCI6MjU2LjgxMjUsInkiOjYzLjc1NjkwMjMyMTY5MDAyfSx7IngiOjI4MS44MTI1LCJ5Ijo1Ni43NX0seyJ4IjozMDYuODEyNSwieSI6NTYuNzV9XQ=="/><path id="dia-s02_d1_cadv-L_B_C_0" marker-end="url(#dia-s02_d1_cadv_flowchart-v2-pointEnd)" d="M500.375 56.75h170.797" class="edge-thickness-normal edge-pattern-solid edge-thickness-normal edge-pattern-solid flowchart-link" data-edge="true" data-et="edge" data-id="L_B_C_0" data-look="classic" data-points="W3sieCI6NTAwLjM3NSwieSI6NTYuNzV9LHsieCI6NTg3Ljc3MzQzNzUsInkiOjU2Ljc1fSx7IngiOjY3NS4xNzE4NzUsInkiOjU2Ljc1fV0="/><path id="dia-s02_d1_cadv-L_C_D_0" marker-end="url(#dia-s02_d1_cadv_flowchart-v2-pointEnd)" d="M912.781 56.75h4.167c4.167 0 12.5 0 20.2 1.17 7.701 1.17 14.768 3.51 18.302 4.68l3.534 1.17" class="edge-thickness-normal edge-pattern-solid edge-thickness-normal edge-pattern-solid flowchart-link" data-edge="true" data-et="edge" data-id="L_C_D_0" data-look="classic" data-points="W3sieCI6OTEyLjc4MTI1LCJ5Ijo1Ni43NX0seyJ4Ijo5MzcuNzgxMjUsInkiOjU2Ljc1fSx7IngiOjk2Mi43ODEyNSwieSI6NjUuMDI3MjI1Mjc2NDIyMjZ9XQ=="/><path id="dia-s02_d1_cadv-L_D_A_0" marker-end="url(#dia-s02_d1_cadv_flowchart-v2-pointEnd)" d="m962.781 132.223-4.166 1.379c-4.167 1.38-12.5 4.139-40.635 5.518-28.134 1.38-76.069 1.38-134.403 1.38H413.993c-50.993 0-91.587 0-115.408-.988-23.822-.988-30.871-2.964-34.396-3.951l-3.525-.988" class="edge-thickness-normal edge-pattern-dotted edge-thickness-normal edge-pattern-solid flowchart-link" data-edge="true" data-et="edge" data-id="L_D_A_0" data-look="classic" data-points=""/></g><g class="edgeLabels"><rect class="background" style="stroke:none"/><rect class="background" style="stroke:none"/><rect class="background" style="stroke:none"/><g class="edgeLabel"><g class="label" data-id="L_D_A_0" transform="translate(587.773 123.25)"><rect width="124.797" height="38.5" x="-62.398" y="-2" class="background"/><text y="-10.1" text-anchor="middle"><tspan x="0" y="-.1em" class="text-outer-tspan row" dy="1.1em" text-anchor="middle"><tspan class="text-inner-tspan" font-style="normal" font-weight="normal">si</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> algo</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> no</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> cuadra,</tspan></tspan><tspan x="0" y="1em" class="text-outer-tspan row" dy="1.1em" text-anchor="middle"><tspan class="text-inner-tspan" font-style="normal" font-weight="normal">se</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> devuelve</tspan></tspan></text></g></g></g><g class="nodes"><g id="dia-s02_d1_cadv-flowchart-A-0" class="node default" data-look="classic" transform="translate(132.406 98.625)"><rect width="248.813" height="81" x="-124.406" y="-40.5" class="basic label-container" style="fill:#2a78d6!important;stroke:#104281!important"/><g class="label" style="color:#fff!important" transform="translate(0 -25.5)"><rect/><rect class="background" style="stroke:none"/><text y="-10.1" style="fill:#fff!important"><tspan x="0" y="-.1em" class="text-outer-tspan row" dy="1.1em"><tspan class="text-inner-tspan" font-style="normal" font-weight="normal">1.</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> COMPRENDER</tspan></tspan><tspan x="0" y="1em" class="text-outer-tspan row" dy="1.1em"><tspan class="text-inner-tspan" font-style="normal" font-weight="normal">¿Qué</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> me</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> están</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> pidiendo?</tspan></tspan><tspan x="0" y="2.1em" class="text-outer-tspan row" dy="1.1em"><tspan class="text-inner-tspan" font-style="normal" font-weight="normal">Lo</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> explico</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> con</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> mis</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> palabras</tspan></tspan></text></g></g><g id="dia-s02_d1_cadv-flowchart-B-1" class="node default" data-look="classic" transform="translate(403.594 56.75)"><rect width="193.563" height="97.5" x="-96.781" y="-48.75" class="basic label-container" style="fill:#4a3aa7!important;stroke:#2a1f6b!important"/><g class="label" style="color:#fff!important" transform="translate(0 -33.75)"><rect/><rect class="background" style="stroke:none"/><text y="-10.1" style="fill:#fff!important"><tspan x="0" y="-.1em" class="text-outer-tspan row" dy="1.1em"><tspan class="text-inner-tspan" font-style="normal" font-weight="normal">2.</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> ANALIZAR</tspan></tspan><tspan x="0" y="1em" class="text-outer-tspan row" dy="1.1em"><tspan class="text-inner-tspan" font-style="normal" font-weight="normal">¿Qué</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> datos</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> entran?</tspan></tspan><tspan x="0" y="2.1em" class="text-outer-tspan row" dy="1.1em"><tspan class="text-inner-tspan" font-style="normal" font-weight="normal">¿Qué</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> sale?</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> ¿Qué</tspan></tspan><tspan x="0" y="3.2em" class="text-outer-tspan row" dy="1.1em"><tspan class="text-inner-tspan" font-style="normal" font-weight="normal">restricciones</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> hay?</tspan></tspan></text></g></g><g id="dia-s02_d1_cadv-flowchart-C-2" class="node default" data-look="classic" transform="translate(793.977 56.75)"><rect width="237.609" height="81" x="-118.805" y="-40.5" class="basic label-container" style="fill:#008300!important;stroke:#005400!important"/><g class="label" style="color:#fff!important" transform="translate(0 -25.5)"><rect/><rect class="background" style="stroke:none"/><text y="-10.1" style="fill:#fff!important"><tspan x="0" y="-.1em" class="text-outer-tspan row" dy="1.1em"><tspan class="text-inner-tspan" font-style="normal" font-weight="normal">3.</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> DISEÑAR</tspan></tspan><tspan x="0" y="1em" class="text-outer-tspan row" dy="1.1em"><tspan class="text-inner-tspan" font-style="normal" font-weight="normal">Pseudocódigo</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> y</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> diagrama</tspan></tspan><tspan x="0" y="2.1em" class="text-outer-tspan row" dy="1.1em"><tspan class="text-inner-tspan" font-style="normal" font-weight="normal">ANTES</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> de</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> programar</tspan></tspan></text></g></g><g id="dia-s02_d1_cadv-flowchart-D-3" class="node default" data-look="classic" transform="translate(1064.258 98.625)"><rect width="202.953" height="81" x="-101.477" y="-40.5" class="basic label-container" style="fill:#eda100!important;stroke:#8a6d00!important"/><g class="label" style="color:#3a2a00!important" transform="translate(0 -25.5)"><rect/><rect class="background" style="stroke:none"/><text y="-10.1" style="fill:#3a2a00!important"><tspan x="0" y="-.1em" class="text-outer-tspan row" dy="1.1em"><tspan class="text-inner-tspan" font-style="normal" font-weight="normal">4.</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> VERIFICAR</tspan></tspan><tspan x="0" y="1em" class="text-outer-tspan row" dy="1.1em"><tspan class="text-inner-tspan" font-style="normal" font-weight="normal">Prueba</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> de</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> escritorio</tspan></tspan><tspan x="0" y="2.1em" class="text-outer-tspan row" dy="1.1em"><tspan class="text-inner-tspan" font-style="normal" font-weight="normal">con</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> casos</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> de</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> prueba</tspan></tspan></text></g></g></g></g><defs><filter id="dia-s02_d1_cadv-drop-shadow" width="130%" height="130%"><feDropShadow dx="4" dy="4" flood-color="#000" flood-opacity=".06" stdDeviation="0"/></filter></defs><defs><filter id="dia-s02_d1_cadv-drop-shadow-small" width="150%" height="150%"><feDropShadow dx="2" dy="2" flood-color="#000" flood-opacity=".06" stdDeviation="0"/></filter></defs><linearGradient id="dia-s02_d1_cadv-gradient" x1="0%" x2="100%" y1="0%" y2="0%" gradientUnits="objectBoundingBox"><stop offset="0%" stop-color="hsl(0, 0%, 83.3333333333%)" stop-opacity="1"/><stop offset="100%" stop-color="hsl(0, 0%, 88.9215686275%)" stop-opacity="1"/></linearGradient></svg>', 'Cuatro pasos, siempre los mismos. Y si en «verificar» algo no cuadra, se devuelve uno a «comprender».')

# %% [markdown]
# ### Cuatro pasos, siempre los mismos
#
# **1. Comprender.** Vuelve a contar el problema **con tus propias palabras**, sin
# mirar el enunciado. Si no puedes, todavía no lo entendiste — y programar sin
# entender es la forma más cara de perder una tarde.
#
# **2. Analizar.** Tres preguntas: ¿qué datos **entran**? ¿qué debe **salir**?
# ¿qué **restricciones** hay (qué valores no tienen sentido)?
#
# **3. Diseñar.** Escribe el **pseudocódigo** y dibuja el **diagrama**. Todavía no
# programes. Esta etapa se salta el 90 % de los novatos, y es la razón por la que
# se demoran el triple.
#
# **4. Verificar.** Antes de ejecutar nada, haz la **prueba de escritorio**:
# recorre tu propio algoritmo con lápiz y papel, con un caso cuyo resultado ya
# conozcas. Si no da, arregla el diseño; no el código, que todavía no existe.
#
# Y si en «verificar» algo no cuadra, se devuelve uno a «comprender». Por eso la
# flecha punteada del dibujo.

# %% [markdown]
# ### Un problema bien planteado
#
# Compara estos dos enunciados:
#
# | Mal planteado | Bien planteado |
# |---|---|
# | «Calcular lo del parqueadero» | «Dado el número de **horas** que un carro estuvo en el parqueadero de la UIS y la **tarifa por hora**, calcular cuánto debe pagar, sabiendo que hay un **recargo fijo** de $1.000 por el uso de la barrera.» |
#
# El segundo dice **qué entra**, **qué sale** y **qué reglas hay**. El primero no
# dice nada: ¿lo del parqueadero de quién? ¿cobrado cómo? ¿desde cuándo?
#
# **Tu primer trabajo como programador no es escribir código: es convertir el
# primer enunciado en el segundo.** A eso se le llama plantear el problema.

# %% [markdown]
# ### La ficha de análisis
#
# Antes de diseñar nada, llena estas cinco casillas. Es literalmente el formato
# que vas a usar en el ejercicio E3 y en el taller presencial.
#
# | Casilla | Pregunta | Ejemplo (parqueadero) |
# |---|---|---|
# | **Objetivo** | ¿Qué debe lograr el algoritmo, en una frase? | Calcular el valor a pagar por el parqueadero. |
# | **Entradas** | ¿Qué datos necesito que alguien me dé? | `horas`, `tarifa_hora`, `recargo_fijo` |
# | **Salidas** | ¿Qué entrego? | `total` |
# | **Restricciones** | ¿Qué valores no tienen sentido? | `horas` ≥ 0; `tarifa_hora` > 0; `horas` es un entero |
# | **Casos de prueba** | ¿Con qué datos voy a comprobar que funciona? | 3 h a $2.500 + $1.000 → **8.500**; 0 h → **1.000** |
#
# Fíjate en la última fila. **Los casos de prueba se escriben ANTES de
# programar**, cuando todavía puedes pensar con calma en qué debería dar. Si los
# inventas después, vas a «comprobar» que tu programa hace justo lo que hace.

# %% [markdown]
# ### Variables, constantes y restricciones
#
# | Concepto | Qué es | En el problema del parqueadero | Cómo se escribe |
# |---|---|---|---|
# | **Variable** | Un dato que **cambia** de una ejecución a otra | `horas` (cada carro se queda un rato distinto) | `Definir horas Como Entero` |
# | **Constante** | Un dato que **no cambia** mientras el algoritmo corre | `TARIFA_HORA <- 2500` | `Constante TARIFA_HORA <- 2500` — en MAYÚSCULAS |
# | **Restricción** | Una condición que los datos **deben cumplir** para que el problema tenga sentido | `horas` no puede ser negativa; `horas` es un número entero de horas | Se escribe en la **ficha de análisis**, todavía no en el código (validar es de la Semana 3) |
#
# Las restricciones no se programan hoy —para eso hacen falta los condicionales,
# que llegan la semana entrante— pero **sí se escriben hoy**. Un problema mal
# delimitado produce un programa que funciona con los datos del profesor y explota
# con los del mundo real.

# %%
figura_cajas()

# %% [markdown]
# ### Cómo se llama una variable
#
# **Reglas que obliga el computador:** sin espacios, sin tildes ni eñes, no
# empieza por número, no se llama igual que una palabra reservada (`print`,
# `input`, `if`…).
#
# **Reglas que obliga la decencia:** en minúsculas, palabras unidas con guion
# bajo, y que se entienda: `costo_pasaje`, `total_a_pagar`, `minutos_bus`.
#
# Tres nombres que no debes usar nunca, aunque funcionen: **`x`** (¿x de qué?),
# **`dato1`** (¿dato de qué?) y **`aux`** (auxiliar de qué). El código se escribe
# una vez y se lee veinte.

# %%
figura_eps()

# %% [markdown]
# ### E-P-S aplicado al problema de esta mañana
#
# | | El problema de esta mañana |
# |---|---|
# | **Entrada** | `hora_clase_min` = 360 · `minutos_bus` = 45 · `minutos_caminata` = 8 |
# | **Constantes** | `PORTERIA` = 10 · `COLCHON` = 15 |
# | **Proceso** | `trayecto <- minutos_bus + minutos_caminata + PORTERIA` ⏎ `salida_min <- hora_clase_min - trayecto - COLCHON` |
# | **Salida** | `salida_min` = 282, o sea las **4:42** |
# | **Restricciones** | los minutos no pueden ser negativos; `salida_min` debería dar más de 0 (si no, tocaría salir el día anterior) |
# | **Casos de prueba** | (360, 45, 8) → 282 · (420, 60, 5) → 330 |
#
# Ahora te toca a ti. Ensaya con el formulario de abajo: es el mismo que vas a
# llenar en el ejercicio E3.

# %%
ensayo_eps()

# %% [markdown]
# ### ¿Por qué tres formas de escribir lo mismo?
#
# Porque sirven para cosas distintas y en momentos distintos.
#
# - **El pseudocódigo** es para **pensar**. Nadie lo ejecuta, así que no te
#   castiga por un punto y coma mal puesto; te deja concentrarte en la lógica. Y
#   como está en español, se lo puedes mostrar a alguien que no programa.
# - **El diagrama de flujo** es para **ver**. Un rombo con dos flechas te muestra
#   de un vistazo que hay dos caminos; en texto, esa misma idea hay que
#   reconstruirla leyendo.
# - **Python** es para **ejecutar**. Es el único de los tres que el computador
#   entiende de verdad.
#
# Un buen programador se mueve entre los tres todo el tiempo. Y en un examen
# escrito —donde no hay computador— los dos primeros son los únicos que tienes.

# %%
# Diagrama: s02_d7_tres_idiomas
ava.figura('<svg xmlns="http://www.w3.org/2000/svg" id="dia-s02_d7_tres_idiomas" width="100%" aria-roledescription="flowchart-v2" class="flowchart" role="graphics-document document" style="max-width:1141.91px;background-color:transparent" viewBox="0 0 1141.906 228.5"><style>#dia-s02_d7_tres_idiomas{font-family:system-ui,-apple-system,&apos;Segoe UI&apos;,Roboto,sans-serif;font-size:15px;fill:#000000;}@keyframes edge-animation-frame{from{stroke-dashoffset:0;}}@keyframes dash{to{stroke-dashoffset:0;}}#dia-s02_d7_tres_idiomas .edge-animation-slow{stroke-dasharray:9,5!important;stroke-dashoffset:900;animation:dash 50s linear infinite;stroke-linecap:round;}#dia-s02_d7_tres_idiomas .edge-animation-fast{stroke-dasharray:9,5!important;stroke-dashoffset:900;animation:dash 20s linear infinite;stroke-linecap:round;}#dia-s02_d7_tres_idiomas .error-icon{fill:#552222;}#dia-s02_d7_tres_idiomas .error-text{fill:#552222;stroke:#552222;}#dia-s02_d7_tres_idiomas .edge-thickness-normal{stroke-width:1px;}#dia-s02_d7_tres_idiomas .edge-thickness-thick{stroke-width:3.5px;}#dia-s02_d7_tres_idiomas .edge-pattern-solid{stroke-dasharray:0;}#dia-s02_d7_tres_idiomas .edge-thickness-invisible{stroke-width:0;fill:none;}#dia-s02_d7_tres_idiomas .edge-pattern-dashed{stroke-dasharray:3;}#dia-s02_d7_tres_idiomas .edge-pattern-dotted{stroke-dasharray:2;}#dia-s02_d7_tres_idiomas .marker{fill:#52514e;stroke:#52514e;}#dia-s02_d7_tres_idiomas .marker.cross{stroke:#52514e;}#dia-s02_d7_tres_idiomas svg{font-family:system-ui,-apple-system,&apos;Segoe UI&apos;,Roboto,sans-serif;font-size:15px;}#dia-s02_d7_tres_idiomas p{margin:0;}#dia-s02_d7_tres_idiomas .label{font-family:system-ui,-apple-system,&apos;Segoe UI&apos;,Roboto,sans-serif;color:#000000;}#dia-s02_d7_tres_idiomas .cluster-label text{fill:#333;}#dia-s02_d7_tres_idiomas .cluster-label span{color:#333;}#dia-s02_d7_tres_idiomas .cluster-label span p{background-color:transparent;}#dia-s02_d7_tres_idiomas .label text,#dia-s02_d7_tres_idiomas span{fill:#000000;color:#000000;}#dia-s02_d7_tres_idiomas .node rect,#dia-s02_d7_tres_idiomas .node circle,#dia-s02_d7_tres_idiomas .node ellipse,#dia-s02_d7_tres_idiomas .node polygon,#dia-s02_d7_tres_idiomas .node path{fill:#eee;stroke:#999;stroke-width:1px;}#dia-s02_d7_tres_idiomas .rough-node .label text,#dia-s02_d7_tres_idiomas .node .label text,#dia-s02_d7_tres_idiomas .image-shape .label,#dia-s02_d7_tres_idiomas .icon-shape .label{text-anchor:middle;}#dia-s02_d7_tres_idiomas .node .katex path{fill:#000;stroke:#000;stroke-width:1px;}#dia-s02_d7_tres_idiomas .rough-node .label,#dia-s02_d7_tres_idiomas .node .label,#dia-s02_d7_tres_idiomas .image-shape .label,#dia-s02_d7_tres_idiomas .icon-shape .label{text-align:center;}#dia-s02_d7_tres_idiomas .node.clickable{cursor:pointer;}#dia-s02_d7_tres_idiomas .root .anchor path{fill:#52514e!important;stroke-width:0;stroke:#52514e;}#dia-s02_d7_tres_idiomas .arrowheadPath{fill:#333333;}#dia-s02_d7_tres_idiomas .edgePath .path{stroke:#52514e;stroke-width:1px;}#dia-s02_d7_tres_idiomas .flowchart-link{stroke:#52514e;fill:none;}#dia-s02_d7_tres_idiomas .edgeLabel{background-color:white;text-align:center;}#dia-s02_d7_tres_idiomas .edgeLabel p{background-color:white;}#dia-s02_d7_tres_idiomas .edgeLabel rect{opacity:0.5;background-color:white;fill:white;}#dia-s02_d7_tres_idiomas .labelBkg{background-color:rgba(255, 255, 255, 0.5);}#dia-s02_d7_tres_idiomas .cluster rect{fill:hsl(0, 0%, 98.9215686275%);stroke:#707070;stroke-width:1px;}#dia-s02_d7_tres_idiomas .cluster text{fill:#333;}#dia-s02_d7_tres_idiomas .cluster span{color:#333;}#dia-s02_d7_tres_idiomas div.mermaidTooltip{position:absolute;text-align:center;max-width:200px;padding:2px;font-family:system-ui,-apple-system,&apos;Segoe UI&apos;,Roboto,sans-serif;font-size:12px;background:#fdf6e3;border:1px solid #707070;border-radius:2px;pointer-events:none;z-index:100;}#dia-s02_d7_tres_idiomas .flowchartTitleText{text-anchor:middle;font-size:18px;fill:#000000;}#dia-s02_d7_tres_idiomas rect.text{fill:none;stroke-width:0;}#dia-s02_d7_tres_idiomas .icon-shape,#dia-s02_d7_tres_idiomas .image-shape{background-color:white;text-align:center;}#dia-s02_d7_tres_idiomas .icon-shape p,#dia-s02_d7_tres_idiomas .image-shape p{background-color:white;padding:2px;}#dia-s02_d7_tres_idiomas .icon-shape .label rect,#dia-s02_d7_tres_idiomas .image-shape .label rect{opacity:0.5;background-color:white;fill:white;}#dia-s02_d7_tres_idiomas .label-icon{display:inline-block;height:1em;overflow:visible;vertical-align:-0.125em;}#dia-s02_d7_tres_idiomas .node .label-icon path{fill:currentColor;stroke:revert;stroke-width:revert;}#dia-s02_d7_tres_idiomas .node .neo-node{stroke:#999;}#dia-s02_d7_tres_idiomas [data-look=&quot;neo&quot;].node rect,#dia-s02_d7_tres_idiomas [data-look=&quot;neo&quot;].cluster rect,#dia-s02_d7_tres_idiomas [data-look=&quot;neo&quot;].node polygon{stroke:url(#dia-s02_d7_tres_idiomas-gradient);filter:drop-shadow( 1px 2px 2px rgba(185,185,185,1));}#dia-s02_d7_tres_idiomas [data-look=&quot;neo&quot;].swimlane.cluster rect{filter:none;}#dia-s02_d7_tres_idiomas [data-look=&quot;neo&quot;].node path{stroke:url(#dia-s02_d7_tres_idiomas-gradient);stroke-width:1px;}#dia-s02_d7_tres_idiomas [data-look=&quot;neo&quot;].node .outer-path{filter:drop-shadow( 1px 2px 2px rgba(185,185,185,1));}#dia-s02_d7_tres_idiomas [data-look=&quot;neo&quot;].node .neo-line path{stroke:#999;filter:none;}#dia-s02_d7_tres_idiomas [data-look=&quot;neo&quot;].node circle{stroke:url(#dia-s02_d7_tres_idiomas-gradient);filter:drop-shadow( 1px 2px 2px rgba(185,185,185,1));}#dia-s02_d7_tres_idiomas [data-look=&quot;neo&quot;].node circle .state-start{fill:#000000;}#dia-s02_d7_tres_idiomas [data-look=&quot;neo&quot;].icon-shape .icon{fill:url(#dia-s02_d7_tres_idiomas-gradient);filter:drop-shadow( 1px 2px 2px rgba(185,185,185,1));}#dia-s02_d7_tres_idiomas [data-look=&quot;neo&quot;].icon-shape .icon-neo path{stroke:url(#dia-s02_d7_tres_idiomas-gradient);filter:drop-shadow( 1px 2px 2px rgba(185,185,185,1));}#dia-s02_d7_tres_idiomas :root{--mermaid-font-family:&quot;trebuchet ms&quot;,verdana,arial,sans-serif;}</style><marker id="dia-s02_d7_tres_idiomas_flowchart-v2-pointEnd" class="marker flowchart-v2" markerHeight="8" markerUnits="userSpaceOnUse" markerWidth="8" orient="auto" refX="5" refY="5" viewBox="0 0 10 10"><path d="m0 0 10 5-10 5z" class="arrowMarkerPath" style="stroke-width:1;stroke-dasharray:1,0"/></marker><marker id="dia-s02_d7_tres_idiomas_flowchart-v2-pointStart" class="marker flowchart-v2" markerHeight="8" markerUnits="userSpaceOnUse" markerWidth="8" orient="auto" refX="4.5" refY="5" viewBox="0 0 10 10"><path d="m0 5 10 5V0z" class="arrowMarkerPath" style="stroke-width:1;stroke-dasharray:1,0"/></marker><marker id="dia-s02_d7_tres_idiomas_flowchart-v2-pointEnd-margin" class="marker flowchart-v2" markerHeight="14" markerUnits="userSpaceOnUse" markerWidth="10.5" orient="auto" refX="11.5" refY="7" viewBox="0 0 11.5 14"><path d="m0 0 11.5 7L0 14z" class="arrowMarkerPath" style="stroke-width:0;stroke-dasharray:1,0"/></marker><marker id="dia-s02_d7_tres_idiomas_flowchart-v2-pointStart-margin" class="marker flowchart-v2" markerHeight="14" markerUnits="userSpaceOnUse" markerWidth="11.5" orient="auto" refX="1" refY="7" viewBox="0 0 11.5 14"><polygon points="0,7 11.5,14 11.5,0" class="arrowMarkerPath" style="stroke-width:0;stroke-dasharray:1,0"/></marker><marker id="dia-s02_d7_tres_idiomas_flowchart-v2-circleEnd" class="marker flowchart-v2" markerHeight="11" markerUnits="userSpaceOnUse" markerWidth="11" orient="auto" refX="11" refY="5" viewBox="0 0 10 10"><circle cx="5" cy="5" r="5" class="arrowMarkerPath" style="stroke-width:1;stroke-dasharray:1,0"/></marker><marker id="dia-s02_d7_tres_idiomas_flowchart-v2-circleStart" class="marker flowchart-v2" markerHeight="11" markerUnits="userSpaceOnUse" markerWidth="11" orient="auto" refX="-1" refY="5" viewBox="0 0 10 10"><circle cx="5" cy="5" r="5" class="arrowMarkerPath" style="stroke-width:1;stroke-dasharray:1,0"/></marker><marker id="dia-s02_d7_tres_idiomas_flowchart-v2-circleEnd-margin" class="marker flowchart-v2" markerHeight="14" markerUnits="userSpaceOnUse" markerWidth="14" orient="auto" refX="12.25" refY="5" viewBox="0 0 10 10"><circle cx="5" cy="5" r="5" class="arrowMarkerPath" style="stroke-width:0;stroke-dasharray:1,0"/></marker><marker id="dia-s02_d7_tres_idiomas_flowchart-v2-circleStart-margin" class="marker flowchart-v2" markerHeight="14" markerUnits="userSpaceOnUse" markerWidth="14" orient="auto" refX="-2" refY="5" viewBox="0 0 10 10"><circle cx="5" cy="5" r="5" class="arrowMarkerPath" style="stroke-width:0;stroke-dasharray:1,0"/></marker><marker id="dia-s02_d7_tres_idiomas_flowchart-v2-crossEnd" class="marker cross flowchart-v2" markerHeight="11" markerUnits="userSpaceOnUse" markerWidth="11" orient="auto" refX="12" refY="5.2" viewBox="0 0 11 11"><path d="m1 1 9 9m0-9-9 9" class="arrowMarkerPath" style="stroke-width:2;stroke-dasharray:1,0"/></marker><marker id="dia-s02_d7_tres_idiomas_flowchart-v2-crossStart" class="marker cross flowchart-v2" markerHeight="11" markerUnits="userSpaceOnUse" markerWidth="11" orient="auto" refX="-1" refY="5.2" viewBox="0 0 11 11"><path d="m1 1 9 9m0-9-9 9" class="arrowMarkerPath" style="stroke-width:2;stroke-dasharray:1,0"/></marker><marker id="dia-s02_d7_tres_idiomas_flowchart-v2-crossEnd-margin" class="marker cross flowchart-v2" markerHeight="12" markerUnits="userSpaceOnUse" markerWidth="12" orient="auto" refX="17.7" refY="7.5" viewBox="0 0 15 15"><path d="m1 1 13 13M1 14 14 1" class="arrowMarkerPath" style="stroke-width:2.5"/></marker><marker id="dia-s02_d7_tres_idiomas_flowchart-v2-crossStart-margin" class="marker cross flowchart-v2" markerHeight="12" markerUnits="userSpaceOnUse" markerWidth="12" orient="auto" refX="-3.5" refY="7.5" viewBox="0 0 15 15"><path d="m1 1 13 13M1 14 14 1" class="arrowMarkerPath" style="stroke-width:2.5;stroke-dasharray:1,0"/></marker><g class="root"><g class="edgePaths"><path id="dia-s02_d7_tres_idiomas-L_uno_dos_0" marker-end="url(#dia-s02_d7_tres_idiomas_flowchart-v2-pointEnd)" d="M760.844 86h4.166c4.167 0 12.5 0 20.196 1.069 7.695 1.069 14.752 3.206 18.281 4.275l3.529 1.069" class="edge-thickness-normal edge-pattern-solid edge-thickness-normal edge-pattern-solid flowchart-link" data-edge="true" data-et="edge" data-id="L_uno_dos_0" data-look="classic" data-points="W3sieCI6NzYwLjg0Mzc1LCJ5Ijo4Nn0seyJ4Ijo3ODUuODQzNzUsInkiOjg2fSx7IngiOjgxMC44NDM3NSwieSI6OTMuNTcyNDU3Njk4MTA2ODl9XQ=="/><path id="dia-s02_d7_tres_idiomas-L_dos_tres_0" marker-end="url(#dia-s02_d7_tres_idiomas_flowchart-v2-pointEnd)" d="m810.844 191.428-4.167 1.262c-4.167 1.262-12.5 3.786-43.059 5.048S680.276 199 613.302 199s-148.138 0-206.427-4.116c-58.29-4.116-93.705-12.348-111.412-16.464l-17.707-4.116" class="edge-thickness-normal edge-pattern-solid edge-thickness-normal edge-pattern-solid flowchart-link" data-edge="true" data-et="edge" data-id="L_dos_tres_0" data-look="classic" data-points="W3sieCI6ODEwLjg0Mzc1LCJ5IjoxOTEuNDI3NTQyMzAxODkzMX0seyJ4Ijo3ODUuODQzNzUsInkiOjE5OX0seyJ4Ijo2MjcuNDkyMTg3NSwieSI6MTk5fSx7IngiOjM4NCwieSI6MTk5fSx7IngiOjI3My44NTkzNzUsInkiOjE3My4zOTg1NzkzNzE5NjY3fV0="/><path id="dia-s02_d7_tres_idiomas-L_tres_uno_0" marker-end="url(#dia-s02_d7_tres_idiomas_flowchart-v2-pointEnd)" d="m273.859 111.601 18.357-4.266c18.357-4.267 55.07-12.801 91.117-17.068S454.76 86 472.451 86h17.69" class="edge-thickness-normal edge-pattern-dotted edge-thickness-normal edge-pattern-solid flowchart-link" data-edge="true" data-et="edge" data-id="L_tres_uno_0" data-look="classic" data-points="W3sieCI6MjczLjg1OTM3NSwieSI6MTExLjYwMTQyMDYyODAzMzN9LHsieCI6Mzg0LCJ5Ijo4Nn0seyJ4Ijo0OTQuMTQwNjI1LCJ5Ijo4Nn1d"/></g><g class="edgeLabels"><rect class="background" style="stroke:none"/><rect class="background" style="stroke:none"/><g class="edgeLabel"><g class="label" data-id="L_tres_uno_0" transform="translate(384 77)"><rect width="170.281" height="22" x="-85.141" y="-2" class="background"/><text y="-10.1" text-anchor="middle"><tspan x="0" y="-.1em" class="text-outer-tspan row" dy="1.1em" text-anchor="middle"><tspan class="text-inner-tspan" font-style="normal" font-weight="normal">si</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> falla,</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> vuelves</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> a</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> pensar</tspan></tspan></text></g></g></g><g class="nodes"><g class="root"><g class="clusters" transform="translate(0 56.5)"><g id="dia-s02_d7_tres_idiomas-tres" class="cluster" data-look="classic"><rect width="265.859" height="156" x="8" y="8"/><g class="cluster-label" transform="translate(43.578 8)"><rect class="background" style="stroke:none"/><text y="-10.1"><tspan x="0" y="-.1em" class="text-outer-tspan row" dy="1.1em"><tspan class="text-inner-tspan" font-style="normal" font-weight="normal">3.</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> Python</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> —</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> para</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> EJECUTAR</tspan></tspan></text></g></g></g><g class="nodes" transform="translate(0 56.5)"><g id="dia-s02_d7_tres_idiomas-flowchart-C-2" class="node default" data-look="classic" transform="translate(140.93 86)"><rect width="195.859" height="81" x="-97.93" y="-40.5" class="basic label-container" style="fill:#008300!important;stroke:#005400!important"/><g class="label" style="color:#fff!important" transform="translate(0 -25.5)"><rect/><rect class="background" style="stroke:none"/><text y="-10.1" style="fill:#fff!important"><tspan x="0" y="-.1em" class="text-outer-tspan row" dy="1.1em"><tspan class="text-inner-tspan" font-style="normal" font-weight="normal">copias</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> =</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> int(input())</tspan></tspan><tspan x="0" y="1em" class="text-outer-tspan row" dy="1.1em"><tspan class="text-inner-tspan" font-style="normal" font-weight="normal">total</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> =</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> copias</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> *</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> 100</tspan></tspan><tspan x="0" y="2.1em" class="text-outer-tspan row" dy="1.1em"><tspan class="text-inner-tspan" font-style="normal" font-weight="normal">print(total)</tspan></tspan></text></g></g></g></g><g class="root"><g class="clusters" transform="translate(802.844 56.5)"><g id="dia-s02_d7_tres_idiomas-dos" class="cluster" data-look="classic"><rect width="323.063" height="156" x="8" y="8"/><g class="cluster-label" transform="translate(86.656 8)"><rect class="background" style="stroke:none"/><text y="-10.1"><tspan x="0" y="-.1em" class="text-outer-tspan row" dy="1.1em"><tspan class="text-inner-tspan" font-style="normal" font-weight="normal">2.</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> Diagrama</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> —</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> para</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> VER</tspan></tspan></text></g></g></g><g class="nodes" transform="translate(802.844 56.5)"><g id="dia-s02_d7_tres_idiomas-flowchart-B-1" class="node default" data-look="classic" transform="translate(169.531 86)"><rect width="253.063" height="81" x="-126.531" y="-40.5" class="basic label-container" style="fill:#eda100!important;stroke:#8a6d00!important"/><g class="label" style="color:#3a2a00!important" transform="translate(0 -25.5)"><rect/><rect class="background" style="stroke:none"/><text y="-10.1" style="fill:#3a2a00!important"><tspan x="0" y="-.1em" class="text-outer-tspan row" dy="1.1em"><tspan class="text-inner-tspan" font-style="normal" font-weight="normal">óvalo</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> →</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> paralelogramo</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> →</tspan></tspan><tspan x="0" y="1em" class="text-outer-tspan row" dy="1.1em"><tspan class="text-inner-tspan" font-style="normal" font-weight="normal">rectángulo</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> →</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> paralelogramo</tspan></tspan><tspan x="0" y="2.1em" class="text-outer-tspan row" dy="1.1em"><tspan class="text-inner-tspan" font-style="normal" font-weight="normal">→</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> óvalo</tspan></tspan></text></g></g></g></g><g class="root"><g class="clusters" transform="translate(486.14)"><g id="dia-s02_d7_tres_idiomas-uno" class="cluster" data-look="classic"><rect width="266.703" height="156" x="8" y="8"/><g class="cluster-label" transform="translate(28.61 8)"><rect class="background" style="stroke:none"/><text y="-10.1"><tspan x="0" y="-.1em" class="text-outer-tspan row" dy="1.1em"><tspan class="text-inner-tspan" font-style="normal" font-weight="normal">1.</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> Pseudocódigo</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> —</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> para</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> PENSAR</tspan></tspan></text></g></g></g><g class="nodes" transform="translate(486.14)"><g id="dia-s02_d7_tres_idiomas-flowchart-A-0" class="node default" data-look="classic" transform="translate(141.352 86)"><rect width="196.703" height="81" x="-98.352" y="-40.5" class="basic label-container" style="fill:#4a3aa7!important;stroke:#2a1f6b!important"/><g class="label" style="color:#fff!important" transform="translate(0 -25.5)"><rect/><rect class="background" style="stroke:none"/><text y="-10.1" style="fill:#fff!important"><tspan x="0" y="-.1em" class="text-outer-tspan row" dy="1.1em"><tspan class="text-inner-tspan" font-style="normal" font-weight="normal">Leer</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> copias</tspan></tspan><tspan x="0" y="1em" class="text-outer-tspan row" dy="1.1em"><tspan class="text-inner-tspan" font-style="normal" font-weight="normal">total</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> ←</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> copias</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> *</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> 100</tspan></tspan><tspan x="0" y="2.1em" class="text-outer-tspan row" dy="1.1em"><tspan class="text-inner-tspan" font-style="normal" font-weight="normal">Escribir</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> total</tspan></tspan></text></g></g></g></g></g></g><defs><filter id="dia-s02_d7_tres_idiomas-drop-shadow" width="130%" height="130%"><feDropShadow dx="4" dy="4" flood-color="#000" flood-opacity=".06" stdDeviation="0"/></filter></defs><defs><filter id="dia-s02_d7_tres_idiomas-drop-shadow-small" width="150%" height="150%"><feDropShadow dx="2" dy="2" flood-color="#000" flood-opacity=".06" stdDeviation="0"/></filter></defs><linearGradient id="dia-s02_d7_tres_idiomas-gradient" x1="0%" x2="100%" y1="0%" y2="0%" gradientUnits="objectBoundingBox"><stop offset="0%" stop-color="hsl(0, 0%, 83.3333333333%)" stop-opacity="1"/><stop offset="100%" stop-color="hsl(0, 0%, 88.9215686275%)" stop-opacity="1"/></linearGradient></svg>', 'Las tres representaciones del mismo algoritmo. Se va de una a otra todo el tiempo.')

# %%
ps.comparador(CODIGO_GANCHO)

# %%
tarjeta_corte()

# %% [markdown]
# ---
#
# ## 4. Laboratorio · 55 min
#
# Bienvenido a la Parte B. De aquí en adelante todo se toca.
#
# El hilo es un solo programa —el de la papelería de la Carrera 9— y con él vas a
# hacer cuatro cosas, en este orden: **predecir** qué hace, **ejecutarlo**,
# **investigarlo** rompiéndolo a propósito y **modificarlo**.

# %% [markdown]
# ### 4.1 Pseudocódigo: español con reglas
#
# El pseudocódigo es un punto medio entre el español y un lenguaje de
# programación. Es lo bastante libre para escribirlo rápido y lo bastante estricto
# para que no queden ambigüedades.
#
# Compara:
#
# | Español de todos los días | Pseudocódigo |
# |---|---|
# | «pregúntale cuántas copias y cóbrale» | `Escribir "¿Cuántas copias?"` ⏎ `Leer copias` ⏎ `total <- copias * PRECIO_COPIA + ANILLADO` ⏎ `Escribir "Total: $", total` |
#
# La primera frase se la puedes decir a un cajero, y funciona porque el cajero
# **rellena los huecos** con su experiencia: sabe cuánto vale la copia, sabe que
# hay que cobrar el anillado, sabe que hay que decirle el total en voz alta. **El
# computador no rellena huecos.** Todo lo que no digas, no pasa.
#
# Con **seis palabras** te alcanza para todo lo de hoy: `Algoritmo`, `Definir`,
# `Constante`, `Leer`, `Escribir` y la flecha `<-`.

# %%
chuleta()

# %% [markdown]
# ### Predecir *(no ejecutes todavía)*
#
# ```
# Algoritmo CostoDeFotocopias
#     // La papelería de la Carrera 9, frente a la UIS
#     Definir copias, total Como Entero
#     Constante PRECIO_COPIA <- 100
#     Constante ANILLADO <- 2500
#
#     Escribir "¿Cuántas copias vas a sacar?"
#     Leer copias
#
#     total <- copias * PRECIO_COPIA + ANILLADO
#
#     Escribir "Total a pagar: $", total
# FinAlgoritmo
# ```
#
# Vas a sacar **40 copias** y las vas a mandar a anillar. Antes de ejecutar nada,
# responde:

# %%
quiz_prediccion()

# %% [markdown]
# ### Ejecutar
#
# Ahora sí. El `"40"` de la última línea es lo que el usuario iba a teclear.

# %%
PAPELERIA = """Algoritmo CostoDeFotocopias
    // La papelería de la Carrera 9, frente a la UIS
    Definir copias, total Como Entero
    Constante PRECIO_COPIA <- 100
    Constante ANILLADO <- 2500

    Escribir "¿Cuántas copias vas a sacar?"
    Leer copias

    total <- copias * PRECIO_COPIA + ANILLADO

    Escribir "Total a pagar: $", total
FinAlgoritmo"""

# El "40" es lo que el usuario iba a teclear. Cámbialo y vuelve a ejecutar.
ps.ejecutar_pseudo(PAPELERIA, entradas=["40"]).imprimir()

# %% [markdown]
# ### Investigar
#
# Sobre la celda de arriba (cámbiala y reejecútala cuantas veces quieras):
#
# 1. Cambia `entradas=["40"]` por `entradas=["1"]`. ¿Tiene sentido el resultado?
#    ¿Y con `["0"]`?
# 2. Sube `PRECIO_COPIA` a 150. ¿Cuántas líneas tuviste que tocar? Esa es
#    exactamente la razón por la que existen las constantes.
# 3. **Borra la línea `Leer copias`** y ejecuta. Lee el error con calma: te va a
#    decir que la caja `copias` existe pero está vacía.
# 4. **Cambia `total <- copias * PRECIO_COPIA` por `total = copias *
#    PRECIO_COPIA`** (signo igual en vez de flecha) y ejecuta. Guarda ese mensaje
#    en la memoria: lo vas a volver a ver.
# 5. Sube la línea `Leer copias` **arriba** del `Escribir "¿Cuántas copias...?"`.
#    El programa sigue funcionando… pero ahora le pide el dato al usuario **antes
#    de decirle qué quiere**. Eso no es un error de sintaxis: es un **error de
#    lógica**. El computador no te va a avisar.

# %% [markdown]
# ### Modificar — ahora escribes tú
#
# Este es tu banco de trabajo. Escribe pseudocódigo a la izquierda, pon las
# entradas a la derecha y usa los cuatro botones. **Reto de calentamiento:** haz
# que el algoritmo también muestre cuánto cuestan las copias **sin** el anillado.

# %%
ps.laboratorio(PAPELERIA, entradas=["40"])

# %% [markdown]
# ### 4.2 Prueba de escritorio (trazado manual)
#
# Es seguir tu propio algoritmo **como si tú fueras el computador**: instrucción
# por instrucción, anotando en una tabla cuánto vale cada variable después de cada
# paso.
#
# Suena primitivo. Es la herramienta más poderosa que vas a aprender este
# semestre, por una razón: **encuentra los errores de lógica**, que son los únicos
# que el computador no te va a señalar. Cuando un programa «corre pero da mal», la
# prueba de escritorio es lo que lo salva.
#
# Con el trazador de abajo puedes ver una hecha por el computador. Después te va a
# tocar hacerlas tú, en papel, en el examen. Fíjate bien en **cuándo** cambia cada
# caja.

# %%
ps.trazador(PAPELERIA, entradas=["40"])

# %% [markdown]
# ### La misma tabla, en tu cuaderno
#
# | Paso | Instrucción | `copias` | `total` | Salida |
# |---|---|---|---|---|
# | 1 | `Definir copias, total Como Entero` | — | — | |
# | 2 | `Constante PRECIO_COPIA <- 100` | — | — | |
# | 3 | `Constante ANILLADO <- 2500` | — | — | |
# | 4 | `Escribir "¿Cuántas copias...?"` | — | — | ¿Cuántas copias vas a sacar? |
# | 5 | `Leer copias` | 40 | — | |
# | 6 | `total <- copias * PRECIO_COPIA + ANILLADO` | 40 | 6500 | |
# | 7 | `Escribir "Total a pagar: $", total` | 40 | 6500 | Total a pagar: $6500 |
#
# Tres reglas para que la tabla sirva:
#
# 1. **Una fila por instrucción ejecutada**, no por línea escrita.
# 2. En cada fila, el valor de **todas** las variables, incluso las que no
#    cambiaron. Así se ve de un vistazo cuál cambió.
# 3. Un guion (`—`) significa «la caja existe pero está vacía». No es cero: cero
#    es un valor.

# %% [markdown]
# ### 4.3 Los cinco símbolos del diagrama de flujo
#
# Un diagrama de flujo no es un dibujo bonito: es un lenguaje, y tiene exactamente
# cinco palabras.

# %%
# Diagrama: s02_d3_simbolos
ava.figura('<svg xmlns="http://www.w3.org/2000/svg" id="dia-s02_d3_simbolos" width="100%" aria-roledescription="flowchart-v2" class="flowchart" role="graphics-document document" style="max-width:270.828px;background-color:transparent" viewBox="0 0 270.828 692.922"><style>#dia-s02_d3_simbolos{font-family:system-ui,-apple-system,&apos;Segoe UI&apos;,Roboto,sans-serif;font-size:15px;fill:#000000;}@keyframes edge-animation-frame{from{stroke-dashoffset:0;}}@keyframes dash{to{stroke-dashoffset:0;}}#dia-s02_d3_simbolos .edge-animation-slow{stroke-dasharray:9,5!important;stroke-dashoffset:900;animation:dash 50s linear infinite;stroke-linecap:round;}#dia-s02_d3_simbolos .edge-animation-fast{stroke-dasharray:9,5!important;stroke-dashoffset:900;animation:dash 20s linear infinite;stroke-linecap:round;}#dia-s02_d3_simbolos .error-icon{fill:#552222;}#dia-s02_d3_simbolos .error-text{fill:#552222;stroke:#552222;}#dia-s02_d3_simbolos .edge-thickness-normal{stroke-width:1px;}#dia-s02_d3_simbolos .edge-thickness-thick{stroke-width:3.5px;}#dia-s02_d3_simbolos .edge-pattern-solid{stroke-dasharray:0;}#dia-s02_d3_simbolos .edge-thickness-invisible{stroke-width:0;fill:none;}#dia-s02_d3_simbolos .edge-pattern-dashed{stroke-dasharray:3;}#dia-s02_d3_simbolos .edge-pattern-dotted{stroke-dasharray:2;}#dia-s02_d3_simbolos .marker{fill:#52514e;stroke:#52514e;}#dia-s02_d3_simbolos .marker.cross{stroke:#52514e;}#dia-s02_d3_simbolos svg{font-family:system-ui,-apple-system,&apos;Segoe UI&apos;,Roboto,sans-serif;font-size:15px;}#dia-s02_d3_simbolos p{margin:0;}#dia-s02_d3_simbolos .label{font-family:system-ui,-apple-system,&apos;Segoe UI&apos;,Roboto,sans-serif;color:#000000;}#dia-s02_d3_simbolos .cluster-label text{fill:#333;}#dia-s02_d3_simbolos .cluster-label span{color:#333;}#dia-s02_d3_simbolos .cluster-label span p{background-color:transparent;}#dia-s02_d3_simbolos .label text,#dia-s02_d3_simbolos span{fill:#000000;color:#000000;}#dia-s02_d3_simbolos .node rect,#dia-s02_d3_simbolos .node circle,#dia-s02_d3_simbolos .node ellipse,#dia-s02_d3_simbolos .node polygon,#dia-s02_d3_simbolos .node path{fill:#eee;stroke:#999;stroke-width:1px;}#dia-s02_d3_simbolos .rough-node .label text,#dia-s02_d3_simbolos .node .label text,#dia-s02_d3_simbolos .image-shape .label,#dia-s02_d3_simbolos .icon-shape .label{text-anchor:middle;}#dia-s02_d3_simbolos .node .katex path{fill:#000;stroke:#000;stroke-width:1px;}#dia-s02_d3_simbolos .rough-node .label,#dia-s02_d3_simbolos .node .label,#dia-s02_d3_simbolos .image-shape .label,#dia-s02_d3_simbolos .icon-shape .label{text-align:center;}#dia-s02_d3_simbolos .node.clickable{cursor:pointer;}#dia-s02_d3_simbolos .root .anchor path{fill:#52514e!important;stroke-width:0;stroke:#52514e;}#dia-s02_d3_simbolos .arrowheadPath{fill:#333333;}#dia-s02_d3_simbolos .edgePath .path{stroke:#52514e;stroke-width:1px;}#dia-s02_d3_simbolos .flowchart-link{stroke:#52514e;fill:none;}#dia-s02_d3_simbolos .edgeLabel{background-color:white;text-align:center;}#dia-s02_d3_simbolos .edgeLabel p{background-color:white;}#dia-s02_d3_simbolos .edgeLabel rect{opacity:0.5;background-color:white;fill:white;}#dia-s02_d3_simbolos .labelBkg{background-color:rgba(255, 255, 255, 0.5);}#dia-s02_d3_simbolos .cluster rect{fill:hsl(0, 0%, 98.9215686275%);stroke:#707070;stroke-width:1px;}#dia-s02_d3_simbolos .cluster text{fill:#333;}#dia-s02_d3_simbolos .cluster span{color:#333;}#dia-s02_d3_simbolos div.mermaidTooltip{position:absolute;text-align:center;max-width:200px;padding:2px;font-family:system-ui,-apple-system,&apos;Segoe UI&apos;,Roboto,sans-serif;font-size:12px;background:#fdf6e3;border:1px solid #707070;border-radius:2px;pointer-events:none;z-index:100;}#dia-s02_d3_simbolos .flowchartTitleText{text-anchor:middle;font-size:18px;fill:#000000;}#dia-s02_d3_simbolos rect.text{fill:none;stroke-width:0;}#dia-s02_d3_simbolos .icon-shape,#dia-s02_d3_simbolos .image-shape{background-color:white;text-align:center;}#dia-s02_d3_simbolos .icon-shape p,#dia-s02_d3_simbolos .image-shape p{background-color:white;padding:2px;}#dia-s02_d3_simbolos .icon-shape .label rect,#dia-s02_d3_simbolos .image-shape .label rect{opacity:0.5;background-color:white;fill:white;}#dia-s02_d3_simbolos .label-icon{display:inline-block;height:1em;overflow:visible;vertical-align:-0.125em;}#dia-s02_d3_simbolos .node .label-icon path{fill:currentColor;stroke:revert;stroke-width:revert;}#dia-s02_d3_simbolos .node .neo-node{stroke:#999;}#dia-s02_d3_simbolos [data-look=&quot;neo&quot;].node rect,#dia-s02_d3_simbolos [data-look=&quot;neo&quot;].cluster rect,#dia-s02_d3_simbolos [data-look=&quot;neo&quot;].node polygon{stroke:url(#dia-s02_d3_simbolos-gradient);filter:drop-shadow( 1px 2px 2px rgba(185,185,185,1));}#dia-s02_d3_simbolos [data-look=&quot;neo&quot;].swimlane.cluster rect{filter:none;}#dia-s02_d3_simbolos [data-look=&quot;neo&quot;].node path{stroke:url(#dia-s02_d3_simbolos-gradient);stroke-width:1px;}#dia-s02_d3_simbolos [data-look=&quot;neo&quot;].node .outer-path{filter:drop-shadow( 1px 2px 2px rgba(185,185,185,1));}#dia-s02_d3_simbolos [data-look=&quot;neo&quot;].node .neo-line path{stroke:#999;filter:none;}#dia-s02_d3_simbolos [data-look=&quot;neo&quot;].node circle{stroke:url(#dia-s02_d3_simbolos-gradient);filter:drop-shadow( 1px 2px 2px rgba(185,185,185,1));}#dia-s02_d3_simbolos [data-look=&quot;neo&quot;].node circle .state-start{fill:#000000;}#dia-s02_d3_simbolos [data-look=&quot;neo&quot;].icon-shape .icon{fill:url(#dia-s02_d3_simbolos-gradient);filter:drop-shadow( 1px 2px 2px rgba(185,185,185,1));}#dia-s02_d3_simbolos [data-look=&quot;neo&quot;].icon-shape .icon-neo path{stroke:url(#dia-s02_d3_simbolos-gradient);filter:drop-shadow( 1px 2px 2px rgba(185,185,185,1));}#dia-s02_d3_simbolos :root{--mermaid-font-family:&quot;trebuchet ms&quot;,verdana,arial,sans-serif;}</style><marker id="dia-s02_d3_simbolos_flowchart-v2-pointEnd" class="marker flowchart-v2" markerHeight="8" markerUnits="userSpaceOnUse" markerWidth="8" orient="auto" refX="5" refY="5" viewBox="0 0 10 10"><path d="m0 0 10 5-10 5z" class="arrowMarkerPath" style="stroke-width:1;stroke-dasharray:1,0"/></marker><marker id="dia-s02_d3_simbolos_flowchart-v2-pointStart" class="marker flowchart-v2" markerHeight="8" markerUnits="userSpaceOnUse" markerWidth="8" orient="auto" refX="4.5" refY="5" viewBox="0 0 10 10"><path d="m0 5 10 5V0z" class="arrowMarkerPath" style="stroke-width:1;stroke-dasharray:1,0"/></marker><marker id="dia-s02_d3_simbolos_flowchart-v2-pointEnd-margin" class="marker flowchart-v2" markerHeight="14" markerUnits="userSpaceOnUse" markerWidth="10.5" orient="auto" refX="11.5" refY="7" viewBox="0 0 11.5 14"><path d="m0 0 11.5 7L0 14z" class="arrowMarkerPath" style="stroke-width:0;stroke-dasharray:1,0"/></marker><marker id="dia-s02_d3_simbolos_flowchart-v2-pointStart-margin" class="marker flowchart-v2" markerHeight="14" markerUnits="userSpaceOnUse" markerWidth="11.5" orient="auto" refX="1" refY="7" viewBox="0 0 11.5 14"><polygon points="0,7 11.5,14 11.5,0" class="arrowMarkerPath" style="stroke-width:0;stroke-dasharray:1,0"/></marker><marker id="dia-s02_d3_simbolos_flowchart-v2-circleEnd" class="marker flowchart-v2" markerHeight="11" markerUnits="userSpaceOnUse" markerWidth="11" orient="auto" refX="11" refY="5" viewBox="0 0 10 10"><circle cx="5" cy="5" r="5" class="arrowMarkerPath" style="stroke-width:1;stroke-dasharray:1,0"/></marker><marker id="dia-s02_d3_simbolos_flowchart-v2-circleStart" class="marker flowchart-v2" markerHeight="11" markerUnits="userSpaceOnUse" markerWidth="11" orient="auto" refX="-1" refY="5" viewBox="0 0 10 10"><circle cx="5" cy="5" r="5" class="arrowMarkerPath" style="stroke-width:1;stroke-dasharray:1,0"/></marker><marker id="dia-s02_d3_simbolos_flowchart-v2-circleEnd-margin" class="marker flowchart-v2" markerHeight="14" markerUnits="userSpaceOnUse" markerWidth="14" orient="auto" refX="12.25" refY="5" viewBox="0 0 10 10"><circle cx="5" cy="5" r="5" class="arrowMarkerPath" style="stroke-width:0;stroke-dasharray:1,0"/></marker><marker id="dia-s02_d3_simbolos_flowchart-v2-circleStart-margin" class="marker flowchart-v2" markerHeight="14" markerUnits="userSpaceOnUse" markerWidth="14" orient="auto" refX="-2" refY="5" viewBox="0 0 10 10"><circle cx="5" cy="5" r="5" class="arrowMarkerPath" style="stroke-width:0;stroke-dasharray:1,0"/></marker><marker id="dia-s02_d3_simbolos_flowchart-v2-crossEnd" class="marker cross flowchart-v2" markerHeight="11" markerUnits="userSpaceOnUse" markerWidth="11" orient="auto" refX="12" refY="5.2" viewBox="0 0 11 11"><path d="m1 1 9 9m0-9-9 9" class="arrowMarkerPath" style="stroke-width:2;stroke-dasharray:1,0"/></marker><marker id="dia-s02_d3_simbolos_flowchart-v2-crossStart" class="marker cross flowchart-v2" markerHeight="11" markerUnits="userSpaceOnUse" markerWidth="11" orient="auto" refX="-1" refY="5.2" viewBox="0 0 11 11"><path d="m1 1 9 9m0-9-9 9" class="arrowMarkerPath" style="stroke-width:2;stroke-dasharray:1,0"/></marker><marker id="dia-s02_d3_simbolos_flowchart-v2-crossEnd-margin" class="marker cross flowchart-v2" markerHeight="12" markerUnits="userSpaceOnUse" markerWidth="12" orient="auto" refX="17.7" refY="7.5" viewBox="0 0 15 15"><path d="m1 1 13 13M1 14 14 1" class="arrowMarkerPath" style="stroke-width:2.5"/></marker><marker id="dia-s02_d3_simbolos_flowchart-v2-crossStart-margin" class="marker cross flowchart-v2" markerHeight="12" markerUnits="userSpaceOnUse" markerWidth="12" orient="auto" refX="-3.5" refY="7.5" viewBox="0 0 15 15"><path d="m1 1 13 13M1 14 14 1" class="arrowMarkerPath" style="stroke-width:2.5;stroke-dasharray:1,0"/></marker><g class="root"><g class="edgePaths"><path id="dia-s02_d3_simbolos-L_T_E_0" marker-end="url(#dia-s02_d3_simbolos_flowchart-v2-pointEnd)" d="m135.914 41.5-.083 4.083c-.084 4.084-.25 12.25-.263 19.917s.127 14.834.197 18.417l.071 3.584" class="edge-thickness-normal edge-pattern-solid edge-thickness-normal edge-pattern-solid flowchart-link" data-edge="true" data-et="edge" data-id="L_T_E_0" data-look="classic" data-points="W3sieCI6MTM1LjkxNDA2MjUsInkiOjQxLjV9LHsieCI6MTM1LjQxNDA2MjUsInkiOjY2fSx7IngiOjEzNS45MTQwNjI1LCJ5Ijo5MS41fV0="/><path id="dia-s02_d3_simbolos-L_E_P_0" marker-end="url(#dia-s02_d3_simbolos_flowchart-v2-pointEnd)" d="m135.914 141-.083 4.083c-.084 4.084-.25 12.25-.334 19.834-.083 7.583-.083 14.583-.083 18.083v3.5" class="edge-thickness-normal edge-pattern-solid edge-thickness-normal edge-pattern-solid flowchart-link" data-edge="true" data-et="edge" data-id="L_E_P_0" data-look="classic" data-points="W3sieCI6MTM1LjkxNDA2MjUsInkiOjE0MX0seyJ4IjoxMzUuNDE0MDYyNSwieSI6MTY1LjV9LHsieCI6MTM1LjQxNDA2MjUsInkiOjE5MC41fV0="/><path id="dia-s02_d3_simbolos-L_P_D_0" marker-end="url(#dia-s02_d3_simbolos_flowchart-v2-pointEnd)" d="M135.414 255v46" class="edge-thickness-normal edge-pattern-solid edge-thickness-normal edge-pattern-solid flowchart-link" data-edge="true" data-et="edge" data-id="L_P_D_0" data-look="classic" data-points="W3sieCI6MTM1LjQxNDA2MjUsInkiOjI1NX0seyJ4IjoxMzUuNDE0MDYyNSwieSI6MjgwfSx7IngiOjEzNS40MTQwNjI1LCJ5IjozMDV9XQ=="/><path id="dia-s02_d3_simbolos-L_D_F_0" marker-end="url(#dia-s02_d3_simbolos_flowchart-v2-pointEnd)" d="m121.581 534.589-1.065 8.306c-1.065 8.305-3.195 24.916-2.671 38.582.523 13.666 3.7 24.388 5.289 29.749l1.588 5.361" class="edge-thickness-normal edge-pattern-solid edge-thickness-normal edge-pattern-solid flowchart-link" data-edge="true" data-et="edge" data-id="L_D_F_0" data-look="classic" data-points="W3sieCI6MTIxLjU4MTI3MDE2OTY5OTg5LCJ5Ijo1MzQuNTg5MDgyNjY5Njk5OX0seyJ4IjoxMTUuMTkxNDA2MjUsInkiOjU4NC40MjE4NzV9LHsieCI6MTI1Ljg1ODMwMTg1NDM5NTYsInkiOjYyMC40MjE4NzV9XQ=="/><path id="dia-s02_d3_simbolos-L_D_F_2" marker-end="url(#dia-s02_d3_simbolos_flowchart-v2-pointEnd)" d="m149.247 534.589 1.065 8.306c1.065 8.305 3.195 24.916 2.671 38.582-.523 13.666-3.7 24.388-5.288 29.749l-1.589 5.361" class="edge-thickness-normal edge-pattern-solid edge-thickness-normal edge-pattern-solid flowchart-link" data-edge="true" data-et="edge" data-id="L_D_F_2" data-look="classic" data-points="W3sieCI6MTQ5LjI0Njg1NDgzMDMwMDEsInkiOjUzNC41ODkwODI2Njk2OTk5fSx7IngiOjE1NS42MzY3MTg3NSwieSI6NTg0LjQyMTg3NX0seyJ4IjoxNDQuOTY5ODIzMTQ1NjA0NCwieSI6NjIwLjQyMTg3NX1d"/></g><g class="edgeLabels"><rect class="background" style="stroke:none"/><rect class="background" style="stroke:none"/><rect class="background" style="stroke:none"/><g class="edgeLabel"><g class="label" data-id="L_D_F_0" transform="translate(115.717 569.127)"><rect width="17.359" height="22" x="-8.398" y="-2" class="background"/><text y="-10.1" text-anchor="middle"><tspan x="0" y="-.1em" class="text-outer-tspan row" dy="1.1em" text-anchor="middle"><tspan class="text-inner-tspan" font-style="normal" font-weight="normal">Sí</tspan></tspan></text></g></g><g class="edgeLabel"><g class="label" data-id="L_D_F_2" transform="translate(154.83 569.127)"><rect width="23.531" height="22" x="-11.766" y="-2" class="background"/><text y="-10.1" text-anchor="middle"><tspan x="0" y="-.1em" class="text-outer-tspan row" dy="1.1em" text-anchor="middle"><tspan class="text-inner-tspan" font-style="normal" font-weight="normal">No</tspan></tspan></text></g></g></g><g class="nodes"><g id="dia-s02_d3_simbolos-flowchart-T-0" class="node default" data-look="classic"><g class="basic label-container outer-path"><path fill="#008300" stroke="none" stroke-width="0" d="M-64.852-16.5H64.852l1.057.034 1.053.101 1.044.17 1.03.235 1.015.3.992.366.968.428c.333.174.666.347.937.49l.905.548c.209.145.418.29.867.605l.827.66.783.71.736.76.686.805.632.848.577.887.52.921.458.953.397.98.334 1.004.268 1.023.202 1.039.135 1.049.068 1.055V.53l-.068 1.055-.135 1.05-.202 1.038-.268 1.023-.334 1.004-.397.98-.459.953-.519.921-.577.887-.632.848-.686.805-.736.76-.783.71-.827.66c-.278.195-.557.39-.867.605l-.905.549-.937.489-.968.428-.992.365-1.014.301-1.031.236-1.044.169-1.053.101-1.057.034H-64.852l-1.057-.034-1.053-.101-1.044-.17c-.256-.058-.513-.116-1.03-.235l-1.015-.3-.992-.366-.968-.428-.937-.49-.905-.548-.867-.605-.827-.66-.783-.71-.736-.76-.686-.805-.632-.848-.577-.887-.52-.921-.458-.953-.397-.98-.334-1.004-.268-1.023-.202-1.039-.135-1.049-.068-1.055V-.53l.068-1.055.135-1.05.202-1.038.268-1.023c.09-.267.178-.535.334-1.004l.397-.98.459-.953.519-.921c.135-.209.27-.417.577-.887l.632-.848.686-.805.736-.76.783-.71c.245-.197.49-.392.827-.66l.867-.605.905-.549.937-.489.968-.428.992-.365 1.014-.301 1.031-.236 1.044-.169 1.053-.101 1.057-.034" style="fill:#008300!important;stroke:#005400!important" transform="translate(135.414 24.5)"/><path fill="none" stroke="#005400" stroke-dasharray="0 0" stroke-width="1.3" d="M-64.852-16.5H64.852m-129.704 0H64.852m0 0 1.057.034m-1.057-.034 1.057.034m0 0 1.053.101m-1.053-.101 1.053.101m0 0 1.044.17m-1.044-.17 1.044.17m0 0 1.03.235m-1.03-.236 1.03.236m0 0 1.015.3m-1.014-.3 1.014.3m0 0 .992.366m-.992-.365.992.365m0 0 .968.428m-.968-.428.968.428m0 0 .937.49m-.937-.49.937.49m0 0 .905.548m-.905-.549.905.549m0 0 .867.605m-.867-.605.867.605m0 0c.315.25.63.501.827.66m-.827-.66.827.66m0 0 .783.71m-.783-.71.783.71m0 0 .736.76m-.736-.76.736.76m0 0 .686.805m-.686-.805.686.805m0 0 .632.848m-.632-.848.632.848m0 0 .577.887m-.577-.887.577.887m0 0 .52.921m-.52-.921.52.921m0 0 .458.953m-.459-.953.46.953m0 0 .396.98m-.397-.98.397.98m0 0 .334 1.004m-.334-1.004.334 1.004m0 0 .268 1.023m-.268-1.023.268 1.023m0 0 .202 1.039m-.202-1.039.202 1.039m0 0 .135 1.049m-.135-1.05.135 1.05m0 0 .068 1.055m-.068-1.055.068 1.055m0 0V.53m0-1.058V.53m0 0-.068 1.055M81.343.53l-.068 1.055m0 0-.135 1.05m.135-1.05-.135 1.05m0 0-.202 1.038m.202-1.039-.202 1.039m0 0-.268 1.023m.268-1.023-.268 1.023m0 0L80.336 5.7m.334-1.004L80.336 5.7m0 0-.397.98m.397-.98-.397.98m0 0-.459.953m.46-.953-.46.953m0 0-.519.921m.52-.921-.52.921m0 0-.577.887m.577-.887-.577.887m0 0-.632.848m.632-.848-.632.848m0 0-.686.805m.686-.805-.686.805m0 0c-.26.27-.521.538-.736.76m.736-.76-.736.76m0 0-.783.71m.783-.71-.783.71m0 0-.827.66m.827-.66c-.285.229-.571.457-.827.66m0 0-.867.605m.867-.605-.867.605m0 0-.905.549m.905-.549-.905.549m0 0-.937.489m.937-.49c-.342.18-.685.358-.937.49m0 0-.968.428m.968-.428-.968.428m0 0-.992.365m.992-.365-.992.365m0 0-1.014.301m1.014-.3-1.014.3m0 0-1.031.236m1.03-.236-1.03.236m0 0-1.044.169m1.044-.17-1.044.17m0 0-1.053.101m1.053-.101-1.053.101m0 0-1.057.034m1.057-.034-1.057.034m0 0H-64.852m129.704 0H-64.852m0 0-1.057-.034m1.057.034-1.057-.034m0 0-1.053-.101m1.053.101-1.053-.101m0 0-1.044-.17m1.044.17-1.044-.17m0 0-1.03-.235m1.03.236-1.03-.236m0 0-1.015-.3m1.014.3-1.014-.3m0 0-.992-.366m.992.365-.992-.365m0 0-.968-.428m.968.428-.968-.428m0 0-.937-.49m.937.49-.937-.49m0 0c-.202-.121-.403-.244-.905-.548m.905.549-.905-.549m0 0-.867-.605m.867.605-.867-.605m0 0-.827-.66m.827.66-.827-.66m0 0-.783-.71m.783.71-.783-.71m0 0-.736-.76m.736.76-.736-.76m0 0-.686-.805m.686.805-.686-.805m0 0-.632-.848m.632.848-.632-.848m0 0-.577-.887m.577.887-.577-.887m0 0-.52-.921m.52.921-.52-.921m0 0-.458-.953m.459.953-.46-.953m0 0-.396-.98m.397.98-.397-.98m0 0-.334-1.004m.334 1.004-.334-1.004m0 0-.268-1.023m.268 1.023-.268-1.023m0 0-.202-1.039m.202 1.039-.202-1.039m0 0-.135-1.049m.135 1.05-.135-1.05m0 0L-81.343.53m.068 1.055L-81.343.53m0 0V-.53m0 1.058V-.53m0 0 .068-1.055m-.068 1.055.068-1.055m0 0 .135-1.05m-.135 1.05.135-1.05m0 0 .202-1.038m-.202 1.039.202-1.039m0 0 .268-1.023m-.268 1.023.268-1.023m0 0 .334-1.004m-.334 1.004.334-1.004m0 0 .397-.98m-.397.98c.09-.223.18-.447.397-.98m0 0 .459-.953m-.46.953.46-.953m0 0c.183-.325.365-.65.519-.921m-.52.921.52-.921m0 0 .577-.887m-.577.887.577-.887m0 0 .632-.848m-.632.848.632-.848m0 0 .686-.805m-.686.805.686-.805m0 0 .736-.76m-.736.76.736-.76m0 0 .783-.71m-.783.71c.298-.271.597-.543.783-.71m0 0 .827-.66m-.827.66.827-.66m0 0 .867-.605m-.867.605.867-.605m0 0 .905-.549m-.905.549.905-.549m0 0 .937-.489m-.937.49.937-.49m0 0 .968-.428m-.968.428.968-.428m0 0 .992-.365m-.992.365.992-.365m0 0c.366-.11.733-.218 1.014-.301m-1.014.3 1.014-.3m0 0 1.031-.236m-1.03.236 1.03-.236m0 0 1.044-.169m-1.044.17 1.044-.17m0 0 1.053-.101m-1.053.101 1.053-.101m0 0 1.057-.034m-1.057.034 1.057-.034m0 0" style="fill:#008300!important;stroke:#005400!important" transform="translate(135.414 24.5)"/></g><g class="label" style="color:#fff!important" transform="translate(135.414 15.5)"><rect/><rect class="background" style="stroke:none"/><text y="-10.1" style="fill:#fff!important"><tspan x="0" y="-.1em" class="text-outer-tspan row" dy="1.1em"><tspan class="text-inner-tspan" font-style="normal" font-weight="normal">Óvalo</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> —</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> INICIO</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> /</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> FIN</tspan></tspan></text></g></g><g id="dia-s02_d3_simbolos-flowchart-E-1" class="node default" data-look="classic" transform="translate(135.414 115.75)"><polygon points="-24.75,0 178.20361328125,0 202.95361328125,-49.5 0,-49.5" class="label-container" style="fill:#2a78d6!important;stroke:#104281!important" transform="translate(-89.102 24.75)"/><g class="label" style="color:#fff!important" transform="translate(0 -17.25)"><rect/><rect class="background" style="stroke:none"/><text y="-10.1" style="fill:#fff!important"><tspan x="0" y="-.1em" class="text-outer-tspan row" dy="1.1em"><tspan class="text-inner-tspan" font-style="normal" font-weight="normal">Paralelogramo</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> —</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> LEER</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> /</tspan></tspan><tspan x="0" y="1em" class="text-outer-tspan row" dy="1.1em"><tspan class="text-inner-tspan" font-style="normal" font-weight="normal">ESCRIBIR</tspan></tspan></text></g></g><g id="dia-s02_d3_simbolos-flowchart-P-2" class="node default" data-look="classic" transform="translate(135.414 222.75)"><rect width="254.828" height="64.5" x="-127.414" y="-32.25" class="basic label-container" style="fill:#4a3aa7!important;stroke:#2a1f6b!important"/><g class="label" style="color:#fff!important" transform="translate(0 -17.25)"><rect/><rect class="background" style="stroke:none"/><text y="-10.1" style="fill:#fff!important"><tspan x="0" y="-.1em" class="text-outer-tspan row" dy="1.1em"><tspan class="text-inner-tspan" font-style="normal" font-weight="normal">Rectángulo</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> —</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> PROCESO</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> (un</tspan></tspan><tspan x="0" y="1em" class="text-outer-tspan row" dy="1.1em"><tspan class="text-inner-tspan" font-style="normal" font-weight="normal">cálculo)</tspan></tspan></text></g></g><g id="dia-s02_d3_simbolos-flowchart-D-3" class="node default" data-look="classic" transform="translate(135.414 426.71)"><polygon points="121.7109375,0 243.421875,-121.7109375 121.7109375,-243.421875 0,-121.7109375" class="label-container" style="fill:#eda100!important;stroke:#8a6d00!important" transform="translate(-121.21 121.71)"/><g class="label" style="color:#3a2a00!important" transform="translate(0 -17.25)"><rect/><rect class="background" style="stroke:none"/><text y="-10.1" style="fill:#3a2a00!important"><tspan x="0" y="-.1em" class="text-outer-tspan row" dy="1.1em"><tspan class="text-inner-tspan" font-style="normal" font-weight="normal">Rombo</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> —</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> DECISIÓN</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> (¿sí</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> o</tspan></tspan><tspan x="0" y="1em" class="text-outer-tspan row" dy="1.1em"><tspan class="text-inner-tspan" font-style="normal" font-weight="normal">no?)</tspan></tspan></text></g></g><g id="dia-s02_d3_simbolos-flowchart-F-4" class="node default" data-look="classic" transform="translate(135.414 652.672)"><rect width="243.563" height="64.5" x="-121.781" y="-32.25" class="basic label-container" style="fill:#fcfcfb!important;stroke:#52514e!important"/><g class="label" style="color:#0b0b0b!important" transform="translate(0 -17.25)"><rect/><rect class="background" style="stroke:none"/><text y="-10.1" style="fill:#0b0b0b!important"><tspan x="0" y="-.1em" class="text-outer-tspan row" dy="1.1em"><tspan class="text-inner-tspan" font-style="normal" font-weight="normal">Flecha</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> —</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> el</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> ORDEN</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> en</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> que</tspan></tspan><tspan x="0" y="1em" class="text-outer-tspan row" dy="1.1em"><tspan class="text-inner-tspan" font-style="normal" font-weight="normal">se</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> ejecuta</tspan></tspan></text></g></g></g></g><defs><filter id="dia-s02_d3_simbolos-drop-shadow" width="130%" height="130%"><feDropShadow dx="4" dy="4" flood-color="#000" flood-opacity=".06" stdDeviation="0"/></filter></defs><defs><filter id="dia-s02_d3_simbolos-drop-shadow-small" width="150%" height="150%"><feDropShadow dx="2" dy="2" flood-color="#000" flood-opacity=".06" stdDeviation="0"/></filter></defs><linearGradient id="dia-s02_d3_simbolos-gradient" x1="0%" x2="100%" y1="0%" y2="0%" gradientUnits="objectBoundingBox"><stop offset="0%" stop-color="hsl(0, 0%, 83.3333333333%)" stop-opacity="1"/><stop offset="100%" stop-color="hsl(0, 0%, 88.9215686275%)" stop-opacity="1"/></linearGradient></svg>', 'Los cinco símbolos. La forma dice qué hace el bloque, antes de leer una sola letra.')

# %%
tabla_simbolos()

# %% [markdown]
# Y este es el diagrama del programa que acabas de ejecutar. **No lo dibujó
# nadie**: lo dedujo el computador de tu pseudocódigo.

# %%
display(HTML(ps.diagrama(PAPELERIA)))

# %%
# Diagrama: s02_d5_papeleria
ava.figura('<svg xmlns="http://www.w3.org/2000/svg" id="dia-s02_d5_papeleria" width="100%" aria-roledescription="flowchart-v2" class="flowchart" role="graphics-document document" style="max-width:271.359px;background-color:transparent" viewBox="0 0 271.359 528.5"><style>#dia-s02_d5_papeleria{font-family:system-ui,-apple-system,&apos;Segoe UI&apos;,Roboto,sans-serif;font-size:15px;fill:#000000;}@keyframes edge-animation-frame{from{stroke-dashoffset:0;}}@keyframes dash{to{stroke-dashoffset:0;}}#dia-s02_d5_papeleria .edge-animation-slow{stroke-dasharray:9,5!important;stroke-dashoffset:900;animation:dash 50s linear infinite;stroke-linecap:round;}#dia-s02_d5_papeleria .edge-animation-fast{stroke-dasharray:9,5!important;stroke-dashoffset:900;animation:dash 20s linear infinite;stroke-linecap:round;}#dia-s02_d5_papeleria .error-icon{fill:#552222;}#dia-s02_d5_papeleria .error-text{fill:#552222;stroke:#552222;}#dia-s02_d5_papeleria .edge-thickness-normal{stroke-width:1px;}#dia-s02_d5_papeleria .edge-thickness-thick{stroke-width:3.5px;}#dia-s02_d5_papeleria .edge-pattern-solid{stroke-dasharray:0;}#dia-s02_d5_papeleria .edge-thickness-invisible{stroke-width:0;fill:none;}#dia-s02_d5_papeleria .edge-pattern-dashed{stroke-dasharray:3;}#dia-s02_d5_papeleria .edge-pattern-dotted{stroke-dasharray:2;}#dia-s02_d5_papeleria .marker{fill:#52514e;stroke:#52514e;}#dia-s02_d5_papeleria .marker.cross{stroke:#52514e;}#dia-s02_d5_papeleria svg{font-family:system-ui,-apple-system,&apos;Segoe UI&apos;,Roboto,sans-serif;font-size:15px;}#dia-s02_d5_papeleria p{margin:0;}#dia-s02_d5_papeleria .label{font-family:system-ui,-apple-system,&apos;Segoe UI&apos;,Roboto,sans-serif;color:#000000;}#dia-s02_d5_papeleria .cluster-label text{fill:#333;}#dia-s02_d5_papeleria .cluster-label span{color:#333;}#dia-s02_d5_papeleria .cluster-label span p{background-color:transparent;}#dia-s02_d5_papeleria .label text,#dia-s02_d5_papeleria span{fill:#000000;color:#000000;}#dia-s02_d5_papeleria .node rect,#dia-s02_d5_papeleria .node circle,#dia-s02_d5_papeleria .node ellipse,#dia-s02_d5_papeleria .node polygon,#dia-s02_d5_papeleria .node path{fill:#eee;stroke:#999;stroke-width:1px;}#dia-s02_d5_papeleria .rough-node .label text,#dia-s02_d5_papeleria .node .label text,#dia-s02_d5_papeleria .image-shape .label,#dia-s02_d5_papeleria .icon-shape .label{text-anchor:middle;}#dia-s02_d5_papeleria .node .katex path{fill:#000;stroke:#000;stroke-width:1px;}#dia-s02_d5_papeleria .rough-node .label,#dia-s02_d5_papeleria .node .label,#dia-s02_d5_papeleria .image-shape .label,#dia-s02_d5_papeleria .icon-shape .label{text-align:center;}#dia-s02_d5_papeleria .node.clickable{cursor:pointer;}#dia-s02_d5_papeleria .root .anchor path{fill:#52514e!important;stroke-width:0;stroke:#52514e;}#dia-s02_d5_papeleria .arrowheadPath{fill:#333333;}#dia-s02_d5_papeleria .edgePath .path{stroke:#52514e;stroke-width:1px;}#dia-s02_d5_papeleria .flowchart-link{stroke:#52514e;fill:none;}#dia-s02_d5_papeleria .edgeLabel{background-color:white;text-align:center;}#dia-s02_d5_papeleria .edgeLabel p{background-color:white;}#dia-s02_d5_papeleria .edgeLabel rect{opacity:0.5;background-color:white;fill:white;}#dia-s02_d5_papeleria .labelBkg{background-color:rgba(255, 255, 255, 0.5);}#dia-s02_d5_papeleria .cluster rect{fill:hsl(0, 0%, 98.9215686275%);stroke:#707070;stroke-width:1px;}#dia-s02_d5_papeleria .cluster text{fill:#333;}#dia-s02_d5_papeleria .cluster span{color:#333;}#dia-s02_d5_papeleria div.mermaidTooltip{position:absolute;text-align:center;max-width:200px;padding:2px;font-family:system-ui,-apple-system,&apos;Segoe UI&apos;,Roboto,sans-serif;font-size:12px;background:#fdf6e3;border:1px solid #707070;border-radius:2px;pointer-events:none;z-index:100;}#dia-s02_d5_papeleria .flowchartTitleText{text-anchor:middle;font-size:18px;fill:#000000;}#dia-s02_d5_papeleria rect.text{fill:none;stroke-width:0;}#dia-s02_d5_papeleria .icon-shape,#dia-s02_d5_papeleria .image-shape{background-color:white;text-align:center;}#dia-s02_d5_papeleria .icon-shape p,#dia-s02_d5_papeleria .image-shape p{background-color:white;padding:2px;}#dia-s02_d5_papeleria .icon-shape .label rect,#dia-s02_d5_papeleria .image-shape .label rect{opacity:0.5;background-color:white;fill:white;}#dia-s02_d5_papeleria .label-icon{display:inline-block;height:1em;overflow:visible;vertical-align:-0.125em;}#dia-s02_d5_papeleria .node .label-icon path{fill:currentColor;stroke:revert;stroke-width:revert;}#dia-s02_d5_papeleria .node .neo-node{stroke:#999;}#dia-s02_d5_papeleria [data-look=&quot;neo&quot;].node rect,#dia-s02_d5_papeleria [data-look=&quot;neo&quot;].cluster rect,#dia-s02_d5_papeleria [data-look=&quot;neo&quot;].node polygon{stroke:url(#dia-s02_d5_papeleria-gradient);filter:drop-shadow( 1px 2px 2px rgba(185,185,185,1));}#dia-s02_d5_papeleria [data-look=&quot;neo&quot;].swimlane.cluster rect{filter:none;}#dia-s02_d5_papeleria [data-look=&quot;neo&quot;].node path{stroke:url(#dia-s02_d5_papeleria-gradient);stroke-width:1px;}#dia-s02_d5_papeleria [data-look=&quot;neo&quot;].node .outer-path{filter:drop-shadow( 1px 2px 2px rgba(185,185,185,1));}#dia-s02_d5_papeleria [data-look=&quot;neo&quot;].node .neo-line path{stroke:#999;filter:none;}#dia-s02_d5_papeleria [data-look=&quot;neo&quot;].node circle{stroke:url(#dia-s02_d5_papeleria-gradient);filter:drop-shadow( 1px 2px 2px rgba(185,185,185,1));}#dia-s02_d5_papeleria [data-look=&quot;neo&quot;].node circle .state-start{fill:#000000;}#dia-s02_d5_papeleria [data-look=&quot;neo&quot;].icon-shape .icon{fill:url(#dia-s02_d5_papeleria-gradient);filter:drop-shadow( 1px 2px 2px rgba(185,185,185,1));}#dia-s02_d5_papeleria [data-look=&quot;neo&quot;].icon-shape .icon-neo path{stroke:url(#dia-s02_d5_papeleria-gradient);filter:drop-shadow( 1px 2px 2px rgba(185,185,185,1));}#dia-s02_d5_papeleria :root{--mermaid-font-family:&quot;trebuchet ms&quot;,verdana,arial,sans-serif;}</style><marker id="dia-s02_d5_papeleria_flowchart-v2-pointEnd" class="marker flowchart-v2" markerHeight="8" markerUnits="userSpaceOnUse" markerWidth="8" orient="auto" refX="5" refY="5" viewBox="0 0 10 10"><path d="m0 0 10 5-10 5z" class="arrowMarkerPath" style="stroke-width:1;stroke-dasharray:1,0"/></marker><marker id="dia-s02_d5_papeleria_flowchart-v2-pointStart" class="marker flowchart-v2" markerHeight="8" markerUnits="userSpaceOnUse" markerWidth="8" orient="auto" refX="4.5" refY="5" viewBox="0 0 10 10"><path d="m0 5 10 5V0z" class="arrowMarkerPath" style="stroke-width:1;stroke-dasharray:1,0"/></marker><marker id="dia-s02_d5_papeleria_flowchart-v2-pointEnd-margin" class="marker flowchart-v2" markerHeight="14" markerUnits="userSpaceOnUse" markerWidth="10.5" orient="auto" refX="11.5" refY="7" viewBox="0 0 11.5 14"><path d="m0 0 11.5 7L0 14z" class="arrowMarkerPath" style="stroke-width:0;stroke-dasharray:1,0"/></marker><marker id="dia-s02_d5_papeleria_flowchart-v2-pointStart-margin" class="marker flowchart-v2" markerHeight="14" markerUnits="userSpaceOnUse" markerWidth="11.5" orient="auto" refX="1" refY="7" viewBox="0 0 11.5 14"><polygon points="0,7 11.5,14 11.5,0" class="arrowMarkerPath" style="stroke-width:0;stroke-dasharray:1,0"/></marker><marker id="dia-s02_d5_papeleria_flowchart-v2-circleEnd" class="marker flowchart-v2" markerHeight="11" markerUnits="userSpaceOnUse" markerWidth="11" orient="auto" refX="11" refY="5" viewBox="0 0 10 10"><circle cx="5" cy="5" r="5" class="arrowMarkerPath" style="stroke-width:1;stroke-dasharray:1,0"/></marker><marker id="dia-s02_d5_papeleria_flowchart-v2-circleStart" class="marker flowchart-v2" markerHeight="11" markerUnits="userSpaceOnUse" markerWidth="11" orient="auto" refX="-1" refY="5" viewBox="0 0 10 10"><circle cx="5" cy="5" r="5" class="arrowMarkerPath" style="stroke-width:1;stroke-dasharray:1,0"/></marker><marker id="dia-s02_d5_papeleria_flowchart-v2-circleEnd-margin" class="marker flowchart-v2" markerHeight="14" markerUnits="userSpaceOnUse" markerWidth="14" orient="auto" refX="12.25" refY="5" viewBox="0 0 10 10"><circle cx="5" cy="5" r="5" class="arrowMarkerPath" style="stroke-width:0;stroke-dasharray:1,0"/></marker><marker id="dia-s02_d5_papeleria_flowchart-v2-circleStart-margin" class="marker flowchart-v2" markerHeight="14" markerUnits="userSpaceOnUse" markerWidth="14" orient="auto" refX="-2" refY="5" viewBox="0 0 10 10"><circle cx="5" cy="5" r="5" class="arrowMarkerPath" style="stroke-width:0;stroke-dasharray:1,0"/></marker><marker id="dia-s02_d5_papeleria_flowchart-v2-crossEnd" class="marker cross flowchart-v2" markerHeight="11" markerUnits="userSpaceOnUse" markerWidth="11" orient="auto" refX="12" refY="5.2" viewBox="0 0 11 11"><path d="m1 1 9 9m0-9-9 9" class="arrowMarkerPath" style="stroke-width:2;stroke-dasharray:1,0"/></marker><marker id="dia-s02_d5_papeleria_flowchart-v2-crossStart" class="marker cross flowchart-v2" markerHeight="11" markerUnits="userSpaceOnUse" markerWidth="11" orient="auto" refX="-1" refY="5.2" viewBox="0 0 11 11"><path d="m1 1 9 9m0-9-9 9" class="arrowMarkerPath" style="stroke-width:2;stroke-dasharray:1,0"/></marker><marker id="dia-s02_d5_papeleria_flowchart-v2-crossEnd-margin" class="marker cross flowchart-v2" markerHeight="12" markerUnits="userSpaceOnUse" markerWidth="12" orient="auto" refX="17.7" refY="7.5" viewBox="0 0 15 15"><path d="m1 1 13 13M1 14 14 1" class="arrowMarkerPath" style="stroke-width:2.5"/></marker><marker id="dia-s02_d5_papeleria_flowchart-v2-crossStart-margin" class="marker cross flowchart-v2" markerHeight="12" markerUnits="userSpaceOnUse" markerWidth="12" orient="auto" refX="-3.5" refY="7.5" viewBox="0 0 15 15"><path d="m1 1 13 13M1 14 14 1" class="arrowMarkerPath" style="stroke-width:2.5;stroke-dasharray:1,0"/></marker><g class="root"><g class="edgePaths"><path id="dia-s02_d5_papeleria-L_I_E1_0" marker-end="url(#dia-s02_d5_papeleria_flowchart-v2-pointEnd)" d="m136.18 41.5-.084 4.083c-.083 4.084-.25 12.25-.263 19.917s.128 14.834.198 18.417l.07 3.584" class="edge-thickness-normal edge-pattern-solid edge-thickness-normal edge-pattern-solid flowchart-link" data-edge="true" data-et="edge" data-id="L_I_E1_0" data-look="classic" data-points="W3sieCI6MTM2LjE3OTY4NzUsInkiOjQxLjV9LHsieCI6MTM1LjY3OTY4NzUsInkiOjY2fSx7IngiOjEzNi4xNzk2ODc1LCJ5Ijo5MS41fV0="/><path id="dia-s02_d5_papeleria-L_E1_L1_0" marker-end="url(#dia-s02_d5_papeleria_flowchart-v2-pointEnd)" d="m136.18 141-.084 4.083c-.083 4.084-.25 12.25-.263 19.917s.128 14.834.198 18.417l.07 3.584" class="edge-thickness-normal edge-pattern-solid edge-thickness-normal edge-pattern-solid flowchart-link" data-edge="true" data-et="edge" data-id="L_E1_L1_0" data-look="classic" data-points="W3sieCI6MTM2LjE3OTY4NzUsInkiOjE0MX0seyJ4IjoxMzUuNjc5Njg3NSwieSI6MTY1LjV9LHsieCI6MTM2LjE3OTY4NzUsInkiOjE5MX1d"/><path id="dia-s02_d5_papeleria-L_L1_P1_0" marker-end="url(#dia-s02_d5_papeleria_flowchart-v2-pointEnd)" d="m136.18 224-.084 4.083c-.083 4.084-.25 12.25-.333 19.834S135.68 262.5 135.68 266v3.5" class="edge-thickness-normal edge-pattern-solid edge-thickness-normal edge-pattern-solid flowchart-link" data-edge="true" data-et="edge" data-id="L_L1_P1_0" data-look="classic" data-points="W3sieCI6MTM2LjE3OTY4NzUsInkiOjIyNH0seyJ4IjoxMzUuNjc5Njg3NSwieSI6MjQ4LjV9LHsieCI6MTM1LjY3OTY4NzUsInkiOjI3My41fV0="/><path id="dia-s02_d5_papeleria-L_P1_E2_0" marker-end="url(#dia-s02_d5_papeleria_flowchart-v2-pointEnd)" d="M135.68 338v4.167c0 4.166 0 12.5.07 20.25s.211 14.917.281 18.5l.07 3.584" class="edge-thickness-normal edge-pattern-solid edge-thickness-normal edge-pattern-solid flowchart-link" data-edge="true" data-et="edge" data-id="L_P1_E2_0" data-look="classic" data-points="W3sieCI6MTM1LjY3OTY4NzUsInkiOjMzOH0seyJ4IjoxMzUuNjc5Njg3NSwieSI6MzYzfSx7IngiOjEzNi4xNzk2ODc1LCJ5IjozODguNX1d"/><path id="dia-s02_d5_papeleria-L_E2_F_0" marker-end="url(#dia-s02_d5_papeleria_flowchart-v2-pointEnd)" d="m136.18 438-.084 4.083c-.083 4.084-.25 12.25-.263 19.917s.128 14.834.198 18.417l.07 3.584" class="edge-thickness-normal edge-pattern-solid edge-thickness-normal edge-pattern-solid flowchart-link" data-edge="true" data-et="edge" data-id="L_E2_F_0" data-look="classic" data-points="W3sieCI6MTM2LjE3OTY4NzUsInkiOjQzOH0seyJ4IjoxMzUuNjc5Njg3NSwieSI6NDYyLjV9LHsieCI6MTM2LjE3OTY4NzUsInkiOjQ4OC4wMDAwMDAwMDAwMDA1fV0="/></g><g class="edgeLabels"><rect class="background" style="stroke:none"/><rect class="background" style="stroke:none"/><rect class="background" style="stroke:none"/><rect class="background" style="stroke:none"/><rect class="background" style="stroke:none"/></g><g class="nodes"><g id="dia-s02_d5_papeleria-flowchart-I-0" class="node default" data-look="classic"><g class="basic label-container outer-path"><path fill="#008300" stroke="none" stroke-width="0" d="M-17.164-16.5h34.328l1.057.034 1.053.101 1.044.17 1.031.235 1.014.3.993.366.967.428.938.49.904.548c.318.22.635.442.868.605l.827.66.783.71.736.76.685.805.633.848.577.887.519.921.459.953.397.98.333 1.004.268 1.023.203 1.039.135 1.049.068 1.055V.53l-.068 1.055-.135 1.05-.203 1.038-.268 1.023-.333 1.004-.397.98-.459.953-.52.921-.576.887-.633.848-.685.805-.736.76-.783.71-.827.66-.868.605-.904.549-.938.489-.967.428-.993.365-1.014.301c-.351.08-.703.16-1.03.236l-1.045.169-1.053.101-1.057.034h-34.328l-1.057-.034-1.053-.101-1.044-.17-1.031-.235-1.014-.3-.993-.366-.967-.428-.938-.49-.904-.548-.868-.605c-.175-.14-.35-.278-.827-.66l-.783-.71-.736-.76-.685-.805-.633-.848-.577-.887-.519-.921-.459-.953-.397-.98-.333-1.004-.268-1.023-.203-1.039-.135-1.049-.068-1.055V-.53l.068-1.055.135-1.05.203-1.038.268-1.023.333-1.004.397-.98.459-.953.52-.921.576-.887.633-.848.685-.805.736-.76.783-.71.827-.66.868-.605.904-.549.938-.489.967-.428.993-.365 1.014-.301 1.03-.236 1.045-.169 1.053-.101 1.057-.034" style="fill:#008300!important;stroke:#005400!important" transform="translate(135.68 24.5)"/><path fill="none" stroke="#005400" stroke-dasharray="0 0" stroke-width="1.3" d="M-17.164-16.5h34.328m-34.328 0h34.328m0 0 1.057.034m-1.057-.034 1.057.034m0 0 1.053.101m-1.053-.101 1.053.101m0 0 1.044.17m-1.044-.17 1.044.17m0 0 1.031.235m-1.03-.236 1.03.236m0 0 1.014.3m-1.014-.3 1.014.3m0 0 .993.366m-.993-.365.993.365m0 0 .967.428m-.967-.428.967.428m0 0 .938.49m-.938-.49.938.49m0 0 .904.548m-.904-.549.904.549m0 0 .868.605m-.868-.605.868.605m0 0 .827.66m-.827-.66c.284.226.568.452.827.66m0 0 .783.71m-.783-.71.783.71m0 0 .736.76m-.736-.76.736.76m0 0 .685.805m-.685-.805.685.805m0 0 .633.848m-.633-.848.633.848m0 0 .577.887m-.577-.887.577.887m0 0 .519.921m-.52-.921.52.921m0 0 .459.953m-.459-.953.459.953m0 0 .397.98m-.397-.98.397.98m0 0 .333 1.004m-.333-1.004.333 1.004m0 0 .268 1.023m-.268-1.023.268 1.023m0 0 .203 1.039m-.203-1.039.203 1.039m0 0 .135 1.049m-.135-1.05.135 1.05m0 0 .068 1.055m-.068-1.055.068 1.055m0 0V.53m0-1.058V.53m0 0-.068 1.055M33.656.53c-.025.38-.05.76-.068 1.055m0 0-.135 1.05m.135-1.05-.135 1.05m0 0-.203 1.038m.203-1.039-.203 1.039m0 0-.268 1.023m.268-1.023-.268 1.023m0 0L32.649 5.7m.333-1.004L32.649 5.7m0 0-.397.98m.397-.98-.397.98m0 0-.459.953m.459-.953-.459.953m0 0-.52.921m.52-.921-.52.921m0 0-.576.887m.577-.887-.577.887m0 0-.633.848m.633-.848-.633.848m0 0-.685.805m.685-.805-.685.805m0 0-.736.76m.736-.76-.736.76m0 0-.783.71m.783-.71-.783.71m0 0c-.26.209-.521.416-.827.66m.827-.66c-.249.2-.497.397-.827.66m0 0-.868.605m.868-.605-.868.605m0 0-.904.549m.904-.549-.904.549m0 0-.938.489m.938-.49-.938.49m0 0-.967.428m.967-.428-.967.428m0 0-.993.365m.993-.365-.993.365m0 0-1.014.301m1.014-.3-1.014.3m0 0-1.03.236m1.03-.236-1.03.236m0 0-1.045.169m1.044-.17-1.044.17m0 0-1.053.101m1.053-.101-1.053.101m0 0-1.057.034m1.057-.034-1.057.034m0 0h-34.328m34.328 0h-34.328m0 0-1.057-.034m1.057.034-1.057-.034m0 0-1.053-.101m1.053.101-1.053-.101m0 0-1.044-.17m1.044.17-1.044-.17m0 0c-.356-.08-.712-.162-1.031-.235m1.03.236-1.03-.236m0 0-1.014-.3m1.014.3-1.014-.3m0 0-.993-.366m.993.365-.993-.365m0 0-.967-.428m.967.428-.967-.428m0 0-.938-.49m.938.49-.938-.49m0 0c-.322-.194-.644-.39-.904-.548m.904.549-.904-.549m0 0-.868-.605m.868.605c-.285-.198-.57-.396-.868-.605m0 0-.827-.66m.827.66-.827-.66m0 0-.783-.71m.783.71-.783-.71m0 0-.736-.76m.736.76-.736-.76m0 0-.685-.805m.685.805-.685-.805m0 0-.633-.848m.633.848-.633-.848m0 0-.577-.887m.577.887-.577-.887m0 0-.519-.921m.52.921-.52-.921m0 0-.459-.953m.459.953-.459-.953m0 0-.397-.98m.397.98-.397-.98m0 0-.333-1.004m.333 1.004-.333-1.004m0 0-.268-1.023m.268 1.023-.268-1.023m0 0-.203-1.039m.203 1.039-.203-1.039m0 0-.135-1.049m.135 1.05-.135-1.05m0 0L-33.656.53m.068 1.055L-33.656.53m0 0V-.53m0 1.058V-.53m0 0 .068-1.055m-.068 1.055.068-1.055m0 0 .135-1.05m-.135 1.05.135-1.05m0 0 .203-1.038m-.203 1.039.203-1.039m0 0 .268-1.023m-.268 1.023c.06-.233.122-.467.268-1.023m0 0 .333-1.004m-.333 1.004.333-1.004m0 0 .397-.98m-.397.98.397-.98m0 0 .459-.953m-.459.953.459-.953m0 0c.18-.32.361-.642.52-.921m-.52.921.52-.921m0 0 .576-.887m-.577.887.577-.887m0 0 .633-.848m-.633.848.633-.848m0 0 .685-.805m-.685.805.685-.805m0 0 .736-.76m-.736.76.736-.76m0 0 .783-.71m-.783.71.783-.71m0 0 .827-.66m-.827.66.827-.66m0 0 .868-.605m-.868.605.868-.605m0 0 .904-.549m-.904.549.904-.549m0 0 .938-.489m-.938.49.938-.49m0 0 .967-.428m-.967.428.967-.428m0 0c.35-.13.702-.258.993-.365m-.993.365.993-.365m0 0 1.014-.301m-1.014.3 1.014-.3m0 0 1.03-.236m-1.03.236 1.03-.236m0 0 1.045-.169m-1.044.17 1.044-.17m0 0 1.053-.101m-1.053.101 1.053-.101m0 0 1.057-.034m-1.057.034 1.057-.034m0 0" style="fill:#008300!important;stroke:#005400!important" transform="translate(135.68 24.5)"/></g><g class="label" style="color:#fff!important" transform="translate(135.68 15.5)"><rect/><rect class="background" style="stroke:none"/><text y="-10.1" style="fill:#fff!important"><tspan x="0" y="-.1em" class="text-outer-tspan row" dy="1.1em"><tspan class="text-inner-tspan" font-style="normal" font-weight="normal">INICIO</tspan></tspan></text></g></g><g id="dia-s02_d5_papeleria-flowchart-E1-1" class="node default" data-look="classic" transform="translate(135.68 115.75)"><polygon points="-24.75,0 200.796875,0 225.546875,-49.5 0,-49.5" class="label-container" style="fill:#2a78d6!important;stroke:#104281!important" transform="translate(-100.398 24.75)"/><g class="label" style="color:#fff!important" transform="translate(0 -17.25)"><rect/><rect class="background" style="stroke:none"/><text y="-10.1" style="fill:#fff!important"><tspan x="0" y="-.1em" class="text-outer-tspan row" dy="1.1em"><tspan class="text-inner-tspan" font-style="normal" font-weight="normal">ESCRIBIR</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> &apos;¿Cuántas</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> copias</tspan></tspan><tspan x="0" y="1em" class="text-outer-tspan row" dy="1.1em"><tspan class="text-inner-tspan" font-style="normal" font-weight="normal">vas</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> a</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> sacar?&apos;</tspan></tspan></text></g></g><g id="dia-s02_d5_papeleria-flowchart-L1-2" class="node default" data-look="classic" transform="translate(135.68 207)"><polygon points="-16.5,0 99.09375,0 115.59375,-33 0,-33" class="label-container" style="fill:#2a78d6!important;stroke:#104281!important" transform="translate(-49.547 16.5)"/><g class="label" style="color:#fff!important" transform="translate(0 -9)"><rect/><rect class="background" style="stroke:none"/><text y="-10.1" style="fill:#fff!important"><tspan x="0" y="-.1em" class="text-outer-tspan row" dy="1.1em"><tspan class="text-inner-tspan" font-style="normal" font-weight="normal">LEER</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> copias</tspan></tspan></text></g></g><g id="dia-s02_d5_papeleria-flowchart-P1-3" class="node default" data-look="classic" transform="translate(135.68 305.75)"><rect width="255.359" height="64.5" x="-127.68" y="-32.25" class="basic label-container" style="fill:#4a3aa7!important;stroke:#2a1f6b!important"/><g class="label" style="color:#fff!important" transform="translate(0 -17.25)"><rect/><rect class="background" style="stroke:none"/><text y="-10.1" style="fill:#fff!important"><tspan x="0" y="-.1em" class="text-outer-tspan row" dy="1.1em"><tspan class="text-inner-tspan" font-style="normal" font-weight="normal">total</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> ←</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> copias</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> *</tspan></tspan><tspan x="0" y="1em" class="text-outer-tspan row" dy="1.1em"><tspan class="text-inner-tspan" font-style="normal" font-weight="normal">PRECIO_COPIA</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> +</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> ANILLADO</tspan></tspan></text></g></g><g id="dia-s02_d5_papeleria-flowchart-E2-4" class="node default" data-look="classic" transform="translate(135.68 412.75)"><polygon points="-24.75,0 201.1875,0 225.9375,-49.5 0,-49.5" class="label-container" style="fill:#2a78d6!important;stroke:#104281!important" transform="translate(-100.594 24.75)"/><g class="label" style="color:#fff!important" transform="translate(0 -17.25)"><rect/><rect class="background" style="stroke:none"/><text y="-10.1" style="fill:#fff!important"><tspan x="0" y="-.1em" class="text-outer-tspan row" dy="1.1em"><tspan class="text-inner-tspan" font-style="normal" font-weight="normal">ESCRIBIR</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> &apos;Total</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> a</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> pagar:</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> $&apos;,</tspan></tspan><tspan x="0" y="1em" class="text-outer-tspan row" dy="1.1em"><tspan class="text-inner-tspan" font-style="normal" font-weight="normal">total</tspan></tspan></text></g></g><g id="dia-s02_d5_papeleria-flowchart-F-5" class="node default" data-look="classic"><g class="basic label-container outer-path"><path fill="#008300" stroke="none" stroke-width="0" d="M-6.64-16.5H6.64l1.058.034 1.053.101 1.044.17 1.03.235 1.015.3.993.366.967.428c.374.195.749.39.937.49.189.113.377.228.905.548.314.218.628.437.867.605.212.168.423.336.827.66l.783.71.736.76.686.805.632.848.577.887.52.921.458.953.397.98.334 1.004.268 1.023.202 1.039.135 1.049.068 1.055V.53l-.068 1.055-.135 1.05-.202 1.038-.268 1.023-.334 1.004-.397.98-.458.953-.52.921-.577.887-.632.848-.686.805-.736.76-.783.71c-.24.193-.48.385-.827.66l-.867.605-.905.549-.937.489-.967.428-.993.365-1.014.301-1.031.236-1.044.169-1.053.101-1.057.034H-6.641l-1.057-.034-1.053-.101-1.044-.17-1.03-.235-1.015-.3-.993-.366-.967-.428-.937-.49-.905-.548-.867-.605-.827-.66-.783-.71-.736-.76-.686-.805-.632-.848-.577-.887-.52-.921-.458-.953-.397-.98-.334-1.004-.268-1.023-.202-1.039-.135-1.049-.068-1.055V-.53l.068-1.055.135-1.05.202-1.038.268-1.023.334-1.004.397-.98.458-.953.52-.921.577-.887.632-.848.686-.805.736-.76.783-.71c.19-.153.38-.305.827-.66l.867-.605.905-.549.937-.489.967-.428.993-.365 1.014-.301c.301-.07.602-.138 1.031-.236l1.044-.169 1.053-.101 1.057-.034" style="fill:#008300!important;stroke:#005400!important" transform="translate(135.68 504)"/><path fill="none" stroke="#005400" stroke-dasharray="0 0" stroke-width="1.3" d="M-6.64-16.5H6.64m-13.28 0H6.64m0 0 1.058.034M6.64-16.5l1.057.034m0 0 1.053.101m-1.053-.101 1.053.101m0 0 1.044.17m-1.044-.17 1.044.17m0 0 1.03.235m-1.03-.236 1.03.236m0 0 1.015.3m-1.014-.3 1.014.3m0 0 .993.366m-.993-.365.993.365m0 0 .967.428m-.967-.428.967.428m0 0 .937.49m-.937-.49c.317.165.634.33.937.49m0 0c.2.12.4.24.905.548m-.905-.549.905.549m0 0 .867.605m-.867-.605.867.605m0 0 .827.66m-.827-.66.827.66m0 0 .783.71m-.783-.71.783.71m0 0 .736.76m-.736-.76.736.76m0 0 .686.805m-.686-.805.686.805m0 0 .632.848m-.632-.848.632.848m0 0 .577.887m-.577-.887.577.887m0 0 .52.921m-.52-.921.52.921m0 0 .458.953m-.458-.953.458.953m0 0 .397.98m-.397-.98.397.98m0 0 .334 1.004m-.334-1.004.334 1.004m0 0 .268 1.023m-.268-1.023.268 1.023m0 0 .202 1.039m-.202-1.039c.075.383.15.766.202 1.039m0 0 .135 1.049m-.135-1.05c.045.346.09.69.135 1.05m0 0 .068 1.055m-.068-1.055.068 1.055m0 0V.53m0-1.058V.53m0 0-.068 1.055M23.132.53l-.068 1.055m0 0-.135 1.05m.135-1.05-.135 1.05m0 0-.202 1.038m.202-1.039-.202 1.039m0 0-.268 1.023m.268-1.023-.268 1.023m0 0L22.125 5.7m.334-1.004L22.125 5.7m0 0-.397.98m.397-.98-.397.98m0 0-.458.953m.458-.953-.458.953m0 0-.52.921m.52-.921-.52.921m0 0-.577.887m.577-.887c-.16.248-.321.495-.577.887m0 0-.632.848m.632-.848-.632.848m0 0-.686.805m.686-.805-.686.805m0 0-.736.76m.736-.76-.736.76m0 0-.783.71m.783-.71-.783.71m0 0c-.22.177-.44.353-.827.66m.827-.66-.827.66m0 0-.867.605m.867-.605-.867.605m0 0-.905.549m.905-.549-.905.549m0 0-.937.489m.937-.49-.937.49m0 0-.967.428m.967-.428-.967.428m0 0-.993.365m.993-.365-.993.365m0 0-1.014.301m1.014-.3-1.014.3m0 0-1.031.236m1.03-.236-1.03.236m0 0-1.044.169m1.044-.17-1.044.17m0 0-1.053.101m1.053-.101-1.053.101m0 0L6.64 16.5m1.057-.034L6.64 16.5m0 0H-6.641m13.282 0H-6.641m0 0-1.057-.034m1.057.034-1.057-.034m0 0-1.053-.101m1.053.101-1.053-.101m0 0-1.044-.17m1.044.17-1.044-.17m0 0-1.03-.235m1.03.236-1.03-.236m0 0-1.015-.3m1.014.3-1.014-.3m0 0-.993-.366m.993.365-.993-.365m0 0-.967-.428m.967.428-.967-.428m0 0-.937-.49m.937.49-.937-.49m0 0-.905-.548m.905.549-.905-.549m0 0-.867-.605m.867.605-.867-.605m0 0-.827-.66m.827.66c-.283-.225-.566-.45-.827-.66m0 0-.783-.71m.783.71c-.255-.23-.51-.461-.783-.71m0 0-.736-.76m.736.76-.736-.76m0 0-.686-.805m.686.805-.686-.805m0 0-.632-.848m.632.848-.632-.848m0 0-.577-.887m.577.887-.577-.887m0 0-.52-.921m.52.921-.52-.921m0 0-.458-.953m.458.953-.458-.953m0 0-.397-.98m.397.98-.397-.98m0 0-.334-1.004m.334 1.004-.334-1.004m0 0-.268-1.023m.268 1.023-.268-1.023m0 0-.202-1.039m.202 1.039-.202-1.039m0 0-.135-1.049m.135 1.05-.135-1.05m0 0L-23.132.53m.068 1.055L-23.132.53m0 0V-.53m0 1.058V-.53m0 0 .068-1.055m-.068 1.055.068-1.055m0 0 .135-1.05m-.135 1.05.135-1.05m0 0 .202-1.038m-.202 1.039.202-1.039m0 0 .268-1.023m-.268 1.023.268-1.023m0 0 .334-1.004m-.334 1.004.334-1.004m0 0 .397-.98m-.397.98.397-.98m0 0 .458-.953m-.458.953.458-.953m0 0 .52-.921m-.52.921.52-.921m0 0 .577-.887m-.577.887.577-.887m0 0 .632-.848m-.632.848.632-.848m0 0 .686-.805m-.686.805.686-.805m0 0 .736-.76m-.736.76.736-.76m0 0 .783-.71m-.783.71.783-.71m0 0 .827-.66m-.827.66c.166-.134.333-.267.827-.66m0 0 .867-.605m-.867.605.867-.605m0 0 .905-.549m-.905.549.905-.549m0 0 .937-.489m-.937.49.937-.49m0 0 .967-.428m-.967.428.967-.428m0 0 .993-.365m-.993.365.993-.365m0 0 1.014-.301m-1.014.3 1.014-.3m0 0 1.031-.236m-1.03.236 1.03-.236m0 0 1.044-.169m-1.044.17 1.044-.17m0 0 1.053-.101m-1.053.101c.222-.02.444-.042 1.053-.101m0 0 1.057-.034m-1.057.034 1.057-.034m0 0" style="fill:#008300!important;stroke:#005400!important" transform="translate(135.68 504)"/></g><g class="label" style="color:#fff!important" transform="translate(135.68 495)"><rect/><rect class="background" style="stroke:none"/><text y="-10.1" style="fill:#fff!important"><tspan x="0" y="-.1em" class="text-outer-tspan row" dy="1.1em"><tspan class="text-inner-tspan" font-style="normal" font-weight="normal">FIN</tspan></tspan></text></g></g></g></g><defs><filter id="dia-s02_d5_papeleria-drop-shadow" width="130%" height="130%"><feDropShadow dx="4" dy="4" flood-color="#000" flood-opacity=".06" stdDeviation="0"/></filter></defs><defs><filter id="dia-s02_d5_papeleria-drop-shadow-small" width="150%" height="150%"><feDropShadow dx="2" dy="2" flood-color="#000" flood-opacity=".06" stdDeviation="0"/></filter></defs><linearGradient id="dia-s02_d5_papeleria-gradient" x1="0%" x2="100%" y1="0%" y2="0%" gradientUnits="objectBoundingBox"><stop offset="0%" stop-color="hsl(0, 0%, 83.3333333333%)" stop-opacity="1"/><stop offset="100%" stop-color="hsl(0, 0%, 88.9215686275%)" stop-opacity="1"/></linearGradient></svg>', 'El mismo algoritmo dibujado a mano con la convención de la clase. Compara los dos: son el mismo diagrama.')

# %% [markdown]
# ### Reglas para que un diagrama de flujo sea correcto
#
# 1. **Un solo INICIO.** Si tu diagrama tiene dos puntos de arranque, no es un
#    algoritmo: son dos.
# 2. **Todo camino llega al FIN.** Si una rama se queda colgando, hay un caso que
#    tu algoritmo no resuelve.
# 3. **Las flechas tienen punta y una sola dirección.** Una línea sin punta no
#    dice nada.
# 4. **Del rombo salen dos flechas rotuladas, y solo dos.** Si necesitas tres
#    respuestas, necesitas dos rombos.
# 5. **Una caja, una instrucción.** El diagrama debe poder leerse en voz alta como
#    una lista de órdenes.
#
# Dos diagramas que rompen esas reglas:

# %%
# Diagrama: s02_d6a_rombo_mudo
ava.figura('<svg xmlns="http://www.w3.org/2000/svg" id="dia-s02_d6a_rombo_mudo" width="100%" aria-roledescription="flowchart-v2" class="flowchart" role="graphics-document document" style="max-width:468.141px;background-color:transparent" viewBox="0 0 468.141 496.375"><style>#dia-s02_d6a_rombo_mudo{font-family:system-ui,-apple-system,&apos;Segoe UI&apos;,Roboto,sans-serif;font-size:15px;fill:#000000;}@keyframes edge-animation-frame{from{stroke-dashoffset:0;}}@keyframes dash{to{stroke-dashoffset:0;}}#dia-s02_d6a_rombo_mudo .edge-animation-slow{stroke-dasharray:9,5!important;stroke-dashoffset:900;animation:dash 50s linear infinite;stroke-linecap:round;}#dia-s02_d6a_rombo_mudo .edge-animation-fast{stroke-dasharray:9,5!important;stroke-dashoffset:900;animation:dash 20s linear infinite;stroke-linecap:round;}#dia-s02_d6a_rombo_mudo .error-icon{fill:#552222;}#dia-s02_d6a_rombo_mudo .error-text{fill:#552222;stroke:#552222;}#dia-s02_d6a_rombo_mudo .edge-thickness-normal{stroke-width:1px;}#dia-s02_d6a_rombo_mudo .edge-thickness-thick{stroke-width:3.5px;}#dia-s02_d6a_rombo_mudo .edge-pattern-solid{stroke-dasharray:0;}#dia-s02_d6a_rombo_mudo .edge-thickness-invisible{stroke-width:0;fill:none;}#dia-s02_d6a_rombo_mudo .edge-pattern-dashed{stroke-dasharray:3;}#dia-s02_d6a_rombo_mudo .edge-pattern-dotted{stroke-dasharray:2;}#dia-s02_d6a_rombo_mudo .marker{fill:#52514e;stroke:#52514e;}#dia-s02_d6a_rombo_mudo .marker.cross{stroke:#52514e;}#dia-s02_d6a_rombo_mudo svg{font-family:system-ui,-apple-system,&apos;Segoe UI&apos;,Roboto,sans-serif;font-size:15px;}#dia-s02_d6a_rombo_mudo p{margin:0;}#dia-s02_d6a_rombo_mudo .label{font-family:system-ui,-apple-system,&apos;Segoe UI&apos;,Roboto,sans-serif;color:#000000;}#dia-s02_d6a_rombo_mudo .cluster-label text{fill:#333;}#dia-s02_d6a_rombo_mudo .cluster-label span{color:#333;}#dia-s02_d6a_rombo_mudo .cluster-label span p{background-color:transparent;}#dia-s02_d6a_rombo_mudo .label text,#dia-s02_d6a_rombo_mudo span{fill:#000000;color:#000000;}#dia-s02_d6a_rombo_mudo .node rect,#dia-s02_d6a_rombo_mudo .node circle,#dia-s02_d6a_rombo_mudo .node ellipse,#dia-s02_d6a_rombo_mudo .node polygon,#dia-s02_d6a_rombo_mudo .node path{fill:#eee;stroke:#999;stroke-width:1px;}#dia-s02_d6a_rombo_mudo .rough-node .label text,#dia-s02_d6a_rombo_mudo .node .label text,#dia-s02_d6a_rombo_mudo .image-shape .label,#dia-s02_d6a_rombo_mudo .icon-shape .label{text-anchor:middle;}#dia-s02_d6a_rombo_mudo .node .katex path{fill:#000;stroke:#000;stroke-width:1px;}#dia-s02_d6a_rombo_mudo .rough-node .label,#dia-s02_d6a_rombo_mudo .node .label,#dia-s02_d6a_rombo_mudo .image-shape .label,#dia-s02_d6a_rombo_mudo .icon-shape .label{text-align:center;}#dia-s02_d6a_rombo_mudo .node.clickable{cursor:pointer;}#dia-s02_d6a_rombo_mudo .root .anchor path{fill:#52514e!important;stroke-width:0;stroke:#52514e;}#dia-s02_d6a_rombo_mudo .arrowheadPath{fill:#333333;}#dia-s02_d6a_rombo_mudo .edgePath .path{stroke:#52514e;stroke-width:1px;}#dia-s02_d6a_rombo_mudo .flowchart-link{stroke:#52514e;fill:none;}#dia-s02_d6a_rombo_mudo .edgeLabel{background-color:white;text-align:center;}#dia-s02_d6a_rombo_mudo .edgeLabel p{background-color:white;}#dia-s02_d6a_rombo_mudo .edgeLabel rect{opacity:0.5;background-color:white;fill:white;}#dia-s02_d6a_rombo_mudo .labelBkg{background-color:rgba(255, 255, 255, 0.5);}#dia-s02_d6a_rombo_mudo .cluster rect{fill:hsl(0, 0%, 98.9215686275%);stroke:#707070;stroke-width:1px;}#dia-s02_d6a_rombo_mudo .cluster text{fill:#333;}#dia-s02_d6a_rombo_mudo .cluster span{color:#333;}#dia-s02_d6a_rombo_mudo div.mermaidTooltip{position:absolute;text-align:center;max-width:200px;padding:2px;font-family:system-ui,-apple-system,&apos;Segoe UI&apos;,Roboto,sans-serif;font-size:12px;background:#fdf6e3;border:1px solid #707070;border-radius:2px;pointer-events:none;z-index:100;}#dia-s02_d6a_rombo_mudo .flowchartTitleText{text-anchor:middle;font-size:18px;fill:#000000;}#dia-s02_d6a_rombo_mudo rect.text{fill:none;stroke-width:0;}#dia-s02_d6a_rombo_mudo .icon-shape,#dia-s02_d6a_rombo_mudo .image-shape{background-color:white;text-align:center;}#dia-s02_d6a_rombo_mudo .icon-shape p,#dia-s02_d6a_rombo_mudo .image-shape p{background-color:white;padding:2px;}#dia-s02_d6a_rombo_mudo .icon-shape .label rect,#dia-s02_d6a_rombo_mudo .image-shape .label rect{opacity:0.5;background-color:white;fill:white;}#dia-s02_d6a_rombo_mudo .label-icon{display:inline-block;height:1em;overflow:visible;vertical-align:-0.125em;}#dia-s02_d6a_rombo_mudo .node .label-icon path{fill:currentColor;stroke:revert;stroke-width:revert;}#dia-s02_d6a_rombo_mudo .node .neo-node{stroke:#999;}#dia-s02_d6a_rombo_mudo [data-look=&quot;neo&quot;].node rect,#dia-s02_d6a_rombo_mudo [data-look=&quot;neo&quot;].cluster rect,#dia-s02_d6a_rombo_mudo [data-look=&quot;neo&quot;].node polygon{stroke:url(#dia-s02_d6a_rombo_mudo-gradient);filter:drop-shadow( 1px 2px 2px rgba(185,185,185,1));}#dia-s02_d6a_rombo_mudo [data-look=&quot;neo&quot;].swimlane.cluster rect{filter:none;}#dia-s02_d6a_rombo_mudo [data-look=&quot;neo&quot;].node path{stroke:url(#dia-s02_d6a_rombo_mudo-gradient);stroke-width:1px;}#dia-s02_d6a_rombo_mudo [data-look=&quot;neo&quot;].node .outer-path{filter:drop-shadow( 1px 2px 2px rgba(185,185,185,1));}#dia-s02_d6a_rombo_mudo [data-look=&quot;neo&quot;].node .neo-line path{stroke:#999;filter:none;}#dia-s02_d6a_rombo_mudo [data-look=&quot;neo&quot;].node circle{stroke:url(#dia-s02_d6a_rombo_mudo-gradient);filter:drop-shadow( 1px 2px 2px rgba(185,185,185,1));}#dia-s02_d6a_rombo_mudo [data-look=&quot;neo&quot;].node circle .state-start{fill:#000000;}#dia-s02_d6a_rombo_mudo [data-look=&quot;neo&quot;].icon-shape .icon{fill:url(#dia-s02_d6a_rombo_mudo-gradient);filter:drop-shadow( 1px 2px 2px rgba(185,185,185,1));}#dia-s02_d6a_rombo_mudo [data-look=&quot;neo&quot;].icon-shape .icon-neo path{stroke:url(#dia-s02_d6a_rombo_mudo-gradient);filter:drop-shadow( 1px 2px 2px rgba(185,185,185,1));}#dia-s02_d6a_rombo_mudo :root{--mermaid-font-family:&quot;trebuchet ms&quot;,verdana,arial,sans-serif;}</style><marker id="dia-s02_d6a_rombo_mudo_flowchart-v2-pointEnd" class="marker flowchart-v2" markerHeight="8" markerUnits="userSpaceOnUse" markerWidth="8" orient="auto" refX="5" refY="5" viewBox="0 0 10 10"><path d="m0 0 10 5-10 5z" class="arrowMarkerPath" style="stroke-width:1;stroke-dasharray:1,0"/></marker><marker id="dia-s02_d6a_rombo_mudo_flowchart-v2-pointStart" class="marker flowchart-v2" markerHeight="8" markerUnits="userSpaceOnUse" markerWidth="8" orient="auto" refX="4.5" refY="5" viewBox="0 0 10 10"><path d="m0 5 10 5V0z" class="arrowMarkerPath" style="stroke-width:1;stroke-dasharray:1,0"/></marker><marker id="dia-s02_d6a_rombo_mudo_flowchart-v2-pointEnd-margin" class="marker flowchart-v2" markerHeight="14" markerUnits="userSpaceOnUse" markerWidth="10.5" orient="auto" refX="11.5" refY="7" viewBox="0 0 11.5 14"><path d="m0 0 11.5 7L0 14z" class="arrowMarkerPath" style="stroke-width:0;stroke-dasharray:1,0"/></marker><marker id="dia-s02_d6a_rombo_mudo_flowchart-v2-pointStart-margin" class="marker flowchart-v2" markerHeight="14" markerUnits="userSpaceOnUse" markerWidth="11.5" orient="auto" refX="1" refY="7" viewBox="0 0 11.5 14"><polygon points="0,7 11.5,14 11.5,0" class="arrowMarkerPath" style="stroke-width:0;stroke-dasharray:1,0"/></marker><marker id="dia-s02_d6a_rombo_mudo_flowchart-v2-circleEnd" class="marker flowchart-v2" markerHeight="11" markerUnits="userSpaceOnUse" markerWidth="11" orient="auto" refX="11" refY="5" viewBox="0 0 10 10"><circle cx="5" cy="5" r="5" class="arrowMarkerPath" style="stroke-width:1;stroke-dasharray:1,0"/></marker><marker id="dia-s02_d6a_rombo_mudo_flowchart-v2-circleStart" class="marker flowchart-v2" markerHeight="11" markerUnits="userSpaceOnUse" markerWidth="11" orient="auto" refX="-1" refY="5" viewBox="0 0 10 10"><circle cx="5" cy="5" r="5" class="arrowMarkerPath" style="stroke-width:1;stroke-dasharray:1,0"/></marker><marker id="dia-s02_d6a_rombo_mudo_flowchart-v2-circleEnd-margin" class="marker flowchart-v2" markerHeight="14" markerUnits="userSpaceOnUse" markerWidth="14" orient="auto" refX="12.25" refY="5" viewBox="0 0 10 10"><circle cx="5" cy="5" r="5" class="arrowMarkerPath" style="stroke-width:0;stroke-dasharray:1,0"/></marker><marker id="dia-s02_d6a_rombo_mudo_flowchart-v2-circleStart-margin" class="marker flowchart-v2" markerHeight="14" markerUnits="userSpaceOnUse" markerWidth="14" orient="auto" refX="-2" refY="5" viewBox="0 0 10 10"><circle cx="5" cy="5" r="5" class="arrowMarkerPath" style="stroke-width:0;stroke-dasharray:1,0"/></marker><marker id="dia-s02_d6a_rombo_mudo_flowchart-v2-crossEnd" class="marker cross flowchart-v2" markerHeight="11" markerUnits="userSpaceOnUse" markerWidth="11" orient="auto" refX="12" refY="5.2" viewBox="0 0 11 11"><path d="m1 1 9 9m0-9-9 9" class="arrowMarkerPath" style="stroke-width:2;stroke-dasharray:1,0"/></marker><marker id="dia-s02_d6a_rombo_mudo_flowchart-v2-crossStart" class="marker cross flowchart-v2" markerHeight="11" markerUnits="userSpaceOnUse" markerWidth="11" orient="auto" refX="-1" refY="5.2" viewBox="0 0 11 11"><path d="m1 1 9 9m0-9-9 9" class="arrowMarkerPath" style="stroke-width:2;stroke-dasharray:1,0"/></marker><marker id="dia-s02_d6a_rombo_mudo_flowchart-v2-crossEnd-margin" class="marker cross flowchart-v2" markerHeight="12" markerUnits="userSpaceOnUse" markerWidth="12" orient="auto" refX="17.7" refY="7.5" viewBox="0 0 15 15"><path d="m1 1 13 13M1 14 14 1" class="arrowMarkerPath" style="stroke-width:2.5"/></marker><marker id="dia-s02_d6a_rombo_mudo_flowchart-v2-crossStart-margin" class="marker cross flowchart-v2" markerHeight="12" markerUnits="userSpaceOnUse" markerWidth="12" orient="auto" refX="-3.5" refY="7.5" viewBox="0 0 15 15"><path d="m1 1 13 13M1 14 14 1" class="arrowMarkerPath" style="stroke-width:2.5;stroke-dasharray:1,0"/></marker><g class="root"><g class="edgePaths"><path id="dia-s02_d6a_rombo_mudo-L_I_D_0" marker-end="url(#dia-s02_d6a_rombo_mudo_flowchart-v2-pointEnd)" d="m215.879 41.5-.083 4.083c-.084 4.084-.25 12.25-.334 19.834-.083 7.583-.083 14.583-.083 18.083V87" class="edge-thickness-normal edge-pattern-solid edge-thickness-normal edge-pattern-solid flowchart-link" data-edge="true" data-et="edge" data-id="L_I_D_0" data-look="classic" data-points="W3sieCI6MjE1Ljg3ODkwNjI1LCJ5Ijo0MS41fSx7IngiOjIxNS4zNzg5MDYyNSwieSI6NjZ9LHsieCI6MjE1LjM3ODkwNjI1LCJ5Ijo5MX1d"/><path id="dia-s02_d6a_rombo_mudo-L_D_P_0" marker-end="url(#dia-s02_d6a_rombo_mudo_flowchart-v2-pointEnd)" d="m173.562 210.558-13.953 12.969c-13.953 12.97-41.859 38.909-55.812 59.962s-13.953 37.219-13.953 45.303v8.083" class="edge-thickness-normal edge-pattern-solid edge-thickness-normal edge-pattern-solid flowchart-link" data-edge="true" data-et="edge" data-id="L_D_P_0" data-look="classic" data-points="W3sieCI6MTczLjU2MTUyMTg3ODM3NjU0LCJ5IjoyMTAuNTU3NjE1NjI4Mzc2NTR9LHsieCI6ODkuODQzNzUsInkiOjI4OC4zNzV9LHsieCI6ODkuODQzNzUsInkiOjM0MC44NzV9XQ=="/><path id="dia-s02_d6a_rombo_mudo-L_P_F_0" marker-end="url(#dia-s02_d6a_rombo_mudo_flowchart-v2-pointEnd)" d="M89.844 388.875v6.917c0 6.916 0 20.75.07 31.25s.211 17.667.281 21.25l.07 3.584" class="edge-thickness-normal edge-pattern-solid edge-thickness-normal edge-pattern-solid flowchart-link" data-edge="true" data-et="edge" data-id="L_P_F_0" data-look="classic" data-points="W3sieCI6ODkuODQzNzUsInkiOjM4OC44NzV9LHsieCI6ODkuODQzNzUsInkiOjQzMC4zNzV9LHsieCI6OTAuMzQzNzUsInkiOjQ1NS44NzV9XQ=="/><path id="dia-s02_d6a_rombo_mudo-L_D_X_0" marker-end="url(#dia-s02_d6a_rombo_mudo_flowchart-v2-pointEnd)" d="m257.196 210.558 13.953 12.969c13.953 12.97 41.859 38.909 55.812 57.212s13.953 28.969 13.953 34.303v5.333" class="edge-thickness-normal edge-pattern-dotted edge-thickness-normal edge-pattern-solid flowchart-link" data-edge="true" data-et="edge" data-id="L_D_X_0" data-look="classic" data-points="W3sieCI6MjU3LjE5NjI5MDYyMTYyMzQ2LCJ5IjoyMTAuNTU3NjE1NjI4Mzc2NTR9LHsieCI6MzQwLjkxNDA2MjUsInkiOjI4OC4zNzV9LHsieCI6MzQwLjkxNDA2MjUsInkiOjMyNC4zNzV9XQ=="/></g><g class="edgeLabels"><rect class="background" style="stroke:none"/><g class="edgeLabel"><g class="label" data-id="L_D_P_0" transform="translate(89.563 279.375)"><rect width="17.359" height="22" x="-8.398" y="-2" class="background"/><text y="-10.1" text-anchor="middle"><tspan x="0" y="-.1em" class="text-outer-tspan row" dy="1.1em" text-anchor="middle"><tspan class="text-inner-tspan" font-style="normal" font-weight="normal">Sí</tspan></tspan></text></g></g><rect class="background" style="stroke:none"/><rect class="background" style="stroke:none"/></g><g class="nodes"><g id="dia-s02_d6a_rombo_mudo-flowchart-I-0" class="node default" data-look="classic"><g class="basic label-container outer-path"><path fill="#008300" stroke="none" stroke-width="0" d="M-17.164-16.5h34.328l1.057.034 1.053.101 1.044.17 1.031.235 1.014.3.993.366.967.428.938.49.904.548.868.605.827.66.783.71.736.76.685.805.633.848.577.887.519.921.459.953.397.98.333 1.004.268 1.023.203 1.039.135 1.049.068 1.055V.53l-.068 1.055-.135 1.05-.203 1.038-.268 1.023-.333 1.004-.397.98-.459.953-.52.921-.576.887-.633.848-.685.805-.736.76-.783.71-.827.66-.868.605-.904.549-.938.489-.967.428-.993.365c-.4.12-.802.239-1.014.301l-1.03.236-1.045.169-1.053.101-1.057.034h-34.328l-1.057-.034-1.053-.101-1.044-.17c-.376-.085-.751-.17-1.031-.235l-1.014-.3-.993-.366-.967-.428-.938-.49-.904-.548c-.217-.15-.434-.302-.868-.605-.279-.222-.558-.444-.827-.66l-.783-.71-.736-.76-.685-.805-.633-.848-.577-.887-.519-.921-.459-.953-.397-.98-.333-1.004-.268-1.023-.203-1.039-.135-1.049-.068-1.055V-.53l.068-1.055.135-1.05.203-1.038.268-1.023.333-1.004.397-.98.459-.953.52-.921.576-.887.633-.848.685-.805.736-.76.783-.71.827-.66.868-.605c.245-.15.49-.298.904-.549l.938-.489.967-.428.993-.365 1.014-.301 1.03-.236 1.045-.169 1.053-.101 1.057-.034" style="fill:#008300!important;stroke:#005400!important" transform="translate(215.379 24.5)"/><path fill="none" stroke="#005400" stroke-dasharray="0 0" stroke-width="1.3" d="M-17.164-16.5h34.328m-34.328 0h34.328m0 0 1.057.034m-1.057-.034 1.057.034m0 0 1.053.101m-1.053-.101 1.053.101m0 0 1.044.17m-1.044-.17 1.044.17m0 0c.331.075.663.15 1.031.235m-1.03-.236 1.03.236m0 0 1.014.3m-1.014-.3 1.014.3m0 0 .993.366m-.993-.365.993.365m0 0 .967.428m-.967-.428.967.428m0 0 .938.49m-.938-.49c.304.159.609.317.938.49m0 0 .904.548m-.904-.549.904.549m0 0 .868.605m-.868-.605.868.605m0 0 .827.66m-.827-.66.827.66m0 0 .783.71m-.783-.71.783.71m0 0 .736.76m-.736-.76.736.76m0 0 .685.805m-.685-.805.685.805m0 0 .633.848m-.633-.848.633.848m0 0 .577.887m-.577-.887.577.887m0 0 .519.921m-.52-.921.52.921m0 0 .459.953m-.459-.953.459.953m0 0 .397.98m-.397-.98.397.98m0 0 .333 1.004m-.333-1.004.333 1.004m0 0 .268 1.023m-.268-1.023.268 1.023m0 0 .203 1.039m-.203-1.039.203 1.039m0 0 .135 1.049m-.135-1.05.135 1.05m0 0 .068 1.055m-.068-1.055.068 1.055m0 0V.53m0-1.058V.53m0 0-.068 1.055M33.656.53l-.068 1.055m0 0-.135 1.05m.135-1.05-.135 1.05m0 0-.203 1.038m.203-1.039-.203 1.039m0 0-.268 1.023m.268-1.023-.268 1.023m0 0L32.649 5.7m.333-1.004L32.649 5.7m0 0-.397.98m.397-.98-.397.98m0 0-.459.953m.459-.953-.459.953m0 0-.52.921m.52-.921-.52.921m0 0-.576.887m.577-.887-.577.887m0 0-.633.848m.633-.848-.633.848m0 0-.685.805m.685-.805-.685.805m0 0-.736.76m.736-.76-.736.76m0 0-.783.71m.783-.71-.783.71m0 0-.827.66m.827-.66-.827.66m0 0-.868.605m.868-.605-.868.605m0 0-.904.549m.904-.549-.904.549m0 0-.938.489m.938-.49-.938.49m0 0-.967.428m.967-.428-.967.428m0 0-.993.365m.993-.365-.993.365m0 0-1.014.301m1.014-.3-1.014.3m0 0-1.03.236m1.03-.236-1.03.236m0 0-1.045.169m1.044-.17-1.044.17m0 0-1.053.101m1.053-.101-1.053.101m0 0-1.057.034m1.057-.034-1.057.034m0 0h-34.328m34.328 0h-34.328m0 0-1.057-.034m1.057.034-1.057-.034m0 0-1.053-.101m1.053.101-1.053-.101m0 0-1.044-.17m1.044.17-1.044-.17m0 0-1.031-.235m1.03.236-1.03-.236m0 0-1.014-.3m1.014.3-1.014-.3m0 0-.993-.366m.993.365-.993-.365m0 0-.967-.428m.967.428-.967-.428m0 0-.938-.49m.938.49c-.23-.12-.462-.24-.938-.49m0 0c-.352-.212-.703-.426-.904-.548m.904.549-.904-.549m0 0-.868-.605m.868.605-.868-.605m0 0-.827-.66m.827.66-.827-.66m0 0-.783-.71m.783.71-.783-.71m0 0-.736-.76m.736.76-.736-.76m0 0-.685-.805m.685.805-.685-.805m0 0-.633-.848m.633.848-.633-.848m0 0-.577-.887m.577.887-.577-.887m0 0-.519-.921m.52.921c-.199-.35-.396-.702-.52-.921m0 0-.459-.953m.459.953-.459-.953m0 0-.397-.98m.397.98-.397-.98m0 0-.333-1.004m.333 1.004-.333-1.004m0 0-.268-1.023m.268 1.023-.268-1.023m0 0-.203-1.039m.203 1.039-.203-1.039m0 0c-.03-.242-.062-.485-.135-1.049m.135 1.05-.135-1.05m0 0L-33.656.53m.068 1.055L-33.656.53m0 0V-.53m0 1.058V-.53m0 0 .068-1.055m-.068 1.055.068-1.055m0 0 .135-1.05m-.135 1.05.135-1.05m0 0 .203-1.038m-.203 1.039.203-1.039m0 0 .268-1.023m-.268 1.023.268-1.023m0 0 .333-1.004m-.333 1.004.333-1.004m0 0 .397-.98m-.397.98.397-.98m0 0 .459-.953m-.459.953.459-.953m0 0 .52-.921m-.52.921.52-.921m0 0 .576-.887m-.577.887.577-.887m0 0 .633-.848m-.633.848.633-.848m0 0 .685-.805m-.685.805.685-.805m0 0 .736-.76m-.736.76.736-.76m0 0 .783-.71m-.783.71c.297-.27.594-.54.783-.71m0 0 .827-.66m-.827.66.827-.66m0 0 .868-.605m-.868.605.868-.605m0 0 .904-.549m-.904.549.904-.549m0 0 .938-.489m-.938.49.938-.49m0 0 .967-.428m-.967.428.967-.428m0 0 .993-.365m-.993.365.993-.365m0 0 1.014-.301m-1.014.3 1.014-.3m0 0 1.03-.236m-1.03.236 1.03-.236m0 0 1.045-.169m-1.044.17 1.044-.17m0 0 1.053-.101m-1.053.101 1.053-.101m0 0 1.057-.034m-1.057.034 1.057-.034m0 0" style="fill:#008300!important;stroke:#005400!important" transform="translate(215.379 24.5)"/></g><g class="label" style="color:#fff!important" transform="translate(215.379 15.5)"><rect/><rect class="background" style="stroke:none"/><text y="-10.1" style="fill:#fff!important"><tspan x="0" y="-.1em" class="text-outer-tspan row" dy="1.1em"><tspan class="text-inner-tspan" font-style="normal" font-weight="normal">INICIO</tspan></tspan></text></g></g><g id="dia-s02_d6a_rombo_mudo-flowchart-D-1" class="node default" data-look="classic" transform="translate(215.379 171.688)"><polygon points="80.6875,0 161.375,-80.6875 80.6875,-161.375 0,-80.6875" class="label-container" style="fill:#eda100!important;stroke:#8a6d00!important" transform="translate(-80.188 80.688)"/><g class="label" style="color:#3a2a00!important" transform="translate(0 -9)"><rect/><rect class="background" style="stroke:none"/><text y="-10.1" style="fill:#3a2a00!important"><tspan x="0" y="-.1em" class="text-outer-tspan row" dy="1.1em"><tspan class="text-inner-tspan" font-style="normal" font-weight="normal">¿saldo</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> &gt;</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> pasaje?</tspan></tspan></text></g></g><g id="dia-s02_d6a_rombo_mudo-flowchart-P-2" class="node default" data-look="classic" transform="translate(89.844 364.875)"><rect width="163.688" height="48" x="-81.844" y="-24" class="basic label-container"/><g class="label" transform="translate(0 -9)"><rect/><rect class="background" style="stroke:none"/><text y="-10.1"><tspan x="0" y="-.1em" class="text-outer-tspan row" dy="1.1em"><tspan class="text-inner-tspan" font-style="normal" font-weight="normal">pagar</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> el</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> pasaje</tspan></tspan></text></g></g><g id="dia-s02_d6a_rombo_mudo-flowchart-F-3" class="node default" data-look="classic"><g class="basic label-container outer-path"><path fill="#008300" stroke="none" stroke-width="0" d="M-6.64-16.5H6.64l1.058.034 1.053.101 1.044.17 1.03.235 1.015.3.993.366.967.428.937.49.905.548.867.605c.315.25.63.502.827.66l.783.71.736.76.686.805.632.848.577.887.52.921.458.953.397.98.334 1.004.268 1.023.202 1.039.135 1.049.068 1.055V.53l-.068 1.055-.135 1.05-.202 1.038-.268 1.023-.334 1.004-.397.98-.458.953-.52.921-.577.887-.632.848-.686.805-.736.76-.783.71-.827.66-.867.605-.905.549-.937.489-.967.428-.993.365-1.014.301-1.031.236-1.044.169-1.053.101-1.057.034H-6.641l-1.057-.034-1.053-.101-1.044-.17-1.03-.235-1.015-.3-.993-.366-.967-.428c-.34-.177-.68-.354-.937-.49l-.905-.548-.867-.605-.827-.66c-.282-.255-.564-.51-.783-.71l-.736-.76-.686-.805-.632-.848-.577-.887-.52-.921-.458-.953-.397-.98-.334-1.004-.268-1.023-.202-1.039-.135-1.049-.068-1.055V-.53l.068-1.055.135-1.05.202-1.038c.07-.265.14-.53.268-1.023l.334-1.004.397-.98.458-.953.52-.921.577-.887.632-.848.686-.805.736-.76.783-.71.827-.66.867-.605.905-.549.937-.489.967-.428.993-.365 1.014-.301 1.031-.236c.255-.04.51-.082 1.044-.169l1.053-.101 1.057-.034" style="fill:#008300!important;stroke:#005400!important" transform="translate(89.844 471.875)"/><path fill="none" stroke="#005400" stroke-dasharray="0 0" stroke-width="1.3" d="M-6.64-16.5H6.64m-13.28 0H6.64m0 0 1.058.034M6.64-16.5l1.057.034m0 0 1.053.101m-1.053-.101 1.053.101m0 0 1.044.17m-1.044-.17 1.044.17m0 0 1.03.235m-1.03-.236 1.03.236m0 0 1.015.3m-1.014-.3 1.014.3m0 0 .993.366m-.993-.365.993.365m0 0 .967.428m-.967-.428.967.428m0 0 .937.49m-.937-.49.937.49m0 0 .905.548m-.905-.549.905.549m0 0 .867.605m-.867-.605.867.605m0 0 .827.66m-.827-.66.827.66m0 0 .783.71m-.783-.71.783.71m0 0 .736.76m-.736-.76.736.76m0 0 .686.805m-.686-.805.686.805m0 0 .632.848m-.632-.848.632.848m0 0 .577.887m-.577-.887.577.887m0 0 .52.921m-.52-.921.52.921m0 0 .458.953m-.458-.953.458.953m0 0 .397.98m-.397-.98.397.98m0 0 .334 1.004m-.334-1.004.334 1.004m0 0 .268 1.023m-.268-1.023.268 1.023m0 0 .202 1.039m-.202-1.039.202 1.039m0 0 .135 1.049m-.135-1.05.135 1.05m0 0 .068 1.055m-.068-1.055.068 1.055m0 0V.53m0-1.058V.53m0 0-.068 1.055M23.132.53l-.068 1.055m0 0-.135 1.05m.135-1.05-.135 1.05m0 0-.202 1.038m.202-1.039-.202 1.039m0 0-.268 1.023m.268-1.023-.268 1.023m0 0L22.125 5.7m.334-1.004L22.125 5.7m0 0-.397.98m.397-.98-.397.98m0 0-.458.953m.458-.953-.458.953m0 0-.52.921m.52-.921-.52.921m0 0c-.121.187-.242.374-.577.887m.577-.887-.577.887m0 0-.632.848m.632-.848-.632.848m0 0-.686.805m.686-.805-.686.805m0 0-.736.76m.736-.76-.736.76m0 0-.783.71m.783-.71-.783.71m0 0-.827.66m.827-.66-.827.66m0 0-.867.605m.867-.605c-.226.159-.453.317-.867.605m0 0-.905.549m.905-.549-.905.549m0 0-.937.489m.937-.49-.937.49m0 0-.967.428m.967-.428-.967.428m0 0-.993.365m.993-.365-.993.365m0 0c-.231.07-.463.138-1.014.301m1.014-.3-1.014.3m0 0-1.031.236m1.03-.236-1.03.236m0 0-1.044.169m1.044-.17c-.243.04-.485.08-1.044.17m0 0c-.215.02-.43.04-1.053.101m1.053-.101c-.22.02-.44.042-1.053.101m0 0L6.64 16.5m1.057-.034L6.64 16.5m0 0H-6.641m13.282 0H-6.641m0 0-1.057-.034m1.057.034-1.057-.034m0 0-1.053-.101m1.053.101-1.053-.101m0 0-1.044-.17m1.044.17-1.044-.17m0 0-1.03-.235m1.03.236-1.03-.236m0 0-1.015-.3m1.014.3-1.014-.3m0 0-.993-.366m.993.365-.993-.365m0 0-.967-.428m.967.428-.967-.428m0 0-.937-.49m.937.49-.937-.49m0 0-.905-.548m.905.549-.905-.549m0 0-.867-.605m.867.605-.867-.605m0 0c-.306-.243-.612-.487-.827-.66m.827.66c-.311-.247-.622-.495-.827-.66m0 0-.783-.71m.783.71-.783-.71m0 0-.736-.76m.736.76-.736-.76m0 0-.686-.805m.686.805-.686-.805m0 0-.632-.848m.632.848-.632-.848m0 0-.577-.887m.577.887-.577-.887m0 0-.52-.921m.52.921-.52-.921m0 0-.458-.953m.458.953-.458-.953m0 0-.397-.98m.397.98-.397-.98m0 0-.334-1.004m.334 1.004-.334-1.004m0 0-.268-1.023m.268 1.023c-.1-.386-.202-.77-.268-1.023m0 0-.202-1.039m.202 1.039-.202-1.039m0 0-.135-1.049m.135 1.05-.135-1.05m0 0L-23.132.53m.068 1.055L-23.132.53m0 0V-.53m0 1.058V-.53m0 0 .068-1.055m-.068 1.055.068-1.055m0 0 .135-1.05m-.135 1.05.135-1.05m0 0 .202-1.038m-.202 1.039.202-1.039m0 0 .268-1.023m-.268 1.023.268-1.023m0 0 .334-1.004m-.334 1.004.334-1.004m0 0 .397-.98m-.397.98.397-.98m0 0 .458-.953m-.458.953.458-.953m0 0 .52-.921m-.52.921.52-.921m0 0 .577-.887m-.577.887.577-.887m0 0 .632-.848m-.632.848.632-.848m0 0 .686-.805m-.686.805.686-.805m0 0 .736-.76m-.736.76.736-.76m0 0 .783-.71m-.783.71.783-.71m0 0 .827-.66m-.827.66c.29-.233.582-.465.827-.66m0 0 .867-.605m-.867.605.867-.605m0 0 .905-.549m-.905.549.905-.549m0 0 .937-.489m-.937.49.937-.49m0 0 .967-.428m-.967.428.967-.428m0 0 .993-.365m-.993.365.993-.365m0 0 1.014-.301m-1.014.3 1.014-.3m0 0 1.031-.236m-1.03.236 1.03-.236m0 0 1.044-.169m-1.044.17 1.044-.17m0 0 1.053-.101m-1.053.101 1.053-.101m0 0 1.057-.034m-1.057.034 1.057-.034m0 0" style="fill:#008300!important;stroke:#005400!important" transform="translate(89.844 471.875)"/></g><g class="label" style="color:#fff!important" transform="translate(89.844 462.875)"><rect/><rect class="background" style="stroke:none"/><text y="-10.1" style="fill:#fff!important"><tspan x="0" y="-.1em" class="text-outer-tspan row" dy="1.1em"><tspan class="text-inner-tspan" font-style="normal" font-weight="normal">FIN</tspan></tspan></text></g></g><g id="dia-s02_d6a_rombo_mudo-flowchart-X-8" class="node default" data-look="classic" transform="translate(340.914 364.875)"><rect width="238.453" height="81" x="-119.227" y="-40.5" class="basic label-container" style="fill:#ffe8e8!important;stroke:#d03b3b!important"/><g class="label" style="color:#d03b3b!important" transform="translate(0 -25.5)"><rect/><rect class="background" style="stroke:none"/><text y="-10.1" style="fill:#d03b3b!important"><tspan x="0" y="-.1em" class="text-outer-tspan row" dy="1.1em"><tspan class="text-inner-tspan" font-style="normal" font-weight="normal">¿Y</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> si</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> la</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> respuesta</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> es</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> NO?</tspan></tspan><tspan x="0" y="1em" class="text-outer-tspan row" dy="1.1em"><tspan class="text-inner-tspan" font-style="normal" font-weight="normal">Ese</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> camino</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> no</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> existe:</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> el</tspan></tspan><tspan x="0" y="2.1em" class="text-outer-tspan row" dy="1.1em"><tspan class="text-inner-tspan" font-style="normal" font-weight="normal">algoritmo</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> se</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> queda</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> mudo.</tspan></tspan></text></g></g></g></g><defs><filter id="dia-s02_d6a_rombo_mudo-drop-shadow" width="130%" height="130%"><feDropShadow dx="4" dy="4" flood-color="#000" flood-opacity=".06" stdDeviation="0"/></filter></defs><defs><filter id="dia-s02_d6a_rombo_mudo-drop-shadow-small" width="150%" height="150%"><feDropShadow dx="2" dy="2" flood-color="#000" flood-opacity=".06" stdDeviation="0"/></filter></defs><linearGradient id="dia-s02_d6a_rombo_mudo-gradient" x1="0%" x2="100%" y1="0%" y2="0%" gradientUnits="objectBoundingBox"><stop offset="0%" stop-color="hsl(0, 0%, 83.3333333333%)" stop-opacity="1"/><stop offset="100%" stop-color="hsl(0, 0%, 88.9215686275%)" stop-opacity="1"/></linearGradient></svg>', 'Del rombo sale una sola flecha: el algoritmo no dice qué hacer cuando la respuesta es No.')

# %%
# Diagrama: s02_d6b_caja_multiple
ava.figura('<svg xmlns="http://www.w3.org/2000/svg" id="dia-s02_d6b_caja_multiple" width="100%" aria-roledescription="flowchart-v2" class="flowchart" role="graphics-document document" style="max-width:287.834px;background-color:transparent" viewBox="0 0 287.834 246.5"><style>#dia-s02_d6b_caja_multiple{font-family:system-ui,-apple-system,&apos;Segoe UI&apos;,Roboto,sans-serif;font-size:15px;fill:#000000;}@keyframes edge-animation-frame{from{stroke-dashoffset:0;}}@keyframes dash{to{stroke-dashoffset:0;}}#dia-s02_d6b_caja_multiple .edge-animation-slow{stroke-dasharray:9,5!important;stroke-dashoffset:900;animation:dash 50s linear infinite;stroke-linecap:round;}#dia-s02_d6b_caja_multiple .edge-animation-fast{stroke-dasharray:9,5!important;stroke-dashoffset:900;animation:dash 20s linear infinite;stroke-linecap:round;}#dia-s02_d6b_caja_multiple .error-icon{fill:#552222;}#dia-s02_d6b_caja_multiple .error-text{fill:#552222;stroke:#552222;}#dia-s02_d6b_caja_multiple .edge-thickness-normal{stroke-width:1px;}#dia-s02_d6b_caja_multiple .edge-thickness-thick{stroke-width:3.5px;}#dia-s02_d6b_caja_multiple .edge-pattern-solid{stroke-dasharray:0;}#dia-s02_d6b_caja_multiple .edge-thickness-invisible{stroke-width:0;fill:none;}#dia-s02_d6b_caja_multiple .edge-pattern-dashed{stroke-dasharray:3;}#dia-s02_d6b_caja_multiple .edge-pattern-dotted{stroke-dasharray:2;}#dia-s02_d6b_caja_multiple .marker{fill:#52514e;stroke:#52514e;}#dia-s02_d6b_caja_multiple .marker.cross{stroke:#52514e;}#dia-s02_d6b_caja_multiple svg{font-family:system-ui,-apple-system,&apos;Segoe UI&apos;,Roboto,sans-serif;font-size:15px;}#dia-s02_d6b_caja_multiple p{margin:0;}#dia-s02_d6b_caja_multiple .label{font-family:system-ui,-apple-system,&apos;Segoe UI&apos;,Roboto,sans-serif;color:#000000;}#dia-s02_d6b_caja_multiple .cluster-label text{fill:#333;}#dia-s02_d6b_caja_multiple .cluster-label span{color:#333;}#dia-s02_d6b_caja_multiple .cluster-label span p{background-color:transparent;}#dia-s02_d6b_caja_multiple .label text,#dia-s02_d6b_caja_multiple span{fill:#000000;color:#000000;}#dia-s02_d6b_caja_multiple .node rect,#dia-s02_d6b_caja_multiple .node circle,#dia-s02_d6b_caja_multiple .node ellipse,#dia-s02_d6b_caja_multiple .node polygon,#dia-s02_d6b_caja_multiple .node path{fill:#eee;stroke:#999;stroke-width:1px;}#dia-s02_d6b_caja_multiple .rough-node .label text,#dia-s02_d6b_caja_multiple .node .label text,#dia-s02_d6b_caja_multiple .image-shape .label,#dia-s02_d6b_caja_multiple .icon-shape .label{text-anchor:middle;}#dia-s02_d6b_caja_multiple .node .katex path{fill:#000;stroke:#000;stroke-width:1px;}#dia-s02_d6b_caja_multiple .rough-node .label,#dia-s02_d6b_caja_multiple .node .label,#dia-s02_d6b_caja_multiple .image-shape .label,#dia-s02_d6b_caja_multiple .icon-shape .label{text-align:center;}#dia-s02_d6b_caja_multiple .node.clickable{cursor:pointer;}#dia-s02_d6b_caja_multiple .root .anchor path{fill:#52514e!important;stroke-width:0;stroke:#52514e;}#dia-s02_d6b_caja_multiple .arrowheadPath{fill:#333333;}#dia-s02_d6b_caja_multiple .edgePath .path{stroke:#52514e;stroke-width:1px;}#dia-s02_d6b_caja_multiple .flowchart-link{stroke:#52514e;fill:none;}#dia-s02_d6b_caja_multiple .edgeLabel{background-color:white;text-align:center;}#dia-s02_d6b_caja_multiple .edgeLabel p{background-color:white;}#dia-s02_d6b_caja_multiple .edgeLabel rect{opacity:0.5;background-color:white;fill:white;}#dia-s02_d6b_caja_multiple .labelBkg{background-color:rgba(255, 255, 255, 0.5);}#dia-s02_d6b_caja_multiple .cluster rect{fill:hsl(0, 0%, 98.9215686275%);stroke:#707070;stroke-width:1px;}#dia-s02_d6b_caja_multiple .cluster text{fill:#333;}#dia-s02_d6b_caja_multiple .cluster span{color:#333;}#dia-s02_d6b_caja_multiple div.mermaidTooltip{position:absolute;text-align:center;max-width:200px;padding:2px;font-family:system-ui,-apple-system,&apos;Segoe UI&apos;,Roboto,sans-serif;font-size:12px;background:#fdf6e3;border:1px solid #707070;border-radius:2px;pointer-events:none;z-index:100;}#dia-s02_d6b_caja_multiple .flowchartTitleText{text-anchor:middle;font-size:18px;fill:#000000;}#dia-s02_d6b_caja_multiple rect.text{fill:none;stroke-width:0;}#dia-s02_d6b_caja_multiple .icon-shape,#dia-s02_d6b_caja_multiple .image-shape{background-color:white;text-align:center;}#dia-s02_d6b_caja_multiple .icon-shape p,#dia-s02_d6b_caja_multiple .image-shape p{background-color:white;padding:2px;}#dia-s02_d6b_caja_multiple .icon-shape .label rect,#dia-s02_d6b_caja_multiple .image-shape .label rect{opacity:0.5;background-color:white;fill:white;}#dia-s02_d6b_caja_multiple .label-icon{display:inline-block;height:1em;overflow:visible;vertical-align:-0.125em;}#dia-s02_d6b_caja_multiple .node .label-icon path{fill:currentColor;stroke:revert;stroke-width:revert;}#dia-s02_d6b_caja_multiple .node .neo-node{stroke:#999;}#dia-s02_d6b_caja_multiple [data-look=&quot;neo&quot;].node rect,#dia-s02_d6b_caja_multiple [data-look=&quot;neo&quot;].cluster rect,#dia-s02_d6b_caja_multiple [data-look=&quot;neo&quot;].node polygon{stroke:url(#dia-s02_d6b_caja_multiple-gradient);filter:drop-shadow( 1px 2px 2px rgba(185,185,185,1));}#dia-s02_d6b_caja_multiple [data-look=&quot;neo&quot;].swimlane.cluster rect{filter:none;}#dia-s02_d6b_caja_multiple [data-look=&quot;neo&quot;].node path{stroke:url(#dia-s02_d6b_caja_multiple-gradient);stroke-width:1px;}#dia-s02_d6b_caja_multiple [data-look=&quot;neo&quot;].node .outer-path{filter:drop-shadow( 1px 2px 2px rgba(185,185,185,1));}#dia-s02_d6b_caja_multiple [data-look=&quot;neo&quot;].node .neo-line path{stroke:#999;filter:none;}#dia-s02_d6b_caja_multiple [data-look=&quot;neo&quot;].node circle{stroke:url(#dia-s02_d6b_caja_multiple-gradient);filter:drop-shadow( 1px 2px 2px rgba(185,185,185,1));}#dia-s02_d6b_caja_multiple [data-look=&quot;neo&quot;].node circle .state-start{fill:#000000;}#dia-s02_d6b_caja_multiple [data-look=&quot;neo&quot;].icon-shape .icon{fill:url(#dia-s02_d6b_caja_multiple-gradient);filter:drop-shadow( 1px 2px 2px rgba(185,185,185,1));}#dia-s02_d6b_caja_multiple [data-look=&quot;neo&quot;].icon-shape .icon-neo path{stroke:url(#dia-s02_d6b_caja_multiple-gradient);filter:drop-shadow( 1px 2px 2px rgba(185,185,185,1));}#dia-s02_d6b_caja_multiple :root{--mermaid-font-family:&quot;trebuchet ms&quot;,verdana,arial,sans-serif;}</style><marker id="dia-s02_d6b_caja_multiple_flowchart-v2-pointEnd" class="marker flowchart-v2" markerHeight="8" markerUnits="userSpaceOnUse" markerWidth="8" orient="auto" refX="5" refY="5" viewBox="0 0 10 10"><path d="m0 0 10 5-10 5z" class="arrowMarkerPath" style="stroke-width:1;stroke-dasharray:1,0"/></marker><marker id="dia-s02_d6b_caja_multiple_flowchart-v2-pointStart" class="marker flowchart-v2" markerHeight="8" markerUnits="userSpaceOnUse" markerWidth="8" orient="auto" refX="4.5" refY="5" viewBox="0 0 10 10"><path d="m0 5 10 5V0z" class="arrowMarkerPath" style="stroke-width:1;stroke-dasharray:1,0"/></marker><marker id="dia-s02_d6b_caja_multiple_flowchart-v2-pointEnd-margin" class="marker flowchart-v2" markerHeight="14" markerUnits="userSpaceOnUse" markerWidth="10.5" orient="auto" refX="11.5" refY="7" viewBox="0 0 11.5 14"><path d="m0 0 11.5 7L0 14z" class="arrowMarkerPath" style="stroke-width:0;stroke-dasharray:1,0"/></marker><marker id="dia-s02_d6b_caja_multiple_flowchart-v2-pointStart-margin" class="marker flowchart-v2" markerHeight="14" markerUnits="userSpaceOnUse" markerWidth="11.5" orient="auto" refX="1" refY="7" viewBox="0 0 11.5 14"><polygon points="0,7 11.5,14 11.5,0" class="arrowMarkerPath" style="stroke-width:0;stroke-dasharray:1,0"/></marker><marker id="dia-s02_d6b_caja_multiple_flowchart-v2-circleEnd" class="marker flowchart-v2" markerHeight="11" markerUnits="userSpaceOnUse" markerWidth="11" orient="auto" refX="11" refY="5" viewBox="0 0 10 10"><circle cx="5" cy="5" r="5" class="arrowMarkerPath" style="stroke-width:1;stroke-dasharray:1,0"/></marker><marker id="dia-s02_d6b_caja_multiple_flowchart-v2-circleStart" class="marker flowchart-v2" markerHeight="11" markerUnits="userSpaceOnUse" markerWidth="11" orient="auto" refX="-1" refY="5" viewBox="0 0 10 10"><circle cx="5" cy="5" r="5" class="arrowMarkerPath" style="stroke-width:1;stroke-dasharray:1,0"/></marker><marker id="dia-s02_d6b_caja_multiple_flowchart-v2-circleEnd-margin" class="marker flowchart-v2" markerHeight="14" markerUnits="userSpaceOnUse" markerWidth="14" orient="auto" refX="12.25" refY="5" viewBox="0 0 10 10"><circle cx="5" cy="5" r="5" class="arrowMarkerPath" style="stroke-width:0;stroke-dasharray:1,0"/></marker><marker id="dia-s02_d6b_caja_multiple_flowchart-v2-circleStart-margin" class="marker flowchart-v2" markerHeight="14" markerUnits="userSpaceOnUse" markerWidth="14" orient="auto" refX="-2" refY="5" viewBox="0 0 10 10"><circle cx="5" cy="5" r="5" class="arrowMarkerPath" style="stroke-width:0;stroke-dasharray:1,0"/></marker><marker id="dia-s02_d6b_caja_multiple_flowchart-v2-crossEnd" class="marker cross flowchart-v2" markerHeight="11" markerUnits="userSpaceOnUse" markerWidth="11" orient="auto" refX="12" refY="5.2" viewBox="0 0 11 11"><path d="m1 1 9 9m0-9-9 9" class="arrowMarkerPath" style="stroke-width:2;stroke-dasharray:1,0"/></marker><marker id="dia-s02_d6b_caja_multiple_flowchart-v2-crossStart" class="marker cross flowchart-v2" markerHeight="11" markerUnits="userSpaceOnUse" markerWidth="11" orient="auto" refX="-1" refY="5.2" viewBox="0 0 11 11"><path d="m1 1 9 9m0-9-9 9" class="arrowMarkerPath" style="stroke-width:2;stroke-dasharray:1,0"/></marker><marker id="dia-s02_d6b_caja_multiple_flowchart-v2-crossEnd-margin" class="marker cross flowchart-v2" markerHeight="12" markerUnits="userSpaceOnUse" markerWidth="12" orient="auto" refX="17.7" refY="7.5" viewBox="0 0 15 15"><path d="m1 1 13 13M1 14 14 1" class="arrowMarkerPath" style="stroke-width:2.5"/></marker><marker id="dia-s02_d6b_caja_multiple_flowchart-v2-crossStart-margin" class="marker cross flowchart-v2" markerHeight="12" markerUnits="userSpaceOnUse" markerWidth="12" orient="auto" refX="-3.5" refY="7.5" viewBox="0 0 15 15"><path d="m1 1 13 13M1 14 14 1" class="arrowMarkerPath" style="stroke-width:2.5;stroke-dasharray:1,0"/></marker><g class="root"><g class="edgePaths"><path id="dia-s02_d6b_caja_multiple-L_I_P_0" marker-end="url(#dia-s02_d6b_caja_multiple_flowchart-v2-pointEnd)" d="m137.602 41.5-.084 4.083c-.083 4.084-.25 12.25-.333 19.834S137.102 80 137.102 83.5V87" class="edge-thickness-normal edge-pattern-solid edge-thickness-normal edge-pattern-solid flowchart-link" data-edge="true" data-et="edge" data-id="L_I_P_0" data-look="classic" data-points="W3sieCI6MTM3LjYwMTU2MjUsInkiOjQxLjV9LHsieCI6MTM3LjEwMTU2MjUsInkiOjY2fSx7IngiOjEzNy4xMDE1NjI1LCJ5Ijo5MX1d"/><path id="dia-s02_d6b_caja_multiple-L_P_F_0" marker-end="url(#dia-s02_d6b_caja_multiple_flowchart-v2-pointEnd)" d="M137.102 155.5v4.167c0 4.166 0 12.5.07 20.25s.211 14.917.281 18.5l.07 3.584" class="edge-thickness-normal edge-pattern-solid edge-thickness-normal edge-pattern-solid flowchart-link" data-edge="true" data-et="edge" data-id="L_P_F_0" data-look="classic" data-points="W3sieCI6MTM3LjEwMTU2MjUsInkiOjE1NS41fSx7IngiOjEzNy4xMDE1NjI1LCJ5IjoxODAuNX0seyJ4IjoxMzcuNjAxNTYyNSwieSI6MjA2fV0="/></g><g class="edgeLabels"><rect class="background" style="stroke:none"/><rect class="background" style="stroke:none"/></g><g class="nodes"><g id="dia-s02_d6b_caja_multiple-flowchart-I-0" class="node default" data-look="classic"><g class="basic label-container outer-path"><path fill="#008300" stroke="none" stroke-width="0" d="M-17.164-16.5h34.328l1.057.034 1.053.101c.372.06.745.12 1.044.17l1.031.235 1.014.3.993.366.967.428.938.49.904.548.868.605.827.66.783.71.736.76.685.805.633.848.577.887.519.921.459.953.397.98.333 1.004.268 1.023.203 1.039.135 1.049.068 1.055V.53l-.068 1.055-.135 1.05-.203 1.038-.268 1.023-.333 1.004-.397.98-.459.953-.52.921-.576.887-.633.848-.685.805-.736.76-.783.71-.827.66-.868.605-.904.549-.938.489-.967.428-.993.365-1.014.301-1.03.236c-.375.06-.75.12-1.045.169l-1.053.101-1.057.034h-34.328l-1.057-.034-1.053-.101-1.044-.17-1.031-.235-1.014-.3-.993-.366-.967-.428-.938-.49-.904-.548c-.24-.166-.478-.333-.868-.605l-.827-.66-.783-.71-.736-.76-.685-.805-.633-.848-.577-.887-.519-.921-.459-.953-.397-.98-.333-1.004-.268-1.023-.203-1.039-.135-1.049-.068-1.055V-.53l.068-1.055.135-1.05.203-1.038.268-1.023.333-1.004.397-.98.459-.953.52-.921.576-.887.633-.848.685-.805.736-.76.783-.71.827-.66.868-.605.904-.549.938-.489.967-.428.993-.365 1.014-.301 1.03-.236 1.045-.169 1.053-.101 1.057-.034" style="fill:#008300!important;stroke:#005400!important" transform="translate(137.102 24.5)"/><path fill="none" stroke="#005400" stroke-dasharray="0 0" stroke-width="1.3" d="M-17.164-16.5h34.328m-34.328 0h34.328m0 0 1.057.034m-1.057-.034 1.057.034m0 0 1.053.101m-1.053-.101 1.053.101m0 0 1.044.17m-1.044-.17 1.044.17m0 0 1.031.235m-1.03-.236 1.03.236m0 0 1.014.3m-1.014-.3 1.014.3m0 0 .993.366m-.993-.365.993.365m0 0 .967.428m-.967-.428.967.428m0 0 .938.49m-.938-.49.938.49m0 0 .904.548m-.904-.549.904.549m0 0 .868.605m-.868-.605.868.605m0 0 .827.66m-.827-.66.827.66m0 0 .783.71m-.783-.71.783.71m0 0 .736.76m-.736-.76.736.76m0 0 .685.805m-.685-.805.685.805m0 0 .633.848m-.633-.848.633.848m0 0 .577.887m-.577-.887.577.887m0 0 .519.921m-.52-.921.52.921m0 0 .459.953m-.459-.953.459.953m0 0 .397.98m-.397-.98.397.98m0 0 .333 1.004m-.333-1.004.333 1.004m0 0 .268 1.023m-.268-1.023.268 1.023m0 0 .203 1.039m-.203-1.039.203 1.039m0 0 .135 1.049m-.135-1.05.135 1.05m0 0 .068 1.055m-.068-1.055.068 1.055m0 0V.53m0-1.058V.53m0 0-.068 1.055M33.656.53l-.068 1.055m0 0-.135 1.05m.135-1.05-.135 1.05m0 0-.203 1.038m.203-1.039-.203 1.039m0 0-.268 1.023m.268-1.023-.268 1.023m0 0L32.649 5.7m.333-1.004L32.649 5.7m0 0-.397.98m.397-.98-.397.98m0 0-.459.953m.459-.953-.459.953m0 0-.52.921m.52-.921c-.18.321-.362.642-.52.921m0 0c-.163.253-.327.505-.576.887m.577-.887-.577.887m0 0-.633.848m.633-.848-.633.848m0 0-.685.805m.685-.805-.685.805m0 0-.736.76m.736-.76-.736.76m0 0-.783.71m.783-.71-.783.71m0 0-.827.66m.827-.66-.827.66m0 0-.868.605m.868-.605-.868.605m0 0-.904.549m.904-.549-.904.549m0 0-.938.489m.938-.49-.938.49m0 0-.967.428m.967-.428-.967.428m0 0-.993.365m.993-.365-.993.365m0 0-1.014.301m1.014-.3-1.014.3m0 0-1.03.236m1.03-.236-1.03.236m0 0-1.045.169m1.044-.17-1.044.17m0 0-1.053.101m1.053-.101-1.053.101m0 0-1.057.034m1.057-.034-1.057.034m0 0h-34.328m34.328 0h-34.328m0 0-1.057-.034m1.057.034-1.057-.034m0 0-1.053-.101m1.053.101-1.053-.101m0 0-1.044-.17m1.044.17-1.044-.17m0 0-1.031-.235m1.03.236-1.03-.236m0 0-1.014-.3m1.014.3-1.014-.3m0 0-.993-.366m.993.365-.993-.365m0 0-.967-.428m.967.428-.967-.428m0 0-.938-.49m.938.49-.938-.49m0 0-.904-.548m.904.549-.904-.549m0 0-.868-.605m.868.605-.868-.605m0 0-.827-.66m.827.66-.827-.66m0 0-.783-.71m.783.71-.783-.71m0 0-.736-.76m.736.76-.736-.76m0 0-.685-.805m.685.805-.685-.805m0 0-.633-.848m.633.848-.633-.848m0 0-.577-.887m.577.887-.577-.887m0 0-.519-.921m.52.921-.52-.921m0 0-.459-.953m.459.953-.459-.953m0 0-.397-.98m.397.98-.397-.98m0 0-.333-1.004m.333 1.004-.333-1.004m0 0-.268-1.023m.268 1.023-.268-1.023m0 0-.203-1.039m.203 1.039-.203-1.039m0 0-.135-1.049m.135 1.05-.135-1.05m0 0L-33.656.53m.068 1.055L-33.656.53m0 0V-.53m0 1.058V-.53m0 0 .068-1.055m-.068 1.055.068-1.055m0 0 .135-1.05m-.135 1.05c.04-.307.08-.613.135-1.05m0 0 .203-1.038m-.203 1.039.203-1.039m0 0 .268-1.023m-.268 1.023.268-1.023m0 0 .333-1.004m-.333 1.004.333-1.004m0 0 .397-.98m-.397.98.397-.98m0 0 .459-.953m-.459.953.459-.953m0 0 .52-.921m-.52.921.52-.921m0 0 .576-.887m-.577.887.577-.887m0 0 .633-.848m-.633.848.633-.848m0 0 .685-.805m-.685.805.685-.805m0 0 .736-.76m-.736.76.736-.76m0 0 .783-.71m-.783.71.783-.71m0 0 .827-.66m-.827.66c.324-.26.648-.518.827-.66m0 0c.342-.24.685-.478.868-.605m-.868.605.868-.605m0 0 .904-.549m-.904.549.904-.549m0 0 .938-.489m-.938.49c.229-.12.457-.24.938-.49m0 0 .967-.428m-.967.428.967-.428m0 0 .993-.365m-.993.365.993-.365m0 0c.318-.095.636-.19 1.014-.301m-1.014.3 1.014-.3m0 0 1.03-.236m-1.03.236 1.03-.236m0 0 1.045-.169m-1.044.17 1.044-.17m0 0 1.053-.101m-1.053.101 1.053-.101m0 0 1.057-.034m-1.057.034 1.057-.034m0 0" style="fill:#008300!important;stroke:#005400!important" transform="translate(137.102 24.5)"/></g><g class="label" style="color:#fff!important" transform="translate(137.102 15.5)"><rect/><rect class="background" style="stroke:none"/><text y="-10.1" style="fill:#fff!important"><tspan x="0" y="-.1em" class="text-outer-tspan row" dy="1.1em"><tspan class="text-inner-tspan" font-style="normal" font-weight="normal">INICIO</tspan></tspan></text></g></g><g id="dia-s02_d6b_caja_multiple-flowchart-P-1" class="node default" data-look="classic" transform="translate(137.102 123.25)"><rect width="258.203" height="64.5" x="-129.102" y="-32.25" class="basic label-container" style="fill:#ffe8e8!important;stroke:#d03b3b!important"/><g class="label" style="color:#8a0000!important" transform="translate(0 -17.25)"><rect/><rect class="background" style="stroke:none"/><text y="-10.1" style="fill:#8a0000!important"><tspan x="0" y="-.1em" class="text-outer-tspan row" dy="1.1em"><tspan class="text-inner-tspan" font-style="normal" font-weight="normal">leer</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> copias,</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> calcular</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> el</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> total,</tspan></tspan><tspan x="0" y="1em" class="text-outer-tspan row" dy="1.1em"><tspan class="text-inner-tspan" font-style="normal" font-weight="normal">imprimir</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> el</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> total</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> y</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> despedirse</tspan></tspan></text></g></g><g id="dia-s02_d6b_caja_multiple-flowchart-F-2" class="node default" data-look="classic"><g class="basic label-container outer-path"><path fill="#008300" stroke="none" stroke-width="0" d="M-6.64-16.5H6.64l1.058.034 1.053.101 1.044.17 1.03.235 1.015.3.993.366.967.428.937.49.905.548.867.605.827.66.783.71.736.76.686.805.632.848.577.887.52.921.458.953.397.98.334 1.004.268 1.023.202 1.039.135 1.049.068 1.055V.53c-.02.327-.042.655-.068 1.055-.05.397-.102.793-.135 1.05l-.202 1.038-.268 1.023-.334 1.004-.397.98-.458.953-.52.921-.577.887-.632.848-.686.805-.736.76-.783.71-.827.66-.867.605c-.212.13-.425.258-.905.549l-.937.489-.967.428c-.216.08-.432.16-.993.365l-1.014.301-1.031.236-1.044.169-1.053.101-1.057.034H-6.641l-1.057-.034-1.053-.101-1.044-.17-1.03-.235-1.015-.3-.993-.366-.967-.428-.937-.49-.905-.548-.867-.605-.827-.66-.783-.71-.736-.76-.686-.805-.632-.848-.577-.887-.52-.921-.458-.953-.397-.98-.334-1.004-.268-1.023-.202-1.039-.135-1.049-.068-1.055V-.53l.068-1.055.135-1.05.202-1.038.268-1.023.334-1.004.397-.98.458-.953.52-.921.577-.887.632-.848.686-.805.736-.76.783-.71.827-.66.867-.605.905-.549.937-.489.967-.428.993-.365 1.014-.301 1.031-.236 1.044-.169 1.053-.101 1.057-.034" style="fill:#008300!important;stroke:#005400!important" transform="translate(137.102 222)"/><path fill="none" stroke="#005400" stroke-dasharray="0 0" stroke-width="1.3" d="M-6.64-16.5H6.64m-13.28 0H6.64m0 0 1.058.034M6.64-16.5l1.057.034m0 0 1.053.101m-1.053-.101 1.053.101m0 0 1.044.17m-1.044-.17 1.044.17m0 0c.277.062.553.126 1.03.235m-1.03-.236 1.03.236m0 0 1.015.3m-1.014-.3 1.014.3m0 0c.268.1.535.198.993.366m-.993-.365.993.365m0 0 .967.428m-.967-.428.967.428m0 0 .937.49m-.937-.49.937.49m0 0 .905.548m-.905-.549.905.549m0 0 .867.605m-.867-.605.867.605m0 0c.29.23.58.462.827.66m-.827-.66.827.66m0 0c.243.22.487.44.783.71m-.783-.71c.285.257.569.516.783.71m0 0 .736.76m-.736-.76.736.76m0 0 .686.805m-.686-.805.686.805m0 0 .632.848m-.632-.848.632.848m0 0 .577.887m-.577-.887c.225.344.449.689.577.887m0 0 .52.921m-.52-.921.52.921m0 0 .458.953m-.458-.953.458.953m0 0 .397.98m-.397-.98.397.98m0 0 .334 1.004m-.334-1.004.334 1.004m0 0 .268 1.023m-.268-1.023.268 1.023m0 0 .202 1.039m-.202-1.039.202 1.039m0 0 .135 1.049m-.135-1.05.135 1.05m0 0 .068 1.055m-.068-1.055c.015.224.03.448.068 1.055m0 0V.53m0-1.058V.53m0 0-.068 1.055M23.132.53l-.068 1.055m0 0-.135 1.05m.135-1.05-.135 1.05m0 0-.202 1.038m.202-1.039-.202 1.039m0 0-.268 1.023m.268-1.023-.268 1.023m0 0L22.125 5.7m.334-1.004L22.125 5.7m0 0-.397.98m.397-.98-.397.98m0 0-.458.953m.458-.953-.458.953m0 0-.52.921m.52-.921-.52.921m0 0-.577.887m.577-.887-.577.887m0 0-.632.848m.632-.848c-.14.19-.282.379-.632.848m0 0-.686.805m.686-.805-.686.805m0 0-.736.76m.736-.76-.736.76m0 0-.783.71m.783-.71-.783.71m0 0-.827.66m.827-.66-.827.66m0 0-.867.605m.867-.605-.867.605m0 0-.905.549m.905-.549-.905.549m0 0-.937.489m.937-.49-.937.49m0 0-.967.428m.967-.428-.967.428m0 0-.993.365m.993-.365-.993.365m0 0-1.014.301m1.014-.3-1.014.3m0 0-1.031.236m1.03-.236-1.03.236m0 0-1.044.169m1.044-.17-1.044.17m0 0-1.053.101m1.053-.101-1.053.101m0 0L6.64 16.5m1.057-.034L6.64 16.5m0 0H-6.641m13.282 0H-6.641m0 0-1.057-.034m1.057.034-1.057-.034m0 0-1.053-.101m1.053.101-1.053-.101m0 0-1.044-.17m1.044.17-1.044-.17m0 0-1.03-.235m1.03.236-1.03-.236m0 0-1.015-.3m1.014.3-1.014-.3m0 0-.993-.366m.993.365-.993-.365m0 0-.967-.428m.967.428-.967-.428m0 0-.937-.49m.937.49-.937-.49m0 0-.905-.548m.905.549-.905-.549m0 0-.867-.605m.867.605-.867-.605m0 0c-.214-.17-.428-.34-.827-.66m.827.66-.827-.66m0 0-.783-.71m.783.71c-.293-.265-.586-.53-.783-.71m0 0-.736-.76m.736.76-.736-.76m0 0-.686-.805m.686.805-.686-.805m0 0-.632-.848m.632.848-.632-.848m0 0-.577-.887m.577.887-.577-.887m0 0-.52-.921m.52.921-.52-.921m0 0-.458-.953m.458.953-.458-.953m0 0-.397-.98m.397.98-.397-.98m0 0-.334-1.004m.334 1.004-.334-1.004m0 0-.268-1.023m.268 1.023-.268-1.023m0 0-.202-1.039m.202 1.039-.202-1.039m0 0-.135-1.049m.135 1.05-.135-1.05m0 0L-23.132.53m.068 1.055L-23.132.53m0 0V-.53m0 1.058V-.53m0 0 .068-1.055m-.068 1.055.068-1.055m0 0 .135-1.05m-.135 1.05.135-1.05m0 0 .202-1.038m-.202 1.039.202-1.039m0 0 .268-1.023m-.268 1.023.268-1.023m0 0 .334-1.004m-.334 1.004.334-1.004m0 0 .397-.98m-.397.98.397-.98m0 0 .458-.953m-.458.953.458-.953m0 0 .52-.921m-.52.921.52-.921m0 0 .577-.887m-.577.887.577-.887m0 0 .632-.848m-.632.848.632-.848m0 0 .686-.805m-.686.805.686-.805m0 0 .736-.76m-.736.76.736-.76m0 0 .783-.71m-.783.71.783-.71m0 0 .827-.66m-.827.66.827-.66m0 0 .867-.605m-.867.605.867-.605m0 0 .905-.549m-.905.549.905-.549m0 0 .937-.489m-.937.49c.34-.179.681-.356.937-.49m0 0 .967-.428m-.967.428.967-.428m0 0 .993-.365m-.993.365.993-.365m0 0 1.014-.301m-1.014.3 1.014-.3m0 0 1.031-.236m-1.03.236 1.03-.236m0 0 1.044-.169m-1.044.17 1.044-.17m0 0 1.053-.101m-1.053.101 1.053-.101m0 0 1.057-.034m-1.057.034 1.057-.034m0 0" style="fill:#008300!important;stroke:#005400!important" transform="translate(137.102 222)"/></g><g class="label" style="color:#fff!important" transform="translate(137.102 213)"><rect/><rect class="background" style="stroke:none"/><text y="-10.1" style="fill:#fff!important"><tspan x="0" y="-.1em" class="text-outer-tspan row" dy="1.1em"><tspan class="text-inner-tspan" font-style="normal" font-weight="normal">FIN</tspan></tspan></text></g></g><g id="dia-s02_d6b_caja_multiple-flowchart-G-3" class="node default" data-look="classic"><g class="basic label-container outer-path"><path fill="#ffe8e8" stroke="none" stroke-width="0" d="M-13.047-16.5h26.094l1.057.034 1.053.101 1.044.17 1.031.235 1.014.3.993.366.967.428c.288.15.577.3.938.49l.904.548c.26.18.519.361.868.605l.827.66.783.71.735.76.686.805.633.848.577.887.519.921.459.953.397.98.333 1.004.268 1.023.202 1.039.136 1.049.067 1.055V.53l-.067 1.055-.136 1.05-.202 1.038-.268 1.023-.333 1.004c-.1.244-.198.488-.397.98l-.46.953-.518.921-.577.887-.633.848-.686.805-.735.76-.783.71-.827.66-.868.605-.904.549-.938.489-.967.428-.993.365c-.35.105-.701.209-1.014.301l-1.031.236c-.316.05-.631.102-1.044.169l-1.053.101-1.057.034h-26.094l-1.057-.034-1.053-.101-1.044-.17c-.369-.083-.737-.168-1.031-.235l-1.014-.3-.993-.366-.967-.428c-.307-.16-.615-.32-.938-.49l-.904-.548-.868-.605-.827-.66-.783-.71-.735-.76-.686-.805-.633-.848-.577-.887-.519-.921-.459-.953-.397-.98-.333-1.004-.268-1.023-.202-1.039-.136-1.049-.067-1.055V-.53l.067-1.055.136-1.05.202-1.038.268-1.023.333-1.004.397-.98.46-.953.518-.921.577-.887.633-.848.686-.805.735-.76.783-.71.827-.66.868-.605.904-.549.938-.489.967-.428.993-.365 1.014-.301 1.031-.236 1.044-.169 1.053-.101 1.057-.034" style="fill:#ffe8e8!important;stroke:#d03b3b!important" transform="translate(250.296 24.5)"/><path fill="none" stroke="#d03b3b" stroke-dasharray="0 0" stroke-width="1.3" d="M-13.047-16.5h26.094m-26.094 0h26.094m0 0 1.057.034m-1.057-.034 1.057.034m0 0 1.053.101m-1.053-.101 1.053.101m0 0 1.044.17m-1.044-.17 1.044.17m0 0 1.031.235m-1.031-.236 1.031.236m0 0 1.014.3m-1.014-.3 1.014.3m0 0 .993.366m-.993-.365.993.365m0 0 .967.428m-.967-.428.967.428m0 0 .938.49m-.938-.49.938.49m0 0 .904.548m-.904-.549.904.549m0 0 .868.605m-.868-.605.868.605m0 0 .827.66m-.827-.66c.265.21.53.422.827.66m0 0 .783.71m-.783-.71.783.71m0 0 .735.76m-.735-.76.735.76m0 0 .686.805m-.686-.805.686.805m0 0 .633.848m-.633-.848.633.848m0 0 .577.887m-.577-.887.577.887m0 0 .519.921m-.52-.921.52.921m0 0 .459.953m-.46-.953.46.953m0 0 .397.98m-.397-.98c.116.286.231.573.397.98m0 0 .333 1.004m-.333-1.004.333 1.004m0 0 .268 1.023m-.268-1.023.268 1.023m0 0 .202 1.039m-.202-1.039.202 1.039m0 0 .136 1.049m-.136-1.05.136 1.05m0 0 .067 1.055m-.067-1.055.067 1.055m0 0V.53m0-1.058V.53m0 0-.067 1.055M29.538.53l-.067 1.055m0 0-.136 1.05m.136-1.05-.136 1.05m0 0-.202 1.038m.202-1.039-.202 1.039m0 0-.268 1.023m.268-1.023-.268 1.023m0 0L28.532 5.7m.333-1.004L28.532 5.7m0 0c-.09.22-.18.441-.397.98m.397-.98-.397.98m0 0-.46.953m.46-.953-.46.953m0 0q-.261.467-.518.921m.519-.921-.52.921m0 0-.576.887m.577-.887-.577.887m0 0-.633.848m.633-.848-.633.848m0 0-.686.805m.686-.805-.686.805m0 0-.735.76m.735-.76-.735.76m0 0-.783.71m.783-.71-.783.71m0 0-.827.66m.827-.66c-.18.145-.36.288-.827.66m0 0-.868.605m.868-.605c-.226.157-.45.315-.868.605m0 0-.904.549m.904-.549-.904.549m0 0-.938.489m.938-.49c-.208.11-.416.217-.938.49m0 0-.967.428m.967-.428-.967.428m0 0-.993.365m.993-.365-.993.365m0 0-1.014.301m1.014-.3-1.014.3m0 0-1.031.236m1.031-.236-1.031.236m0 0-1.044.169m1.044-.17-1.044.17m0 0-1.053.101m1.053-.101-1.053.101m0 0-1.057.034m1.057-.034-1.057.034m0 0h-26.094m26.094 0h-26.094m0 0-1.057-.034m1.057.034-1.057-.034m0 0-1.053-.101m1.053.101-1.053-.101m0 0-1.044-.17m1.044.17-1.044-.17m0 0-1.031-.235m1.031.236-1.031-.236m0 0-1.014-.3m1.014.3-1.014-.3m0 0-.993-.366m.993.365-.993-.365m0 0-.967-.428m.967.428-.967-.428m0 0-.938-.49m.938.49-.938-.49m0 0-.904-.548m.904.549-.904-.549m0 0-.868-.605m.868.605-.868-.605m0 0-.827-.66m.827.66-.827-.66m0 0-.783-.71m.783.71-.783-.71m0 0-.735-.76m.735.76-.735-.76m0 0-.686-.805m.686.805-.686-.805m0 0-.633-.848m.633.848-.633-.848m0 0-.577-.887m.577.887-.577-.887m0 0-.519-.921m.52.921c-.113-.198-.225-.397-.52-.921m0 0-.459-.953m.46.953-.46-.953m0 0-.397-.98m.397.98-.397-.98m0 0-.333-1.004m.333 1.004-.333-1.004m0 0-.268-1.023m.268 1.023-.268-1.023m0 0-.202-1.039m.202 1.039-.202-1.039m0 0-.136-1.049m.136 1.05-.136-1.05m0 0L-29.538.53m.067 1.055L-29.538.53m0 0V-.53m0 1.058V-.53m0 0 .067-1.055m-.067 1.055.067-1.055m0 0 .136-1.05m-.136 1.05.136-1.05m0 0 .202-1.038m-.202 1.039.202-1.039m0 0 .268-1.023m-.268 1.023.268-1.023m0 0 .333-1.004m-.333 1.004.333-1.004m0 0 .397-.98m-.397.98.397-.98m0 0c.176-.364.35-.728.46-.953m-.46.953c.15-.312.3-.624.46-.953m0 0 .518-.921m-.519.921.52-.921m0 0 .576-.887m-.577.887.577-.887m0 0 .633-.848m-.633.848.633-.848m0 0 .686-.805m-.686.805.686-.805m0 0 .735-.76m-.735.76.735-.76m0 0 .783-.71m-.783.71.783-.71m0 0 .827-.66m-.827.66.827-.66m0 0 .868-.605m-.868.605.868-.605m0 0 .904-.549m-.904.549.904-.549m0 0 .938-.489m-.938.49.938-.49m0 0 .967-.428m-.967.428.967-.428m0 0 .993-.365m-.993.365.993-.365m0 0 1.014-.301m-1.014.3 1.014-.3m0 0 1.031-.236m-1.031.236 1.031-.236m0 0 1.044-.169m-1.044.17 1.044-.17m0 0c.22-.02.44-.042 1.053-.101m-1.053.101c.266-.025.532-.05 1.053-.101m0 0 1.057-.034m-1.057.034 1.057-.034m0 0" style="fill:#ffe8e8!important;stroke:#d03b3b!important" transform="translate(250.296 24.5)"/></g><g class="label" style="color:#8a0000!important" transform="translate(250.296 15.5)"><rect/><rect class="background" style="stroke:none"/><text y="-10.1" style="fill:#8a0000!important"><tspan x="0" y="-.1em" class="text-outer-tspan row" dy="1.1em"><tspan class="text-inner-tspan" font-style="normal" font-weight="normal">FIN</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> 2</tspan></tspan></text></g></g></g></g><defs><filter id="dia-s02_d6b_caja_multiple-drop-shadow" width="130%" height="130%"><feDropShadow dx="4" dy="4" flood-color="#000" flood-opacity=".06" stdDeviation="0"/></filter></defs><defs><filter id="dia-s02_d6b_caja_multiple-drop-shadow-small" width="150%" height="150%"><feDropShadow dx="2" dy="2" flood-color="#000" flood-opacity=".06" stdDeviation="0"/></filter></defs><linearGradient id="dia-s02_d6b_caja_multiple-gradient" x1="0%" x2="100%" y1="0%" y2="0%" gradientUnits="objectBoundingBox"><stop offset="0%" stop-color="hsl(0, 0%, 83.3333333333%)" stop-opacity="1"/><stop offset="100%" stop-color="hsl(0, 0%, 88.9215686275%)" stop-opacity="1"/></linearGradient></svg>', 'Dos cosas están mal: la caja roja hace cuatro cosas —debería ser cuatro cajas— y hay un segundo FIN al que no llega ninguna flecha. Si nadie puede llegar ahí, sobra.')

# %% [markdown]
# ### El diagrama no se dibuja: se deduce
#
# Vuelve al banco de trabajo (la celda del editor), cámbiale una línea a tu
# pseudocódigo y oprime **Ver diagrama**. El dibujo cambia solo.
#
# Eso es lo que hay que entender: **el diagrama de flujo no es una tarea aparte,
# es una foto de tu algoritmo**. Si el diagrama queda raro, no es que lo hayas
# dibujado mal: es que el algoritmo está raro.

# %% [markdown]
# ### 4.3.4 El puente a Flowgorithm
#
# | Nuestro pseudocódigo | Bloque de Flowgorithm | Forma en pantalla | Menú |
# |---|---|---|---|
# | `Algoritmo` / `FinAlgoritmo` | *Main* (ya viene puesto) | óvalos verdes arriba y abajo | — |
# | `Definir x Como Entero` | **Declare** · `x` · tipo `Integer` | rectángulo con esquinas dobles | clic derecho → Declare |
# | `Constante PASAJE <- 3200` | **Assign** en MAYÚSCULAS (Flowgorithm no tiene constantes) | rectángulo | clic derecho → Assign |
# | `Leer x` | **Input** · variable `x` | paralelogramo | clic derecho → Input |
# | `Escribir e` | **Output** · expresión `e` | paralelogramo | clic derecho → Output |
# | `x <- expr` | **Assign** · `x` ← `expr` | rectángulo | clic derecho → Assign |
# | `Si c Entonces … Sino … FinSi` | **If** con ramas *True* / *False* | rombo | clic derecho → If |
# | `Mientras c Hacer … FinMientras` | **While** | rombo con retorno | clic derecho → While |
# | `Entero / Real / Cadena / Logico` | `Integer / Real / String / Boolean` | — | — |
# | `Verdadero / Falso` | `true / false` | — | — |
# | `<>` | `!=` | — | — |
# | `Y / O / NO` | `AND / OR / NOT` | — | — |
#
# **Flowgorithm no corre aquí, y está bien.** Flowgorithm es un programa de
# escritorio para Windows; este cuadernillo vive en un navegador sobre Linux. En
# la Clase 2 vas a construir el diagrama en Flowgorithm en los equipos de la sala.
# Lo que haces aquí es **llegar con el algoritmo ya pensado y probado**: el
# diagrama que ves arriba lo dibujó el computador a partir de tu pseudocódigo, así
# que armarlo en Flowgorithm es copiar bloque por bloque usando esta tabla.

# %% [markdown]
# ### 4.4 Una variable es una caja con nombre

# %%
figura_cajas()

# %% [markdown]
# Cuando escribes `copias <- 40`, el computador hace tres cosas: busca la caja
# rotulada `copias`, **bota lo que hubiera adentro** y mete el 40. No hay
# «historial»: el valor anterior desaparece. Por eso el orden de las instrucciones
# lo es todo.
#
# El **nombre** lo eliges tú, y es lo único que vas a ver dentro de seis meses
# cuando releas tu propio código. `x`, `dato1` y `aux` no le dicen nada a nadie.
# `costo_pasaje` sí.

# %%
figura_incremento()

# %% [markdown]
# ### El renglón más raro de toda la programación
#
# ```
# viajes <- viajes + 1
# ```
#
# En la clase de matemáticas, `x = x + 1` es **falso siempre**: no hay número que
# sea igual a sí mismo más uno. En programación esa línea no es una ecuación: es
# **una orden**, y se lee de derecha a izquierda:
#
# 1. **Primero** se mira qué hay adentro de la caja `viajes` (digamos, 3).
# 2. **Después** se calcula `3 + 1`, que da 4.
# 3. **Por último** se guarda el 4 en la caja `viajes`, borrando el 3.
#
# Por eso escribimos `<-` y no `=`: la flecha **apunta hacia la caja**. Cuando
# pases a Python vas a escribir `viajes = viajes + 1`, con un signo igual que en
# realidad significa lo mismo que la flecha. Recuérdalo así: **en programación,
# `=` no pregunta, ordena.**

# %%
# Ejecuta esto tal cual. Después cambia el orden de las dos últimas líneas
# y vuelve a ejecutar: ¿por qué cambia el resultado?
viajes = 3
print("Antes: ", viajes)
viajes = viajes + 1
print("Después:", viajes)

# %%
ps.trazador("""Algoritmo ContarViajes
    Definir viajes Como Entero
    viajes <- 3
    viajes <- viajes + 1
    viajes <- viajes + 1
    Escribir "Total de viajes: ", viajes
FinAlgoritmo""")

# %% [markdown]
# ### 4.5 Tipos: qué le cabe a cada caja
#
# | Pseudocódigo | Python | Qué guarda | Ejemplos | Cuidado |
# |---|---|---|---|---|
# | `Entero` | `int` | números sin decimales | `40`, `-3`, `0` | `3200` sin puntos ni comas: `3.200` es otra cosa |
# | `Real` | `float` | números con decimales | `3.85`, `-0.5` | el separador decimal es el **punto**, no la coma |
# | `Cadena` | `str` | texto | `"Ana"`, `"3200"` | `"3200"` es texto, **no** es el número 3200 |
# | `Logico` | `bool` | verdadero o falso | `Verdadero`, `Falso` | en Python se escriben `True` y `False`, con mayúscula |

# %%
# type() te dice de qué tipo es una caja. Ejecuta y mira la diferencia
# entre el número 3200 y el texto "3200".
print(type(3200))       # <class 'int'>
print(type(3.85))       # <class 'float'>
print(type("3200"))     # <class 'str'>
print(type(True))       # <class 'bool'>

# Y ahora la trampa clásica:
print(3200 + 100)       # 3300  -> suma
print("3200" + "100")   # 3200100 -> ¡pega los textos!

# %% [markdown]
# **`"3200" + "100"` da `3200100`.** No es un error de Python: es que a los
# textos, el `+` los **pega**. Si lo que quieres es sumar, primero tienes que
# convertir el texto en número. Eso es una **conversión explícita**, y «explícita»
# significa que la pides tú, a mano, con todas sus letras.
#
# ### Las tres conversiones
#
# | Quiero pasar de… | …a | Python | Pseudocódigo | Falla si… |
# |---|---|---|---|---|
# | texto | entero | `int("40")` → `40` | `ConvertirAEntero("40")` | el texto no es un número entero: `int("cuarenta")`, `int("3.5")`, `int("")` |
# | texto | real | `float("3.85")` → `3.85` | `ConvertirAReal("3.85")` | el texto no parece un número: `float("tres")` |
# | número | texto | `str(40)` → `"40"` | `ConvertirATexto(40)` | nunca falla |

# %%
# Ida y vuelta entre tipos. Ejecuta y mira los tipos que imprime.
texto = "3200"
numero = int(texto)          # texto -> entero
otra_vez = str(numero)       # entero -> texto

print(texto, type(texto))
print(numero, type(numero))
print(otra_vez, type(otra_vez))
print("¿Son iguales?", texto == otra_vez)

# Y ahora, la conversión que decide si sumas o pegas:
print(int("3200") + int("100"))   # 3300
print("3200" + "100")             # 3200100

# %% [markdown]
# ### 4.6 `Leer` y `Escribir`, `input()` y `print()`
#
# En pseudocódigo, `Leer copias` sabe que tiene que guardar un **número** porque
# arriba escribiste `Definir copias Como Entero`. Le dijiste de qué tipo era la
# caja antes de llenarla.
#
# Mira las dos columnas, fila por fila:

# %%
ps.comparador(PAPELERIA)

# %% [markdown]
# ### Por qué aquí no tecleas
#
# En este cuadernillo tu programa **no te va a preguntar nada**: los datos que el
# usuario iba a teclear se los entregas tú de antemano, en una lista.
#
# ```python
# ps.usar_entradas(["40"])     # esto es "el usuario va a teclear 40"
# copias = int(input())        # y esto es exactamente el input() de siempre
# ```
#
# Tres razones, y las tres son buenas:
#
# 1. **Puedes probar el mismo programa con muchos usuarios distintos, en un
#    segundo.** Cambias la lista y vuelves a ejecutar. Esa lista tiene nombre
#    propio en ingeniería: es un **caso de prueba**, justo lo que definiste en la
#    ficha de análisis de la Parte A. Un programa serio se prueba con diez casos,
#    no con uno; nadie va a teclear diez veces a mano.
# 2. **Tus pruebas se pueden repetir.** Si el corrector automático tuviera que
#    teclear, no podría corregir. Todo el software profesional del mundo se prueba
#    así: los datos entran desde un archivo o una lista, no desde un teclado.
# 3. **El código es idéntico.** `input()` sigue siendo `input()`. Cuando corras
#    este mismo programa en tu computador, en VS Code, te va a preguntar de
#    verdad, y no tendrás que cambiarle **ni una letra**.
#
# Y el detalle que sí tienes que grabarte:
#
# > **`input()` siempre te entrega TEXTO.** Aunque el usuario teclee `40`, lo que
# > llega a tu programa es `"40"`, con comillas. Si quieres sumar, tú decides:
# > `int(input())`.
#
# ¿Y por qué en pseudocódigo `Leer copias` sí sabe que es un número? Porque arriba
# escribiste `Definir copias Como Entero`: **le dijiste de qué tipo era la caja
# antes de llenarla**. Python no tiene esa declaración, así que no puede adivinar,
# y te pasa la responsabilidad a ti. Ese es, en una frase, todo el asunto de las
# conversiones explícitas.
#
# Y una costumbre profesional, ya que estamos: fíjate en que casi todos los
# ejercicios de hoy te piden una **función con parámetros**
# (`hora_de_salida(hora_clase, bus, ...)`) en vez de una función que pregunta. Es
# a propósito: una función que recibe sus datos se puede probar, reutilizar y
# combinar; una que pregunta, no.

# %%
# El MISMO algoritmo de la papelería, ahora en Python.
# Compara línea por línea con el pseudocódigo de arriba.
ps.usar_entradas(["40"])          # esto es "el usuario va a teclear 40"

PRECIO_COPIA = 100
ANILLADO = 2500

print("¿Cuántas copias vas a sacar?")
copias = int(input())             # input() da TEXTO; int() lo vuelve número

total = copias * PRECIO_COPIA + ANILLADO

print("Total a pagar: $", total, sep="")

# %% [markdown]
# ### `print()` hace más de lo que parece
#
# ```python
# print("Total:", 6500)             # Total: 6500      <- pone un espacio entre los pedazos
# print("Total:", 6500, sep="")     # Total:6500       <- sin separador
# print("Total: $", 6500, sep="")   # Total: $6500
# print("cargando", end="")         # no salta de línea al terminar
# ```
#
# `sep` es lo que `print` mete **entre** los pedazos (por defecto, un espacio) y
# `end` es lo que pone **al final** (por defecto, un salto de línea). El
# `Escribir` del pseudocódigo se comporta como `sep=""`: pega los pedazos tal cual.

# %% [markdown]
# ### 4.7 Lee el error
#
# Las dos celdas que siguen **fallan a propósito**. Ejecútalas, lee el mensaje
# rojo con calma y después arréglalas. Aprender a leer un error es la mitad del
# oficio.

# %%
# Esta celda falla a propósito. Ejecútala y lee el mensaje rojo antes de arreglarla.
edad_escrita = "diecinueve"
edad = int(edad_escrita)
print("El año entrante cumples", edad + 1)

# %% [markdown]
# ```
# ValueError: invalid literal for int() with base 10: 'diecinueve'
# ```
#
# Se lee de abajo hacia arriba. La última línea es el diagnóstico: **`ValueError`**
# significa *«el tipo de dato era el correcto (un texto) pero el valor no me
# sirve»*. Y te muestra exactamente cuál: `'diecinueve'`.
#
# `int()` sabe convertir `"19"`, pero no sabe español. Tampoco sabe convertir
# `"19.5"` (eso es `float()`) ni `""` (una cadena vacía no es ningún número).
#
# Compáralo con el `NameError` de la semana pasada: aquel decía *«ese nombre no
# existe»*; este dice *«el nombre existe, pero lo que tiene adentro no me sirve»*.
# Aprender a distinguir los apellidos de los errores (`NameError`, `TypeError`,
# `ValueError`, `SyntaxError`) te ahorra horas.
#
# **Arréglalo:** cambia `"diecinueve"` por `"19"` y ejecuta otra vez.

# %%
# Y este es el otro clásico. ¿Cuál es la diferencia con el de arriba?
edad = "19"
print("El año entrante cumples", edad + 1)   # TypeError

# %% [markdown]
# ```
# TypeError: can only concatenate str (not "int") to str
# ```
#
# Aquí ni siquiera intentaste convertir: le pediste a Python que sumara un texto y
# un número, y se negó. Otros lenguajes adivinan en estos casos —y por adivinar
# producen errores silenciosos que aparecen tres meses después—. Python prefiere
# frenar.
#
# | Error | Qué te está diciendo | Ejemplo típico |
# |---|---|---|
# | `SyntaxError` | «no entendí ni siquiera lo que escribiste» | falta una comilla o un paréntesis |
# | `NameError` | «ese nombre no existe» | escribiste `gasto_semanal` y la variable es `gasto_semana` |
# | `TypeError` | «esos dos tipos no se pueden mezclar así» | `"19" + 1` |
# | `ValueError` | «el tipo está bien, pero ese valor no me sirve» | `int("diecinueve")` |
#
# Cuando algo falle, lee **la última línea primero**: ahí está el apellido del
# error y el diagnóstico. Las de arriba solo dicen dónde.

# %% [markdown]
# ---
#
# ## 5. Ocho ejercicios · 50 min
#
# Aquí es donde se juega tu nota: **80 puntos** repartidos en ocho ejercicios.
# Cada uno son dos celdas — la tuya y la de prueba.
#
# Tres reglas de la casa:
#
# - **Los intentos no restan.** Ejecuta la celda de prueba tantas veces como
#   quieras.
# - **Las pistas tampoco.** Cada ejercicio trae tres, de la que hace pensar a la
#   que casi resuelve. Se piden con `pista("E1")`, `pista("E2")`… y **no gastan
#   preguntas del tutor**.
# - Si ejecutas una celda de ejercicio sin haberla tocado, te va a salir
#   `NotImplementedError`. No es un fallo del cuadernillo: es un error de
#   ejecución **puesto a propósito** que significa «aquí falta tu parte». Bórralo
#   cuando escribas tu respuesta.
#
# Varios ejercicios se corrigen **ejecutando** tu pseudocódigo, no leyéndolo. Si
# el orden está mal, te lo va a decir el propio intérprete.

# %% [markdown]
# Antes del ejercicio 1, un ensayo sin nota para equivocarte gratis:

# %%
ensayo_e1()

# %% [markdown]
# ### Ejercicio 1 — Ordena el algoritmo
#
# *Dificultad ★☆☆☆ · 5 puntos*
#
# Las siete líneas del algoritmo de la papelería quedaron revueltas:
#
# ```
# A)     Leer copias
# B)     Escribir "Total a pagar: $", total
# C) Algoritmo CostoDeFotocopias
# D)     total <- copias * 100 + 2500
# E)     Escribir "¿Cuántas copias vas a sacar?"
# F) FinAlgoritmo
# G)     Definir copias, total Como Entero
# ```
#
# Escribe en `orden_e1` la lista de letras en el orden correcto. Por ejemplo, si
# creyeras que va primero la B y después la A, escribirías `["B", "A", ...]`.
#
# **Pista gratis:** un algoritmo no puede usar una caja que todavía no existe, ni
# imprimir un resultado que todavía no calculó.
#
# El corrector no va a leer tu lista: va a **armar el pseudocódigo con tu orden y
# ejecutarlo**.
#
# > ¿Atascado? Ejecuta `pista("E1")` en una celda nueva. Hay 3, de la que hace pensar a la que casi resuelve. Pedirlas no resta puntos.

# %%
# Escribe la lista de letras en el orden correcto.
orden_e1 = []
### INICIO SOLUCION
orden_e1 = ["C", "G", "E", "A", "D", "B", "F"]
### FIN SOLUCION

# %%
LINEAS_E1 = {
    "A": "    Leer copias",
    "B": '    Escribir "Total a pagar: $", total',
    "C": "Algoritmo CostoDeFotocopias",
    "D": "    total <- copias * 100 + 2500",
    "E": '    Escribir "¿Cuántas copias vas a sacar?"',
    "F": "FinAlgoritmo",
    "G": "    Definir copias, total Como Entero",
}

assert isinstance(orden_e1, list), "orden_e1 debe ser una lista, por ejemplo ['C', 'G', ...]"
assert len(orden_e1) == 7, f"El algoritmo tiene 7 líneas y tú pusiste {len(orden_e1)}"
assert sorted(orden_e1) == list("ABCDEFG"), "Usa cada letra exactamente una vez, de la A a la G"
assert orden_e1[0] == "C", "Todo algoritmo empieza por su cabecera: la línea Algoritmo"
assert orden_e1[-1] == "F", "Y termina por FinAlgoritmo"

# El corrector no lee el orden: arma el algoritmo con él y lo ejecuta.
codigo_e1 = "\n".join(LINEAS_E1[letra] for letra in orden_e1)
r_e1 = ps.ejecutar_pseudo(codigo_e1, entradas=["40"])
assert r_e1.ok, "Tu orden no se puede ejecutar. El motor dice: " + r_e1.error_corto
assert "6500" in r_e1.salida, (
    "Tu orden ejecuta, pero no da el total correcto. Con 40 copias debe salir 6500. "
    "Revisa que el cálculo ocurra DESPUÉS de leer las copias.")

corregir("ejercicio_1", orden_e1)
print("E1 correcto: el algoritmo quedó en orden y se ejecuta.")

# %%
quiz_simbolos()

# %% [markdown]
# ### Ejercicio 2 — Cada símbolo con su significado
#
# *Dificultad ★☆☆☆ · 5 puntos*
#
# Completa el diccionario `simbolos_e2` emparejando cada forma con lo que
# representa. Los valores posibles son exactamente estos cinco textos:
#
# `"inicio_fin"` · `"entrada_salida"` · `"proceso"` · `"decision"` · `"flujo"`
#
# Cada significado se usa **una sola vez**. Si dudas, vuelve a la tabla de los
# cinco símbolos de la sección 4.3.
#
# > ¿Atascado? Ejecuta `pista("E2")` en una celda nueva. Hay 3, de la que hace pensar a la que casi resuelve. Pedirlas no resta puntos.

# %%
# Empareja cada símbolo con su significado.
simbolos_e2 = {
    "ovalo":         ...,
    "paralelogramo": ...,
    "rectangulo":    ...,
    "rombo":         ...,
    "flecha":        ...,
}
### INICIO SOLUCION
simbolos_e2 = {
    "ovalo":         "inicio_fin",
    "paralelogramo": "entrada_salida",
    "rectangulo":    "proceso",
    "rombo":         "decision",
    "flecha":        "flujo",
}
### FIN SOLUCION

# %%
VALIDOS_E2 = {"inicio_fin", "entrada_salida", "proceso", "decision", "flujo"}

assert isinstance(simbolos_e2, dict), "simbolos_e2 debe ser un diccionario"
assert set(simbolos_e2.keys()) == {"ovalo", "paralelogramo", "rectangulo", "rombo", "flecha"}, (
    "Las claves deben ser exactamente: ovalo, paralelogramo, rectangulo, rombo, flecha")
assert all(isinstance(v, str) for v in simbolos_e2.values()), (
    "Cada significado va entre comillas, como texto. Los cinco válidos son: "
    + ", ".join(sorted(VALIDOS_E2)))
assert set(simbolos_e2.values()) == VALIDOS_E2, (
    "Cada significado se usa una sola vez, y los cinco tienen que aparecer. Son: "
    + ", ".join(sorted(VALIDOS_E2)))

corregir("ejercicio_2", simbolos_e2)
print("E2 correcto: ya reconoces los cinco símbolos.")

# %%
quiz_ficha()

# %% [markdown]
# ### Ejercicio 3 — La ficha de análisis
#
# *Dificultad ★★☆☆ · 10 puntos*
#
# **Problema:** *En el parqueadero de la UIS se cobra una **tarifa por hora** y,
# además, un **recargo fijo** por el uso de la barrera. Dado el número de
# **horas** que estuvo el carro, calcular cuánto debe pagar.*
#
# Llena el diccionario `ficha_e3` con los cinco campos de la ficha de análisis:
#
# - `"entradas"`: la lista de los **nombres de variable** de los datos que entran
#   (en minúsculas, con guion bajo, sin tildes).
# - `"proceso"`: **una sola línea de pseudocódigo** que calcule el resultado
#   usando esos nombres y guardándolo en `total`.
# - `"salida"`: la lista con el nombre de lo que se entrega.
# - `"restricciones"`: una lista con al menos **dos** restricciones, escritas como
#   frases.
# - `"casos_prueba"`: una lista de al menos **dos** tuplas `(horas, tarifa_hora,
#   recargo_fijo, total_esperado)`.
#
# Los nombres de las entradas están fijados a propósito (el corrector los necesita
# exactos): **`horas`**, **`tarifa_hora`**, **`recargo_fijo`**.
#
# Tu línea de proceso no se lee: **se ejecuta** dentro de un algoritmo de verdad.
#
# > ¿Atascado? Ejecuta `pista("E3")` en una celda nueva. Hay 3, de la que hace pensar a la que casi resuelve. Pedirlas no resta puntos.

# %%
ficha_e3 = {
    "entradas": [...],
    "proceso": "...",
    "salida": [...],
    "restricciones": [...],
    "casos_prueba": [...],
}
### INICIO SOLUCION
ficha_e3 = {
    "entradas": ["horas", "tarifa_hora", "recargo_fijo"],
    "proceso": "total <- horas * tarifa_hora + recargo_fijo",
    "salida": ["total"],
    "restricciones": [
        "horas no puede ser negativa",
        "tarifa_hora debe ser mayor que cero",
    ],
    "casos_prueba": [
        (3, 2500, 1000, 8500),
        (0, 2500, 1000, 1000),
    ],
}
### FIN SOLUCION

# %%
assert isinstance(ficha_e3, dict), "ficha_e3 debe ser un diccionario"
faltan_e3 = {"entradas", "proceso", "salida", "restricciones", "casos_prueba"} - set(ficha_e3)
assert not faltan_e3, "Te faltan campos en la ficha: " + ", ".join(sorted(faltan_e3))

assert set(ficha_e3["entradas"]) == {"horas", "tarifa_hora", "recargo_fijo"}, (
    "Las entradas deben ser exactamente horas, tarifa_hora y recargo_fijo. "
    "Si pusiste 'total', recuerda que eso SALE, no entra.")
assert ficha_e3["salida"] == ["total"], "La salida es una sola cosa: ['total']"

assert len(ficha_e3["restricciones"]) >= 2, (
    "Escribe al menos dos restricciones: valores que NO tendrían sentido en este problema.")
assert all(isinstance(t, str) and len(t.strip()) >= 10 for t in ficha_e3["restricciones"]), (
    "Cada restricción debe ser una frase, no una palabra suelta.")

# El proceso se comprueba EJECUTÁNDOLO.
proceso_e3 = ficha_e3["proceso"]
assert isinstance(proceso_e3, str), "El proceso es una línea de pseudocódigo, en texto"
assert "<-" in proceso_e3, "En pseudocódigo se guarda con la flecha <-, no con ="
assert proceso_e3.split("<-")[0].strip() == "total", "El resultado debe guardarse en 'total'"

programa_e3 = (
    "Algoritmo Parqueadero\n"
    "    Definir horas, tarifa_hora, recargo_fijo, total Como Entero\n"
    "    horas <- 3\n"
    "    tarifa_hora <- 2500\n"
    "    recargo_fijo <- 1000\n"
    f"    {proceso_e3.strip()}\n"
    "    Escribir total\n"
    "FinAlgoritmo")
r_e3 = ps.ejecutar_pseudo(programa_e3)
assert r_e3.ok, "Tu línea de proceso no se puede ejecutar. El motor dice: " + r_e3.error_corto
assert r_e3.memoria["total"] == 8500, (
    f"Con 3 horas a $2.500 y $1.000 de recargo el total es 8500, y tu proceso dio "
    f"{r_e3.memoria['total']}. Revisa si multiplicaste antes de sumar.")

assert len(ficha_e3["casos_prueba"]) >= 2, "Define al menos dos casos de prueba."
for caso in ficha_e3["casos_prueba"]:
    assert len(caso) == 4, "Cada caso es (horas, tarifa_hora, recargo_fijo, total_esperado)"
    h, t, rc, esperado = caso
    assert h * t + rc == esperado, (
        f"El caso {caso} no cuadra: con {h} horas a {t} más {rc} el total sería {h * t + rc}.")
print("E3 correcto: la ficha está completa y tu proceso da el resultado esperado.")

# %% [markdown]
# ### Ejercicio 4 — Completa el pseudocódigo
#
# *Dificultad ★★☆☆ · 10 puntos*
#
# Este algoritmo calcula **cuánto te sobra en la tarjeta de Metrolínea** después
# de una semana. Le falta una línea: la que hace la cuenta.
#
# Reemplaza los tres guiones bajos `___` por la expresión correcta. **No cambies
# nada más**: ni los nombres, ni el orden, ni los mensajes.
#
# El corrector va a **ejecutar tu pseudocódigo** con dos recargas distintas:
#
# | Recargas | Debe sobrar |
# |---|---|
# | $25.000 | $5.800 |
# | $50.000 | $30.800 |
#
# > ¿Atascado? Ejecuta `pista("E4")` en una celda nueva. Hay 3, de la que hace pensar a la que casi resuelve. Pedirlas no resta puntos.

# %%
pseudo_e4 = """Algoritmo RecargaMetrolinea
    Definir saldo, sobra Como Entero
    Constante PASAJE <- 3200
    Constante VIAJES <- 6

    Escribir "¿Cuánto vas a recargar?"
    Leer saldo

    sobra <- ___

    Escribir "Te sobran $", sobra
FinAlgoritmo"""
### INICIO SOLUCION
pseudo_e4 = """Algoritmo RecargaMetrolinea
    Definir saldo, sobra Como Entero
    Constante PASAJE <- 3200
    Constante VIAJES <- 6

    Escribir "¿Cuánto vas a recargar?"
    Leer saldo

    sobra <- saldo - VIAJES * PASAJE

    Escribir "Te sobran $", sobra
FinAlgoritmo"""
### FIN SOLUCION

# %%
assert isinstance(pseudo_e4, str), "pseudo_e4 debe seguir siendo una cadena de texto"
assert "___" not in pseudo_e4, "Todavía quedan guiones bajos ___ sin reemplazar."
assert "Constante PASAJE <- 3200" in pseudo_e4, "No cambies las constantes del algoritmo."

for recarga, esperado in [("25000", 5800), ("50000", 30800)]:
    r_e4 = ps.ejecutar_pseudo(pseudo_e4, entradas=[recarga])
    assert r_e4.ok, (
        f"Con una recarga de ${recarga} tu algoritmo falla. El motor dice: {r_e4.error_corto}")
    assert "sobra" in r_e4.memoria, "El resultado debe quedar guardado en la variable 'sobra'."
    assert r_e4.memoria["sobra"] == esperado, (
        f"Con ${recarga} deben sobrar ${esperado}, y tu algoritmo dejó {r_e4.memoria['sobra']}. "
        f"Recuerda: son 6 viajes a $3.200 cada uno.")
    assert str(esperado) in r_e4.salida, (
        "El algoritmo calcula bien pero no está mostrando el resultado. "
        "Revisa la línea Escribir.")
print("E4 correcto: tu pseudocódigo se ejecuta y da lo esperado en los dos casos.")

# %% [markdown]
# ### Ejercicio 5 — Prueba de escritorio
#
# *Dificultad ★★☆☆ · 10 puntos*
#
# Este algoritmo descuenta dos pasajes de una tarjeta de Metrolínea:
#
# ```
# 1  Algoritmo ViajesDeLaSemana
# 2      Definir saldo, viajes Como Entero
# 3      Constante PASAJE <- 3200
# 4      saldo <- 12000
# 5      viajes <- 0
# 6      saldo <- saldo - PASAJE
# 7      viajes <- viajes + 1
# 8      saldo <- saldo - PASAJE
# 9      viajes <- viajes + 1
# 10     Escribir "Saldo final: ", saldo
# 11 FinAlgoritmo
# ```
#
# **Hazlo a mano, en papel.** Recorre las instrucciones de la 2 a la 10 y anota,
# después de cada una, cuánto valen `saldo` y `viajes`. Después escribe esa tabla
# en `traza_e5` como una lista de **9 tuplas** `(saldo, viajes)`, una por
# instrucción ejecutada.
#
# Usa **`None`** cuando la caja exista pero todavía esté vacía. `None` no es lo
# mismo que 0: cero es un valor; `None` es «no hay nada adentro».
#
# **Nota de honestidad.** Sí, podrías ejecutar el algoritmo con el trazador y
# copiar la respuesta. También podrías copiar un examen. El día del parcial no vas
# a tener trazador, y esta es exactamente la destreza que se evalúa allá. Hazla a
# mano.
#
# > ¿Atascado? Ejecuta `pista("E5")` en una celda nueva. Hay 3, de la que hace pensar a la que casi resuelve. Pedirlas no resta puntos.

# %%
# Una tupla (saldo, viajes) por cada instrucción ejecutada, de la línea 2 a la 10.
traza_e5 = [
    (None, None),   # 2  Definir saldo, viajes Como Entero
    # ...y así hasta la línea 10. Son 9 filas en total.
]
### INICIO SOLUCION
traza_e5 = [
    (None,  None),   # 2  Definir saldo, viajes Como Entero
    (None,  None),   # 3  Constante PASAJE <- 3200
    (12000, None),   # 4  saldo <- 12000
    (12000, 0),      # 5  viajes <- 0
    (8800,  0),      # 6  saldo <- saldo - PASAJE
    (8800,  1),      # 7  viajes <- viajes + 1
    (5600,  1),      # 8  saldo <- saldo - PASAJE
    (5600,  2),      # 9  viajes <- viajes + 1
    (5600,  2),      # 10 Escribir "Saldo final: ", saldo
]
### FIN SOLUCION

# %%
CODIGO_E5 = """Algoritmo ViajesDeLaSemana
    Definir saldo, viajes Como Entero
    Constante PASAJE <- 3200
    saldo <- 12000
    viajes <- 0
    saldo <- saldo - PASAJE
    viajes <- viajes + 1
    saldo <- saldo - PASAJE
    viajes <- viajes + 1
    Escribir "Saldo final: ", saldo
FinAlgoritmo"""

# La respuesta NO está escrita aquí: se calcula ejecutando el algoritmo.
esperada_e5 = ps.ejecutar_pseudo(CODIGO_E5).tabla_traza(["saldo", "viajes"])

assert isinstance(traza_e5, list), "traza_e5 debe ser una lista de tuplas"
assert len(traza_e5) == len(esperada_e5), (
    f"El algoritmo ejecuta {len(esperada_e5)} instrucciones y tu tabla tiene "
    f"{len(traza_e5)} filas. Cuenta desde el Definir (línea 2) hasta el Escribir (línea 10).")

for i, (mia, ok) in enumerate(zip(traza_e5, esperada_e5), start=2):
    assert isinstance(mia, (tuple, list)) and len(mia) == 2, (
        f"La fila de la línea {i} debe ser una tupla (saldo, viajes)")
    assert tuple(mia) == tuple(ok), (
        f"Después de la línea {i} debería quedar saldo={ok[0]} y viajes={ok[1]}, "
        f"pero tú anotaste saldo={mia[0]} y viajes={mia[1]}. "
        "Revisa esa instrucción: ¿qué caja toca y con qué valor?")
print("E5 correcto: tu prueba de escritorio coincide paso a paso con la ejecución real.")

# %% [markdown]
# ### Ejercicio 6 — Tipos y conversiones
#
# *Dificultad ★★★☆ · 10 puntos*
#
# Un formulario web te entrega los datos de un estudiante. **Todo llega como
# texto**, porque así funcionan los formularios (y `input()`):
#
# ```python
# datos = {"nombre": "Valentina", "edad": "19", "promedio": "3.85"}
# ```
#
# Crea estas cinco variables, cada una **del tipo correcto**:
#
# | Variable | Qué debe contener | Tipo |
# |---|---|---|
# | `nombre_e6` | el nombre, tal cual | `str` |
# | `edad_e6` | la edad como número entero | `int` |
# | `promedio_e6` | el promedio como número con decimales | `float` |
# | `es_becada_e6` | `True` si el promedio es **mayor o igual a 4.0** | `bool` |
# | `ficha_e6` | el texto `"Valentina tiene 19 anos"` armado con las variables anteriores | `str` |
#
# Para `ficha_e6` **no escribas el texto a mano**: constrúyelo pegando las
# variables, y usa `str()` donde haga falta. (Sin tilde en «anos», para no pelear
# con las tildes todavía.)
#
# > ¿Atascado? Ejecuta `pista("E6")` en una celda nueva. Hay 3, de la que hace pensar a la que casi resuelve. Pedirlas no resta puntos.

# %%
datos = {"nombre": "Valentina", "edad": "19", "promedio": "3.85"}

nombre_e6 = ...
edad_e6 = ...
promedio_e6 = ...
es_becada_e6 = ...
ficha_e6 = ...
### INICIO SOLUCION
nombre_e6 = datos["nombre"]
edad_e6 = int(datos["edad"])
promedio_e6 = float(datos["promedio"])
es_becada_e6 = promedio_e6 >= 4.0
ficha_e6 = nombre_e6 + " tiene " + str(edad_e6) + " anos"
### FIN SOLUCION

# %%
assert type(nombre_e6) is str, "nombre_e6 debe ser texto (str)"
assert nombre_e6 == "Valentina", "nombre_e6 debe salir de datos['nombre']"

assert type(edad_e6) is int, (
    f"edad_e6 debe ser un entero (int) y es {type(edad_e6).__name__}. "
    "Recuerda que datos['edad'] es el TEXTO '19': hay que convertirlo con int().")
assert edad_e6 == 19, "edad_e6 debe valer 19"

assert type(promedio_e6) is float, (
    f"promedio_e6 debe ser un número con decimales (float) y es {type(promedio_e6).__name__}. "
    "Se convierte con float(), no con int(): int('3.85') ni siquiera funciona.")
assert abs(promedio_e6 - 3.85) < 1e-9, "promedio_e6 debe valer 3.85"

assert type(es_becada_e6) is bool, (
    f"es_becada_e6 debe ser True o False (bool) y es {type(es_becada_e6).__name__}. "
    "Una comparación como  promedio_e6 >= 4.0  ya da un bool.")
assert es_becada_e6 is False, (
    "Con promedio 3.85 la respuesta es False: 3.85 no llega a 4.0. "
    "Ojo, escribe False (mayúscula inicial), no 'False' entre comillas.")

assert type(ficha_e6) is str, "ficha_e6 debe ser texto"
assert ficha_e6 == "Valentina tiene 19 anos", (
    f"ficha_e6 debe quedar exactamente 'Valentina tiene 19 anos' y quedó '{ficha_e6}'. "
    "Cuida los espacios: 'tiene ' lleva espacio al final.")
print("E6 correcto: cada dato quedó en su tipo y la ficha se armó bien.")

# %%
# Diagrama: s02_d4_gancho
ava.figura('<svg xmlns="http://www.w3.org/2000/svg" id="dia-s02_d4_gancho" width="100%" aria-roledescription="flowchart-v2" class="flowchart" role="graphics-document document" style="max-width:271.922px;background-color:transparent" viewBox="0 0 271.922 742.5"><style>#dia-s02_d4_gancho{font-family:system-ui,-apple-system,&apos;Segoe UI&apos;,Roboto,sans-serif;font-size:15px;fill:#000000;}@keyframes edge-animation-frame{from{stroke-dashoffset:0;}}@keyframes dash{to{stroke-dashoffset:0;}}#dia-s02_d4_gancho .edge-animation-slow{stroke-dasharray:9,5!important;stroke-dashoffset:900;animation:dash 50s linear infinite;stroke-linecap:round;}#dia-s02_d4_gancho .edge-animation-fast{stroke-dasharray:9,5!important;stroke-dashoffset:900;animation:dash 20s linear infinite;stroke-linecap:round;}#dia-s02_d4_gancho .error-icon{fill:#552222;}#dia-s02_d4_gancho .error-text{fill:#552222;stroke:#552222;}#dia-s02_d4_gancho .edge-thickness-normal{stroke-width:1px;}#dia-s02_d4_gancho .edge-thickness-thick{stroke-width:3.5px;}#dia-s02_d4_gancho .edge-pattern-solid{stroke-dasharray:0;}#dia-s02_d4_gancho .edge-thickness-invisible{stroke-width:0;fill:none;}#dia-s02_d4_gancho .edge-pattern-dashed{stroke-dasharray:3;}#dia-s02_d4_gancho .edge-pattern-dotted{stroke-dasharray:2;}#dia-s02_d4_gancho .marker{fill:#52514e;stroke:#52514e;}#dia-s02_d4_gancho .marker.cross{stroke:#52514e;}#dia-s02_d4_gancho svg{font-family:system-ui,-apple-system,&apos;Segoe UI&apos;,Roboto,sans-serif;font-size:15px;}#dia-s02_d4_gancho p{margin:0;}#dia-s02_d4_gancho .label{font-family:system-ui,-apple-system,&apos;Segoe UI&apos;,Roboto,sans-serif;color:#000000;}#dia-s02_d4_gancho .cluster-label text{fill:#333;}#dia-s02_d4_gancho .cluster-label span{color:#333;}#dia-s02_d4_gancho .cluster-label span p{background-color:transparent;}#dia-s02_d4_gancho .label text,#dia-s02_d4_gancho span{fill:#000000;color:#000000;}#dia-s02_d4_gancho .node rect,#dia-s02_d4_gancho .node circle,#dia-s02_d4_gancho .node ellipse,#dia-s02_d4_gancho .node polygon,#dia-s02_d4_gancho .node path{fill:#eee;stroke:#999;stroke-width:1px;}#dia-s02_d4_gancho .rough-node .label text,#dia-s02_d4_gancho .node .label text,#dia-s02_d4_gancho .image-shape .label,#dia-s02_d4_gancho .icon-shape .label{text-anchor:middle;}#dia-s02_d4_gancho .node .katex path{fill:#000;stroke:#000;stroke-width:1px;}#dia-s02_d4_gancho .rough-node .label,#dia-s02_d4_gancho .node .label,#dia-s02_d4_gancho .image-shape .label,#dia-s02_d4_gancho .icon-shape .label{text-align:center;}#dia-s02_d4_gancho .node.clickable{cursor:pointer;}#dia-s02_d4_gancho .root .anchor path{fill:#52514e!important;stroke-width:0;stroke:#52514e;}#dia-s02_d4_gancho .arrowheadPath{fill:#333333;}#dia-s02_d4_gancho .edgePath .path{stroke:#52514e;stroke-width:1px;}#dia-s02_d4_gancho .flowchart-link{stroke:#52514e;fill:none;}#dia-s02_d4_gancho .edgeLabel{background-color:white;text-align:center;}#dia-s02_d4_gancho .edgeLabel p{background-color:white;}#dia-s02_d4_gancho .edgeLabel rect{opacity:0.5;background-color:white;fill:white;}#dia-s02_d4_gancho .labelBkg{background-color:rgba(255, 255, 255, 0.5);}#dia-s02_d4_gancho .cluster rect{fill:hsl(0, 0%, 98.9215686275%);stroke:#707070;stroke-width:1px;}#dia-s02_d4_gancho .cluster text{fill:#333;}#dia-s02_d4_gancho .cluster span{color:#333;}#dia-s02_d4_gancho div.mermaidTooltip{position:absolute;text-align:center;max-width:200px;padding:2px;font-family:system-ui,-apple-system,&apos;Segoe UI&apos;,Roboto,sans-serif;font-size:12px;background:#fdf6e3;border:1px solid #707070;border-radius:2px;pointer-events:none;z-index:100;}#dia-s02_d4_gancho .flowchartTitleText{text-anchor:middle;font-size:18px;fill:#000000;}#dia-s02_d4_gancho rect.text{fill:none;stroke-width:0;}#dia-s02_d4_gancho .icon-shape,#dia-s02_d4_gancho .image-shape{background-color:white;text-align:center;}#dia-s02_d4_gancho .icon-shape p,#dia-s02_d4_gancho .image-shape p{background-color:white;padding:2px;}#dia-s02_d4_gancho .icon-shape .label rect,#dia-s02_d4_gancho .image-shape .label rect{opacity:0.5;background-color:white;fill:white;}#dia-s02_d4_gancho .label-icon{display:inline-block;height:1em;overflow:visible;vertical-align:-0.125em;}#dia-s02_d4_gancho .node .label-icon path{fill:currentColor;stroke:revert;stroke-width:revert;}#dia-s02_d4_gancho .node .neo-node{stroke:#999;}#dia-s02_d4_gancho [data-look=&quot;neo&quot;].node rect,#dia-s02_d4_gancho [data-look=&quot;neo&quot;].cluster rect,#dia-s02_d4_gancho [data-look=&quot;neo&quot;].node polygon{stroke:url(#dia-s02_d4_gancho-gradient);filter:drop-shadow( 1px 2px 2px rgba(185,185,185,1));}#dia-s02_d4_gancho [data-look=&quot;neo&quot;].swimlane.cluster rect{filter:none;}#dia-s02_d4_gancho [data-look=&quot;neo&quot;].node path{stroke:url(#dia-s02_d4_gancho-gradient);stroke-width:1px;}#dia-s02_d4_gancho [data-look=&quot;neo&quot;].node .outer-path{filter:drop-shadow( 1px 2px 2px rgba(185,185,185,1));}#dia-s02_d4_gancho [data-look=&quot;neo&quot;].node .neo-line path{stroke:#999;filter:none;}#dia-s02_d4_gancho [data-look=&quot;neo&quot;].node circle{stroke:url(#dia-s02_d4_gancho-gradient);filter:drop-shadow( 1px 2px 2px rgba(185,185,185,1));}#dia-s02_d4_gancho [data-look=&quot;neo&quot;].node circle .state-start{fill:#000000;}#dia-s02_d4_gancho [data-look=&quot;neo&quot;].icon-shape .icon{fill:url(#dia-s02_d4_gancho-gradient);filter:drop-shadow( 1px 2px 2px rgba(185,185,185,1));}#dia-s02_d4_gancho [data-look=&quot;neo&quot;].icon-shape .icon-neo path{stroke:url(#dia-s02_d4_gancho-gradient);filter:drop-shadow( 1px 2px 2px rgba(185,185,185,1));}#dia-s02_d4_gancho :root{--mermaid-font-family:&quot;trebuchet ms&quot;,verdana,arial,sans-serif;}</style><marker id="dia-s02_d4_gancho_flowchart-v2-pointEnd" class="marker flowchart-v2" markerHeight="8" markerUnits="userSpaceOnUse" markerWidth="8" orient="auto" refX="5" refY="5" viewBox="0 0 10 10"><path d="m0 0 10 5-10 5z" class="arrowMarkerPath" style="stroke-width:1;stroke-dasharray:1,0"/></marker><marker id="dia-s02_d4_gancho_flowchart-v2-pointStart" class="marker flowchart-v2" markerHeight="8" markerUnits="userSpaceOnUse" markerWidth="8" orient="auto" refX="4.5" refY="5" viewBox="0 0 10 10"><path d="m0 5 10 5V0z" class="arrowMarkerPath" style="stroke-width:1;stroke-dasharray:1,0"/></marker><marker id="dia-s02_d4_gancho_flowchart-v2-pointEnd-margin" class="marker flowchart-v2" markerHeight="14" markerUnits="userSpaceOnUse" markerWidth="10.5" orient="auto" refX="11.5" refY="7" viewBox="0 0 11.5 14"><path d="m0 0 11.5 7L0 14z" class="arrowMarkerPath" style="stroke-width:0;stroke-dasharray:1,0"/></marker><marker id="dia-s02_d4_gancho_flowchart-v2-pointStart-margin" class="marker flowchart-v2" markerHeight="14" markerUnits="userSpaceOnUse" markerWidth="11.5" orient="auto" refX="1" refY="7" viewBox="0 0 11.5 14"><polygon points="0,7 11.5,14 11.5,0" class="arrowMarkerPath" style="stroke-width:0;stroke-dasharray:1,0"/></marker><marker id="dia-s02_d4_gancho_flowchart-v2-circleEnd" class="marker flowchart-v2" markerHeight="11" markerUnits="userSpaceOnUse" markerWidth="11" orient="auto" refX="11" refY="5" viewBox="0 0 10 10"><circle cx="5" cy="5" r="5" class="arrowMarkerPath" style="stroke-width:1;stroke-dasharray:1,0"/></marker><marker id="dia-s02_d4_gancho_flowchart-v2-circleStart" class="marker flowchart-v2" markerHeight="11" markerUnits="userSpaceOnUse" markerWidth="11" orient="auto" refX="-1" refY="5" viewBox="0 0 10 10"><circle cx="5" cy="5" r="5" class="arrowMarkerPath" style="stroke-width:1;stroke-dasharray:1,0"/></marker><marker id="dia-s02_d4_gancho_flowchart-v2-circleEnd-margin" class="marker flowchart-v2" markerHeight="14" markerUnits="userSpaceOnUse" markerWidth="14" orient="auto" refX="12.25" refY="5" viewBox="0 0 10 10"><circle cx="5" cy="5" r="5" class="arrowMarkerPath" style="stroke-width:0;stroke-dasharray:1,0"/></marker><marker id="dia-s02_d4_gancho_flowchart-v2-circleStart-margin" class="marker flowchart-v2" markerHeight="14" markerUnits="userSpaceOnUse" markerWidth="14" orient="auto" refX="-2" refY="5" viewBox="0 0 10 10"><circle cx="5" cy="5" r="5" class="arrowMarkerPath" style="stroke-width:0;stroke-dasharray:1,0"/></marker><marker id="dia-s02_d4_gancho_flowchart-v2-crossEnd" class="marker cross flowchart-v2" markerHeight="11" markerUnits="userSpaceOnUse" markerWidth="11" orient="auto" refX="12" refY="5.2" viewBox="0 0 11 11"><path d="m1 1 9 9m0-9-9 9" class="arrowMarkerPath" style="stroke-width:2;stroke-dasharray:1,0"/></marker><marker id="dia-s02_d4_gancho_flowchart-v2-crossStart" class="marker cross flowchart-v2" markerHeight="11" markerUnits="userSpaceOnUse" markerWidth="11" orient="auto" refX="-1" refY="5.2" viewBox="0 0 11 11"><path d="m1 1 9 9m0-9-9 9" class="arrowMarkerPath" style="stroke-width:2;stroke-dasharray:1,0"/></marker><marker id="dia-s02_d4_gancho_flowchart-v2-crossEnd-margin" class="marker cross flowchart-v2" markerHeight="12" markerUnits="userSpaceOnUse" markerWidth="12" orient="auto" refX="17.7" refY="7.5" viewBox="0 0 15 15"><path d="m1 1 13 13M1 14 14 1" class="arrowMarkerPath" style="stroke-width:2.5"/></marker><marker id="dia-s02_d4_gancho_flowchart-v2-crossStart-margin" class="marker cross flowchart-v2" markerHeight="12" markerUnits="userSpaceOnUse" markerWidth="12" orient="auto" refX="-3.5" refY="7.5" viewBox="0 0 15 15"><path d="m1 1 13 13M1 14 14 1" class="arrowMarkerPath" style="stroke-width:2.5;stroke-dasharray:1,0"/></marker><g class="root"><g class="edgePaths"><path id="dia-s02_d4_gancho-L_I_L1_0" marker-end="url(#dia-s02_d4_gancho_flowchart-v2-pointEnd)" d="m136.461 41.5-.083 4.083c-.084 4.084-.25 12.25-.263 19.917s.127 14.834.197 18.417l.071 3.584" class="edge-thickness-normal edge-pattern-solid edge-thickness-normal edge-pattern-solid flowchart-link" data-edge="true" data-et="edge" data-id="L_I_L1_0" data-look="classic" data-points="W3sieCI6MTM2LjQ2MDkzNzUsInkiOjQxLjV9LHsieCI6MTM1Ljk2MDkzNzUsInkiOjY2fSx7IngiOjEzNi40NjA5Mzc1LCJ5Ijo5MS41fV0="/><path id="dia-s02_d4_gancho-L_L1_L2_0" marker-end="url(#dia-s02_d4_gancho_flowchart-v2-pointEnd)" d="m136.461 124.5-.083 4.083c-.084 4.084-.25 12.25-.263 19.917s.127 14.834.197 18.417l.071 3.584" class="edge-thickness-normal edge-pattern-solid edge-thickness-normal edge-pattern-solid flowchart-link" data-edge="true" data-et="edge" data-id="L_L1_L2_0" data-look="classic" data-points="W3sieCI6MTM2LjQ2MDkzNzUsInkiOjEyNC41fSx7IngiOjEzNS45NjA5Mzc1LCJ5IjoxNDl9LHsieCI6MTM2LjQ2MDkzNzUsInkiOjE3NC41fV0="/><path id="dia-s02_d4_gancho-L_L2_L3_0" marker-end="url(#dia-s02_d4_gancho_flowchart-v2-pointEnd)" d="m136.461 207.5-.083 4.083c-.084 4.084-.25 12.25-.263 19.917s.127 14.834.197 18.417l.071 3.584" class="edge-thickness-normal edge-pattern-solid edge-thickness-normal edge-pattern-solid flowchart-link" data-edge="true" data-et="edge" data-id="L_L2_L3_0" data-look="classic" data-points="W3sieCI6MTM2LjQ2MDkzNzUsInkiOjIwNy41fSx7IngiOjEzNS45NjA5Mzc1LCJ5IjoyMzJ9LHsieCI6MTM2LjQ2MDkzNzUsInkiOjI1Ny41fV0="/><path id="dia-s02_d4_gancho-L_L3_P1_0" marker-end="url(#dia-s02_d4_gancho_flowchart-v2-pointEnd)" d="m136.461 290.5-.083 4.083c-.084 4.084-.25 12.25-.334 19.834-.083 7.583-.083 14.583-.083 18.083v3.5" class="edge-thickness-normal edge-pattern-solid edge-thickness-normal edge-pattern-solid flowchart-link" data-edge="true" data-et="edge" data-id="L_L3_P1_0" data-look="classic" data-points="W3sieCI6MTM2LjQ2MDkzNzUsInkiOjI5MC41fSx7IngiOjEzNS45NjA5Mzc1LCJ5IjozMTV9LHsieCI6MTM1Ljk2MDkzNzUsInkiOjM0MH1d"/><path id="dia-s02_d4_gancho-L_P1_P2_0" marker-end="url(#dia-s02_d4_gancho_flowchart-v2-pointEnd)" d="M135.961 421v46" class="edge-thickness-normal edge-pattern-solid edge-thickness-normal edge-pattern-solid flowchart-link" data-edge="true" data-et="edge" data-id="L_P1_P2_0" data-look="classic" data-points="W3sieCI6MTM1Ljk2MDkzNzUsInkiOjQyMX0seyJ4IjoxMzUuOTYwOTM3NSwieSI6NDQ2fSx7IngiOjEzNS45NjA5Mzc1LCJ5Ijo0NzF9XQ=="/><path id="dia-s02_d4_gancho-L_P2_E1_0" marker-end="url(#dia-s02_d4_gancho_flowchart-v2-pointEnd)" d="M135.961 552v4.167c0 4.166 0 12.5.07 20.25s.211 14.917.281 18.5l.071 3.584" class="edge-thickness-normal edge-pattern-solid edge-thickness-normal edge-pattern-solid flowchart-link" data-edge="true" data-et="edge" data-id="L_P2_E1_0" data-look="classic" data-points="W3sieCI6MTM1Ljk2MDkzNzUsInkiOjU1Mn0seyJ4IjoxMzUuOTYwOTM3NSwieSI6NTc3fSx7IngiOjEzNi40NjA5Mzc1LCJ5Ijo2MDIuNX1d"/><path id="dia-s02_d4_gancho-L_E1_F_0" marker-end="url(#dia-s02_d4_gancho_flowchart-v2-pointEnd)" d="m136.461 652-.083 4.083c-.084 4.084-.25 12.25-.263 19.917s.127 14.834.197 18.417l.071 3.584" class="edge-thickness-normal edge-pattern-solid edge-thickness-normal edge-pattern-solid flowchart-link" data-edge="true" data-et="edge" data-id="L_E1_F_0" data-look="classic" data-points="W3sieCI6MTM2LjQ2MDkzNzUsInkiOjY1Mn0seyJ4IjoxMzUuOTYwOTM3NSwieSI6Njc2LjV9LHsieCI6MTM2LjQ2MDkzNzUsInkiOjcwMn1d"/></g><g class="edgeLabels"><rect class="background" style="stroke:none"/><rect class="background" style="stroke:none"/><rect class="background" style="stroke:none"/><rect class="background" style="stroke:none"/><rect class="background" style="stroke:none"/><rect class="background" style="stroke:none"/><rect class="background" style="stroke:none"/></g><g class="nodes"><g id="dia-s02_d4_gancho-flowchart-I-0" class="node default" data-look="classic"><g class="basic label-container outer-path"><path fill="#008300" stroke="none" stroke-width="0" d="M-17.164-16.5h34.328l1.057.034 1.053.101 1.044.17c.334.075.668.152 1.031.235l1.014.3.993.366.967.428.938.49.904.548.868.605.827.66.783.71.736.76.685.805.633.848.577.887.519.921.459.953.397.98.333 1.004.268 1.023.203 1.039.135 1.049.068 1.055V.53l-.068 1.055-.135 1.05-.203 1.038-.268 1.023-.333 1.004-.397.98-.459.953-.52.921-.576.887-.633.848-.685.805-.736.76-.783.71-.827.66-.868.605-.904.549-.938.489-.967.428-.993.365-1.014.301-1.03.236-1.045.169-1.053.101-1.057.034h-34.328l-1.057-.034-1.053-.101-1.044-.17c-.207-.046-.413-.094-1.031-.235l-1.014-.3-.993-.366-.967-.428-.938-.49-.904-.548-.868-.605-.827-.66-.783-.71-.736-.76-.685-.805-.633-.848-.577-.887-.519-.921-.459-.953-.397-.98-.333-1.004-.268-1.023-.203-1.039c-.03-.243-.062-.486-.135-1.049L-33.656.53V-.53l.068-1.055.135-1.05.203-1.038.268-1.023.333-1.004.397-.98.459-.953.52-.921c.115-.179.231-.357.576-.887l.633-.848.685-.805.736-.76.783-.71.827-.66.868-.605.904-.549.938-.489.967-.428.993-.365 1.014-.301 1.03-.236 1.045-.169 1.053-.101 1.057-.034" style="fill:#008300!important;stroke:#005400!important" transform="translate(135.96 24.5)"/><path fill="none" stroke="#005400" stroke-dasharray="0 0" stroke-width="1.3" d="M-17.164-16.5h34.328m-34.328 0h34.328m0 0 1.057.034m-1.057-.034 1.057.034m0 0 1.053.101m-1.053-.101 1.053.101m0 0 1.044.17m-1.044-.17 1.044.17m0 0 1.031.235m-1.03-.236 1.03.236m0 0 1.014.3m-1.014-.3 1.014.3m0 0 .993.366m-.993-.365.993.365m0 0 .967.428m-.967-.428.967.428m0 0 .938.49m-.938-.49.938.49m0 0 .904.548m-.904-.549.904.549m0 0 .868.605m-.868-.605.868.605m0 0 .827.66m-.827-.66.827.66m0 0 .783.71m-.783-.71.783.71m0 0c.235.243.47.487.736.76m-.736-.76.736.76m0 0 .685.805m-.685-.805.685.805m0 0 .633.848m-.633-.848.633.848m0 0 .577.887m-.577-.887.577.887m0 0 .519.921m-.52-.921c.169.297.336.595.52.921m0 0 .459.953m-.459-.953.459.953m0 0 .397.98m-.397-.98.397.98m0 0 .333 1.004m-.333-1.004.333 1.004m0 0 .268 1.023m-.268-1.023.268 1.023m0 0 .203 1.039m-.203-1.039.203 1.039m0 0 .135 1.049m-.135-1.05.135 1.05m0 0 .068 1.055m-.068-1.055.068 1.055m0 0V.53m0-1.058V.53m0 0-.068 1.055M33.656.53l-.068 1.055m0 0-.135 1.05m.135-1.05-.135 1.05m0 0-.203 1.038m.203-1.039-.203 1.039m0 0-.268 1.023m.268-1.023-.268 1.023m0 0c-.075.224-.15.449-.333 1.004m.333-1.004L32.649 5.7m0 0-.397.98m.397-.98-.397.98m0 0-.459.953m.459-.953-.459.953m0 0c-.204.362-.407.723-.52.921m.52-.921-.52.921m0 0-.576.887m.577-.887-.577.887m0 0-.633.848m.633-.848-.633.848m0 0-.685.805m.685-.805-.685.805m0 0-.736.76m.736-.76-.736.76m0 0-.783.71m.783-.71-.783.71m0 0-.827.66m.827-.66-.827.66m0 0-.868.605m.868-.605-.868.605m0 0-.904.549m.904-.549-.904.549m0 0-.938.489m.938-.49-.938.49m0 0-.967.428m.967-.428-.967.428m0 0-.993.365m.993-.365-.993.365m0 0c-.344.102-.687.205-1.014.301m1.014-.3-1.014.3m0 0-1.03.236m1.03-.236-1.03.236m0 0-1.045.169m1.044-.17-1.044.17m0 0-1.053.101m1.053-.101-1.053.101m0 0-1.057.034m1.057-.034-1.057.034m0 0h-34.328m34.328 0h-34.328m0 0-1.057-.034m1.057.034-1.057-.034m0 0-1.053-.101m1.053.101-1.053-.101m0 0-1.044-.17m1.044.17-1.044-.17m0 0-1.031-.235m1.03.236-1.03-.236m0 0-1.014-.3m1.014.3-1.014-.3m0 0-.993-.366m.993.365-.993-.365m0 0-.967-.428m.967.428-.967-.428m0 0c-.298-.155-.596-.31-.938-.49m.938.49-.938-.49m0 0-.904-.548m.904.549-.904-.549m0 0-.868-.605m.868.605-.868-.605m0 0q-.41-.325-.827-.66m.827.66-.827-.66m0 0-.783-.71m.783.71-.783-.71m0 0-.736-.76m.736.76-.736-.76m0 0-.685-.805m.685.805-.685-.805m0 0-.633-.848m.633.848-.633-.848m0 0-.577-.887m.577.887-.577-.887m0 0-.519-.921m.52.921-.52-.921m0 0-.459-.953m.459.953-.459-.953m0 0-.397-.98m.397.98-.397-.98m0 0-.333-1.004m.333 1.004-.333-1.004m0 0-.268-1.023m.268 1.023-.268-1.023m0 0-.203-1.039m.203 1.039-.203-1.039m0 0-.135-1.049m.135 1.05-.135-1.05m0 0L-33.656.53m.068 1.055L-33.656.53m0 0V-.53m0 1.058V-.53m0 0 .068-1.055m-.068 1.055.068-1.055m0 0 .135-1.05m-.135 1.05.135-1.05m0 0 .203-1.038m-.203 1.039.203-1.039m0 0 .268-1.023m-.268 1.023.268-1.023m0 0 .333-1.004m-.333 1.004.333-1.004m0 0 .397-.98m-.397.98.397-.98m0 0 .459-.953m-.459.953.459-.953m0 0 .52-.921m-.52.921.52-.921m0 0 .576-.887m-.577.887.577-.887m0 0 .633-.848m-.633.848.633-.848m0 0 .685-.805m-.685.805.685-.805m0 0 .736-.76m-.736.76.736-.76m0 0 .783-.71m-.783.71.783-.71m0 0 .827-.66m-.827.66.827-.66m0 0c.193-.135.385-.27.868-.605m-.868.605.868-.605m0 0c.245-.15.491-.298.904-.549m-.904.549.904-.549m0 0 .938-.489m-.938.49.938-.49m0 0 .967-.428m-.967.428.967-.428m0 0 .993-.365m-.993.365.993-.365m0 0 1.014-.301m-1.014.3 1.014-.3m0 0 1.03-.236m-1.03.236 1.03-.236m0 0c.376-.06.75-.12 1.045-.169m-1.044.17 1.044-.17m0 0 1.053-.101m-1.053.101 1.053-.101m0 0 1.057-.034m-1.057.034 1.057-.034m0 0" style="fill:#008300!important;stroke:#005400!important" transform="translate(135.96 24.5)"/></g><g class="label" style="color:#fff!important" transform="translate(135.96 15.5)"><rect/><rect class="background" style="stroke:none"/><text y="-10.1" style="fill:#fff!important"><tspan x="0" y="-.1em" class="text-outer-tspan row" dy="1.1em"><tspan class="text-inner-tspan" font-style="normal" font-weight="normal">INICIO</tspan></tspan></text></g></g><g id="dia-s02_d4_gancho-flowchart-L1-1" class="node default" data-look="classic" transform="translate(135.96 107.5)"><polygon points="-16.5,0 161.828125,0 178.328125,-33 0,-33" class="label-container" style="fill:#2a78d6!important;stroke:#104281!important" transform="translate(-80.914 16.5)"/><g class="label" style="color:#fff!important" transform="translate(0 -9)"><rect/><rect class="background" style="stroke:none"/><text y="-10.1" style="fill:#fff!important"><tspan x="0" y="-.1em" class="text-outer-tspan row" dy="1.1em"><tspan class="text-inner-tspan" font-style="normal" font-weight="normal">LEER</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> hora_clase_min</tspan></tspan></text></g></g><g id="dia-s02_d4_gancho-flowchart-L2-2" class="node default" data-look="classic" transform="translate(135.96 190.5)"><polygon points="-16.5,0 142.421875,0 158.921875,-33 0,-33" class="label-container" style="fill:#2a78d6!important;stroke:#104281!important" transform="translate(-71.21 16.5)"/><g class="label" style="color:#fff!important" transform="translate(0 -9)"><rect/><rect class="background" style="stroke:none"/><text y="-10.1" style="fill:#fff!important"><tspan x="0" y="-.1em" class="text-outer-tspan row" dy="1.1em"><tspan class="text-inner-tspan" font-style="normal" font-weight="normal">LEER</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> minutos_bus</tspan></tspan></text></g></g><g id="dia-s02_d4_gancho-flowchart-L3-3" class="node default" data-look="classic" transform="translate(135.96 273.5)"><polygon points="-16.5,0 179.171875,0 195.671875,-33 0,-33" class="label-container" style="fill:#2a78d6!important;stroke:#104281!important" transform="translate(-89.586 16.5)"/><g class="label" style="color:#fff!important" transform="translate(0 -9)"><rect/><rect class="background" style="stroke:none"/><text y="-10.1" style="fill:#fff!important"><tspan x="0" y="-.1em" class="text-outer-tspan row" dy="1.1em"><tspan class="text-inner-tspan" font-style="normal" font-weight="normal">LEER</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> minutos_caminata</tspan></tspan></text></g></g><g id="dia-s02_d4_gancho-flowchart-P1-4" class="node default" data-look="classic" transform="translate(135.96 380.5)"><rect width="239.141" height="81" x="-119.57" y="-40.5" class="basic label-container" style="fill:#4a3aa7!important;stroke:#2a1f6b!important"/><g class="label" style="color:#fff!important" transform="translate(0 -25.5)"><rect/><rect class="background" style="stroke:none"/><text y="-10.1" style="fill:#fff!important"><tspan x="0" y="-.1em" class="text-outer-tspan row" dy="1.1em"><tspan class="text-inner-tspan" font-style="normal" font-weight="normal">trayecto</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> ←</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> minutos_bus</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> +</tspan></tspan><tspan x="0" y="1em" class="text-outer-tspan row" dy="1.1em"><tspan class="text-inner-tspan" font-style="normal" font-weight="normal">minutos_caminata</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> +</tspan></tspan><tspan x="0" y="2.1em" class="text-outer-tspan row" dy="1.1em"><tspan class="text-inner-tspan" font-style="normal" font-weight="normal">PORTERIA</tspan></tspan></text></g></g><g id="dia-s02_d4_gancho-flowchart-P2-5" class="node default" data-look="classic" transform="translate(135.96 511.5)"><rect width="249.656" height="81" x="-124.828" y="-40.5" class="basic label-container" style="fill:#4a3aa7!important;stroke:#2a1f6b!important"/><g class="label" style="color:#fff!important" transform="translate(0 -25.5)"><rect/><rect class="background" style="stroke:none"/><text y="-10.1" style="fill:#fff!important"><tspan x="0" y="-.1em" class="text-outer-tspan row" dy="1.1em"><tspan class="text-inner-tspan" font-style="normal" font-weight="normal">salida_min</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> ←</tspan></tspan><tspan x="0" y="1em" class="text-outer-tspan row" dy="1.1em"><tspan class="text-inner-tspan" font-style="normal" font-weight="normal">hora_clase_min</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> -</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> trayecto</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> -</tspan></tspan><tspan x="0" y="2.1em" class="text-outer-tspan row" dy="1.1em"><tspan class="text-inner-tspan" font-style="normal" font-weight="normal">COLCHON</tspan></tspan></text></g></g><g id="dia-s02_d4_gancho-flowchart-E1-6" class="node default" data-look="classic" transform="translate(135.96 626.75)"><polygon points="-24.75,0 206.421875,0 231.171875,-49.5 0,-49.5" class="label-container" style="fill:#2a78d6!important;stroke:#104281!important" transform="translate(-103.21 24.75)"/><g class="label" style="color:#fff!important" transform="translate(0 -17.25)"><rect/><rect class="background" style="stroke:none"/><text y="-10.1" style="fill:#fff!important"><tspan x="0" y="-.1em" class="text-outer-tspan row" dy="1.1em"><tspan class="text-inner-tspan" font-style="normal" font-weight="normal">ESCRIBIR</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> &apos;Debes</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> salir</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> a</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> las&apos;,</tspan></tspan><tspan x="0" y="1em" class="text-outer-tspan row" dy="1.1em"><tspan class="text-inner-tspan" font-style="normal" font-weight="normal">salida_min</tspan></tspan></text></g></g><g id="dia-s02_d4_gancho-flowchart-F-7" class="node default" data-look="classic"><g class="basic label-container outer-path"><path fill="#008300" stroke="none" stroke-width="0" d="M-6.64-16.5H6.64l1.058.034 1.053.101 1.044.17 1.03.235 1.015.3.993.366.967.428.937.49c.359.216.717.434.905.548l.867.605.827.66.783.71.736.76.686.805.632.848.577.887.52.921.458.953.397.98.334 1.004.268 1.023.202 1.039.135 1.049c.015.223.03.447.068 1.055V.53l-.068 1.055-.135 1.05-.202 1.038-.268 1.023-.334 1.004-.397.98-.458.953-.52.921-.577.887-.632.848-.686.805-.736.76-.783.71c-.234.188-.468.375-.827.66l-.867.605-.905.549-.937.489-.967.428-.993.365-1.014.301-1.031.236-1.044.169-1.053.101-1.057.034H-6.641l-1.057-.034-1.053-.101-1.044-.17-1.03-.235-1.015-.3-.993-.366-.967-.428-.937-.49-.905-.548-.867-.605q-.418-.332-.827-.66l-.783-.71-.736-.76-.686-.805-.632-.848-.577-.887-.52-.921-.458-.953-.397-.98-.334-1.004-.268-1.023-.202-1.039-.135-1.049-.068-1.055V-.53l.068-1.055.135-1.05.202-1.038.268-1.023.334-1.004.397-.98.458-.953.52-.921.577-.887.632-.848.686-.805.736-.76.783-.71.827-.66.867-.605.905-.549.937-.489.967-.428.993-.365 1.014-.301 1.031-.236 1.044-.169 1.053-.101 1.057-.034" style="fill:#008300!important;stroke:#005400!important" transform="translate(135.96 718)"/><path fill="none" stroke="#005400" stroke-dasharray="0 0" stroke-width="1.3" d="M-6.64-16.5H6.64m-13.28 0H6.64m0 0 1.058.034M6.64-16.5l1.057.034m0 0 1.053.101m-1.053-.101 1.053.101m0 0 1.044.17m-1.044-.17 1.044.17m0 0 1.03.235m-1.03-.236 1.03.236m0 0 1.015.3m-1.014-.3 1.014.3m0 0 .993.366m-.993-.365.993.365m0 0 .967.428m-.967-.428.967.428m0 0 .937.49m-.937-.49.937.49m0 0c.323.195.646.39.905.548m-.905-.549.905.549m0 0 .867.605m-.867-.605.867.605m0 0c.201.16.403.32.827.66m-.827-.66.827.66m0 0 .783.71m-.783-.71.783.71m0 0 .736.76m-.736-.76.736.76m0 0 .686.805m-.686-.805.686.805m0 0 .632.848m-.632-.848.632.848m0 0 .577.887m-.577-.887.577.887m0 0 .52.921m-.52-.921.52.921m0 0 .458.953m-.458-.953.458.953m0 0 .397.98m-.397-.98.397.98m0 0 .334 1.004m-.334-1.004.334 1.004m0 0 .268 1.023m-.268-1.023.268 1.023m0 0 .202 1.039m-.202-1.039.202 1.039m0 0 .135 1.049m-.135-1.05.135 1.05m0 0 .068 1.055m-.068-1.055.068 1.055m0 0V.53m0-1.058V.53m0 0-.068 1.055M23.132.53l-.068 1.055m0 0-.135 1.05m.135-1.05-.135 1.05m0 0-.202 1.038m.202-1.039c-.04.211-.082.422-.202 1.039m0 0-.268 1.023m.268-1.023-.268 1.023m0 0L22.125 5.7m.334-1.004L22.125 5.7m0 0-.397.98m.397-.98-.397.98m0 0-.458.953m.458-.953-.458.953m0 0-.52.921m.52-.921-.52.921m0 0-.577.887m.577-.887-.577.887m0 0-.632.848m.632-.848-.632.848m0 0-.686.805m.686-.805-.686.805m0 0-.736.76m.736-.76-.736.76m0 0-.783.71m.783-.71q-.391.357-.783.71m0 0-.827.66m.827-.66c-.192.154-.384.308-.827.66m0 0-.867.605m.867-.605-.867.605m0 0-.905.549m.905-.549-.905.549m0 0-.937.489m.937-.49-.937.49m0 0-.967.428m.967-.428-.967.428m0 0-.993.365m.993-.365-.993.365m0 0-1.014.301m1.014-.3-1.014.3m0 0-1.031.236m1.03-.236-1.03.236m0 0-1.044.169m1.044-.17-1.044.17m0 0-1.053.101m1.053-.101-1.053.101m0 0L6.64 16.5m1.057-.034L6.64 16.5m0 0H-6.641m13.282 0H-6.641m0 0-1.057-.034m1.057.034-1.057-.034m0 0-1.053-.101m1.053.101-1.053-.101m0 0-1.044-.17m1.044.17-1.044-.17m0 0c-.303-.068-.606-.138-1.03-.235m1.03.236-1.03-.236m0 0-1.015-.3m1.014.3-1.014-.3m0 0-.993-.366m.993.365-.993-.365m0 0-.967-.428m.967.428-.967-.428m0 0-.937-.49m.937.49-.937-.49m0 0-.905-.548m.905.549-.905-.549m0 0-.867-.605m.867.605-.867-.605m0 0c-.33-.262-.659-.525-.827-.66m.827.66c-.228-.18-.455-.362-.827-.66m0 0-.783-.71m.783.71-.783-.71m0 0-.736-.76m.736.76-.736-.76m0 0-.686-.805m.686.805-.686-.805m0 0-.632-.848m.632.848-.632-.848m0 0-.577-.887m.577.887-.577-.887m0 0-.52-.921m.52.921c-.165-.29-.329-.582-.52-.921m0 0-.458-.953m.458.953-.458-.953m0 0-.397-.98m.397.98-.397-.98m0 0-.334-1.004m.334 1.004-.334-1.004m0 0-.268-1.023m.268 1.023-.268-1.023m0 0-.202-1.039m.202 1.039-.202-1.039m0 0-.135-1.049m.135 1.05-.135-1.05m0 0c-.02-.292-.038-.585-.068-1.055m.068 1.055L-23.132.53m0 0V-.53m0 1.058V-.53m0 0c.015-.242.03-.483.068-1.055m-.068 1.055.068-1.055m0 0 .135-1.05m-.135 1.05c.04-.32.082-.638.135-1.05m0 0 .202-1.038m-.202 1.039.202-1.039m0 0 .268-1.023m-.268 1.023.268-1.023m0 0 .334-1.004m-.334 1.004.334-1.004m0 0 .397-.98m-.397.98.397-.98m0 0 .458-.953m-.458.953.458-.953m0 0 .52-.921m-.52.921.52-.921m0 0 .577-.887m-.577.887.577-.887m0 0 .632-.848m-.632.848.632-.848m0 0 .686-.805m-.686.805.686-.805m0 0 .736-.76m-.736.76.736-.76m0 0c.201-.183.402-.366.783-.71m-.783.71c.238-.217.477-.434.783-.71m0 0 .827-.66m-.827.66.827-.66m0 0 .867-.605m-.867.605c.23-.162.462-.323.867-.605m0 0 .905-.549m-.905.549.905-.549m0 0 .937-.489m-.937.49.937-.49m0 0 .967-.428m-.967.428.967-.428m0 0 .993-.365m-.993.365.993-.365m0 0 1.014-.301m-1.014.3 1.014-.3m0 0 1.031-.236m-1.03.236 1.03-.236m0 0 1.044-.169m-1.044.17 1.044-.17m0 0 1.053-.101m-1.053.101 1.053-.101m0 0 1.057-.034m-1.057.034 1.057-.034m0 0" style="fill:#008300!important;stroke:#005400!important" transform="translate(135.96 718)"/></g><g class="label" style="color:#fff!important" transform="translate(135.96 709)"><rect/><rect class="background" style="stroke:none"/><text y="-10.1" style="fill:#fff!important"><tspan x="0" y="-.1em" class="text-outer-tspan row" dy="1.1em"><tspan class="text-inner-tspan" font-style="normal" font-weight="normal">FIN</tspan></tspan></text></g></g></g></g><defs><filter id="dia-s02_d4_gancho-drop-shadow" width="130%" height="130%"><feDropShadow dx="4" dy="4" flood-color="#000" flood-opacity=".06" stdDeviation="0"/></filter></defs><defs><filter id="dia-s02_d4_gancho-drop-shadow-small" width="150%" height="150%"><feDropShadow dx="2" dy="2" flood-color="#000" flood-opacity=".06" stdDeviation="0"/></filter></defs><linearGradient id="dia-s02_d4_gancho-gradient" x1="0%" x2="100%" y1="0%" y2="0%" gradientUnits="objectBoundingBox"><stop offset="0%" stop-color="hsl(0, 0%, 83.3333333333%)" stop-opacity="1"/><stop offset="100%" stop-color="hsl(0, 0%, 88.9215686275%)" stop-opacity="1"/></linearGradient></svg>', 'El algoritmo del gancho, dibujado. Es el que vas a traducir a Python en el ejercicio 7.')

# %% [markdown]
# ### Ejercicio 7 — Traduce el algoritmo a Python
#
# *Dificultad ★★★☆ · 15 puntos*
#
# Este es el algoritmo del gancho, el de «¿a qué hora salgo de la casa?»:
#
# ```
# Algoritmo AQueHoraSalgo
#     Definir hora_clase_min, minutos_bus, minutos_caminata Como Entero
#     Definir trayecto, salida_min Como Entero
#     Constante PORTERIA <- 10
#     Constante COLCHON  <- 15
#
#     trayecto   <- minutos_bus + minutos_caminata + PORTERIA
#     salida_min <- hora_clase_min - trayecto - COLCHON
# FinAlgoritmo
# ```
#
# Escríbelo como una **función de Python** que reciba los tres datos y
# **retorne** `salida_min`:
#
# ```python
# def hora_de_salida(hora_clase_min, minutos_bus, minutos_caminata):
#     ...
# ```
#
# Las dos constantes van **dentro** de la función, en mayúsculas. La función **no
# imprime nada y no pregunta nada**: solo recibe y retorna. (Ya sabes por qué: una
# función que recibe sus datos se puede probar; una que pregunta, no.)
#
# Comprobación rápida: con la clase a las 6:00 (que son 360 minutos desde
# medianoche), 45 de bus y 8 de caminata, debe retornar **282**, que son las
# 4:42.
#
# > ¿Atascado? Ejecuta `pista("E7")` en una celda nueva. Hay 3, de la que hace pensar a la que casi resuelve. Pedirlas no resta puntos.

# %%
def hora_de_salida(hora_clase_min, minutos_bus, minutos_caminata):
    # Las dos constantes van aquí adentro, en mayúsculas.
    # Después las dos cuentas del pseudocódigo, y al final: return salida_min
    ...
### INICIO SOLUCION
def hora_de_salida(hora_clase_min, minutos_bus, minutos_caminata):
    PORTERIA = 10
    COLCHON = 15
    trayecto = minutos_bus + minutos_caminata + PORTERIA
    salida_min = hora_clase_min - trayecto - COLCHON
    return salida_min
### FIN SOLUCION

# %%
import inspect

assert callable(hora_de_salida), "hora_de_salida debe ser una función"
firma_e7 = list(inspect.signature(hora_de_salida).parameters)
assert firma_e7 == ["hora_clase_min", "minutos_bus", "minutos_caminata"], (
    f"La función debe recibir exactamente (hora_clase_min, minutos_bus, minutos_caminata) "
    f"y la tuya recibe {firma_e7}")

CASOS_E7 = [
    ((360, 45,  8), 282),   # clase a las 6:00, el caso del gancho -> 4:42
    ((420, 60,  5), 330),   # clase a las 7:00 desde más lejos     -> 5:30
    ((360,  0,  0), 335),   # vives al frente: solo portería y colchón
    ((480, 30, 12), 413),   # clase a las 8:00
]
for args_e7, esperado_e7 in CASOS_E7:
    obtenido_e7 = hora_de_salida(*args_e7)
    assert obtenido_e7 is not None, (
        "Tu función no retorna nada. ¿Se te olvidó la palabra return?")
    assert obtenido_e7 == esperado_e7, (
        f"Con hora_clase_min={args_e7[0]}, bus={args_e7[1]} y caminata={args_e7[2]} "
        f"debe retornar {esperado_e7} y retornó {obtenido_e7}. "
        "Acuérdate de restar TAMBIÉN los 10 de portería y los 15 de colchón.")

# La función de Python y el pseudocódigo tienen que dar lo mismo.
REFERENCIA_E7 = """Algoritmo AQueHoraSalgo
    Definir hora_clase_min, minutos_bus, minutos_caminata Como Entero
    Definir trayecto, salida_min Como Entero
    Constante PORTERIA <- 10
    Constante COLCHON  <- 15
    Leer hora_clase_min
    Leer minutos_bus
    Leer minutos_caminata
    trayecto   <- minutos_bus + minutos_caminata + PORTERIA
    salida_min <- hora_clase_min - trayecto - COLCHON
    Escribir salida_min
FinAlgoritmo"""
r_e7 = ps.ejecutar_pseudo(REFERENCIA_E7, entradas=["390", "50", "7"])
assert hora_de_salida(390, 50, 7) == r_e7.memoria["salida_min"], (
    "Tu función en Python y el pseudocódigo del enunciado dan resultados distintos. "
    "Compáralos línea por línea.")
print("E7 correcto: tu traducción a Python coincide con el pseudocódigo en los 5 casos.")

# %% [markdown]
# ### Ejercicio 8 — El mismo algoritmo, en los dos idiomas
#
# *Dificultad ★★★★ · 15 puntos*
#
# **Problema:** *Calcular cuánto vas a gastar en pasajes durante todo el
# semestre.* Entran tres datos: cuántos **viajes haces por semana**, cuántas
# **semanas** dura el semestre y cuánto cuesta el **pasaje**. Sale un solo número:
# el **gasto total**.
#
# Esta es la evidencia de la semana: el mismo algoritmo escrito en los tres
# idiomas. El diagrama lo dibuja el computador a partir de tu pseudocódigo, así
# que te toca escribir dos cosas:
#
# **1. `pseudo_e8`** — el algoritmo en pseudocódigo, con `Definir`, tres `Leer`
# (en el orden viajes → semanas → pasaje), el cálculo, y un `Escribir` que muestre
# el total. El resultado debe quedar en una variable llamada **`total`**.
#
# **2. `gasto_semestre()`** — una función de Python que **lee los tres datos con
# `input()`** y **retorna** el total como entero.
#
# ```python
# def gasto_semestre():
#     viajes = int(input())
#     ...
# ```
#
# No te preocupes por teclear: el corrector le pasa los datos con
# `ps.entradas([...])`, tal como practicaste en el laboratorio. Tu `input()` es un
# `input()` de verdad.
#
# Comprobación: 10 viajes por semana, 16 semanas, pasaje de $3.200 →
# **$512.000**.
#
# > ¿Atascado? Ejecuta `pista("E8")` en una celda nueva. Hay 3, de la que hace pensar a la que casi resuelve. Pedirlas no resta puntos.

# %%
# 1. Tu algoritmo en pseudocódigo. Completa lo que falta.
pseudo_e8 = """Algoritmo GastoDelSemestre
    Definir viajes, semanas, pasaje, total Como Entero

    Escribir "¿Cuántos viajes haces por semana?"
    Leer viajes

FinAlgoritmo"""


# 2. El mismo algoritmo como función de Python.
def gasto_semestre():
    viajes = int(input())
    ...
### INICIO SOLUCION
pseudo_e8 = """Algoritmo GastoDelSemestre
    Definir viajes, semanas, pasaje, total Como Entero

    Escribir "¿Cuántos viajes haces por semana?"
    Leer viajes
    Escribir "¿Cuántas semanas dura el semestre?"
    Leer semanas
    Escribir "¿Cuánto cuesta el pasaje?"
    Leer pasaje

    total <- viajes * semanas * pasaje

    Escribir "Vas a gastar $", total
FinAlgoritmo"""


def gasto_semestre():
    viajes = int(input())
    semanas = int(input())
    pasaje = int(input())
    return viajes * semanas * pasaje
### FIN SOLUCION

# %%
import inspect
from IPython.display import HTML, display

CASOS_E8 = [
    (["10", "16", "3200"], 512000),
    (["4",  "18", "2900"], 208800),
    (["0",  "16", "3200"], 0),
]

# -- Parte 1: el pseudocódigo -------------------------------------------------
assert isinstance(pseudo_e8, str) and pseudo_e8.strip(), "pseudo_e8 debe ser tu algoritmo en texto"
usadas_e8 = ps.ejecutar_pseudo(pseudo_e8, entradas=["10", "16", "3200"]).instrucciones_usadas
for palabra in ("Definir", "Leer", "Escribir", "Asignar"):
    assert palabra in usadas_e8, (
        f"A tu pseudocódigo le falta al menos un(a) {palabra}. "
        "El algoritmo tiene que definir las cajas, leer los tres datos, calcular y mostrar.")

for entradas_caso, esperado_e8 in CASOS_E8:
    r_e8 = ps.ejecutar_pseudo(pseudo_e8, entradas=entradas_caso)
    assert r_e8.ok, (
        f"Tu pseudocódigo falla con las entradas {entradas_caso}. "
        f"El motor dice: {r_e8.error_corto}")
    assert "total" in r_e8.memoria, (
        "El resultado debe quedar guardado en una variable llamada 'total'")
    assert r_e8.memoria["total"] == esperado_e8, (
        f"Con {entradas_caso[0]} viajes, {entradas_caso[1]} semanas y pasaje de "
        f"${entradas_caso[2]} el total es {esperado_e8}, y tu algoritmo dio "
        f"{r_e8.memoria['total']}.")
    assert str(esperado_e8) in r_e8.salida, (
        "Tu algoritmo calcula bien pero no muestra el total. Revisa el Escribir del final.")

# -- Parte 2: la función de Python --------------------------------------------
assert callable(gasto_semestre), "gasto_semestre debe ser una función"
assert list(inspect.signature(gasto_semestre).parameters) == [], (
    "gasto_semestre() no recibe parámetros: los tres datos los pide con input()")

for entradas_caso, esperado_e8 in CASOS_E8:
    with ps.entradas(entradas_caso):
        obtenido_e8 = gasto_semestre()
    assert obtenido_e8 is not None, "A tu función le falta el return"
    assert obtenido_e8 == esperado_e8, (
        f"Con las entradas {entradas_caso} debe retornar {esperado_e8} "
        f"y retornó {obtenido_e8}.")
    assert type(obtenido_e8) is int, (
        f"El total debe ser un entero (int) y es {type(obtenido_e8).__name__}. "
        "Si usaste float() en vez de int() al convertir, ahí está el problema.")

# -- Parte 3: los dos idiomas tienen que decir lo mismo -----------------------
with ps.entradas(["7", "16", "3500"]):
    py_e8 = gasto_semestre()
pseudo_total_e8 = ps.ejecutar_pseudo(pseudo_e8, entradas=["7", "16", "3500"]).memoria["total"]
assert py_e8 == pseudo_total_e8, (
    f"Tu pseudocódigo da {pseudo_total_e8} y tu Python da {py_e8} con los mismos datos. "
    "Son el mismo algoritmo: tienen que coincidir siempre.")
print("E8 correcto. Escribiste el mismo algoritmo en dos idiomas y los dos dicen lo mismo.")
print("Mira su diagrama de flujo:")
display(HTML(ps.diagrama(pseudo_e8)))

# %% [markdown]
# ---
#
# ## 6. El reto
#
# *(opcional, sin nota)*
#
# ### Reto A — Llévate tu diagrama a la clase
#
# El algoritmo que escribiste en E8 es tuyo. Ejecuta la celda de abajo y vas a
# obtener dos cosas:
#
# 1. **El guion**: la lista exacta de bloques que tienes que arrastrar en
#    Flowgorithm, en orden.
# 2. **El archivo `mi_algoritmo.fprg`**: descárgalo desde el explorador de
#    archivos de Jupyter (menú *File → Open*, después clic derecho sobre el
#    archivo → *Download*) y ábrelo en la sala de cómputo.
#
# En la Clase 2 vas a construir ese mismo diagrama y a ejecutarlo dentro de
# Flowgorithm. Vas a llegar con la tarea medio hecha, y —más importante— vas a
# poder comparar: **el mismo algoritmo en dos herramientas distintas se ve
# distinto y hace lo mismo.**
#
# > **Si el `.fprg` no abre**, no pierdas el tiempo peleando con él: el formato
# > depende de la versión de Flowgorithm instalada en la sala. El guion impreso no
# > depende de nada y es el camino seguro.

# %%
# Si todavía no hiciste E8, se usa el algoritmo de la papelería.
mi_algoritmo = pseudo_e8 if "pseudo_e8" in globals() else PAPELERIA

ps.guion_flowgorithm(mi_algoritmo)
ps.exportar_flowgorithm(mi_algoritmo, "mi_algoritmo.fprg")

# %% [markdown]
# ### Reto B — Un vistazo a la semana entrante *(míralo, no lo estudies)*
#
# Todo lo de hoy fue **secuencia**: una instrucción detrás de otra, sin desvíos.
# La semana entrante aparece el rombo, y con él la palabra `Si`:
#
# ```
# Algoritmo AlcanzaElSaldo
#     Definir saldo Como Entero
#     Constante PASAJE <- 3200
#
#     Escribir "¿Cuánto tienes en la tarjeta?"
#     Leer saldo
#
#     Si saldo >= PASAJE Entonces
#         Escribir "Te alcanza. Sube tranquilo."
#     Sino
#         Escribir "No te alcanza. Toca recargar."
#     FinSi
# FinAlgoritmo
# ```
#
# Ejecuta la celda de abajo con `["12000"]` y después con `["1500"]`, y mira el
# diagrama: vas a ver el rombo con sus dos flechas, **Sí** y **No**. No tienes que
# entenderlo hoy. Solo mira cómo se ve un algoritmo que toma decisiones.

# %%
RETO_SI = """Algoritmo AlcanzaElSaldo
    Definir saldo Como Entero
    Constante PASAJE <- 3200

    Escribir "¿Cuánto tienes en la tarjeta?"
    Leer saldo

    Si saldo >= PASAJE Entonces
        Escribir "Te alcanza. Sube tranquilo."
    Sino
        Escribir "No te alcanza. Toca recargar."
    FinSi
FinAlgoritmo"""

# Cambia "12000" por "1500" y vuelve a ejecutar.
ps.trazador(RETO_SI, entradas=["12000"])

# %% [markdown]
# ---
#
# ## 6. Habla con el asistente · 5 min
#
# Tienes **5 preguntas** en este cuadernillo (las ves en el botón de abajo a la
# derecha). Cinco no es poco: es justo lo que alcanza si preguntas bien. Aquí van
# cinco que valen la pena, una por cada cosa importante de hoy:
#
# 1. *«Te voy a explicar con mis palabras qué es la estructura
#    Entrada-Proceso-Salida. Dime qué me está faltando, sin darme la respuesta
#    completa.»*
# 2. *«Escribí este pseudocódigo [pégalo]. No me lo corrijas: hazme tres preguntas
#    que me ayuden a encontrar yo mismo el error.»*
# 3. *«Mi diagrama de flujo tiene un rombo del que sale una sola flecha. ¿Por qué
#    eso está mal? Explícamelo con un ejemplo de la vida diaria.»*
# 4. *«Hice la prueba de escritorio del ejercicio 5 y me dio distinto al
#    corrector. Pregúntame paso por paso qué anoté, para que yo vea dónde me
#    desvié.»*
# 5. *«¿Por qué `input()` siempre devuelve texto? Dame otro ejemplo, distinto al
#    del cuadernillo, donde eso cause un error.»*
#
# **Lo que no vale la pena preguntar:** *«dame la respuesta del E7»*. Te la va a
# dar —está programado para no hacerlo, pero eventualmente cede—, y el día del
# parcial el que va a estar sentado ahí eres tú.
#
# Fíjate en el patrón de las cinco: ninguna pide una solución. Todas piden **que
# te pregunte a ti**. Ese es el uso que sirve.
#
# Y antes de gastar una: **haz clic en la celda del ejercicio donde estás
# atascado**. El panel toma solo el enunciado, tu código y el último error. Si
# preguntas desde otra parte, el asistente responde a ciegas.

# %% [markdown]
# ---
#
# ## 7. Cierre · 7 min
#
# Antes de reclamar tu insignia, marca honestamente lo que ya puedes hacer. Esto
# no tiene nota: es tu plan para la semana.

# %%
radar_salida()

# %% [markdown]
# ### Lo que cubriste hoy

# %%
tabla_cobertura()

# %% [markdown]
# ### Para profundizar *(fuentes confiables)*
#
# - **PSeInt** (`pseint.sourceforge.net`) — el intérprete de pseudocódigo en
#   español más usado en Latinoamérica. La sintaxis que aprendiste hoy es
#   prácticamente la suya: si lo instalas, ya sabes usarlo.
# - **Flowgorithm** (`flowgorithm.org`) — el que van a usar en la sala. La sección
#   *Documentation* tiene la referencia de cada bloque.
# - *How to Think Like a Computer Scientist* (Runestone Academy), capítulos 1 y 2
#   — libro de CS1 abierto, con ejercicios ejecutables.
# - **Python Tutor** (`pythontutor.com`) — visualiza la memoria de un programa de
#   Python paso a paso, igual que el trazador de hoy pero para Python de verdad.
#   Muy recomendado para las próximas semanas.

# %%
cierre()
