# %% [markdown]
# # Hola, máquina
# ### Semana 1 · Unidad 1 · Fundamentos computacionales y entorno de desarrollo
#
# Bienvenido a Algoritmos y Programación. Esto que estás viendo es un
# **cuadernillo interactivo**: un documento donde el texto y el código conviven y
# donde el código se ejecuta aquí mismo, en tu navegador, sin instalar nada.
#
# En los próximos **diez minutos** vas a ejecutar tu primer programa. Hoy. Tú.
# Y antes de que termine el cuadernillo vas a saber qué pasa por dentro de la
# máquina cuando lo haces.
#
# **Empieza ejecutando la celda de abajo**: haz clic sobre ella y presiona
# `Shift+Enter`.

# %%
# Motor del cuadernillo: barra de progreso, pistas y verificadores.
# No necesitas leer este codigo. Ejecutalo una vez (Shift+Enter) y sigue.
# Codigo fuente legible en el repositorio del curso:
#   notebook/cuadernillos/**/ava_motor.py
#   notebook/cuadernillos/**/contenido.py
import base64, zlib
exec(zlib.decompress(base64.b64decode("...")).decode("utf-8"))
exec(zlib.decompress(base64.b64decode("...")).decode("utf-8"))

ava = Motor(titulo='Hola, máquina', meta_xp=70, insignia='Despegue')
quiz, ordenar, comprobar, pista = ava.quiz, ava.ordenar, ava.comprobar, ava.pista

# Pistas de los ejercicios. Van comprimidas para no destriparlas:
# se piden una a una con pista("E1"), o con el boton Pista.
import json as _json
for _c, _p in _json.loads(zlib.decompress(base64.b64decode("...")).decode("utf-8")).items():
    ava.registrar_pistas(_c, _p)

ava.barra()
esconder_entrada()

# %%
iniciar()

# %% [markdown]
# ## Al terminar este cuadernillo vas a poder…
#
# - Contar, sin leer, **de dónde salió la computación**: de una idea matemática
#   de hace mil años, no de un aparato.
# - Señalar qué parte de un sistema es **hardware**, cuál es **software**, cuál
#   es un **dato** y cuál es un **proceso** — y no confundirlos nunca más.
# - Explicar por qué existen **tres alturas de lenguaje** (máquina, ensamblador,
#   alto nivel) y ver la misma suma escrita en las tres.
# - Distinguir un **editor**, una **terminal**, un **intérprete** y un **IDE**, y
#   decir para qué sirven Python, VS Code y Jupyter sin repetir un eslogan.
# - Crear, escribir y leer un **archivo** desde código.
# - Reconocer los **tres tipos de error** —sintaxis, ejecución y lógica— y saber
#   cuál de los tres nadie te va a avisar.
#
# **Lo que NO se te pide hoy:** escribir programas largos, memorizar fechas ni
# saber nada de antemano. Si nunca has programado, este cuadernillo está escrito
# para ti; si ya programaste, los ejercicios 5 a 7 te van a exigir.

# %% [markdown]
# > **Dos marcadores distintos, no los confundas.** Los **XP** son del juego: los
# > ganas explorando, respondiendo quices y rompiendo cosas. Los **puntos** son tu
# > nota: salen solo de los siete ejercicios y viajan solos a Moodle. Puedes
# > terminar con 70 XP y 0 puntos, o al revés. Lo ideal es lo primero *y* lo
# > segundo.
# >
# > Este cuadernillo tiene **25 puntos** y **70 XP**. La insignia se llama «Despegue».

# %% [markdown]
# ---
#
# ## 1. Tu primer programa · 15 min
#
# Desde 1978, casi todo el que aprende a programar empieza igual: haciendo que la
# máquina salude. Es un ritual de iniciación y hoy te toca a ti.
#
# Ejecuta la celda de abajo (clic + `Shift+Enter`).

# %%
print("¡Hola, mundo!")

# %% [markdown]
# ¿Salió el texto ahí abajo? **Eso fue un programa.** Uno de verdad: una
# instrucción (`print`) que le ordenó a un computador mostrar algo, y el
# computador obedeció.
#
# Ahora lo importante: los programas **se modifican**. Haz que te salude a ti.
# Cambia solo lo que está entre comillas y ejecuta.

# %%
mi_nombre = "escribe tu nombre aquí"   # <- cambia SOLO lo que está entre comillas

print("Hola,", mi_nombre + ".", "Bienvenido a Algoritmos y Programación.")

# %% [markdown]
# Acabas de usar tu primera **variable** (`mi_nombre`): una cajita con nombre
# donde guardas un dato. Volveremos a ellas en la semana 2; hoy solo saluda.
#
# Fíjate en algo que va a gobernar todo el semestre: **el computador no adivinó
# nada.** Hizo exactamente lo que decía la instrucción, ni más ni menos. Cuando
# algo salga mal —y va a salir mal— la causa casi siempre será esa.

# %% [markdown]
# ### 1.2 Tu punto de partida
#
# Antes de enseñarte nada, quiero saber de dónde arrancas. Esto **no tiene nota y
# no se compara con nadie**: es una foto tuya, de hoy, y en la semana 16 la vamos
# a volver a mirar juntos.
#
# Aquí no hay respuestas malas. Hay respuestas *de hoy*. Si no sabes algo,
# responde lo que te parezca y sigue: exactamente para eso existe el curso.
#
# Responde las siete y presiona el botón del final. **+10 XP por completarlo,
# elijas lo que elijas.**

# %%
diagnostico()

# %% [markdown]
# *En el curso real, este punto de partida —junto con un cuestionario un poco más
# completo en Moodle— es la línea base con la que vamos a medir cuánto creciste
# durante el semestre. Se usa de forma anónima y con tu consentimiento informado;
# el profesor te lo explica en la primera clase, y no participar no afecta tu
# nota en absoluto.*

# %% [markdown]
# ---
#
# ## 2. ¿Qué pasó cuando presionaste Shift+Enter? · 5 min
#
# Escribiste una línea en español-ish, presionaste dos teclas y apareció un
# saludo. Entre esas dos cosas ocurrieron, como mínimo, **siete pasos** repartidos
# en cuatro piezas distintas, y ninguna de ellas entiende la palabra `print`.
#
# Ejecuta la celda para verlos.

# %%
# Diagrama: s01_d4_shift_enter
ava.figura('<svg xmlns="http://www.w3.org/2000/svg" id="dia-s01_d4_shift_enter" width="100%" aria-roledescription="sequence" role="graphics-document document" style="max-width:1138px;background-color:transparent" viewBox="-50 -10 1138 509"><rect width="150" height="65" x="888" y="423" fill="#eaeaea" stroke="#666" class="actor actor-bottom" name="C" rx="3" ry="3"/><text x="963" y="455.5" alignment-baseline="central" class="actor actor-box" dominant-baseline="central" style="text-anchor:middle;font-size:16px;font-weight:400"><tspan x="963" dy="0">CPU</tspan></text><rect width="150" height="65" x="535" y="423" fill="#eaeaea" stroke="#666" class="actor actor-bottom" name="K" rx="3" ry="3"/><text x="610" y="455.5" alignment-baseline="central" class="actor actor-box" dominant-baseline="central" style="text-anchor:middle;font-size:16px;font-weight:400"><tspan x="610" dy="0">Kernel de Python</tspan></text><rect width="150" height="65" x="303" y="423" fill="#eaeaea" stroke="#666" class="actor actor-bottom" name="S" rx="3" ry="3"/><text x="378" y="455.5" alignment-baseline="central" class="actor actor-box" dominant-baseline="central" style="text-anchor:middle;font-size:16px;font-weight:400"><tspan x="378" dy="0">Servidor de Jupyter</tspan></text><rect width="150" height="65" x="0" y="423" fill="#eaeaea" stroke="#666" class="actor actor-bottom" name="N" rx="3" ry="3"/><text x="75" y="455.5" alignment-baseline="central" class="actor actor-box" dominant-baseline="central" style="text-anchor:middle;font-size:16px;font-weight:400"><tspan x="75" dy="0">Navegador</tspan></text><line id="actor3" x1="963" x2="963" y1="65" y2="423" stroke="#999" stroke-width=".5" class="actor-line 200" data-et="life-line" data-id="C" name="C"/><g id="root-3" data-et="participant" data-id="C" data-type="participant"><rect width="150" height="65" x="888" y="0" fill="#eaeaea" stroke="#666" class="actor actor-top" name="C" rx="3" ry="3"/><text x="963" y="32.5" alignment-baseline="central" class="actor actor-box" dominant-baseline="central" style="text-anchor:middle;font-size:16px;font-weight:400"><tspan x="963" dy="0">CPU</tspan></text></g><line id="actor2" x1="610" x2="610" y1="65" y2="423" stroke="#999" stroke-width=".5" class="actor-line 200" data-et="life-line" data-id="K" name="K"/><g id="root-2" data-et="participant" data-id="K" data-type="participant"><rect width="150" height="65" x="535" y="0" fill="#eaeaea" stroke="#666" class="actor actor-top" name="K" rx="3" ry="3"/><text x="610" y="32.5" alignment-baseline="central" class="actor actor-box" dominant-baseline="central" style="text-anchor:middle;font-size:16px;font-weight:400"><tspan x="610" dy="0">Kernel de Python</tspan></text></g><line id="actor1" x1="378" x2="378" y1="65" y2="423" stroke="#999" stroke-width=".5" class="actor-line 200" data-et="life-line" data-id="S" name="S"/><g id="root-1" data-et="participant" data-id="S" data-type="participant"><rect width="150" height="65" x="303" y="0" fill="#eaeaea" stroke="#666" class="actor actor-top" name="S" rx="3" ry="3"/><text x="378" y="32.5" alignment-baseline="central" class="actor actor-box" dominant-baseline="central" style="text-anchor:middle;font-size:16px;font-weight:400"><tspan x="378" dy="0">Servidor de Jupyter</tspan></text></g><line id="actor0" x1="75" x2="75" y1="65" y2="423" stroke="#999" stroke-width=".5" class="actor-line 200" data-et="life-line" data-id="N" name="N"/><g id="root-0" data-et="participant" data-id="N" data-type="participant"><rect width="150" height="65" x="0" y="0" fill="#eaeaea" stroke="#666" class="actor actor-top" name="N" rx="3" ry="3"/><text x="75" y="32.5" alignment-baseline="central" class="actor actor-box" dominant-baseline="central" style="text-anchor:middle;font-size:16px;font-weight:400"><tspan x="75" dy="0">Navegador</tspan></text></g><style>#dia-s01_d4_shift_enter{font-family:system-ui,-apple-system,&apos;Segoe UI&apos;,Roboto,sans-serif;font-size:15px;fill:#000000;}@keyframes edge-animation-frame{from{stroke-dashoffset:0;}}@keyframes dash{to{stroke-dashoffset:0;}}#dia-s01_d4_shift_enter .edge-animation-slow{stroke-dasharray:9,5!important;stroke-dashoffset:900;animation:dash 50s linear infinite;stroke-linecap:round;}#dia-s01_d4_shift_enter .edge-animation-fast{stroke-dasharray:9,5!important;stroke-dashoffset:900;animation:dash 20s linear infinite;stroke-linecap:round;}#dia-s01_d4_shift_enter .error-icon{fill:#552222;}#dia-s01_d4_shift_enter .error-text{fill:#552222;stroke:#552222;}#dia-s01_d4_shift_enter .edge-thickness-normal{stroke-width:1px;}#dia-s01_d4_shift_enter .edge-thickness-thick{stroke-width:3.5px;}#dia-s01_d4_shift_enter .edge-pattern-solid{stroke-dasharray:0;}#dia-s01_d4_shift_enter .edge-thickness-invisible{stroke-width:0;fill:none;}#dia-s01_d4_shift_enter .edge-pattern-dashed{stroke-dasharray:3;}#dia-s01_d4_shift_enter .edge-pattern-dotted{stroke-dasharray:2;}#dia-s01_d4_shift_enter .marker{fill:#52514e;stroke:#52514e;}#dia-s01_d4_shift_enter .marker.cross{stroke:#52514e;}#dia-s01_d4_shift_enter svg{font-family:system-ui,-apple-system,&apos;Segoe UI&apos;,Roboto,sans-serif;font-size:15px;}#dia-s01_d4_shift_enter p{margin:0;}#dia-s01_d4_shift_enter .actor{stroke:hsl(0, 0%, 83%);fill:#eee;stroke-width:1;}#dia-s01_d4_shift_enter rect.actor.outer-path[data-look=&quot;neo&quot;]{filter:drop-shadow( 1px 2px 2px rgba(185,185,185,1));}#dia-s01_d4_shift_enter rect.note[data-look=&quot;neo&quot;]{stroke:#999;fill:#666;filter:drop-shadow( 1px 2px 2px rgba(185,185,185,1));}#dia-s01_d4_shift_enter text.actor&gt;tspan{fill:#333;stroke:none;}#dia-s01_d4_shift_enter .actor-line{stroke:hsl(0, 0%, 83%);}#dia-s01_d4_shift_enter .innerArc{stroke-width:1.5;stroke-dasharray:none;}#dia-s01_d4_shift_enter .messageLine0{stroke-width:1.5;stroke-dasharray:none;stroke:#333;}#dia-s01_d4_shift_enter .messageLine1{stroke-width:1.5;stroke-dasharray:2,2;stroke:#333;}#dia-s01_d4_shift_enter [id$=&quot;-arrowhead&quot;] path{fill:#333;stroke:#333;}#dia-s01_d4_shift_enter .sequenceNumber{fill:white;}#dia-s01_d4_shift_enter [id$=&quot;-sequencenumber&quot;]{fill:#333;}#dia-s01_d4_shift_enter [id$=&quot;-crosshead&quot;] path{fill:#333;stroke:#333;}#dia-s01_d4_shift_enter .messageText{fill:#333;stroke:none;}#dia-s01_d4_shift_enter .labelBox{stroke:hsl(0, 0%, 83%);fill:#eee;filter:none;}#dia-s01_d4_shift_enter .labelText,#dia-s01_d4_shift_enter .labelText&gt;tspan{fill:#333;stroke:none;}#dia-s01_d4_shift_enter .loopText,#dia-s01_d4_shift_enter .loopText&gt;tspan{fill:#333;stroke:none;}#dia-s01_d4_shift_enter .sectionTitle,#dia-s01_d4_shift_enter .sectionTitle&gt;tspan{fill:#333;stroke:none;}#dia-s01_d4_shift_enter .loopLine{stroke-width:2px;stroke-dasharray:2,2;stroke:hsl(0, 0%, 83%);fill:hsl(0, 0%, 83%);}#dia-s01_d4_shift_enter .note{stroke:#999;fill:#666;}#dia-s01_d4_shift_enter .noteText,#dia-s01_d4_shift_enter .noteText&gt;tspan{fill:#fff;stroke:none;font-weight:normal;}#dia-s01_d4_shift_enter .activation0{fill:#f4f4f4;stroke:#666;}#dia-s01_d4_shift_enter .activation1{fill:#f4f4f4;stroke:#666;}#dia-s01_d4_shift_enter .activation2{fill:#f4f4f4;stroke:#666;}#dia-s01_d4_shift_enter .actorPopupMenu{position:absolute;}#dia-s01_d4_shift_enter .actorPopupMenuPanel{position:absolute;fill:#eee;box-shadow:0px 8px 16px 0px rgba(0,0,0,0.2);filter:drop-shadow(3px 5px 2px rgb(0 0 0 / 0.4));}#dia-s01_d4_shift_enter .actor-man circle,#dia-s01_d4_shift_enter line{fill:#eee;stroke-width:2px;}#dia-s01_d4_shift_enter g rect.rect{filter:drop-shadow( 1px 2px 2px rgba(185,185,185,1));stroke:#999;}#dia-s01_d4_shift_enter .node .neo-node{stroke:#999;}#dia-s01_d4_shift_enter [data-look=&quot;neo&quot;].node rect,#dia-s01_d4_shift_enter [data-look=&quot;neo&quot;].cluster rect,#dia-s01_d4_shift_enter [data-look=&quot;neo&quot;].node polygon{stroke:url(#dia-s01_d4_shift_enter-gradient);filter:drop-shadow( 1px 2px 2px rgba(185,185,185,1));}#dia-s01_d4_shift_enter [data-look=&quot;neo&quot;].swimlane.cluster rect{filter:none;}#dia-s01_d4_shift_enter [data-look=&quot;neo&quot;].node path{stroke:url(#dia-s01_d4_shift_enter-gradient);stroke-width:1px;}#dia-s01_d4_shift_enter [data-look=&quot;neo&quot;].node .outer-path{filter:drop-shadow( 1px 2px 2px rgba(185,185,185,1));}#dia-s01_d4_shift_enter [data-look=&quot;neo&quot;].node .neo-line path{stroke:#999;filter:none;}#dia-s01_d4_shift_enter [data-look=&quot;neo&quot;].node circle{stroke:url(#dia-s01_d4_shift_enter-gradient);filter:drop-shadow( 1px 2px 2px rgba(185,185,185,1));}#dia-s01_d4_shift_enter [data-look=&quot;neo&quot;].node circle .state-start{fill:#000000;}#dia-s01_d4_shift_enter [data-look=&quot;neo&quot;].icon-shape .icon{fill:url(#dia-s01_d4_shift_enter-gradient);filter:drop-shadow( 1px 2px 2px rgba(185,185,185,1));}#dia-s01_d4_shift_enter [data-look=&quot;neo&quot;].icon-shape .icon-neo path{stroke:url(#dia-s01_d4_shift_enter-gradient);filter:drop-shadow( 1px 2px 2px rgba(185,185,185,1));}#dia-s01_d4_shift_enter :root{--mermaid-font-family:&quot;trebuchet ms&quot;,verdana,arial,sans-serif;
 1c2.757 0 5 2.243 5 5s-2.243 5-5 5-5-2.243-5-5 2.243-5 5-5m0-1a6 6 0 1 0 0 12A6 6 0 0 0 6 0m2.924 6.23c.101.018.101.166 0 .185-.953.181-3.022.556-3.273.556a.65.65 0 0 1-.65-.65c0-.256.384-2.724.562-3.723.017-.096.156-.09.172.007l.492 3.119z"/></symbol></defs><defs><marker id="dia-s01_d4_shift_enter-arrowhead" markerHeight="12" markerUnits="userSpaceOnUse" markerWidth="12" orient="auto-start-reverse" refX="7.9" refY="5"><path d="m-1 0 11 5-10 5z"/></marker></defs><defs><marker id="dia-s01_d4_shift_enter-crosshead" markerHeight="8" markerWidth="15" orient="auto" refX="4" refY="4.5"><path fill="none" stroke="#000" stroke-width="1pt" d="m1 2 5 5m0-5L1 7" style="stroke-dasharray:0,0"/></marker></defs><defs><marker id="dia-s01_d4_shift_enter-filled-head" markerHeight="28" markerWidth="20" orient="auto" refX="15.5" refY="7"><path d="m18 7-9 6 5-6-5-6Z"/></marker></defs><defs><marker id="dia-s01_d4_shift_enter-sequencenumber" markerHeight="40" markerWidth="60" orient="auto" refX="15" refY="15"><circle cx="15" cy="15" r="6"/></marker></defs><defs><marker id="dia-s01_d4_shift_enter-solidTopArrowHead" markerHeight="12" markerUnits="userSpaceOnUse" markerWidth="12" orient="auto-start-reverse" refX="7.9" refY="7.25"><path d="m0 0 10 8H0z"/></marker></defs><defs><marker id="dia-s01_d4_shift_enter-solidBottomArrowHead" markerHeight="12" markerUnits="userSpaceOnUse" markerWidth="12" orient="auto-start-reverse" refX="7.9" refY=".75"><path d="M0 0h10L0 8z"/></marker></defs><defs><marker id="dia-s01_d4_shift_enter-stickTopArrowHead" markerHeight="12" markerUnits="userSpaceOnUse" markerWidth="12" orient="auto-start-reverse" refX="7.5" refY="7"><path fill="none" stroke="#000" stroke-width="1.5" d="m0 0 7 7"/></marker></defs><defs><marker id="dia-s01_d4_shift_enter-stickBottomArrowHead" markerHeight="12" markerUnits="userSpaceOnUse" markerWidth="12" orient="auto-start-reverse" refX="7.5" refY="0"><path fill="none" stroke="#000" stroke-width="1.5" d="m0 7 7-7"/></marker></defs><text x="225" y="80" alignment-baseline="middle" class="messageText" dominant-baseline="middle" dy="1em" style="font-size:16px;font-weight:400" text-anchor="middle">manda el texto de tu celda por la red</text><line x1="82" x2="374" y1="109" y2="109" stroke="none" stroke-width="2" marker-end="url(#dia-s01_d4_shift_enter-arrowhead)" class="messageLine0" data-et="message" data-from="N" data-id="i1" data-to="S" style="fill:none"/><line x1="75" x2="75" y1="109" y2="109" stroke-width="0" marker-start="url(#dia-s01_d4_shift_enter-sequencenumber)"/><text x="75" y="113" class="sequenceNumber" font-family="sans-serif" font-size="12" text-anchor="middle">1</text><text x="493" y="124" alignment-baseline="middle" class="messageText" dominant-baseline="middle" dy="1em" style="font-size:16px;font-weight:400" text-anchor="middle">se lo entrega al intérprete</text><line x1="385" x2="606" y1="153" y2="153" stroke="none" stroke-width="2" marker-end="url(#dia-s01_d4_shift_enter-arrowhead)" class="messageLine0" data-et="message" data-from="S" data-id="i2" data-to="K" style="fill:none"/><line x1="378" x2="378" y1="153" y2="153" stroke-width="0" marker-start="url(#dia-s01_d4_shift_enter-sequencenumber)"/><text x="378" y="157" class="sequenceNumber" font-family="sans-serif" font-size="12" text-anchor="middle">2</text><text x="611" y="168" alignment-baseline="middle" class="messageText" dominant-baseline="middle" dy="1em" style="font-size:16px;font-weight:400" text-anchor="middle">traduce tu línea a instrucciones mínimas</text><path x1="617" stroke="none" stroke-width="2" marker-end="url(#dia-s01_d4_shift_enter-arrowhead)" d="M611 197c60-10 60 30 0 20" class="messageLine0" data-et="message" data-from="K" data-id="i3" data-to="K" style="fill:none"/><line x1="610" x2="610" y1="197" y2="197" stroke-width="0" marker-start="url(#dia-s01_d4_shift_enter-sequencenumber)"/><text x="610" y="201" class="sequenceNumber" font-family="sans-serif" font-size="12" text-anchor="middle">3</text><text x="785" y="242" alignment-baseline="middle" class="messageText" dominant-baseline="middle" dy="1em" style="font-size:16px;font-weight:400" text-anchor="middle">la CPU ejecuta esas instrucciones en binario</text><line x1="617" x2="959" y1="271" y2="271" stroke="none" stroke-width="2" marker-end="url(#dia-s01_d4_shift_enter-arrowhead)" class="messageLine0" data-et="message" data-from="K" data-id="i4" data-to="C" style="fill:none"/><line x1="610" x2="610" y1="271" y2="271" stroke-width="0" marker-start="url(#dia-s01_d4_shift_enter-sequencenumber)"/><text x="610" y="275" class="sequenceNumber" font-family="sans-serif" font-size="12" text-anchor="middle">4</text><text x="788" y="286" alignment-baseline="middle" class="messageText" dominant-baseline="middle" dy="1em" style="font-size:16px;font-weight:400" text-anchor="middle">devuelve el resultado</text><line x1="968" x2="614" y1="315" y2="315" stroke="none" stroke-width="2" marker-end="url(#dia-s01_d4_shift_enter-arrowhead)" class="messageLine1" data-et="message" data-from="C" data-id="i5" data-to="K" style="stroke-dasharray:3,3;fill:none"/><line x1="963" x2="963" y1="315" y2="315" stroke-width="0" marker-start="url(#dia-s01_d4_shift_enter-sequencenumber)"/><text x="963" y="319" class="sequenceNumber" font-family="sans-serif" font-size="12" text-anchor="middle">5</text><text x="496" y="330" alignment-baseline="middle" class="messageText" dominant-baseline="middle" dy="1em" style="font-size:16px;font-weight:400" text-anchor="middle">entrega el texto de salida</text><line x1="615" x2="382" y1="359" y2="359" stroke="none" stroke-width="2" marker-end="url(#dia-s01_d4_shift_enter-arrowhead)" class="messageLine1" data-et="message" data-from="K" data-id="i6" data-to="S" style="stroke-dasharray:3,3;fill:none"/><line x1="610" x2="610" y1="359" y2="359" stroke-width="0" marker-start="url(#dia-s01_d4_shift_enter-sequencenumber)"/><text x="610" y="363" class="sequenceNumber" font-family="sans-serif" font-size="12" text-anchor="middle">6</text><text x="228" y="374" alignment-baseline="middle" class="messageText" dominant-baseline="middle" dy="1em" style="font-size:16px;font-weight:400" text-anchor="middle">lo dibuja debajo de tu celda</text><line x1="383" x2="79" y1="403" y2="403" stroke="none" stroke-width="2" marker-end="url(#dia-s01_d4_shift_enter-arrowhead)" class="messageLine1" data-et="message" data-from="S" data-id="i7" data-to="N" style="stroke-dasharray:3,3;fill:none"/><line x1="378" x2="378" y1="403" y2="403" stroke-width="0" marker-start="url(#dia-s01_d4_shift_enter-sequencenumber)"/><text x="378" y="407" class="sequenceNumber" font-family="sans-serif" font-size="12" text-anchor="middle">7</text></svg>', 'Los tres primeros pasos son software. El cuarto es hardware.')

# %% [markdown]
# Los tres primeros pasos son **software**: programas que se pasan tu texto unos a
# otros. El cuarto es **hardware**: un pedazo de silicio que solo sabe sumar
# números binarios y no tiene idea de que existe el español.
#
# Y es rapidísimo. Ejecuta esto y no toques nada: solo léelo y **predice** cuánto
# va a tardar.

# %%
import time

inicio = time.perf_counter()
total = 0
for i in range(1_000_000):     # un millón de vueltas
    total = total + i
fin = time.perf_counter()

print("Sumé el primer millón de números.")
print("Resultado:", total)
print("Tardé:", round(fin - inicio, 3), "segundos")

# %% [markdown]
# Si tú hicieras esas sumas a mano, a una por segundo, sin dormir ni comer,
# tardarías **once días y medio**. Tu procesador tardó una fracción de segundo.
#
# Esa desproporción es toda la historia de este curso: la máquina es
# absurdamente rápida y absurdamente bruta. **Tú pones la idea; ella pone la
# velocidad.** El resto del cuadernillo es entender cómo tu idea llega hasta ese
# pedazo de silicio.

# %% [markdown]
# ---
#
# ## 3. La máquina por dentro · 35 min
#
# ### 3A. Mil años en cinco minutos
#
# La palabra **algoritmo** no viene de la informática: viene del nombre de una
# persona. Y el primer programa de la historia se escribió **un siglo antes** de
# que existiera el primer computador. Ejecuta la línea de tiempo.

# %%
linea_de_tiempo()

# %% [markdown]
# Fíjate en el ENIAC: 27 toneladas y 17.000 tubos de vidrio para hacer menos
# cuentas que la calculadora de tu celular. ¿Qué cambió? El **transistor**, y el
# hecho de que cada año caben más en el mismo pedazo de silicio.

# %%
grafica_transistores()

# %% [markdown]
# Y mientras el hardware se encogía, el **software** hacía el camino contrario:
# subía de altura.
#
# | Época | Cómo se le hablaba a la máquina | Quién traducía |
# |---|---|---|
# | 1945 | Moviendo cables y interruptores | Nadie: la persona *era* el traductor |
# | 1949 | **Lenguaje ensamblador**: `ADD`, `MOV`, `JMP` | Un programa ensamblador |
# | 1957–1959 | **FORTRAN, COBOL**: fórmulas y frases | Un compilador |
# | 1972 | **C**: alto nivel con control fino de la memoria | Un compilador |
# | 1991 | **Python**: código que se lee casi como inglés | Un **intérprete** |
# | 2015–hoy | Librerías de IA: describes el modelo, no el cálculo | Capas y capas de lo anterior |
#
# Cada fila de esa tabla es la misma jugada: **alguien escribió un programa para
# no tener que volver a escribir lo de abajo a mano.** Eso es, literalmente, la
# historia del software.

# %% [markdown]
# ### Las cuatro cosas que hay dentro de un sistema
#
# Ejecuta el diagrama y quédate con las cuatro palabras: te las van a preguntar
# toda la carrera.

# %%
# Diagrama: s01_d2_capas
ava.figura('<svg xmlns="http://www.w3.org/2000/svg" id="dia-s01_d2_capas" width="100%" aria-roledescription="flowchart-v2" class="flowchart" role="graphics-document document" style="max-width:337.809px;background-color:transparent" viewBox="0 0 337.809 490"><style>#dia-s01_d2_capas{font-family:system-ui,-apple-system,&apos;Segoe UI&apos;,Roboto,sans-serif;font-size:15px;fill:#000000;}@keyframes edge-animation-frame{from{stroke-dashoffset:0;}}@keyframes dash{to{stroke-dashoffset:0;}}#dia-s01_d2_capas .edge-animation-slow{stroke-dasharray:9,5!important;stroke-dashoffset:900;animation:dash 50s linear infinite;stroke-linecap:round;}#dia-s01_d2_capas .edge-animation-fast{stroke-dasharray:9,5!important;stroke-dashoffset:900;animation:dash 20s linear infinite;stroke-linecap:round;}#dia-s01_d2_capas .error-icon{fill:#552222;}#dia-s01_d2_capas .error-text{fill:#552222;stroke:#552222;}#dia-s01_d2_capas .edge-thickness-normal{stroke-width:1px;}#dia-s01_d2_capas .edge-thickness-thick{stroke-width:3.5px;}#dia-s01_d2_capas .edge-pattern-solid{stroke-dasharray:0;}#dia-s01_d2_capas .edge-thickness-invisible{stroke-width:0;fill:none;}#dia-s01_d2_capas .edge-pattern-dashed{stroke-dasharray:3;}#dia-s01_d2_capas .edge-pattern-dotted{stroke-dasharray:2;}#dia-s01_d2_capas .marker{fill:#52514e;stroke:#52514e;}#dia-s01_d2_capas .marker.cross{stroke:#52514e;}#dia-s01_d2_capas svg{font-family:system-ui,-apple-system,&apos;Segoe UI&apos;,Roboto,sans-serif;font-size:15px;}#dia-s01_d2_capas p{margin:0;}#dia-s01_d2_capas .label{font-family:system-ui,-apple-system,&apos;Segoe UI&apos;,Roboto,sans-serif;color:#000000;}#dia-s01_d2_capas .cluster-label text{fill:#333;}#dia-s01_d2_capas .cluster-label span{color:#333;}#dia-s01_d2_capas .cluster-label span p{background-color:transparent;}#dia-s01_d2_capas .label text,#dia-s01_d2_capas span{fill:#000000;color:#000000;}#dia-s01_d2_capas .node rect,#dia-s01_d2_capas .node circle,#dia-s01_d2_capas .node ellipse,#dia-s01_d2_capas .node polygon,#dia-s01_d2_capas .node path{fill:#eee;stroke:#999;stroke-width:1px;}#dia-s01_d2_capas .rough-node .label text,#dia-s01_d2_capas .node .label text,#dia-s01_d2_capas .image-shape .label,#dia-s01_d2_capas .icon-shape .label{text-anchor:middle;}#dia-s01_d2_capas .node .katex path{fill:#000;stroke:#000;stroke-width:1px;}#dia-s01_d2_capas .rough-node .label,#dia-s01_d2_capas .node .label,#dia-s01_d2_capas .image-shape .label,#dia-s01_d2_capas .icon-shape .label{text-align:center;}#dia-s01_d2_capas .node.clickable{cursor:pointer;}#dia-s01_d2_capas .root .anchor path{fill:#52514e!important;stroke-width:0;stroke:#52514e;}#dia-s01_d2_capas .arrowheadPath{fill:#333333;}#dia-s01_d2_capas .edgePath .path{stroke:#52514e;stroke-width:1px;}#dia-s01_d2_capas .flowchart-link{stroke:#52514e;fill:none;}#dia-s01_d2_capas .edgeLabel{background-color:white;text-align:center;}#dia-s01_d2_capas .edgeLabel p{background-color:white;}#dia-s01_d2_capas .edgeLabel rect{opacity:0.5;background-color:white;fill:white;}#dia-s01_d2_capas .labelBkg{background-color:rgba(255, 255, 255, 0.5);}#dia-s01_d2_capas .cluster rect{fill:hsl(0, 0%, 98.9215686275%);stroke:#707070;stroke-width:1px;}#dia-s01_d2_capas .cluster text{fill:#333;}#dia-s01_d2_capas .cluster span{color:#333;}#dia-s01_d2_capas div.mermaidTooltip{position:absolute;text-align:center;max-width:200px;padding:2px;font-family:system-ui,-apple-system,&apos;Segoe UI&apos;,Roboto,sans-serif;font-size:12px;background:#fdf6e3;border:1px solid #707070;border-radius:2px;pointer-events:none;z-index:100;}#dia-s01_d2_capas .flowchartTitleText{text-anchor:middle;font-size:18px;fill:#000000;}#dia-s01_d2_capas rect.text{fill:none;stroke-width:0;}#dia-s01_d2_capas .icon-shape,#dia-s01_d2_capas .image-shape{background-color:white;text-align:center;}#dia-s01_d2_capas .icon-shape p,#dia-s01_d2_capas .image-shape p{background-color:white;padding:2px;}#dia-s01_d2_capas .icon-shape .label rect,#dia-s01_d2_capas .image-shape .label rect{opacity:0.5;background-color:white;fill:white;}#dia-s01_d2_capas .label-icon{display:inline-block;height:1em;overflow:visible;vertical-align:-0.125em;}#dia-s01_d2_capas .node .label-icon path{fill:currentColor;stroke:revert;stroke-width:revert;}#dia-s01_d2_capas .node .neo-node{stroke:#999;}#dia-s01_d2_capas [data-look=&quot;neo&quot;].node rect,#dia-s01_d2_capas [data-look=&quot;neo&quot;].cluster rect,#dia-s01_d2_capas [data-look=&quot;neo&quot;].node polygon{stroke:url(#dia-s01_d2_capas-gradient);filter:drop-shadow( 1px 2px 2px rgba(185,185,185,1));}#dia-s01_d2_capas [data-look=&quot;neo&quot;].swimlane.cluster rect{filter:none;}#dia-s01_d2_capas [data-look=&quot;neo&quot;].node path{stroke:url(#dia-s01_d2_capas-gradient);stroke-width:1px;}#dia-s01_d2_capas [data-look=&quot;neo&quot;].node .outer-path{filter:drop-shadow( 1px 2px 2px rgba(185,185,185,1));}#dia-s01_d2_capas [data-look=&quot;neo&quot;].node .neo-line path{stroke:#999;filter:none;}#dia-s01_d2_capas [data-look=&quot;neo&quot;].node circle{stroke:url(#dia-s01_d2_capas-gradient);filter:drop-shadow( 1px 2px 2px rgba(185,185,185,1));}#dia-s01_d2_capas [data-look=&quot;neo&quot;].node circle .state-start{fill:#000000;}#dia-s01_d2_capas [data-look=&quot;neo&quot;].icon-shape .icon{fill:url(#dia-s01_d2_capas-gradient);filter:drop-shadow( 1px 2px 2px rgba(185,185,185,1));}#dia-s01_d2_capas [data-look=&quot;neo&quot;].icon-shape .icon-neo path{stroke:url(#dia-s01_d2_capas-gradient);filter:drop-shadow( 1px 2px 2px rgba(185,185,185,1));}#dia-s01_d2_capas :root{--mermaid-font-family:&quot;trebuchet ms&quot;,verdana,arial,sans-serif;}#dia-s01_d2_capas .proceso rect{fill:rgb(243, 238, 254)!important;stroke:rgb(74, 58, 167)!important;color:rgb(46, 35, 119)!important;}#dia-s01_d2_capas .proceso polygon{fill:rgb(243, 238, 254)!important;stroke:rgb(74, 58, 167)!important;color:rgb(46, 35, 119)!important;}#dia-s01_d2_capas .proceso ellipse{fill:rgb(243, 238, 254)!important;stroke:rgb(74, 58, 167)!important;color:rgb(46, 35, 119)!important;}#dia-s01_d2_capas .proceso circle{fill:rgb(243, 238, 254)!important;stroke:rgb(74, 58, 167)!important;color:rgb(46, 35, 119)!important;}#dia-s01_d2_capas .proceso path{fill:rgb(243, 238, 254)!important;stroke:rgb(74, 58, 167)!important;color:rgb(46, 35, 119)!important;}#dia-s01_d2_capas .proceso tspan{fill:rgb(46, 35, 119)!important;}#dia-s01_d2_capas .dato rect{fill:rgb(233, 247, 238)!important;stroke:rgb(12, 163, 12)!important;color:rgb(16, 41, 77)!important;}#dia-s01_d2_capas .dato polygon{fill:rgb(233, 247, 238)!important;stroke:rgb(12, 163, 12)!important;color:rgb(16, 41, 77)!important;}#dia-s01_d2_capas .dato ellipse{fill:rgb(233, 247, 238)!important;stroke:rgb(12, 163, 12)!important;color:rgb(16, 41, 77)!important;}#dia-s01_d2_capas .dato circle{fill:rgb(233, 247, 238)!important;stroke:rgb(12, 163, 12)!important;color:rgb(16, 41, 77)!important;}#dia-s01_d2_capas .dato path{fill:rgb(233, 247, 238)!important;stroke:rgb(12, 163, 12)!important;color:rgb(16, 41, 77)!important;}#dia-s01_d2_capas .dato tspan{fill:rgb(16, 41, 77)!important;}#dia-s01_d2_capas .software rect{fill:rgb(232, 240, 251)!important;stroke:rgb(42, 120, 214)!important;color:rgb(16, 41, 77)!important;}#dia-s01_d2_capas .software polygon{fill:rgb(232, 240, 251)!important;stroke:rgb(42, 120, 214)!important;color:rgb(16, 41, 77)!important;}#dia-s01_d2_capas .software ellipse{fill:rgb(232, 240, 251)!important;stroke:rgb(42, 120, 214)!important;color:rgb(16, 41, 77)!important;}#dia-s01_d2_capas .software circle{fill:rgb(232, 240, 251)!important;stroke:rgb(42, 120, 214)!important;color:rgb(16, 41, 77)!important;}#dia-s01_d2_capas .software path{fill:rgb(232, 240, 251)!important;stroke:rgb(42, 120, 214)!important;color:rgb(16, 41, 77)!important;}#dia-s01_d2_capas .software tspan{fill:rgb(16, 41, 77)!important;}#dia-s01_d2_capas .hardware rect{fill:rgb(253, 246, 227)!important;stroke:rgb(237, 161, 0)!important;color:rgb(16, 41, 77)!important;}#dia-s01_d2_capas .hardware polygon{fill:rgb(253, 246, 227)!important;stroke:rgb(237, 161, 0)!important;color:rgb(16, 41, 77)!important;}#dia-s01_d2_capas .hardware ellipse{fill:rgb(253, 246, 227)!important;stroke:rgb(237, 161, 0)!important;color:rgb(16, 41, 77)!important;}#dia-s01_d2_capas .hardware circle{fill:rgb(253, 246, 227)!important;stroke:rgb(237, 161, 0)!important;color:rgb(16, 41, 77)!important;}#dia-s01_d2_capas .hardware path{fill:rgb(253, 246, 227)!important;stroke:rgb(237, 161, 0)!important;color:rgb(16, 41, 77)!important;}#dia-s01_d2_capas .hardware tspan{fill:rgb(16, 41, 77)!important;}</style><marker id="dia-s01_d2_capas_flowchart-v2-pointEnd" class="marker flowchart-v2" markerHeight="8" markerUnits="userSpaceOnUse" markerWidth="8" orient="auto" refX="5" refY="5" viewBox="0 0 10 10"><path d="m0 0 10 5-10 5z" class="arrowMarkerPath" style="stroke-width:1;stroke-dasharray:1,0"/></marker><marker id="dia-
class="basic label-container" style="fill:#e8f0fb!important;stroke:#2a78d6!important"/><g class="label" style="color:#10294d!important" transform="translate(0 -17.25)"><rect/><rect class="background" style="stroke:none"/><text y="-10.1" style="fill:#10294d!important"><tspan x="0" y="-.1em" class="text-outer-tspan row" dy="1.1em"><tspan class="text-inner-tspan" font-style="normal" font-weight="normal">SOFTWARE</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> ·</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> la</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> receta:</tspan></tspan><tspan x="0" y="1em" class="text-outer-tspan row" dy="1.1em"><tspan class="text-inner-tspan" font-style="normal" font-weight="normal">Moodle,</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> Python,</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> un</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> juego</tspan></tspan></text></g></g><g id="dia-s01_d2_capas-flowchart-H-3" class="node default hardware" data-look="classic" transform="translate(132.617 313.25)"><rect width="239.734" height="64.5" x="-119.867" y="-32.25" class="basic label-container" style="fill:#fdf6e3!important;stroke:#eda100!important"/><g class="label" style="color:#10294d!important" transform="translate(0 -17.25)"><rect/><rect class="background" style="stroke:none"/><text y="-10.1" style="fill:#10294d!important"><tspan x="0" y="-.1em" class="text-outer-tspan row" dy="1.1em"><tspan class="text-inner-tspan" font-style="normal" font-weight="normal">HARDWARE</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> ·</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> lo</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> físico:</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> el</tspan></tspan><tspan x="0" y="1em" class="text-outer-tspan row" dy="1.1em"><tspan class="text-inner-tspan" font-style="normal" font-weight="normal">portátil,</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> el</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> lector</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> del</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> carné</tspan></tspan></text></g></g></g></g><defs><filter id="dia-s01_d2_capas-drop-shadow" width="130%" height="130%"><feDropShadow dx="4" dy="4" flood-color="#000" flood-opacity=".06" stdDeviation="0"/></filter></defs><defs><filter id="dia-s01_d2_capas-drop-shadow-small" width="150%" height="150%"><feDropShadow dx="2" dy="2" flood-color="#000" flood-opacity=".06" stdDeviation="0"/></filter></defs><linearGradient id="dia-s01_d2_capas-gradient" x1="0%" x2="100%" y1="0%" y2="0%" gradientUnits="objectBoundingBox"><stop offset="0%" stop-color="hsl(0, 0%, 83.3333333333%)" stop-opacity="1"/><stop offset="100%" stop-color="hsl(0, 0%, 88.9215686275%)" stop-opacity="1"/></linearGradient></svg>', 'Hardware, software, dato y proceso: el ciclo no se acaba nunca.')

# %% [markdown]
# | | Qué es | Cómo lo reconoces | Ejemplo en la UIS |
# |---|---|---|---|
# | **Hardware** | Lo físico | Se puede golpear (no lo hagas) | El portátil de la sala de cómputo, el lector del carné |
# | **Software** | Las instrucciones | Se instala, se actualiza, se borra | Moodle, Python, el juego del celular |
# | **Dato** | Lo que se guarda y se transforma | Es un valor: un número, un texto, una foto | Tu nota 4.3, tu foto del carné, la placa de un bus |
# | **Proceso** | Lo que se hace con los datos | Es un verbo | Calcular el promedio, ordenar por apellido, cobrar el pasaje |
#
# Un error clásico de primer semestre: creer que un archivo de Word es software.
# No lo es. **Word es software; tu documento es un dato.** El software es la
# receta, el dato es el ingrediente y el proceso es cocinar.

# %% [markdown]
# ### ¿Y las «aplicaciones informáticas»?
#
# Todo el software del mundo cabe en cuatro cajones. Ejecuta el diagrama.

# %%
# Diagrama: s01_d7_aplicaciones
ava.figura('<svg xmlns="http://www.w3.org/2000/svg" id="dia-s01_d7_aplicaciones" width="100%" aria-roledescription="flowchart-v2" class="flowchart" role="graphics-document document" style="max-width:1188.9px;background-color:transparent" viewBox="0 0 1188.898 359"><style>#dia-s01_d7_aplicaciones{font-family:system-ui,-apple-system,&apos;Segoe UI&apos;,Roboto,sans-serif;font-size:15px;fill:#000000;}@keyframes edge-animation-frame{from{stroke-dashoffset:0;}}@keyframes dash{to{stroke-dashoffset:0;}}#dia-s01_d7_aplicaciones .edge-animation-slow{stroke-dasharray:9,5!important;stroke-dashoffset:900;animation:dash 50s linear infinite;stroke-linecap:round;}#dia-s01_d7_aplicaciones .edge-animation-fast{stroke-dasharray:9,5!important;stroke-dashoffset:900;animation:dash 20s linear infinite;stroke-linecap:round;}#dia-s01_d7_aplicaciones .error-icon{fill:#552222;}#dia-s01_d7_aplicaciones .error-text{fill:#552222;stroke:#552222;}#dia-s01_d7_aplicaciones .edge-thickness-normal{stroke-width:1px;}#dia-s01_d7_aplicaciones .edge-thickness-thick{stroke-width:3.5px;}#dia-s01_d7_aplicaciones .edge-pattern-solid{stroke-dasharray:0;}#dia-s01_d7_aplicaciones .edge-thickness-invisible{stroke-width:0;fill:none;}#dia-s01_d7_aplicaciones .edge-pattern-dashed{stroke-dasharray:3;}#dia-s01_d7_aplicaciones .edge-pattern-dotted{stroke-dasharray:2;}#dia-s01_d7_aplicaciones .marker{fill:#52514e;stroke:#52514e;}#dia-s01_d7_aplicaciones .marker.cross{stroke:#52514e;}#dia-s01_d7_aplicaciones svg{font-family:system-ui,-apple-system,&apos;Segoe UI&apos;,Roboto,sans-serif;font-size:15px;}#dia-s01_d7_aplicaciones p{margin:0;}#dia-s01_d7_aplicaciones .label{font-family:system-ui,-apple-system,&apos;Segoe UI&apos;,Roboto,sans-serif;color:#000000;}#dia-s01_d7_aplicaciones .cluster-label text{fill:#333;}#dia-s01_d7_aplicaciones .cluster-label span{color:#333;}#dia-s01_d7_aplicaciones .cluster-label span p{background-color:transparent;}#dia-s01_d7_aplicaciones .label text,#dia-s01_d7_aplicaciones span{fill:#000000;color:#000000;}#dia-s01_d7_aplicaciones .node rect,#dia-s01_d7_aplicaciones .node circle,#dia-s01_d7_aplicaciones .node ellipse,#dia-s01_d7_aplicaciones .node polygon,#dia-s01_d7_aplicaciones .node path{fill:#eee;stroke:#999;stroke-width:1px;}#dia-s01_d7_aplicaciones .rough-node .label text,#dia-s01_d7_aplicaciones .node .label text,#dia-s01_d7_aplicaciones .image-shape .label,#dia-s01_d7_aplicaciones .icon-shape .label{text-anchor:middle;}#dia-s01_d7_aplicaciones .node .katex path{fill:#000;stroke:#000;stroke-width:1px;}#dia-s01_d7_aplicaciones .rough-node .label,#dia-s01_d7_aplicaciones .node .label,#dia-s01_d7_aplicaciones .image-shape .label,#dia-s01_d7_aplicaciones .icon-shape .label{text-align:center;}#dia-s01_d7_aplicaciones .node.clickable{cursor:pointer;}#dia-s01_d7_aplicaciones .root .anchor path{fill:#52514e!important;stroke-width:0;stroke:#52514e;}#dia-s01_d7_aplicaciones .arrowheadPath{fill:#333333;}#dia-s01_d7_aplicaciones .edgePath .path{stroke:#52514e;stroke-width:1px;}#dia-s01_d7_aplicaciones .flowchart-link{stroke:#52514e;fill:none;}#dia-s01_d7_aplicaciones .edgeLabel{background-color:white;text-align:center;}#dia-s01_d7_aplicaciones .edgeLabel p{background-color:white;}#dia-s01_d7_aplicaciones .edgeLabel rect{opacity:0.5;background-color:white;fill:white;}#dia-s01_d7_aplicaciones .labelBkg{background-color:rgba(255, 255, 255, 0.5);}#dia-s01_d7_aplicaciones .cluster rect{fill:hsl(0, 0%, 98.9215686275%);stroke:#707070;stroke-width:1px;}#dia-s01_d7_aplicaciones .cluster text{fill:#333;}#dia-s01_d7_aplicaciones .cluster span{color:#333;}#dia-s01_d7_aplicaciones div.mermaidTooltip{position:absolute;text-align:center;max-width:200px;padding:2px;font-family:system-ui,-apple-system,&apos;Segoe UI&apos;,Roboto,sans-serif;font-size:12px;background:#fdf6e3;border:1px solid #707070;border-radius:2px;pointer-events:none;z-index:100;}#dia-s01_d7_aplicaciones .flowchartTitleText{text-anchor:middle;font-size:18px;fill:#000000;}#dia-s01_d7_aplicaciones rect.text{fill:none;stroke-width:0;}#dia-s01_d7_aplicaciones .icon-shape,#dia-s01_d7_aplicaciones .image-shape{background-color:white;text-align:center;}#dia-s01_d7_aplicaciones .icon-shape p,#dia-s01_d7_aplicaciones .image-shape p{background-color:white;padding:2px;}#dia-s01_d7_aplicaciones .icon-shape .label rect,#dia-s01_d7_aplicaciones .image-shape .label rect{opacity:0.5;background-color:white;fill:white;}#dia-s01_d7_aplicaciones .label-icon{display:inline-block;height:1em;overflow:visible;vertical-align:-0.125em;}#dia-s01_d7_aplicaciones .node .label-icon path{fill:currentColor;stroke:revert;stroke-width:revert;}#dia-s01_d7_aplicaciones .node .neo-node{stroke:#999;}#dia-s01_d7_aplicaciones [data-look=&quot;neo&quot;].node rect,#dia-s01_d7_aplicaciones [data-look=&quot;neo&quot;].cluster rect,#dia-s01_d7_aplicaciones [data-look=&quot;neo&quot;].node polygon{stroke:url(#dia-s01_d7_aplicaciones-gradient);filter:drop-shadow( 1px 2px 2px rgba(185,185,185,1));}#dia-s01_d7_aplicaciones [data-look=&quot;neo&quot;].swimlane.cluster rect{filter:none;}#dia-s01_d7_aplicaciones [data-look=&quot;neo&quot;].node path{stroke:url(#dia-s01_d7_aplicaciones-gradient);stroke-width:1px;}#dia-s01_d7_aplicaciones [data-look=&quot;neo&quot;].node .outer-path{filter:drop-shadow( 1px 2px 2px rgba(185,185,185,1));}#dia-s01_d7_aplicaciones [data-look=&quot;neo&quot;].node .neo-line path{stroke:#999;filter:none;}#dia-s01_d7_aplicaciones [data-look=&quot;neo&quot;].node circle{stroke:url(#dia-s01_d7_aplicaciones-gradient);filter:drop-shadow( 1px 2px 2px rgba(185,185,185,1));}#dia-s01_d7_aplicaciones [data-look=&quot;neo&quot;].node circle .state-start{fill:#000000;}#dia-s01_d7_aplicaciones [data-look=&quot;neo&quot;].icon-shape .icon{fill:url(#dia-s01_d7_aplicaciones-gradient);filter:drop-shadow( 1px 2px 2px rgba(185,185,185,1));}#dia-s01_d7_aplicaciones [data-look=&quot;neo&quot;].icon-shape .icon-neo path{stroke:url(#dia-s01_d7_aplicaciones-gradient);filter:drop-shadow( 1px 2px 2px rgba(185,185,185,1));}#dia-s01_d7_aplicaciones :root{--mermaid-font-family:&quot;trebuchet ms&quot;,verdana,arial,sans-serif;}#dia-s01_d7_aplicaciones .raiz rect{fill:rgb(243, 238, 254)!important;stroke:rgb(74, 58, 167)!important;color:rgb(46, 35, 119)!important;}#dia-s01_d7_aplicaciones .raiz polygon{fill:rgb(243, 238, 254)!important;stroke:rgb(74, 58, 167)!important;color:rgb(46, 35, 119)!important;}#dia-s01_d7_aplicaciones .raiz ellipse{fill:rgb(243, 238, 254)!important;stroke:rgb(74, 58, 167)!important;color:rgb(46, 35, 119)!important;}#dia-s01_d7_aplicaciones .raiz circle{fill:rgb(243, 238, 254)!important;stroke:rgb(74, 58, 167)!important;color:rgb(46, 35, 119)!important;}#dia-s01_d7_aplicaciones .raiz path{fill:rgb(243, 238, 254)!important;stroke:rgb(74, 58, 167)!important;color:rgb(46, 35, 119)!important;}#dia-s01_d7_aplicaciones .raiz tspan{fill:rgb(46, 35, 119)!important;}#dia-s01_d7_aplicaciones .cajon rect{fill:rgb(232, 240, 251)!important;stroke:rgb(42, 120, 214)!important;color:rgb(16, 41, 77)!important;}#dia-s01_d7_aplicaciones .cajon polygon{fill:rgb(232, 240, 251)!important;stroke:rgb(42, 120, 214)!important;color:rgb(16, 41, 77)!important;}#dia-s01_d7_aplicaciones .cajon ellipse{fill:rgb(232, 240, 251)!important;stroke:rgb(42, 120, 214)!important;color:rgb(16, 41, 77)!important;}#dia-s01_d7_aplicaciones .cajon circle{fill:rgb(232, 240, 251)!important;stroke:rgb(42, 120, 214)!important;color:rgb(16, 41, 77)!important;}#dia-s01_d7_aplicaciones .cajon path{fill:rgb(232, 240, 251)!important;stroke:rgb(42, 120, 214)!important;color:rgb(16, 41, 77)!important;}#dia-s01_d7_aplicaciones .cajon tspan{fill:rgb(16, 41, 77)!important;}#dia-s01_d7_aplicaciones .ejemplo rect{fill:rgb(253, 246, 227)!important;stroke:rgb(237, 161, 0)!important;color:rgb(16, 41, 77)!important;}#dia-s01_d7_aplicaciones .ejemplo polygon{fill:rgb(253, 246, 227)!important;stroke:rgb(237, 161, 0)!important;color:rgb(16, 41, 77)!important;}#dia-s01_d7_aplicaciones .ejemplo ellipse{fill:rgb(253, 246, 227)!important;stroke:rgb(237, 161, 0)!important;color:rgb(16, 41, 77)!important;}#dia-s01_d7_aplicaciones .ejemplo circle{fill:rgb(253, 246, 227)!important;stroke:rgb(237, 161, 0)!important;color:rgb(16, 41, 77)!important;}#dia-s01_d7_aplicaciones .ejemplo path{fill:rgb(253, 246, 227)!important;stroke:rgb(237, 161, 0)!important;color:rgb(16, 41, 77)!important;}#dia-s01_d7_aplicaciones .ejemplo tspan{fill:rgb(16, 41, 77)!important;}</style><marker id="dia-s01_d7_aplicaciones_flowchart-v2-pointEnd" class="marker flowchart-v2" markerHeight="8" markerUnits="userSpaceOnUse" markerWidth="8" orient="auto" refX="5" refY="5" viewBox="0 0 10 10"><path d="m0 0 10 5-10 5z" class="arrowMarkerPath" style="stroke-width:1;stroke-dasharray:1,0"/></marker><marker id="dia-s01_d7_aplicaciones_flowchart-v2-pointStart" class="marker flowchart-v2" markerHeight="8" markerUnits="userSpaceOnUse" markerWidth="8" orient="auto" refX="4.5" refY="5" viewBox="0 0 10 10"><path d="m0 5 10 5V0z" class="arrowMarkerPath" style="stroke-width:1;stroke-dasharray:1,0"/></marker><marker id="dia-s01_d7_aplicaciones_flowchart-v2-pointEnd-margin" class="marker flowchart-v2" markerHeight="14" markerUnits="userSpaceOnUse" markerWidth="10.5" orient="auto" refX="11.5" refY="7" viewBox="0 0 11.5 14"><path d="m0 0 11.5 7L0 14z" class="arrowMarkerPath" style="stroke-width:0;stroke-dasharray:1,0"/></marker><marker id="dia-s01_d7_aplicaciones_flowchart-v2-pointStart-margin" class="marker flowchart-v2" markerHeight="14" markerUnits="userSpaceOnUse" markerWidth="11.5" orient="auto" refX="1" refY="7" viewBox="0 0 11.5 14"><polygon points="0,7 11.5,14 11.5,0" class="arrowMarkerPath" style="stroke-width:0;stroke-dasharray:1,0"/></marker><marker id="dia-s01_d7_aplicaciones_flowchart-v2-circleEnd" class="marker flowchart-v2" markerHeight="11" markerUnits="userSpaceOnUse" markerWidth="11" orient="auto" refX="11" refY="5" viewBox="0 0 10 10"><circle cx="5" cy="5" r="5" class="arrowMarkerPath" style="stroke-width:1;stroke-dasharray:1,0"/></marker><marker id="dia-s01_d7_aplicaciones_flowchart-v2-circleStart" class="marker flowchart-v2" markerHeight="11" markerUnits="userSpaceOnUse" markerWidth="11" orient="auto" refX="-1" refY="5" viewBox="0 0 10 10"><circle cx="5" cy="5" r="5" class="arrowMarkerPath" style="stroke-width:1;stroke-dasharray:1,0"/></marker><marker id="dia-s01_d7_aplicaciones_flowchart-v2-circleEnd-margin" class="marker flowchart-v2" markerHeight="14" markerUnits="userSpaceOnUse" markerWidth="14" orient="auto" refX="12.25" refY="5" viewBox="0 0 10 10"><circle cx="5" cy="5" r="5" class="arrowMarkerPath" style="stroke-width:0;stroke-dasharray:1,0"/></marker><marker id="dia-s01_d7_aplicaciones_flowchart-v2-circleStart-margin" class="marker flowchart-v2" markerHeight="14" markerUnits="userSpaceOnUse" markerWidth="14" orient="auto" refX="-2" refY="5" viewBox="0 0 10 10"><circle cx="5" cy="5" r="5" class="arrowMarkerPath" style="stroke-width:0;stroke-dasharray:1,0"/></marker><marker id="dia-s01_d7_aplicaciones_flowchart-v2-crossEnd" class="marker cross flowchart-v2" markerHeight="11" markerUnits="userSpaceOnUse" markerWidth="11" orient="auto" refX="12" refY="5.2" viewBox="0 0 11 11"><path d="m1 1 9 9m0-9-9 9" class="arrowMarkerPath" style="stroke-width:2;stroke-dasharray:1,0"/></marker><marker id="dia-s01_d7_aplicaciones_flowchart-v2-crossStart" class="marker cross flowchart-v2" markerHeight="11" markerUnits="userSpaceOnUse" markerWidth="11" orient="auto" refX="-1" refY="5.2" viewBox="0 0 11 11"><path d="m1 1 9 9m0-9-9 9" class="arrowMarkerPath" style="stroke-width:2;stroke-dasharray:1,0"/></marker><marker id="dia-s01_d7_aplicaciones_flowchart-v2-crossEnd-margin" class="marker cross flowchart-v2" markerHeight="12" markerUnits="userSpaceOnUse" markerWidth="12" orient="auto" refX="17.7" refY="7.5" viewBox="0 0 15 15"><path d="m1 1 13 13M1 14 14 1" class="arrowMarkerPath" style="stroke-width:2.5"/></marker><marker id="dia-s01_d7_aplicaciones_flowchart-v2-crossStart-margin" class="marker cross flowchart-v2" markerHeight="12" markerUnits="userSpaceOnUse" markerWidth="12" orient="auto" refX="-3.5" refY="7.5" viewBox="0 0 15 15"><path d="m1 1 13 13M1 14 14 1" class="arrowMarkerPath" style="stroke-width:2.5;stroke-dasharray:1,0"/></marker><g class="root"><g class="edgePaths"><path id="dia-s01_d7_aplicaciones-L_T_SIS_0" marker-end="url(#dia-s01_d7_aplicaciones_flowchart-v2-pointEnd)" d="m474.461 55.426-56.244 7.012c-56.243 7.013-168.73 21.037-224.974 32.925S137 117 137 121.875v4.875" class="edge-thickness-normal edge-pattern-solid edge-thickness-normal edge-pattern-solid flowchart-link" data-edge="true" data-et="edge" data-id="L_T_SIS_0" data-look="classic" data-points="W3sieCI6NDc0LjQ2MDkzNzUsInkiOjU1LjQyNTc1NDk5Nzg3MzI0fSx7IngiOjEzNywieSI6OTcuNX0seyJ4IjoxMzcsInkiOjEzMC43NX1d"/><path id="dia-s01_d7_aplicaciones-L_T_USU_0" marker-end="url(#dia-s01_d7_aplicaciones_flowchart-v2-pointEnd)" d="m509.82 72.5-11.157 4.167c-11.158 4.166-33.473 12.5-44.63 21.541S442.875 117 442.875 121.875v4.875" class="edge-thickness-normal edge-pattern-solid edge-thickness-normal edge-pattern-solid flowchart-link" data-edge="true" data-et="edge" data-id="L
></g><g class="edgeLabels"><rect class="background" style="stroke:none"/><rect class="background" style="stroke:none"/><rect class="background" style="stroke:none"/><rect class="background" style="stroke:none"/><rect class="background" style="stroke:none"/><rect class="background" style="stroke:none"/><rect class="background" style="stroke:none"/><rect class="background" style="stroke:none"/></g><g class="nodes"><g id="dia-s01_d7_aplicaciones-flowchart-T-0" class="node default raiz" data-look="classic" transform="translate(596.18 40.25)"><rect width="243.438" height="64.5" x="-121.719" y="-32.25" class="basic label-container" style="fill:#f3eefe!important;stroke:#4a3aa7!important"/><g class="label" style="color:#2e2377!important" transform="translate(0 -17.25)"><rect/><rect class="background" style="stroke:none"/><text y="-10.1" style="fill:#2e2377!important"><tspan x="0" y="-.1em" class="text-outer-tspan row" dy="1.1em"><tspan class="text-inner-tspan" font-style="normal" font-weight="normal">Aplicaciones</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> informáticas</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> ·</tspan></tspan><tspan x="0" y="1em" class="text-outer-tspan row" dy="1.1em"><tspan class="text-inner-tspan" font-style="normal" font-weight="normal">todo</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> el</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> software</tspan></tspan></text></g></g><g id="dia-s01_d7_aplicaciones-flowchart-SIS-1" class="node default cajon" data-look="classic" transform="translate(137 163)"><rect width="258" height="64.5" x="-129" y="-32.25" class="basic label-container" style="fill:#e8f0fb!important;stroke:#2a78d6!important"/><g class="label" style="color:#10294d!important" transform="translate(0 -17.25)"><rect/><rect class="background" style="stroke:none"/><text y="-10.1" style="fill:#10294d!important"><tspan x="0" y="-.1em" class="text-outer-tspan row" dy="1.1em"><tspan class="text-inner-tspan" font-style="normal" font-weight="normal">Software</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> de</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> sistema</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> ·</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> manda</tspan></tspan><tspan x="0" y="1em" class="text-outer-tspan row" dy="1.1em"><tspan class="text-inner-tspan" font-style="normal" font-weight="normal">en</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> la</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> máquina</tspan></tspan></text></g></g><g id="dia-s01_d7_aplicaciones-flowchart-USU-2" class="node default cajon" data-look="classic" transform="translate(442.875 163)"><rect width="253.75" height="64.5" x="-126.875" y="-32.25" class="basic label-container" style="fill:#e8f0fb!important;stroke:#2a78d6!important"/><g class="label" style="color:#10294d!important" transform="translate(0 -17.25)"><rect/><rect class="background" style="stroke:none"/><text y="-10.1" style="fill:#10294d!important"><tspan x="0" y="-.1em" class="text-outer-tspan row" dy="1.1em"><tspan class="text-inner-tspan" font-style="normal" font-weight="normal">Aplicaciones</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> de</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> usuario</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> ·</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> las</tspan></tspan><tspan x="0" y="1em" class="text-outer-tspan row" dy="1.1em"><tspan class="text-inner-tspan" font-style="normal" font-weight="normal">usa</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> una</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> persona</tspan></tspan></text></g></g><g id="dia-s01_d7_aplicaciones-flowchart-DEV-3" class="node default cajon" data-look="classic" transform="translate(749.484 163)"><rect width="259.469" height="64.5" x="-129.734" y="-32.25" class="basic label-container" style="fill:#e8f0fb!important;stroke:#2a78d6!important"/><g class="label" style="color:#10294d!important" transform="translate(0 -17.25)"><rect/><rect class="background" style="stroke:none"/><text y="-10.1" style="fill:#10294d!important"><tspan x="0" y="-.1em" class="text-outer-tspan row" dy="1.1em"><tspan class="text-inner-tspan" font-style="normal" font-weight="normal">Software</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> de</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> desarrollo</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> ·</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> sirve</tspan></tspan><tspan x="0" y="1em" class="text-outer-tspan row" dy="1.1em"><tspan class="text-inner-tspan" font-style="normal" font-weight="normal">para</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> hacer</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> software</tspan></tspan></text></g></g><g id="dia-s01_d7_aplicaciones-flowchart-ESP-4" class="node default cajon" data-look="classic" transform="translate(1054.82 163)"><rect width="251.203" height="81" x="-125.602" y="-40.5" class="basic label-container" style="fill:#e8f0fb!important;stroke:#2a78d6!important"/><g class="label" style="color:#10294d!important" transform="translate(0 -25.5)"><rect/><rect class="background" style="stroke:none"/><text y="-10.1" style="fill:#10294d!important"><tspan x="0" y="-.1em" class="text-outer-tspan row" dy="1.1em"><tspan class="text-inner-tspan" font-style="normal" font-weight="normal">Aplicaciones</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> especializadas</tspan></tspan><tspan x="0" y="1em" class="text-outer-tspan row" dy="1.1em"><tspan class="text-inner-tspan" font-style="normal" font-weight="normal">y</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> de</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> control</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> ·</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> gobiernan</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> un</tspan></tspan><tspan x="0" y="2.1em" class="text-outer-tspan row" dy="1.1em"><tspan class="text-inner-tspan" font-style="normal" font-weight="normal">equipo</tspan></tspan></text></g></g><g id="dia-s01_d7_aplicaciones-flowchart-S1-14" class="node default ejemplo" data-look="classic" transform="translate(137 302.25)"><rect width="237.813" height="64.5" x="-118.906" y="-32.25" class="basic label-container" style="fill:#fdf6e3!important;stroke:#eda100!important"/><g class="label" style="color:#10294d!important" transform="translate(0 -17.25)"><rect/><rect class="background" style="stroke:none"/><text y="-10.1" style="fill:#10294d!important"><tspan x="0" y="-.1em" class="text-outer-tspan row" dy="1.1em"><tspan class="text-inner-tspan" font-style="normal" font-weight="normal">Windows</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> 11</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> ·</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> Android</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> ·</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> el</tspan></tspan><tspan x="0" y="1em" class="text-outer-tspan row" dy="1.1em"><tspan class="text-inner-tspan" font-style="normal" font-weight="normal">Linux</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> del</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> servidor</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> del</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> AVA</tspan></tspan></text></g></g><g id="dia-s01_d7_aplicaciones-flowchart-U1-16" class="node default ejemplo" data-look="classic" transform="translate(442.875 302.25)"><rect width="228.172" height="64.5" x="-114.086" y="-32.25" class="basic label-container" style="fill:#fdf6e3!important;stroke:#eda100!important"/><g class="label" style="color:#10294d!important" transform="translate(0 -17.25)"><rect/><rect class="background" style="stroke:none"/><text y="-10.1" style="fill:#10294d!important"><tspan x="0" y="-.1em" class="text-outer-tspan row" dy="1.1em"><tspan class="text-inner-tspan" font-style="normal" font-weight="normal">La</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> app</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> de</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> Metrolínea</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> ·</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> el</tspan></tspan><tspan x="0" y="1em" class="text-outer-tspan row" dy="1.1em"><tspan class="text-inner-tspan" font-style="normal" font-weight="normal">Moodle</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> de</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> la</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> UIS</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> ·</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> Nequi</tspan></tspan></text></g></g><g id="dia-s01_d7_aplicaciones-flowchart-D1-18" class="node default ejemplo" data-look="classic" transform="translate(749.484 302.25)"><rect width="256.641" height="64.5" x="-128.32" y="-32.25" class="basic label-container" style="fill:#fdf6e3!important;stroke:#eda100!important"/><g class="label" style="color:#10294d!important" transform="translate(0 -17.25)"><rect/><rect class="background" style="stroke:none"/><text y="-10.1" style="fill:#10294d!important"><tspan x="0" y="-.1em" class="text-outer-tspan row" dy="1.1em"><tspan class="text-inner-tspan" font-style="normal" font-weight="normal">Python</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> ·</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> VS</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> Code</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> ·</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> Jupyter</tspan></tspan><tspan x="0" y="1em" class="text-outer-tspan row" dy="1.1em"><tspan class="text-inner-tspan" font-style="normal" font-weight="normal">—</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> lo</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> que</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> estás</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> usando</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> ahora</tspan></tspan></text></g></g><g id="dia-s01_d7_aplicaciones-flowchart-E1-20" class="node default ejemplo" data-look="classic" transform="translate(1054.82 302.25)"><rect width="252.156" height="97.5" x="-126.078" y="-48.75" class="basic label-container" style="fill:#fdf6e3!important;stroke:#eda100!important"/><g class="label" style="color:#10294d!important" transform="translate(0 -33.75)"><rect/><rect class="background" style="stroke:none"/><text y="-10.1" style="fill:#10294d!important"><tspan x="0" y="-.1em" class="text-outer-tspan row" dy="1.1em"><tspan class="text-inner-tspan" font-style="normal" font-weight="normal">Los</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> semáforos</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> de</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> la</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> Carrera</tspan></tspan><tspan x="0" y="1em" class="text-outer-tspan row" dy="1.1em"><tspan class="text-inner-tspan" font-style="normal" font-weight="normal">27</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> ·</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> un</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> CAD</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> de</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> Civil</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> ·</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> el</tspan></tspan><tspan x="0" y="2.1em" class="text-outer-tspan row" dy="1.1em"><tspan class="text-inner-tspan" font-style="normal" font-weight="normal">clasificador</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> de</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> IA</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> de</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> la</tspan></tspan><tspan x="0" y="3.2em" class="text-outer-tspan row" dy="1.1em"><tspan class="text-inner-tspan" font-style="normal" font-weight="normal">semana</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> 15</tspan></tspan></text></g></g></g></g><defs><filter id="dia-s01_d7_aplicaciones-drop-shadow" width="130%" height="130%"><feDropShadow dx="4" dy="4" flood-color="#000" flood-opacity=".06" stdDeviation="0"/></filter></defs><defs><filter id="dia-s01_d7_aplicaciones-drop-shadow-small" width="150%" height="150%"><feDropShadow dx="2" dy="2" flood-color="#000" flood-opacity=".06" stdDeviation="0"/></filter></defs><linearGradient id="dia-s01_d7_aplicaciones-gradient" x1="0%" x2="100%" y1="0%" y2="0%" gradientUnits="objectBoundingBox"><stop offset="0%" stop-color="hsl(0, 0%, 83.3333333333%)" stop-opacity="1"/><stop offset="100%" stop-color="hsl(0, 0%, 88.9215686275%)" stop-opacity="1"/></linearGradient></svg>', 'Los cuatro cajones, con ejemplos que ya usas en Bucaramanga.')

# %% [markdown]
# Detalle que casi nadie nota el primer día: **el software de desarrollo también
# es software**. Python, VS Code y Jupyter son programas que sirven para escribir
# programas. Estás usando un programa para aprender a hacer programas. Bienvenido
# al oficio.

# %% [markdown]
# Tres preguntas rápidas. No tienen nota: dan XP y te dicen si te quedó claro.

# %%
quiz(
    "Q1", 6,
    "El primer algoritmo pensado para una máquina se escribió…",
    ["un siglo antes de que existiera el primer computador",
     "al mismo tiempo que el ENIAC",
     "cuando se inventó Python",
     "en 1936, con Turing"],
    "un siglo antes de que existiera el primer computador",
    "Ada Lovelace, 1843. La Máquina Analítica para la que lo escribió nunca "
    "llegó a construirse: el algoritmo es anterior al aparato.",
    pistas=["Vuelve a la línea de tiempo: la máquina para la que se escribió ni "
            "siquiera llegó a construirse."],
)

# %%
quiz(
    "Q2", 6,
    "¿Cuál de estas afirmaciones es FALSA?",
    ["El ENIAC se programaba moviendo cables",
     "Un archivo de Word es software",
     "Un transistor es hardware",
     "Ordenar la lista del curso es un proceso"],
    "Un archivo de Word es software",
    "Word es software; tu documento es un <b>dato</b>. La receta y el "
    "ingrediente no son la misma cosa.",
    pistas=["Tres de las cuatro son ciertas. Piensa en la diferencia entre la "
            "receta y el ingrediente."],
)

# %%
quiz(
    "Q3", 6,
    "El software que controla los semáforos de la Carrera 27 es…",
    ["una aplicación de usuario",
     "una aplicación especializada de control",
     "un sistema operativo",
     "una herramienta de desarrollo"],
    "una aplicación especializada de control",
    "Nadie se sienta delante de él: gobierna un equipo del mundo real, igual "
    "que el software de un ascensor o de una máquina de la planta.",
    pistas=["No lo usa una persona en un escritorio ni sirve para escribir "
            "programas: gobierna un equipo del mundo real."],
)

# %% [markdown]
# ### 3B. Los tres pisos del edificio
#
# Tu procesador no entiende `print`. No entiende `suma`. No entiende **ninguna
# palabra**. Solo entiende números, y ni siquiera en decimal: en binario, unos y
# ceros que en el fondo son «hay corriente» y «no hay corriente».
#
# Entonces, ¿cómo diablos funcionó tu programa?
#
# Porque entre tú y el silicio hay **pisos**. Vamos a bajarlos uno por uno, con la
# misma cuenta de siempre: **4 + 9**.

# %% [markdown]
# #### Piso 3 — Alto nivel: lo que tú escribes
#
# Cerca de una persona, lejos de la máquina. Se lee casi como inglés.

# %%
def sumar(a, b):
    return a + b

print(sumar(4, 9))

# %% [markdown]
# #### Piso 2 — Bajo nivel: lo que entiende la máquina virtual de Python
#
# Antes de ejecutar nada, Python **traduce** tu función a una lista de órdenes
# mínimas, cada una tan simple que no se puede partir más: «trae `a`», «trae
# `b`», «súmalos», «devuélvelo». Eso se llama **bytecode**, y es el pariente
# directo del **lenguaje ensamblador**.
#
# Puedes verlo. En serio. Ejecuta:

# %%
import dis
dis.dis(sumar)

# %% [markdown]
# Léelo así, ignorando los números de la izquierda:
#
# | Orden | Qué significa |
# |---|---|
# | `RESUME` | «arranca» (papeleo interno de Python; ignóralo) |
# | `LOAD_FAST a` | trae el valor de `a` y ponlo sobre la mesa |
# | `LOAD_FAST b` | trae el valor de `b` y ponlo sobre la mesa |
# | `BINARY_OP +` | toma los dos de la mesa, súmalos, deja el resultado |
# | `RETURN_VALUE` | entrega lo que quedó en la mesa |
#
# Cinco órdenes para una suma. **Tú escribiste una línea; la máquina necesitó
# cinco pasos.** Y esto todavía no es lenguaje de máquina de verdad: es el
# ensamblador de una máquina *imaginaria* (la máquina virtual de Python).
#
# *(Este listado es el de Python 3.11, que es el del AVA. Si en tu computador ves
# líneas de más o con otro nombre, ignóralas: dependen de la versión.)*
#
# Si en vez de Python usáramos C++ —que se compila directo al procesador— el
# ensamblador real de un Intel se vería así (no lo ejecutes, solo léelo):
#
# ```asm
# mov  eax, DWORD PTR [rbp-4]   ; trae a
# add  eax, DWORD PTR [rbp-8]   ; súmale b
# ret                           ; devuelve el resultado
# ```
#
# ¿Ves el parecido? *Trae, suma, devuelve.* Todos los ensambladores del mundo
# dicen lo mismo con otras palabras.

# %% [markdown]
# #### Piso 1 — Lenguaje de máquina: lo que de verdad viaja
#
# Ni siquiera `LOAD_FAST` existe dentro del computador. Esa palabra es un favor
# que nos hace Python para que podamos leer. Lo que hay de verdad son **bytes**.
# Míralos:

# %%
crudo = sumar.__code__.co_code
print("Los mismos 5 pasos, en bytes:", list(crudo))
print()
print("Y en binario, que es lo único que existe de verdad:")
print(" ".join(format(b, "08b") for b in crudo))

# %% [markdown]
# Eso —esa fila de unos y ceros— es tu función. No una foto de tu función: **es
# tu función**. Cada `1` es un transistor con corriente y cada `0` es uno sin
# corriente.
#
# Ahora entiendes la frase completa: *bajar de nivel es acercarse a la máquina y
# alejarse de la persona*.

# %%
# Diagrama: s01_d3_niveles
ava.figura('<svg xmlns="http://www.w3.org/2000/svg" id="dia-s01_d3_niveles" width="100%" aria-roledescription="flowchart-v2" class="flowchart" role="graphics-document document" style="max-width:267.734px;background-color:transparent" viewBox="0 0 267.734 629.5"><style>#dia-s01_d3_niveles{font-family:system-ui,-apple-system,&apos;Segoe UI&apos;,Roboto,sans-serif;font-size:15px;fill:#000000;}@keyframes edge-animation-frame{from{stroke-dashoffset:0;}}@keyframes dash{to{stroke-dashoffset:0;}}#dia-s01_d3_niveles .edge-animation-slow{stroke-dasharray:9,5!important;stroke-dashoffset:900;animation:dash 50s linear infinite;stroke-linecap:round;}#dia-s01_d3_niveles .edge-animation-fast{stroke-dasharray:9,5!important;stroke-dashoffset:900;animation:dash 20s linear infinite;stroke-linecap:round;}#dia-s01_d3_niveles .error-icon{fill:#552222;}#dia-s01_d3_niveles .error-text{fill:#552222;stroke:#552222;}#dia-s01_d3_niveles .edge-thickness-normal{stroke-width:1px;}#dia-s01_d3_niveles .edge-thickness-thick{stroke-width:3.5px;}#dia-s01_d3_niveles .edge-pattern-solid{stroke-dasharray:0;}#dia-s01_d3_niveles .edge-thickness-invisible{stroke-width:0;fill:none;}#dia-s01_d3_niveles .edge-pattern-dashed{stroke-dasharray:3;}#dia-s01_d3_niveles .edge-pattern-dotted{stroke-dasharray:2;}#dia-s01_d3_niveles .marker{fill:#52514e;stroke:#52514e;}#dia-s01_d3_niveles .marker.cross{stroke:#52514e;}#dia-s01_d3_niveles svg{font-family:system-ui,-apple-system,&apos;Segoe UI&apos;,Roboto,sans-serif;font-size:15px;}#dia-s01_d3_niveles p{margin:0;}#dia-s01_d3_niveles .label{font-family:system-ui,-apple-system,&apos;Segoe UI&apos;,Roboto,sans-serif;color:#000000;}#dia-s01_d3_niveles .cluster-label text{fill:#333;}#dia-s01_d3_niveles .cluster-label span{color:#333;}#dia-s01_d3_niveles .cluster-label span p{background-color:transparent;}#dia-s01_d3_niveles .label text,#dia-s01_d3_niveles span{fill:#000000;color:#000000;}#dia-s01_d3_niveles .node rect,#dia-s01_d3_niveles .node circle,#dia-s01_d3_niveles .node ellipse,#dia-s01_d3_niveles .node polygon,#dia-s01_d3_niveles .node path{fill:#eee;stroke:#999;stroke-width:1px;}#dia-s01_d3_niveles .rough-node .label text,#dia-s01_d3_niveles .node .label text,#dia-s01_d3_niveles .image-shape .label,#dia-s01_d3_niveles .icon-shape .label{text-anchor:middle;}#dia-s01_d3_niveles .node .katex path{fill:#000;stroke:#000;stroke-width:1px;}#dia-s01_d3_niveles .rough-node .label,#dia-s01_d3_niveles .node .label,#dia-s01_d3_niveles .image-shape .label,#dia-s01_d3_niveles .icon-shape .label{text-align:center;}#dia-s01_d3_niveles .node.clickable{cursor:pointer;}#dia-s01_d3_niveles .root .anchor path{fill:#52514e!important;stroke-width:0;stroke:#52514e;}#dia-s01_d3_niveles .arrowheadPath{fill:#333333;}#dia-s01_d3_niveles .edgePath .path{stroke:#52514e;stroke-width:1px;}#dia-s01_d3_niveles .flowchart-link{stroke:#52514e;fill:none;}#dia-s01_d3_niveles .edgeLabel{background-color:white;text-align:center;}#dia-s01_d3_niveles .edgeLabel p{background-color:white;}#dia-s01_d3_niveles .edgeLabel rect{opacity:0.5;background-color:white;fill:white;}#dia-s01_d3_niveles .labelBkg{background-color:rgba(255, 255, 255, 0.5);}#dia-s01_d3_niveles .cluster rect{fill:hsl(0, 0%, 98.9215686275%);stroke:#707070;stroke-width:1px;}#dia-s01_d3_niveles .cluster text{fill:#333;}#dia-s01_d3_niveles .cluster span{color:#333;}#dia-s01_d3_niveles div.mermaidTooltip{position:absolute;text-align:center;max-width:200px;padding:2px;font-family:system-ui,-apple-system,&apos;Segoe UI&apos;,Roboto,sans-serif;font-size:12px;background:#fdf6e3;border:1px solid #707070;border-radius:2px;pointer-events:none;z-index:100;}#dia-s01_d3_niveles .flowchartTitleText{text-anchor:middle;font-size:18px;fill:#000000;}#dia-s01_d3_niveles rect.text{fill:none;stroke-width:0;}#dia-s01_d3_niveles .icon-shape,#dia-s01_d3_niveles .image-shape{background-color:white;text-align:center;}#dia-s01_d3_niveles .icon-shape p,#dia-s01_d3_niveles .image-shape p{background-color:white;padding:2px;}#dia-s01_d3_niveles .icon-shape .label rect,#dia-s01_d3_niveles .image-shape .label rect{opacity:0.5;background-color:white;fill:white;}#dia-s01_d3_niveles .label-icon{display:inline-block;height:1em;overflow:visible;vertical-align:-0.125em;}#dia-s01_d3_niveles .node .label-icon path{fill:currentColor;stroke:revert;stroke-width:revert;}#dia-s01_d3_niveles .node .neo-node{stroke:#999;}#dia-s01_d3_niveles [data-look=&quot;neo&quot;].node rect,#dia-s01_d3_niveles [data-look=&quot;neo&quot;].cluster rect,#dia-s01_d3_niveles [data-look=&quot;neo&quot;].node polygon{stroke:url(#dia-s01_d3_niveles-gradient);filter:drop-shadow( 1px 2px 2px rgba(185,185,185,1));}#dia-s01_d3_niveles [data-look=&quot;neo&quot;].swimlane.cluster rect{filter:none;}#dia-s01_d3_niveles [data-look=&quot;neo&quot;].node path{stroke:url(#dia-s01_d3_niveles-gradient);stroke-width:1px;}#dia-s01_d3_niveles [data-look=&quot;neo&quot;].node .outer-path{filter:drop-shadow( 1px 2px 2px rgba(185,185,185,1));}#dia-s01_d3_niveles [data-look=&quot;neo&quot;].node .neo-line path{stroke:#999;filter:none;}#dia-s01_d3_niveles [data-look=&quot;neo&quot;].node circle{stroke:url(#dia-s01_d3_niveles-gradient);filter:drop-shadow( 1px 2px 2px rgba(185,185,185,1));}#dia-s01_d3_niveles [data-look=&quot;neo&quot;].node circle .state-start{fill:#000000;}#dia-s01_d3_niveles [data-look=&quot;neo&quot;].icon-shape .icon{fill:url(#dia-s01_d3_niveles-gradient);filter:drop-shadow( 1px 2px 2px rgba(185,185,185,1));}#dia-s01_d3_niveles [data-look=&quot;neo&quot;].icon-shape .icon-neo path{stroke:url(#dia-s01_d3_niveles-gradient);filter:drop-shadow( 1px 2px 2px rgba(185,185,185,1));}#dia-s01_d3_niveles :root{--mermaid-font-family:&quot;trebuchet ms&quot;,verdana,arial,sans-serif;}#dia-s01_d3_niveles .alto rect{fill:rgb(233, 247, 238)!important;stroke:rgb(12, 163, 12)!important;color:rgb(16, 41, 77)!important;}#dia-s01_d3_niveles .alto polygon{fill:rgb(233, 247, 238)!important;stroke:rgb(12, 163, 12)!important;color:rgb(16, 41, 77)!important;}#dia-s01_d3_niveles .alto ellipse{fill:rgb(233, 247, 238)!important;stroke:rgb(12, 163, 12)!important;color:rgb(16, 41, 77)!important;}#dia-s01_d3_niveles .alto circle{fill:rgb(233, 247, 238)!important;stroke:rgb(12, 163, 12)!important;color:rgb(16, 41, 77)!important;}#dia-s01_d3_niveles .alto path{fill:rgb(233, 247, 238)!important;stroke:rgb(12, 163, 12)!important;color:rgb(16, 41, 77)!important;}#dia-s01_d3_niveles .alto tspan{fill:rgb(16, 41, 77)!important;}#dia-s01_d3_niveles .bajo rect{fill:rgb(232, 240, 251)!important;stroke:rgb(42, 120, 214)!important;color:rgb(16, 41, 77)!important;}#dia-s01_d3_niveles .bajo polygon{fill:rgb(232, 240, 251)!important;stroke:rgb(42, 120, 214)!important;color:rgb(16, 41, 77)!important;}#dia-s01_d3_niveles .bajo ellipse{fill:rgb(232, 240, 251)!important;stroke:rgb(42, 120, 214)!important;color:rgb(16, 41, 77)!important;}#dia-s01_d3_niveles .bajo circle{fill:rgb(232, 240, 251)!important;stroke:rgb(42, 120, 214)!important;color:rgb(16, 41, 77)!important;}#dia-s01_d3_niveles .bajo path{fill:rgb(232, 240, 251)!important;stroke:rgb(42, 120, 214)!important;color:rgb(16, 41, 77)!important;}#dia-s01_d3_niveles .bajo tspan{fill:rgb(16, 41, 77)!important;}#dia-s01_d3_niveles .maquina rect{fill:rgb(243, 238, 254)!important;stroke:rgb(74, 58, 167)!important;color:rgb(46, 35, 119)!important;}#dia-s01_d3_niveles .maquina polygon{fill:rgb(243, 238, 254)!important;stroke:rgb(74, 58, 167)!important;color:rgb(46, 35, 119)!important;}#dia-s01_d3_niveles .maquina ellipse{fill:rgb(243, 238, 254)!important;stroke:rgb(74, 58, 167)!important;color:rgb(46, 35, 119)!important;}#dia-s01_d3_niveles .maquina circle{fill:rgb(243, 238, 254)!important;stroke:rgb(74, 58, 167)!important;color:rgb(46, 35, 119)!important;}#dia-s01_d3_niveles .maquina path{fill:rgb(243, 238, 254)!important;stroke:rgb(74, 58, 167)!important;color:rgb(46, 35, 119)!important;}#dia-s01_d3_niveles .maquina tspan{fill:rgb(46, 35, 119)!important;}</style><marker id="dia-s01_d3_niveles_flowchart-v2-pointEnd" class="marker flowchart-v2" markerHeight="8" markerUnits="userSpaceOnUse" markerWidth="8" orient="auto" refX="5" refY="5" viewBox="0 0 10 10"><path d="m0 0 10 5-10 5z" class="arrowMarkerPath" style="stroke-width:1;stroke-dasharray:1,0"/></marker><marker id="dia-s01_d3_niveles_flowchart-v2-pointStart" class="marker flowchart-v2" markerHeight="8" markerUnits="userSpaceOnUse" markerWidth="8" orient="auto" refX="4.5" refY="5" viewBox="0 0 10 10"><path d="m0 5 10 5V0z" class="arrowMarkerPath" style="stroke-width:1;stroke-dasharray:1,0"/></marker><marker id="dia-s01_d3_niveles_flowchart-v2-pointEnd-margin" class="marker flowchart-v2" markerHeight="14" markerUnits="userSpaceOnUse" markerWidth="10.5" orient="auto" refX="11.5" refY="7" viewBox="0 0 11.5 14"><path d="m0 0 11.5 7L0 14z" class="arrowMarkerPath" style="stroke-width:0;stroke-dasharray:1,0"/></marker><marker id="dia-s01_d3_niveles_flowchart-v2-pointStart-margin" class="marker flowchart-v2" markerHeight="14" markerUnits="userSpaceOnUse" markerWidth="11.5" orient="auto" refX="1" refY="7" viewBox="0 0 11.5 14"><polygon points="0,7 11.5,14 11.5,0" class="arrowMarkerPath" style="stroke-width:0;stroke-dasharray:1,0"/></marker><marker id="dia-s01_d3_niveles_flowchart-v2-circleEnd" class="marker flowchart-v2" markerHeight="11" markerUnits="userSpaceOnUse" markerWidth="11" orient="auto" refX="11" refY="5" viewBox="0 0 10 10"><circle cx="5" cy="5" r="5" class="arrowMarkerPath" style="stroke-width:1;stroke-dasharray:1,0"/></marker><marker id="dia-s01_d3_niveles_flowchart-v2-circleStart" class="marker flowchart-v2" markerHeight="11" markerUnits="userSpaceOnUse" markerWidth="11" orient="auto" refX="-1" refY="5" viewBox="0 0 10 10"><circle cx="5" cy="5" r="5" class="arrowMarkerPath" style="stroke-width:1;stroke-dasharray:1,0"/></marker><marker id="dia-s01_d3_niveles_flowchart-v2-circleEnd-margin" class="marker flowchart-v2" markerHeight="14" markerUnits="userSpaceOnUse" markerWidth="14" orient="auto" refX="12.25" refY="5" viewBox="0 0 10 10"><circle cx="5" cy="5" r="5" class="arrowMarkerPath" style="stroke-width:0;stroke-dasharray:1,0"/></marker><marker id="dia-s01_d3_niveles_flowchart-v2-circleStart-margin" class="marker flowchart-v2" markerHeight="14" markerUnits="userSpaceOnUse" markerWidth="14" orient="auto" refX="-2" refY="5" viewBox="0 0 10 10"><circle cx="5" cy="5" r="5" class="arrowMarkerPath" style="stroke-width:0;stroke-dasharray:1,0"/></marker><marker id="dia-s01_d3_niveles_flowchart-v2-crossEnd" class="marker cross flowchart-v2" markerHeight="11" markerUnits="userSpaceOnUse" markerWidth="11" orient="auto" refX="12" refY="5.2" viewBox="0 0 11 11"><path d="m1 1 9 9m0-9-9 9" class="arrowMarkerPath" style="stroke-width:2;stroke-dasharray:1,0"/></marker><marker id="dia-s01_d3_niveles_flowchart-v2-crossStart" class="marker cross flowchart-v2" markerHeight="11" markerUnits="userSpaceOnUse" markerWidth="11" orient="auto" refX="-1" refY="5.2" viewBox="0 0 11 11"><path d="m1 1 9 9m0-9-9 9" class="arrowMarkerPath" style="stroke-width:2;stroke-dasharray:1,0"/></marker><marker id="dia-s01_d3_niveles_flowchart-v2-crossEnd-margin" class="marker cross flowchart-v2" markerHeight="12" markerUnits="userSpaceOnUse" markerWidth="12" orient="auto" refX="17.7" refY="7.5" viewBox="0 0 15 15"><path d="m1 1 13 13M1 14 14 1" class="arrowMarkerPath" style="stroke-width:2.5"/></marker><marker id="dia-s01_d3_niveles_flowchart-v2-crossStart-margin" class="marker cross flowchart-v2" markerHeight="12" markerUnits="userSpaceOnUse" markerWidth="12" orient="auto" refX="-3.5" refY="7.5" viewBox="0 0 15 15"><path d="m1 1 13 13M1 14 14 1" class="arrowMarkerPath" style="stroke-width:2.5;stroke-dasharray:1,0"/></marker><g class="root"><g class="edgePaths"><path id="dia-s01_d3_niveles-L_TU_A_0" marker-end="url(#dia-s01_d3_niveles_flowchart-v2-pointEnd)" d="m134.367 41.5-.083 5.917c-.083 5.916-.25 17.75-.333 29s-.084 21.916-.084 27.25V109" class="edge-thickness-normal edge-pattern-solid edge-thickness-normal edge-pattern-solid flowchart-link" data-edge="true" data-et="edge" data-id="L_TU_A_0" data-look="classic" data-points="W3sieCI6MTM0LjM2NzE4NzUsInkiOjQxLjV9LHsieCI6MTMzLjg2NzE4NzUsInkiOjc3fSx7IngiOjEzMy44NjcxODc1LCJ5IjoxMTN9XQ=="/><path id="dia-s01_d3_niveles-L_A_B_0" marker-end="url(#dia-s01_d3_niveles_flowchart-v2-pointEnd)" d="M133.867 177.5v68" class="edge-thickness-normal edge-pattern-solid edge-thickness-normal edge-pattern-solid flowchart-link" data-edge="true" data-et="edge" data-id="L
827.66m0 0 .783.71m-.783-.71.783.71m0 0 .736.76m-.736-.76.736.76m0 0 .686.805m-.686-.805.686.805m0 0 .632.848m-.632-.848.632.848m0 0 .577.887m-.577-.887.577.887m0 0 .52.921m-.52-.921.52.921m0 0 .458.953m-.459-.953.46.953m0 0c.14.35.283.7.396.98m-.397-.98.397.98m0 0 .334 1.004m-.334-1.004.334 1.004m0 0c.055.212.11.424.268 1.023m-.268-1.023.268 1.023m0 0 .202 1.039m-.202-1.039.202 1.039m0 0 .135 1.049m-.135-1.05.135 1.05m0 0 .068 1.055m-.068-1.055.068 1.055m0 0v1.058m0-1.058v1.058m0 0-.068 1.055m.068-1.055-.068 1.055m0 0-.135 1.05m.135-1.05-.135 1.05m0 0-.202 1.038m.202-1.039-.202 1.039m0 0-.268 1.023m.268-1.023-.268 1.023m0 0-.334 1.004m.334-1.004-.334 1.004m0 0-.397.98m.397-.98-.397.98m0 0-.459.953m.46-.953-.46.953m0 0-.519.921m.52-.921-.52.921m0 0-.577.887m.577-.887-.577.887m0 0-.632.848m.632-.848-.632.848m0 0-.686.805m.686-.805-.686.805m0 0-.736.76m.736-.76-.736.76m0 0-.783.71m.783-.71-.783.71m0 0-.827.66m.827-.66-.827.66m0 0-.867.605m.867-.605-.867.605m0 0-.905.549m.905-.549-.905.549m0 0-.937.489m.937-.49-.937.49m0 0-.968.428m.968-.428-.968.428m0 0-.992.365m.992-.365-.992.365m0 0-1.014.301m1.014-.3-1.014.3m0 0-1.031.236m1.03-.236-1.03.236m0 0-1.045.169m1.045-.17-1.045.17m0 0-1.052.101m1.052-.101-1.052.101m0 0-1.058.034m1.058-.034-1.058.034m0 0h-44.89m44.89 0h-44.89m0 0-1.057-.034m1.057.034-1.057-.034m0 0-1.053-.101m1.053.101-1.053-.101m0 0-1.044-.17m1.044.17-1.044-.17m0 0c-.273-.061-.545-.124-1.031-.235m1.03.236-1.03-.236m0 0-1.014-.3m1.014.3-1.014-.3m0 0-.993-.366m.993.365-.993-.365m0 0-.967-.428m.967.428-.967-.428m0 0-.938-.49m.938.49-.938-.49m0 0-.904-.548m.904.549-.904-.549m0 0-.868-.605m.868.605-.868-.605m0 0-.827-.66m.827.66c-.31-.247-.62-.493-.827-.66m0 0-.783-.71m.783.71-.783-.71m0 0-.736-.76m.736.76-.736-.76m0 0-.685-.805m.685.805-.685-.805m0 0-.633-.848m.633.848-.633-.848m0 0-.577-.887m.577.887-.577-.887m0 0-.519-.921m.519.921-.519-.921m0 0-.459-.953m.459.953-.459-.953m0 0-.397-.98m.397.98-.397-.98m0 0-.333-1.004m.333 1.004-.333-1.004m0 0-.268-1.023m.268 1.023-.268-1.023m0 0-.203-1.039m.203 1.039-.203-1.039m0 0-.135-1.049m.135 1.05-.135-1.05m0 0-.068-1.055m.068 1.055-.068-1.055m0 0v-1.058m0 1.058v-1.058m0 0 .068-1.055m-.068 1.055.068-1.055m0 0 .135-1.05m-.135 1.05.135-1.05m0 0 .203-1.038m-.203 1.039.203-1.039m0 0 .268-1.023m-.268 1.023.268-1.023m0 0 .333-1.004m-.333 1.004.333-1.004m0 0 .397-.98m-.397.98.397-.98m0 0 .459-.953m-.459.953.459-.953m0 0 .519-.921m-.519.921.519-.921m0 0 .577-.887m-.577.887.577-.887m0 0 .633-.848m-.633.848.633-.848m0 0 .685-.805m-.685.805.685-.805m0 0 .736-.76m-.736.76.736-.76m0 0 .783-.71m-.783.71.783-.71m0 0 .827-.66m-.827.66c.236-.19.472-.377.827-.66m0 0 .868-.605m-.868.605.868-.605m0 0 .904-.549m-.904.549.904-.549m0 0 .938-.489m-.938.49c.219-.115.438-.23.938-.49m0 0 .967-.428m-.967.428.967-.428m0 0 .993-.365m-.993.365.993-.365m0 0 1.014-.301m-1.014.3 1.014-.3m0 0 1.03-.236m-1.03.236 1.03-.236m0 0 1.045-.169m-1.044.17c.221-.037.443-.072 1.044-.17m0 0 1.053-.101m-1.053.101 1.053-.101m0 0 1.057-.034m-1.057.034 1.057-.034m0 0"/></g><g class="label" transform="translate(133.867 596)"><rect/><rect class="background" style="stroke:none"/><text y="-10.1"><tspan x="0" y="-.1em" class="text-outer-tspan row" dy="1.1em"><tspan class="text-inner-tspan" font-style="normal" font-weight="normal">El</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> silicio</tspan></tspan></text></g></g></g></g><defs><filter id="dia-s01_d3_niveles-drop-shadow" width="130%" height="130%"><feDropShadow dx="4" dy="4" flood-color="#000" flood-opacity=".06" stdDeviation="0"/></filter></defs><defs><filter id="dia-s01_d3_niveles-drop-shadow-small" width="150%" height="150%"><feDropShadow dx="2" dy="2" flood-color="#000" flood-opacity=".06" stdDeviation="0"/></filter></defs><linearGradient id="dia-s01_d3_niveles-gradient" x1="0%" x2="100%" y1="0%" y2="0%" gradientUnits="objectBoundingBox"><stop offset="0%" stop-color="hsl(0, 0%, 83.3333333333%)" stop-opacity="1"/><stop offset="100%" stop-color="hsl(0, 0%, 88.9215686275%)" stop-opacity="1"/></linearGradient></svg>', 'La misma suma, tres veces. Lo que cambia es a qué altura está escrita.')

# %%
tres_pisos(sumar)     # los tres paneles, con la MISMA función

# %% [markdown]
# ### Maneja tú una máquina de verdad (una pequeñita)
#
# Ver bytes es una cosa; **darle órdenes en su idioma** es otra. Te presento la
# **MiniMáquina**: un computador de mentiras con una sola gaveta (el
# *acumulador*) y cuatro instrucciones. Su lenguaje de máquina son números:
#
# | Código | Instrucción | Qué hace |
# |---|---|---|
# | `1 n` | CARGAR n | pone `n` en la gaveta, botando lo que hubiera |
# | `2 n` | SUMAR n | le suma `n` a lo que hay en la gaveta |
# | `3 0` | MOSTRAR | muestra lo que hay en la gaveta |
# | `0 0` | PARAR | apaga la máquina |
#
# Cada instrucción son **dos números**: el código y su argumento. Un programa es
# una lista de números y nada más. Ejecuta este y mira la traza:

# %%
programa = [1, 4,    # CARGAR 4
            2, 9,    # SUMAR 9
            3, 0,    # MOSTRAR
            0, 0]    # PARAR

MiniMaquina(programa).ejecutar(traza=True)

# %% [markdown]
# Acabas de **programar en lenguaje de máquina**. Sin comillas, sin metáfora: le
# diste a una máquina una lista de números y los obedeció en orden.
#
# Y ahora la moraleja de toda la sección. Estas tres cosas hacen exactamente lo
# mismo:
#
# ```
# [1, 4, 2, 9, 3, 0, 0, 0]        <- lenguaje de máquina  (la máquina feliz, tú perdido)
# CARGAR 4 / SUMAR 9 / MOSTRAR    <- ensamblador          (empate incómodo)
# print(4 + 9)                    <- alto nivel           (tú feliz, alguien tradujo por ti)
# ```
#
# Los tres pisos existen porque **alguien tuvo que ceder**. Durante veinte años
# cedieron las personas. Desde FORTRAN cede la máquina — y ese «alguien que
# traduce» es el intérprete que vas a conocer en un minuto.

# %% [markdown]
# ### 3C. ¿Dónde se escribe todo esto?
#
# Cuatro palabras que se confunden todo el tiempo y que a partir de hoy vas a
# distinguir:
#
# | Palabra | Qué es | Analogía | Si desaparece… |
# |---|---|---|---|
# | **Editor** | Un programa para escribir texto (tu código) | El cuaderno | Escribes en Notas y ya, pero sin colores ni ayudas |
# | **Terminal** | Una ventana donde le das órdenes escritas al sistema operativo | La ventanilla de atención | Tienes que hacer todo con clics |
# | **Intérprete** | El programa que lee tu código **y lo ejecuta línea por línea** | El traductor simultáneo | Tu código es un texto muerto |
# | **IDE** | Un paquete que trae editor + terminal + intérprete + depurador | El taller completo | Tienes las herramientas sueltas |
#
# Ejecuta el diagrama para verlo armado.

# %%
# Diagrama: s01_d5_entorno
ava.figura('<svg xmlns="http://www.w3.org/2000/svg" id="dia-s01_d5_entorno" width="100%" aria-roledescription="flowchart-v2" class="flowchart" role="graphics-document document" style="max-width:1351.42px;background-color:transparent" viewBox="0 0 1351.421 333.5"><style>#dia-s01_d5_entorno{font-family:system-ui,-apple-system,&apos;Segoe UI&apos;,Roboto,sans-serif;font-size:15px;fill:#000000;}@keyframes edge-animation-frame{from{stroke-dashoffset:0;}}@keyframes dash{to{stroke-dashoffset:0;}}#dia-s01_d5_entorno .edge-animation-slow{stroke-dasharray:9,5!important;stroke-dashoffset:900;animation:dash 50s linear infinite;stroke-linecap:round;}#dia-s01_d5_entorno .edge-animation-fast{stroke-dasharray:9,5!important;stroke-dashoffset:900;animation:dash 20s linear infinite;stroke-linecap:round;}#dia-s01_d5_entorno .error-icon{fill:#552222;}#dia-s01_d5_entorno .error-text{fill:#552222;stroke:#552222;}#dia-s01_d5_entorno .edge-thickness-normal{stroke-width:1px;}#dia-s01_d5_entorno .edge-thickness-thick{stroke-width:3.5px;}#dia-s01_d5_entorno .edge-pattern-solid{stroke-dasharray:0;}#dia-s01_d5_entorno .edge-thickness-invisible{stroke-width:0;fill:none;}#dia-s01_d5_entorno .edge-pattern-dashed{stroke-dasharray:3;}#dia-s01_d5_entorno .edge-pattern-dotted{stroke-dasharray:2;}#dia-s01_d5_entorno .marker{fill:#52514e;stroke:#52514e;}#dia-s01_d5_entorno .marker.cross{stroke:#52514e;}#dia-s01_d5_entorno svg{font-family:system-ui,-apple-system,&apos;Segoe UI&apos;,Roboto,sans-serif;font-size:15px;}#dia-s01_d5_entorno p{margin:0;}#dia-s01_d5_entorno .label{font-family:system-ui,-apple-system,&apos;Segoe UI&apos;,Roboto,sans-serif;color:#000000;}#dia-s01_d5_entorno .cluster-label text{fill:#333;}#dia-s01_d5_entorno .cluster-label span{color:#333;}#dia-s01_d5_entorno .cluster-label span p{background-color:transparent;}#dia-s01_d5_entorno .label text,#dia-s01_d5_entorno span{fill:#000000;color:#000000;}#dia-s01_d5_entorno .node rect,#dia-s01_d5_entorno .node circle,#dia-s01_d5_entorno .node ellipse,#dia-s01_d5_entorno .node polygon,#dia-s01_d5_entorno .node path{fill:#eee;stroke:#999;stroke-width:1px;}#dia-s01_d5_entorno .rough-node .label text,#dia-s01_d5_entorno .node .label text,#dia-s01_d5_entorno .image-shape .label,#dia-s01_d5_entorno .icon-shape .label{text-anchor:middle;}#dia-s01_d5_entorno .node .katex path{fill:#000;stroke:#000;stroke-width:1px;}#dia-s01_d5_entorno .rough-node .label,#dia-s01_d5_entorno .node .label,#dia-s01_d5_entorno .image-shape .label,#dia-s01_d5_entorno .icon-shape .label{text-align:center;}#dia-s01_d5_entorno .node.clickable{cursor:pointer;}#dia-s01_d5_entorno .root .anchor path{fill:#52514e!important;stroke-width:0;stroke:#52514e;}#dia-s01_d5_entorno .arrowheadPath{fill:#333333;}#dia-s01_d5_entorno .edgePath .path{stroke:#52514e;stroke-width:1px;}#dia-s01_d5_entorno .flowchart-link{stroke:#52514e;fill:none;}#dia-s01_d5_entorno .edgeLabel{background-color:white;text-align:center;}#dia-s01_d5_entorno .edgeLabel p{background-color:white;}#dia-s01_d5_entorno .edgeLabel rect{opacity:0.5;background-color:white;fill:white;}#dia-s01_d5_entorno .labelBkg{background-color:rgba(255, 255, 255, 0.5);}#dia-s01_d5_entorno .cluster rect{fill:hsl(0, 0%, 98.9215686275%);stroke:#707070;stroke-width:1px;}#dia-s01_d5_entorno .cluster text{fill:#333;}#dia-s01_d5_entorno .cluster span{color:#333;}#dia-s01_d5_entorno div.mermaidTooltip{position:absolute;text-align:center;max-width:200px;padding:2px;font-family:system-ui,-apple-system,&apos;Segoe UI&apos;,Roboto,sans-serif;font-size:12px;background:#fdf6e3;border:1px solid #707070;border-radius:2px;pointer-events:none;z-index:100;}#dia-s01_d5_entorno .flowchartTitleText{text-anchor:middle;font-size:18px;fill:#000000;}#dia-s01_d5_entorno rect.text{fill:none;stroke-width:0;}#dia-s01_d5_entorno .icon-shape,#dia-s01_d5_entorno .image-shape{background-color:white;text-align:center;}#dia-s01_d5_entorno .icon-shape p,#dia-s01_d5_entorno .image-shape p{background-color:white;padding:2px;}#dia-s01_d5_entorno .icon-shape .label rect,#dia-s01_d5_entorno .image-shape .label rect{opacity:0.5;background-color:white;fill:white;}#dia-s01_d5_entorno .label-icon{display:inline-block;height:1em;overflow:visible;vertical-align:-0.125em;}#dia-s01_d5_entorno .node .label-icon path{fill:currentColor;stroke:revert;stroke-width:revert;}#dia-s01_d5_entorno .node .neo-node{stroke:#999;}#dia-s01_d5_entorno [data-look=&quot;neo&quot;].node rect,#dia-s01_d5_entorno [data-look=&quot;neo&quot;].cluster rect,#dia-s01_d5_entorno [data-look=&quot;neo&quot;].node polygon{stroke:url(#dia-s01_d5_entorno-gradient);filter:drop-shadow( 1px 2px 2px rgba(185,185,185,1));}#dia-s01_d5_entorno [data-look=&quot;neo&quot;].swimlane.cluster rect{filter:none;}#dia-s01_d5_entorno [data-look=&quot;neo&quot;].node path{stroke:url(#dia-s01_d5_entorno-gradient);stroke-width:1px;}#dia-s01_d5_entorno [data-look=&quot;neo&quot;].node .outer-path{filter:drop-shadow( 1px 2px 2px rgba(185,185,185,1));}#dia-s01_d5_entorno [data-look=&quot;neo&quot;].node .neo-line path{stroke:#999;filter:none;}#dia-s01_d5_entorno [data-look=&quot;neo&quot;].node circle{stroke:url(#dia-s01_d5_entorno-gradient);filter:drop-shadow( 1px 2px 2px rgba(185,185,185,1));}#dia-s01_d5_entorno [data-look=&quot;neo&quot;].node circle .state-start{fill:#000000;}#dia-s01_d5_entorno [data-look=&quot;neo&quot;].icon-shape .icon{fill:url(#dia-s01_d5_entorno-gradient);filter:drop-shadow( 1px 2px 2px rgba(185,185,185,1));}#dia-s01_d5_entorno [data-look=&quot;neo&quot;].icon-shape .icon-neo path{stroke:url(#dia-s01_d5_entorno-gradient);filter:drop-shadow( 1px 2px 2px rgba(185,185,185,1));}#dia-s01_d5_entorno :root{--mermaid-font-family:&quot;trebuchet ms&quot;,verdana,arial,sans-serif;}#dia-s01_d5_entorno .pieza rect{fill:rgb(232, 240, 251)!important;stroke:rgb(42, 120, 214)!important;color:rgb(16, 41, 77)!important;}#dia-s01_d5_entorno .pieza polygon{fill:rgb(232, 240, 251)!important;stroke:rgb(42, 120, 214)!important;color:rgb(16, 41, 77)!important;}#dia-s01_d5_entorno .pieza ellipse{fill:rgb(232, 240, 251)!important;stroke:rgb(42, 120, 214)!important;color:rgb(16, 41, 77)!important;}#dia-s01_d5_entorno .pieza circle{fill:rgb(232, 240, 251)!important;stroke:rgb(42, 120, 214)!important;color:rgb(16, 41, 77)!important;}#dia-s01_d5_entorno .pieza path{fill:rgb(232, 240, 251)!important;stroke:rgb(42, 120, 214)!important;color:rgb(16, 41, 77)!important;}#dia-s01_d5_entorno .pieza tspan{fill:rgb(16, 41, 77)!important;}#dia-s01_d5_entorno .archivo rect{fill:rgb(233, 247, 238)!important;stroke:rgb(12, 163, 12)!important;color:rgb(16, 41, 77)!important;}#dia-s01_d5_entorno .archivo polygon{fill:rgb(233, 247, 238)!important;stroke:rgb(12, 163, 12)!important;color:rgb(16, 41, 77)!important;}#dia-s01_d5_entorno .archivo ellipse{fill:rgb(233, 247, 238)!important;stroke:rgb(12, 163, 12)!important;color:rgb(16, 41, 77)!important;}#dia-s01_d5_entorno .archivo circle{fill:rgb(233, 247, 238)!important;stroke:rgb(12, 163, 12)!important;color:rgb(16, 41, 77)!important;}#dia-s01_d5_entorno .archivo path{fill:rgb(233, 247, 238)!important;stroke:rgb(12, 163, 12)!important;color:rgb(16, 41, 77)!important;}#dia-s01_d5_entorno .archivo tspan{fill:rgb(16, 41, 77)!important;}</style><marker id="dia-s01_d5_entorno_flowchart-v2-pointEnd" class="marker flowchart-v2" markerHeight="8" markerUnits="userSpaceOnUse" markerWidth="8" orient="auto" refX="5" refY="5" viewBox="0 0 10 10"><path d="m0 0 10 5-10 5z" class="arrowMarkerPath" style="stroke-width:1;stroke-dasharray:1,0"/></marker><marker id="dia-s01_d5_entorno_flowchart-v2-pointStart" class="marker flowchart-v2" markerHeight="8" markerUnits="userSpaceOnUse" markerWidth="8" orient="auto" refX="4.5" refY="5" viewBox="0 0 10 10"><path d="m0 5 10 5V0z" class="arrowMarkerPath" style="stroke-width:1;stroke-dasharray:1,0"/></marker><marker id="dia-s01_d5_entorno_flowchart-v2-pointEnd-margin" class="marker flowchart-v2" markerHeight="14" markerUnits="userSpaceOnUse" markerWidth="10.5" orient="auto" refX="11.5" refY="7" viewBox="0 0 11.5 14"><path d="m0 0 11.5 7L0 14z" class="arrowMarkerPath" style="stroke-width:0;stroke-dasharray:1,0"/></marker><marker id="dia-s01_d5_entorno_flowchart-v2-pointStart-margin" class="marker flowchart-v2" markerHeight="14" markerUnits="userSpaceOnUse" markerWidth="11.5" orient="auto" refX="1" refY="7" viewBox="0 0 11.5 14"><polygon points="0,7 11.5,14 11.5,0" class="arrowMarkerPath" style="stroke-width:0;stroke-dasharray:1,0"/></marker><marker id="dia-s01_d5_entorno_flowchart-v2-circleEnd" class="marker flowchart-v2" markerHeight="11" markerUnits="userSpaceOnUse" markerWidth="11" orient="auto" refX="11" refY="5" viewBox="0 0 10 10"><circle cx="5" cy="5" r="5" class="arrowMarkerPath" style="stroke-width:1;stroke-dasharray:1,0"/></marker><marker id="dia-s01_d5_entorno_flowchart-v2-circleStart" class="marker flowchart-v2" markerHeight="11" markerUnits="userSpaceOnUse" markerWidth="11" orient="auto" refX="-1" refY="5" viewBox="0 0 10 10"><circle cx="5" cy="5" r="5" class="arrowMarkerPath" style="stroke-width:1;stroke-dasharray:1,0"/></marker><marker id="dia-s01_d5_entorno_flowchart-v2-circleEnd-margin" class="marker flowchart-v2" markerHeight="14" markerUnits="userSpaceOnUse" markerWidth="14" orient="auto" refX="12.25" refY="5" viewBox="0 0 10 10"><circle cx="5" cy="5" r="5" class="arrowMarkerPath" style="stroke-width:0;stroke-dasharray:1,0"/></marker><marker id="dia-s01_d5_entorno_flowchart-v2-circleStart-margin" class="marker flowchart-v2" markerHeight="14" markerUnits="userSpaceOnUse" markerWidth="14" orient="auto" refX="-2" refY="5" viewBox="0 0 10 10"><circle cx="5" cy="5" r="5" class="arrowMarkerPath" style="stroke-width:0;stroke-dasharray:1,0"/></marker><marker id="dia-s01_d5_entorno_flowchart-v2-crossEnd" class="marker cross flowchart-v2" markerHeight="11" markerUnits="userSpaceOnUse" markerWidth="11" orient="auto" refX="12" refY="5.2" viewBox="0 0 11 11"><path d="m1 1 9 9m0-9-9 9" class="arrowMarkerPath" style="stroke-width:2;stroke-dasharray:1,0"/></marker><marker id="dia-s01_d5_entorno_flowchart-v2-crossStart" class="marker cross flowchart-v2" markerHeight="11" markerUnits="userSpaceOnUse" markerWidth="11" orient="auto" refX="-1" refY="5.2" viewBox="0 0 11 11"><path d="m1 1 9 9m0-9-9 9" class="arrowMarkerPath" style="stroke-width:2;stroke-dasharray:1,0"/></marker><marker id="dia-s01_d5_entorno_flowchart-v2-crossEnd-margin" class="marker cross flowchart-v2" markerHeight="12" markerUnits="userSpaceOnUse" markerWidth="12" orient="auto" refX="17.7" refY="7.5" viewBox="0 0 15 15"><path d="m1 1 13 13M1 14 14 1" class="arrowMarkerPath" style="stroke-width:2.5"/></marker><marker id="dia-s01_d5_entorno_flowchart-v2-crossStart-margin" class="marker cross flowchart-v2" markerHeight="12" markerUnits="userSpaceOnUse" markerWidth="12" orient="auto" refX="-3.5" refY="7.5" viewBox="0 0 15 15"><path d="m1 1 13 13M1 14 14 1" class="arrowMarkerPath" style="stroke-width:2.5;stroke-dasharray:1,0"/></marker><g class="root"><g class="edgePaths"><path id="dia-s01_d5_entorno-L_TU_E_0" marker-end="url(#dia-s01_d5_entorno_flowchart-v2-pointEnd)" d="M47.936 166.75h46" class="edge-thickness-normal edge-pattern-solid edge-thickness-normal edge-pattern-solid flowchart-link" data-edge="true" data-et="edge" data-id="L_TU_E_0" data-look="classic" data-points="W3sieCI6NDcuOTM2MTY4NjcwNjU0MywieSI6MTY2Ljc1fSx7IngiOjcyLjkzNjE2ODY3MDY1NDMsInkiOjE2Ni43NX0seyJ4Ijo5Ny45MzYxNjg2NzA2NTQzLCJ5IjoxNjYuNzV9XQ=="/><path id="dia-s01_d5_entorno-L_E_A_0" marker-end="url(#dia-s01_d5_entorno_flowchart-v2-pointEnd)" d="m965.249 123.826 10.862-1.075c10.862-1.075 32.586-3.226 53.647-3.168s41.46 2.323 51.659 3.456l10.2 1.133" class="edge-thickness-normal edge-pattern-solid edge-thickness-normal edge-pattern-solid flowchart-link" data-edge="true" data-et="edge" data-id="L
1.039m0 0-.135-1.049m.135 1.05-.135-1.05m0 0-.068-1.055m.068 1.055-.068-1.055m0 0v-1.058m0 1.058v-1.058m0 0 .068-1.055m-.068 1.055.068-1.055m0 0 .135-1.05m-.135 1.05.135-1.05m0 0 .202-1.038m-.202 1.039.202-1.039m0 0 .268-1.023m-.268 1.023.268-1.023m0 0 .334-1.004m-.334 1.004.334-1.004m0 0 .397-.98m-.397.98.397-.98m0 0 .458-.953m-.458.953.458-.953m0 0 .52-.921m-.52.921.52-.921m0 0 .577-.887m-.577.887.577-.887m0 0 .632-.848m-.632.848.632-.848m0 0 .686-.805m-.686.805.686-.805m0 0 .736-.76m-.736.76.736-.76m0 0 .783-.71m-.783.71.783-.71m0 0c.23-.185.46-.369.827-.66m-.827.66.827-.66m0 0 .867-.605m-.867.605.867-.605m0 0 .905-.549m-.905.549.905-.549m0 0 .937-.489m-.937.49.937-.49m0 0 .967-.428m-.967.428.967-.428m0 0 .993-.365m-.993.365.993-.365m0 0 1.014-.301m-1.014.3 1.014-.3m0 0 1.031-.236m-1.03.236 1.03-.236m0 0 1.044-.169m-1.044.17 1.044-.17m0 0 1.053-.101m-1.053.101 1.053-.101m0 0 1.057-.034m-1.057.034 1.057-.034m0 0"/></g><g class="label" transform="translate(1219.506 228.125)"><rect/><rect class="background" style="stroke:none"/><text y="-10.1"><tspan x="0" y="-.1em" class="text-outer-tspan row" dy="1.1em"><tspan class="text-inner-tspan" font-style="normal" font-weight="normal">El</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> resultado</tspan></tspan></text></g></g></g></g><defs><filter id="dia-s01_d5_entorno-drop-shadow" width="130%" height="130%"><feDropShadow dx="4" dy="4" flood-color="#000" flood-opacity=".06" stdDeviation="0"/></filter></defs><defs><filter id="dia-s01_d5_entorno-drop-shadow-small" width="150%" height="150%"><feDropShadow dx="2" dy="2" flood-color="#000" flood-opacity=".06" stdDeviation="0"/></filter></defs><linearGradient id="dia-s01_d5_entorno-gradient" x1="0%" x2="100%" y1="0%" y2="0%" gradientUnits="objectBoundingBox"><stop offset="0%" stop-color="hsl(0, 0%, 83.3333333333%)" stop-opacity="1"/><stop offset="100%" stop-color="hsl(0, 0%, 88.9215686275%)" stop-opacity="1"/></linearGradient></svg>', 'El IDE no es una herramienta más: es la caja que contiene a las otras.')

# %% [markdown]
# ### Los tres nombres que vas a oír todo el semestre
#
# | | Qué es exactamente | Para qué sirve | ¿Lo estás usando ahora? |
# |---|---|---|---|
# | **Python** | Un **lenguaje** y su **intérprete** (el programa `python`) | Entender y ejecutar tu código | Sí: es el motor debajo de este cuadernillo |
# | **VS Code** | Un **editor** que con extensiones se comporta como IDE | Escribir proyectos de varios archivos, en tu propio computador | No: eso lo instalas en la sección 8 |
# | **Jupyter** | Un **entorno de cuadernos**: texto + código + resultados en un solo documento | Aprender, explorar datos, mostrar resultados | Sí: esto **es** Jupyter |
#
# Cuidado con una confusión muy común: **Python no es VS Code.** Puedes usar
# Python sin VS Code (lo estás haciendo) y puedes tener VS Code sin Python (te
# serviría para escribir, no para ejecutar).

# %% [markdown]
# ### La terminal, sin salir del cuadernillo
#
# En Jupyter, una línea que empieza con `!` no va al intérprete de Python: va
# **directo a la terminal del sistema**. Es la forma más segura de conocerla.
# Ejecuta la celda y lee cada respuesta.

# %%
# !pwd                 # "print working directory": ¿en qué carpeta estoy parado?
# !ls -l               # lista lo que hay en esta carpeta, con detalles
# !python --version    # ¿qué intérprete de Python tengo instalado?
# !which python        # ¿y dónde está ese programa exactamente?

# %% [markdown]
# Léelo con calma, porque acabas de ver **tres cosas del temario oficial de la
# semana** en cuatro líneas:
#
# - `pwd` te contestó algo como `/home/jovyan/work`. Esa es tu **carpeta de
#   trabajo**: cuando un programa dice `abrir("notas.txt")` sin más señas, lo
#   busca ahí. A eso se le llama *ruta relativa*.
# - `ls` te mostró tus archivos. Ahí está `cuadernillo.ipynb`: **este documento es
#   un archivo**, igual que cualquier otro.
# - `python --version` te contestó `Python 3.11.x`: ese es el **intérprete** del
#   que hablábamos, y `which` te dijo en qué carpeta vive el programa.
#
# Un archivo tiene **nombre**, **extensión** (`.txt`, `.py`, `.ipynb`), **ruta** y
# **contenido**. La extensión no cambia lo que el archivo *es*: es una promesa
# sobre lo que hay adentro.

# %%
# Diagrama: s01_d6_archivos
ava.figura('<svg xmlns="http://www.w3.org/2000/svg" id="dia-s01_d6_archivos" width="100%" aria-roledescription="flowchart-v2" class="flowchart" role="graphics-document document" style="max-width:1955.93px;background-color:transparent" viewBox="0 0 1955.926 134.75"><style>#dia-s01_d6_archivos{font-family:system-ui,-apple-system,&apos;Segoe UI&apos;,Roboto,sans-serif;font-size:15px;fill:#000000;}@keyframes edge-animation-frame{from{stroke-dashoffset:0;}}@keyframes dash{to{stroke-dashoffset:0;}}#dia-s01_d6_archivos .edge-animation-slow{stroke-dasharray:9,5!important;stroke-dashoffset:900;animation:dash 50s linear infinite;stroke-linecap:round;}#dia-s01_d6_archivos .edge-animation-fast{stroke-dasharray:9,5!important;stroke-dashoffset:900;animation:dash 20s linear infinite;stroke-linecap:round;}#dia-s01_d6_archivos .error-icon{fill:#552222;}#dia-s01_d6_archivos .error-text{fill:#552222;stroke:#552222;}#dia-s01_d6_archivos .edge-thickness-normal{stroke-width:1px;}#dia-s01_d6_archivos .edge-thickness-thick{stroke-width:3.5px;}#dia-s01_d6_archivos .edge-pattern-solid{stroke-dasharray:0;}#dia-s01_d6_archivos .edge-thickness-invisible{stroke-width:0;fill:none;}#dia-s01_d6_archivos .edge-pattern-dashed{stroke-dasharray:3;}#dia-s01_d6_archivos .edge-pattern-dotted{stroke-dasharray:2;}#dia-s01_d6_archivos .marker{fill:#52514e;stroke:#52514e;}#dia-s01_d6_archivos .marker.cross{stroke:#52514e;}#dia-s01_d6_archivos svg{font-family:system-ui,-apple-system,&apos;Segoe UI&apos;,Roboto,sans-serif;font-size:15px;}#dia-s01_d6_archivos p{margin:0;}#dia-s01_d6_archivos .label{font-family:system-ui,-apple-system,&apos;Segoe UI&apos;,Roboto,sans-serif;color:#000000;}#dia-s01_d6_archivos .cluster-label text{fill:#333;}#dia-s01_d6_archivos .cluster-label span{color:#333;}#dia-s01_d6_archivos .cluster-label span p{background-color:transparent;}#dia-s01_d6_archivos .label text,#dia-s01_d6_archivos span{fill:#000000;color:#000000;}#dia-s01_d6_archivos .node rect,#dia-s01_d6_archivos .node circle,#dia-s01_d6_archivos .node ellipse,#dia-s01_d6_archivos .node polygon,#dia-s01_d6_archivos .node path{fill:#eee;stroke:#999;stroke-width:1px;}#dia-s01_d6_archivos .rough-node .label text,#dia-s01_d6_archivos .node .label text,#dia-s01_d6_archivos .image-shape .label,#dia-s01_d6_archivos .icon-shape .label{text-anchor:middle;}#dia-s01_d6_archivos .node .katex path{fill:#000;stroke:#000;stroke-width:1px;}#dia-s01_d6_archivos .rough-node .label,#dia-s01_d6_archivos .node .label,#dia-s01_d6_archivos .image-shape .label,#dia-s01_d6_archivos .icon-shape .label{text-align:center;}#dia-s01_d6_archivos .node.clickable{cursor:pointer;}#dia-s01_d6_archivos .root .anchor path{fill:#52514e!important;stroke-width:0;stroke:#52514e;}#dia-s01_d6_archivos .arrowheadPath{fill:#333333;}#dia-s01_d6_archivos .edgePath .path{stroke:#52514e;stroke-width:1px;}#dia-s01_d6_archivos .flowchart-link{stroke:#52514e;fill:none;}#dia-s01_d6_archivos .edgeLabel{background-color:white;text-align:center;}#dia-s01_d6_archivos .edgeLabel p{background-color:white;}#dia-s01_d6_archivos .edgeLabel rect{opacity:0.5;background-color:white;fill:white;}#dia-s01_d6_archivos .labelBkg{background-color:rgba(255, 255, 255, 0.5);}#dia-s01_d6_archivos .cluster rect{fill:hsl(0, 0%, 98.9215686275%);stroke:#707070;stroke-width:1px;}#dia-s01_d6_archivos .cluster text{fill:#333;}#dia-s01_d6_archivos .cluster span{color:#333;}#dia-s01_d6_archivos div.mermaidTooltip{position:absolute;text-align:center;max-width:200px;padding:2px;font-family:system-ui,-apple-system,&apos;Segoe UI&apos;,Roboto,sans-serif;font-size:12px;background:#fdf6e3;border:1px solid #707070;border-radius:2px;pointer-events:none;z-index:100;}#dia-s01_d6_archivos .flowchartTitleText{text-anchor:middle;font-size:18px;fill:#000000;}#dia-s01_d6_archivos rect.text{fill:none;stroke-width:0;}#dia-s01_d6_archivos .icon-shape,#dia-s01_d6_archivos .image-shape{background-color:white;text-align:center;}#dia-s01_d6_archivos .icon-shape p,#dia-s01_d6_archivos .image-shape p{background-color:white;padding:2px;}#dia-s01_d6_archivos .icon-shape .label rect,#dia-s01_d6_archivos .image-shape .label rect{opacity:0.5;background-color:white;fill:white;}#dia-s01_d6_archivos .label-icon{display:inline-block;height:1em;overflow:visible;vertical-align:-0.125em;}#dia-s01_d6_archivos .node .label-icon path{fill:currentColor;stroke:revert;stroke-width:revert;}#dia-s01_d6_archivos .node .neo-node{stroke:#999;}#dia-s01_d6_archivos [data-look=&quot;neo&quot;].node rect,#dia-s01_d6_archivos [data-look=&quot;neo&quot;].cluster rect,#dia-s01_d6_archivos [data-look=&quot;neo&quot;].node polygon{stroke:url(#dia-s01_d6_archivos-gradient);filter:drop-shadow( 1px 2px 2px rgba(185,185,185,1));}#dia-s01_d6_archivos [data-look=&quot;neo&quot;].swimlane.cluster rect{filter:none;}#dia-s01_d6_archivos [data-look=&quot;neo&quot;].node path{stroke:url(#dia-s01_d6_archivos-gradient);stroke-width:1px;}#dia-s01_d6_archivos [data-look=&quot;neo&quot;].node .outer-path{filter:drop-shadow( 1px 2px 2px rgba(185,185,185,1));}#dia-s01_d6_archivos [data-look=&quot;neo&quot;].node .neo-line path{stroke:#999;filter:none;}#dia-s01_d6_archivos [data-look=&quot;neo&quot;].node circle{stroke:url(#dia-s01_d6_archivos-gradient);filter:drop-shadow( 1px 2px 2px rgba(185,185,185,1));}#dia-s01_d6_archivos [data-look=&quot;neo&quot;].node circle .state-start{fill:#000000;}#dia-s01_d6_archivos [data-look=&quot;neo&quot;].icon-shape .icon{fill:url(#dia-s01_d6_archivos-gradient);filter:drop-shadow( 1px 2px 2px rgba(185,185,185,1));}#dia-s01_d6_archivos [data-look=&quot;neo&quot;].icon-shape .icon-neo path{stroke:url(#dia-s01_d6_archivos-gradient);filter:drop-shadow( 1px 2px 2px rgba(185,185,185,1));}#dia-s01_d6_archivos :root{--mermaid-font-family:&quot;trebuchet ms&quot;,verdana,arial,sans-serif;
.004m-.333 1.004.333-1.004m0 0 .397-.98m-.397.98.397-.98m0 0 .459-.953m-.46.953.46-.953m0 0 .519-.921m-.52.921.52-.921m0 0 .577-.887m-.577.887.577-.887m0 0 .632-.848m-.632.848.632-.848m0 0 .686-.805m-.686.805.686-.805m0 0 .736-.76m-.736.76.736-.76m0 0 .783-.71m-.783.71.783-.71m0 0 .827-.66m-.827.66.827-.66m0 0 .867-.605m-.867.605.867-.605m0 0 .905-.549m-.905.549.905-.549m0 0 .937-.489m-.937.49.937-.49m0 0 .968-.428m-.968.428.968-.428m0 0 .992-.365m-.992.365.992-.365m0 0 1.014-.301m-1.014.3 1.014-.3m0 0 1.031-.236m-1.03.236 1.03-.236m0 0 1.045-.169m-1.045.17 1.045-.17m0 0 1.052-.101m-1.052.101 1.052-.101m0 0 1.058-.034m-1.058.034 1.058-.034m0 0"/></g><g class="label" transform="translate(51.445 64.875)"><rect/><rect class="background" style="stroke:none"/><text y="-10.1"><tspan x="0" y="-.1em" class="text-outer-tspan row" dy="1.1em"><tspan class="text-inner-tspan" font-style="normal" font-weight="normal">No</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> existe</tspan></tspan></text></g></g><g id="dia-s01_d6_archivos-flowchart-A-1" class="node default escribir" data-look="classic" transform="translate(259.327 73.875)"><rect width="228.875" height="64.5" x="-114.438" y="-32.25" class="basic label-container" style="fill:#e8f0fb!important;stroke:#2a78d6!important"/><g class="label" style="color:#10294d!important" transform="translate(0 -17.25)"><rect/><rect class="background" style="stroke:none"/><text y="-10.1" style="fill:#10294d!important"><tspan x="0" y="-.1em" class="text-outer-tspan row" dy="1.1em"><tspan class="text-inner-tspan" font-style="normal" font-weight="normal">abrir</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> en</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> modo</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> w</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> ·</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> lo</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> crea</tspan></tspan><tspan x="0" y="1em" class="text-outer-tspan row" dy="1.1em"><tspan class="text-inner-tspan" font-style="normal" font-weight="normal">vacío</tspan></tspan></text></g></g><g id="dia-s01_d6_archivos-flowchart-B-2" class="node default escribir" data-look="classic" transform="translate(530.35 73.875)"><rect width="213.172" height="48" x="-106.586" y="-24" class="basic label-container" style="fill:#e8f0fb!important;stroke:#2a78d6!important"/><g class="label" style="color:#10294d!important" transform="translate(0 -9)"><rect/><rect class="background" style="stroke:none"/><text y="-10.1" style="fill:#10294d!important"><tspan x="0" y="-.1em" class="text-outer-tspan row" dy="1.1em"><tspan class="text-inner-tspan" font-style="normal" font-weight="normal">escribir</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> ·</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> el</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> texto</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> entra</tspan></tspan></text></g></g><g id="dia-s01_d6_archivos-flowchart-C-3" class="node default escribir" data-look="classic" transform="translate(810.077 73.875)"><rect width="246.281" height="64.5" x="-123.141" y="-32.25" class="basic label-container" style="fill:#e8f0fb!important;stroke:#2a78d6!important"/><g class="label" style="color:#10294d!important" transform="translate(0 -17.25)"><rect/><rect class="background" style="stroke:none"/><text y="-10.1" style="fill:#10294d!important"><tspan x="0" y="-.1em" class="text-outer-tspan row" dy="1.1em"><tspan class="text-inner-tspan" font-style="normal" font-weight="normal">cerrar</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> ·</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> queda</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> guardado</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> en</tspan></tspan><tspan x="0" y="1em" class="text-outer-tspan row" dy="1.1em"><tspan class="text-inner-tspan" font-style="normal" font-weight="normal">el</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> disco</tspan></tspan></text></g></g><g id="dia-s01_d6_archivos-flowchart-D-4" class="node default leer" data-look="classic" transform="translate(1100.467 40.25)"><rect width="234.5" height="64.5" x="-117.25" y="-32.25" class="basic label-container" style="fill:#e9f7ee!important;stroke:#0ca30c!important"/><g class="label" style="color:#10294d!important" transform="translate(0 -17.25)"><rect/><rect class="background" style="stroke:none"/><text y="-10.1" style="fill:#10294d!important"><tspan x="0" y="-.1em" class="text-outer-tspan row" dy="1.1em"><tspan class="text-inner-tspan" font-style="normal" font-weight="normal">abrir</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> en</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> modo</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> r</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> ·</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> lo</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> busca</tspan></tspan><tspan x="0" y="1em" class="text-outer-tspan row" dy="1.1em"><tspan class="text-inner-tspan" font-style="normal" font-weight="normal">por</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> su</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> ruta</tspan></tspan></text></g></g><g id="dia-s01_d6_archivos-flowchart-E-5" class="node default leer" data-look="classic" transform="translate(1577.85 40.25)"><rect width="224.172" height="64.5" x="-112.086" y="-32.25" class="basic label-container" style="fill:#e9f7ee!important;stroke:#0ca30c!important"/><g class="label" style="color:#10294d!important" transform="translate(0 -17.25)"><rect/><rect class="background" style="stroke:none"/><text y="-10.1" style="fill:#10294d!important"><tspan x="0" y="-.1em" class="text-outer-tspan row" dy="1.1em"><tspan class="text-inner-tspan" font-style="normal" font-weight="normal">leer</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> ·</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> el</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> texto</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> vuelve</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> a</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> la</tspan></tspan><tspan x="0" y="1em" class="text-outer-tspan row" dy="1.1em"><tspan class="text-inner-tspan" font-style="normal" font-weight="normal">memoria</tspan></tspan></text></g></g><g id="dia-s01_d6_archivos-flowchart-F-6" class="node default" data-look="classic"><g class="basic label-container outer-path"><path fill="#eee" stroke="none" stroke-width="0" d="M1764.673 49.125h158.516l1.586.05 1.579.153 1.566.253 1.547.353 1.521.452 1.489.548 1.45.642 1.407.734 1.357.822 1.301.908 1.24.99c.346.312.69.626 1.175 1.066l1.104 1.14 1.028 1.208c.26.346.518.693.95 1.271l.865 1.33c.24.425.48.85.778 1.382l.689 1.43.595 1.47.5 1.506.403 1.535.303 1.557.203 1.573.101 1.584v1.586l-.101 1.584-.203 1.573-.303 1.557-.403 1.535-.5 1.506-.595 1.47-.689 1.43-.778 1.382-.866 1.33-.949 1.271-1.028 1.208-
"><rect/><rect class="background" style="stroke:none"/><text y="-10.1"><tspan x="0" y="-.1em" class="text-outer-tspan row" dy="1.1em"><tspan class="text-inner-tspan" font-style="normal" font-weight="normal">Nombre</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> ·</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> extensión</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> ·</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> ruta</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> ·</tspan></tspan><tspan x="0" y="1em" class="text-outer-tspan row" dy="1.1em"><tspan class="text-inner-tspan" font-style="normal" font-weight="normal">contenido</tspan></tspan></text></g></g></g></g><defs><filter id="dia-s01_d6_archivos-drop-shadow" width="130%" height="130%"><feDropShadow dx="4" dy="4" flood-color="#000" flood-opacity=".06" stdDeviation="0"/></filter></defs><defs><filter id="dia-s01_d6_archivos-drop-shadow-small" width="150%" height="150%"><feDropShadow dx="2" dy="2" flood-color="#000" flood-opacity=".06" stdDeviation="0"/></filter></defs><linearGradient id="dia-s01_d6_archivos-gradient" x1="0%" x2="100%" y1="0%" y2="0%" gradientUnits="objectBoundingBox"><stop offset="0%" stop-color="hsl(0, 0%, 83.3333333333%)" stop-opacity="1"/><stop offset="100%" stop-color="hsl(0, 0%, 88.9215686275%)" stop-opacity="1"/></linearGradient></svg>', 'Abrir, hacer algo, cerrar. Dos veces: una para escribir y otra para leer.')

# %%
# Crea un archivo, escribe en él y vuelve a leerlo. Tres verbos: abrir, escribir, cerrar.
with open("prueba.txt", "w", encoding="utf-8") as f:
    f.write("Mi primer archivo creado con código.\n")

print(open("prueba.txt", encoding="utf-8").read())
# !ls -l prueba.txt

# %%
quiz(
    "Q4", 6,
    "Estás en la sala de cómputo y quieres ejecutar un archivo <code>tarea.py</code> "
    "que ya escribiste. ¿Qué necesitas SÍ o SÍ?",
    ["Un editor", "El intérprete de Python", "Un IDE", "Una terminal"],
    "El intérprete de Python",
    "Escribir el archivo ya lo hiciste. Para <b>ejecutarlo</b> solo hay un "
    "candidato: el intérprete. El editor, el IDE y la terminal son comodidades.",
    pistas=["Fíjate en el verbo: no quieres *escribirlo* otra vez, quieres "
            "*ejecutarlo*. ¿Cuál de los cuatro es el único que ejecuta?"],
)

# %% [markdown]
# ---
#
# ## 4. Los tres errores · 20 min
#
# Vas a equivocarte muchísimo este semestre. No es una amenaza, es aritmética:
# equivocarse es el 80 % de programar, también para quien lleva veinte años.
#
# Lo que separa a quien avanza de quien se bloquea no es equivocarse menos: es
# **saber qué clase de error tiene enfrente**. Hay exactamente tres, y se
# comportan de forma muy distinta.
#
# Las tres celdas que siguen están rotas **a propósito**. Ejecútalas tal cual. No
# puedes dañar nada: si algo se enreda, `Kernel → Restart` y el cuadernillo queda
# como nuevo.

# %% [markdown]
# ### Error 1 de 3 — de sintaxis
#
# **Predice antes de ejecutar:** en la celda de abajo hay dos líneas. La segunda
# está mal escrita. ¿Crees que la primera alcanzará a imprimirse?
#
# Ejecuta y compruébalo.

# %%
print("Esta línea está perfecta. ¿Se imprimirá?")

nota = 4.2
if nota >= 3.0
    print("Aprobado")

# %% [markdown]
# **No se imprimió nada.** Ni siquiera la primera línea, que estaba perfecta.
#
# Esa es la firma del **error de sintaxis**: Python revisa **todo** el texto antes
# de ejecutar **una sola línea**, como quien lee un párrafo completo antes de
# empezar a leerlo en voz alta. Si encuentra algo que no es español —perdón, que
# no es Python— se planta y no arranca.
#
# Cómo se lee el mensaje, de arriba abajo:
#
# | Parte | Qué te está diciendo |
# |---|---|
# | `Cell In[12], line 4` | **dónde**: celda 12, línea 4 |
# | `if nota >= 3.0` | la línea culpable, copiada |
# | `^` | el dedo señalando el punto exacto |
# | `SyntaxError: expected ':'` | **qué**: esperaba dos puntos |
#
# Python te dijo qué le falta, en qué línea y en qué carácter. Es lo más parecido
# a un profesor particular que vas a encontrar gratis.
#
# **Los cuatro sospechosos de siempre:** falta `:` al final de un `if`/`for`/`def`;
# falta una comilla; falta un paréntesis de cierre; falta o sobra una sangría.
#
# Arregla la celda de arriba (ponle los dos puntos), ejecútala de nuevo y mira
# cómo ahora **sí** se imprime la primera línea. Después ejecuta la celda de abajo
# para cobrar tus XP.

# %%
registrar("errores_sintaxis")   # +8 XP cuando la celda de arriba compile

# %% [markdown]
# ### Error 2 de 3 — de ejecución
#
# **Predice:** la celda de abajo tiene cuatro `print` numerados. ¿Cuántos alcanzan
# a salir?

# %%
print("Paso 1: recibo la nota del parcial")
nota_texto = "4.2"

print("Paso 2: la muestro tal cual ->", nota_texto)
print("Paso 3: le sumo un punto  ->", nota_texto + 1)
print("Paso 4: aquí nunca llego")

# %% [markdown]
# **Salieron dos de cuatro.** Ahí está toda la diferencia con el error anterior:
# aquí el programa **sí arrancó**, corrió un rato y se estrelló en la línea 5.
# Nunca llegó al paso 4.
#
# A esto se le llama **error de ejecución** (o *de tiempo de ejecución*, o
# *excepción*). La sintaxis estaba impecable: el problema apareció cuando los
# **datos reales** llegaron a la instrucción.
#
# Cómo se lee un traceback: **de abajo hacia arriba**.
#
# 1. **La última línea es la respuesta.** `TypeError: can only concatenate str
#    (not "int") to str`. Traducido: «me pediste pegar un texto con un número, y
#    eso no lo sé hacer».
# 2. **La flecha `---->` es el lugar.** Señala la línea exacta.
# 3. Lo de arriba es el camino que trajo el programa hasta ahí. Hoy no lo
#    necesitas; en la semana 9 sí.
#
# ¿Por qué falló? `nota_texto` es `"4.2"` **con comillas**: para Python es un
# texto, no un número. Un texto y un número no se suman, igual que no se suman
# tres manzanas y la palabra «manzana».
#
# **Los cuatro sospechosos de siempre:**
#
# | Mensaje | Qué pasó |
# |---|---|
# | `NameError` | usaste un nombre que no existe (¿lo escribiste mal? ¿olvidaste comillas?) |
# | `TypeError` | mezclaste tipos que no se mezclan |
# | `ZeroDivisionError` | dividiste por cero |
# | `IndexError` | pediste el elemento 4 de una lista de 3 |
#
# **Arréglalo:** quítale las comillas a `"4.2"` para que sea un número de verdad,
# y ejecuta otra vez. Deben salir los cuatro pasos.

# %%
registrar("errores_ejecucion")   # +8 XP cuando la celda de arriba corra entera

# %% [markdown]
# ### Error 3 de 3 — de lógica *(el peligroso)*
#
# **Predice, y esta vez apúntalo mentalmente:** si sacaste 4.0, 4.0 y 4.0 en tus
# tres parciales, ¿cuál es tu promedio?
#
# Ya lo sabes: 4.0. No hace falta calculadora. Ahora ejecuta la celda.

# %%
n1, n2, n3 = 4.0, 4.0, 4.0

promedio = n1 + n2 + n3 / 3

print("Tu promedio del semestre es:", promedio)

# %% [markdown]
# Léelo otra vez: **9.33 de promedio, con tres notas de 4.0.**
#
# Y ahora lo verdaderamente inquietante: **¿dónde está el mensaje rojo?**
#
# No hay. No hay error de sintaxis (la línea está perfectamente escrita) ni error
# de ejecución (sumar y dividir números es legal). Python hizo **exactamente** lo
# que le pediste: por la regla de precedencia, primero dividió `n3 / 3` y después
# sumó. `4.0 + 4.0 + 1.333…`
#
# Tú querías `(n1 + n2 + n3) / 3`. Escribiste otra cosa. Y la máquina, que no
# tiene opinión sobre tus promedios, obedeció sin chistar.
#
# Eso es un **error de lógica**: el programa corre, entrega un resultado, y el
# resultado está mal. **Nadie te avisa. Nunca.**
#
# #### ¿Y entonces cómo se cazan?
#
# Instalando tu propia alarma. Un **caso de prueba** es una situación cuyo
# resultado correcto conoces de antemano, como los tres cuatros. Ejecuta:

# %%
assert promedio == 4.0, "Con tres notas de 4.0 el promedio TIENE que dar 4.0"

# %% [markdown]
# **Acabas de fabricar el mensaje rojo que Python no te iba a dar.** Eso es
# `assert`: una frase que dice «esto tiene que ser cierto; si no lo es, grita».
#
# Y aquí está el secreto del cuadernillo: **las celdas de prueba de los ejercicios
# que vienen son exactamente esto.** Cuando ejecutes `test_ejercicio_1` y te
# salga verde, es que un montón de `assert` que escribimos nosotros se
# cumplieron. Cuando salga rojo, uno falló y te dirá cuál.
#
# Ahora **arregla** la celda del promedio (paréntesis) y vuelve a ejecutar las dos
# celdas: la del promedio y la del `assert`. Cuando el `assert` no diga nada,
# ganaste: en programación, **el silencio es la buena noticia**.

# %%
registrar("errores_logica")   # +8 XP cuando el assert pase

# %% [markdown]
# ### Los tres, uno al lado del otro
#
# | | **Sintaxis** | **Ejecución** | **Lógica** |
# |---|---|---|---|
# | ¿Cuándo aparece? | Antes de ejecutar nada | A mitad del programa | Nunca «aparece» |
# | ¿Alcanzó a correr algo? | No, ni una línea | Sí, hasta el punto del choque | Sí, **todo** |
# | ¿Quién te avisa? | Python, con `SyntaxError` | Python, con un traceback | **Nadie. Solo tú.** |
# | ¿Dónde miras? | La línea y el `^` | La última línea del traceback | Tus casos de prueba |
# | Analogía | Una frase sin verbo: no se entiende | Una receta que pide un huevo y no hay huevos | Una receta que sale perfecta… de otro plato |
# | Se caza con | Leer el mensaje | Leer el mensaje | `assert` y casos conocidos |
#
# Ejecuta el árbol de decisión y guárdalo: te va a servir todo el semestre.

# %%
# Diagrama: s01_d8_arbol_errores
ava.figura('<svg xmlns="http://www.w3.org/2000/svg" id="dia-s01_d8_arbol_errores" width="100%" aria-roledescription="flowchart-v2" class="flowchart" role="graphics-document document" style="max-width:851.091px;background-color:transparent" viewBox="0 0 851.091 1018.891"><style>#dia-s01_d8_arbol_errores{font-family:system-ui,-apple-system,&apos;Segoe UI&apos;,Roboto,sans-serif;font-size:15px;fill:#000000;}@keyframes edge-animation-frame{from{stroke-dashoffset:0;}}@keyframes dash{to{stroke-dashoffset:0;}}#dia-s01_d8_arbol_errores .edge-animation-slow{stroke-dasharray:9,5!important;stroke-dashoffset:900;animation:dash 50s linear infinite;stroke-linecap:round;}#dia-s01_d8_arbol_errores .edge-animation-fast{stroke-dasharray:9,5!important;stroke-dashoffset:900;animation:dash 20s linear infinite;stroke-linecap:round;}#dia-s01_d8_arbol_errores .error-icon{fill:#552222;}#dia-s01_d8_arbol_errores .error-text{fill:#552222;stroke:#552222;}#dia-s01_d8_arbol_errores .edge-thickness-normal{stroke-width:1px;}#dia-s01_d8_arbol_errores .edge-thickness-thick{stroke-width:3.5px;}#dia-s01_d8_arbol_errores .edge-pattern-solid{stroke-dasharray:0;}#dia-s01_d8_arbol_errores .edge-thickness-invisible{stroke-width:0;fill:none;}#dia-s01_d8_arbol_errores .edge-pattern-dashed{stroke-dasharray:3;}#dia-s01_d8_arbol_errores .edge-pattern-dotted{stroke-dasharray:2;}#dia-s01_d8_arbol_errores .marker{fill:#52514e;stroke:#52514e;}#dia-s01_d8_arbol_errores .marker.cross{stroke:#52514e;}#dia-s01_d8_arbol_errores svg{font-family:system-ui,-apple-system,&apos;Segoe UI&apos;,Roboto,sans-serif;font-size:15px;}#dia-s01_d8_arbol_errores p{margin:0;}#dia-s01_d8_arbol_errores .label{font-family:system-ui,-apple-system,&apos;Segoe UI&apos;,Roboto,sans-serif;color:#000000;}#dia-s01_d8_arbol_errores .cluster-label text{fill:#333;}#dia-s01_d8_arbol_errores .cluster-label span{color:#333;}#dia-s01_d8_arbol_errores .cluster-label span p{background-color:transparent;}#dia-s01_d8_arbol_errores .label text,#dia-s01_d8_arbol_errores span{fill:#000000;color:#000000;}#dia-s01_d8_arbol_errores .node rect,#dia-s01_d8_arbol_errores .node circle,#dia-s01_d8_arbol_errores .node ellipse,#dia-s01_d8_arbol_errores .node polygon,#dia-s01_d8_arbol_errores .node path{fill:#eee;stroke:#999;stroke-width:1px;}#dia-s01_d8_arbol_errores .rough-node .label text,#dia-s01_d8_arbol_errores .node .label text,#dia-s01_d8_arbol_errores .image-shape .label,#dia-s01_d8_arbol_errores .icon-shape .label{text-anchor:middle;}#dia-s01_d8_arbol_errores .node .katex path{fill:#000;stroke:#000;stroke-width:1px;}#dia-s01_d8_arbol_errores .rough-node .label,#dia-s01_d8_arbol_errores .node .label,#dia-s01_d8_arbol_errores .image-shape .label,#dia-s01_d8_arbol_errores .icon-shape .label{text-align:center;}#dia-s01_d8_arbol_errores .node.clickable{cursor:pointer;}#dia-s01_d8_arbol_errores .root .anchor path{fill:#52514e!important;stroke-width:0;stroke:#52514e;}#dia-s01_d8_arbol_errores .arrowheadPath{fill:#333333;}#dia-s01_d8_arbol_errores .edgePath .path{stroke:#52514e;stroke-width:1px;}#dia-s01_d8_arbol_errores .flowchart-link{stroke:#52514e;fill:none;}#dia-s01_d8_arbol_errores .edgeLabel{background-color:white;text-align:center;}#dia-s01_d8_arbol_errores .edgeLabel p{background-color:white;}#dia-s01_d8_arbol_errores .edgeLabel rect{opacity:0.5;background-color:white;fill:white;}#dia-s01_d8_arbol_errores .labelBkg{background-color:rgba(255, 255, 255, 0.5);}#dia-s01_d8_arbol_errores .cluster rect{fill:hsl(0, 0%, 98.9215686275%);stroke:#707070;stroke-width:1px;}#dia-s01_d8_arbol_errores .cluster text{fill:#333;}#dia-s01_d8_arbol_errores .cluster span{color:#333;}#dia-s01_d8_arbol_errores div.mermaidTooltip{position:absolute;text-align:center;max-width:200px;padding:2px;font-family:system-ui,-apple-system,&apos;Segoe UI&apos;,Roboto,sans-serif;font-size:12px;background:#fdf6e3;border:1px solid #707070;border-radius:2px;pointer-events:none;z-index:100;}#dia-s01_d8_arbol_errores .flowchartTitleText{text-anchor:middle;font-size:18px;fill:#000000;}#dia-s01_d8_arbol_errores rect.text{fill:none;stroke-width:0;}#dia-s01_d8_arbol_errores .icon-shape,#dia-s01_d8_arbol_errores .image-shape{background-color:white;text-align:center;}#dia-s01_d8_arbol_errores .icon-shape p,#dia-s01_d8_arbol_errores .image-shape p{background-color:white;padding:2px;}#dia-s01_d8_arbol_errores .icon-shape .label rect,#dia-s01_d8_arbol_errores .image-shape .label rect{opacity:0.5;background-color:white;fill:white;}#dia-s01_d8_arbol_errores .label-icon{display:inline-block;height:1em;overflow:visible;vertical-align:-0.125em;}#dia-s01_d8_arbol_errores .node .label-icon path{fill:currentColor;stroke:revert;stroke-width:revert;}#dia-s01_d8_arbol_errores .node .neo-node{stroke:#999;}#dia-s01_d8_arbol_errores [data-look=&quot;neo&quot;].node rect,#dia-s01_d8_arbol_errores [data-look=&quot;neo&quot;].cluster rect,#dia-s01_d8_arbol_errores [data-look=&quot;neo&quot;].node polygon{stroke:url(#dia-s01_d8_arbol_errores-gradient);filter:drop-shadow( 1px 2px 2px rgba(185,185,185,1));}#dia-s01_d8_arbol_errores [data-look=&quot;neo&quot;].swimlane.cluster rect{filter:none;}#dia-s01_d8_arbol_errores [data-look=&quot;neo&quot;].node path{stroke:url(#dia-s01_d8_arbol_errores-gradient);stroke-width:1px;}#dia-s01_d8_arbol_errores [data-look=&quot;neo&quot;].node .outer-path{filter:drop-shadow( 1px 2px 2px rgba(185,185,185,1));}#dia-s01_d8_arbol_errores [data-look=&quot;neo&quot;].node .neo-line path{stroke:#999;filter:none;}#dia-s01_d8_arbol_errores [data-look=&quot;neo&quot;].node circle{stroke:url(#dia-s01_d8_arbol_errores-gradient);filter:drop-shadow( 1px 2px 2px rgba(185,185,185,1));}#dia-s01_d8_arbol_errores [data-look=&quot;neo&quot;].node circle .state-start{fill:#000000;}#dia-s01_d8_arbol_errores [data-look=&quot;neo&quot;].icon-shape .icon{fill:url(#dia-s01_d8_arbol_errores-gradient);filter:drop-shadow( 1px 2px 2px rgba(185,185,185,1));}#dia-s01_d8_arbol_errores [data-look=&quot;neo&quot;].icon-shape .icon-neo path{stroke:url(#dia-s01_d8_arbol_errores-gradient);filter:drop-shadow( 1px 2px 2px rgba(185,185,185,1));}#dia-s01_d8_arbol_errores :root{--mermaid-font-family:&quot;trebuchet ms&quot;,verdana,arial,sans-serif;}#dia-s01_d8_arbol_errores .error rect{fill:rgb(253, 241, 241)!important;stroke:rgb(208, 59, 59)!important;color:rgb(16, 41, 77)!important;}#dia-s01_d8_arbol_errores .error polygon{fill:rgb(253, 241, 241)!important;stroke:rgb(208, 59, 59)!important;color:rgb(16, 41, 77)!important;}#dia-s01_d8_arbol_errores .error ellipse{fill:rgb(253, 241, 241)!important;stroke:rgb(208, 59, 59)!important;color:rgb(16, 41, 77)!important;}#dia-s01_d8_arbol_errores .error circle{fill:rgb(253, 241, 241)!important;stroke:rgb(208, 59, 59)!important;color:rgb(16, 41, 77)!important;}#dia-s01_d8_arbol_errores .error path{fill:rgb(253, 241, 241)!important;stroke:rgb(208, 59, 59)!important;color:rgb(16, 41, 77)!important;}#dia-s01_d8_arbol_errores .error tspan{fill:rgb(16, 41, 77)!important;}#dia-s01_d8_arbol_errores .bien rect{fill:rgb(233, 247, 238)!important;stroke:rgb(12, 163, 12)!important;color:rgb(16, 41, 77)!important;}#dia-s01_d8_arbol_errores .bien polygon{fill:rgb(233, 247, 238)!important;stroke:rgb(12, 163, 12)!important;color:rgb(16, 41, 77)!important;}#dia-s01_d8_arbol_errores .bien ellipse{fill:rgb(233, 247, 238)!important;stroke:rgb(12, 163, 12)!important;color:rgb(16, 41, 77)!important;}#dia-s01_d8_arbol_errores .bien circle{fill:rgb(233, 247, 238)!important;stroke:rgb(12, 163, 12)!important;color:rgb(16, 41, 77)!important;}#dia-s01_d8_arbol_errores .bien path{fill:rgb(233, 247, 238)!important;stroke:rgb(12, 163, 12)!important;color:rgb(16, 41, 77)!important;}#dia-s01_d8_arbol_errores .bien tspan{fill:rgb(16, 41, 77)!important;}</style><marker id="dia-s01_d8_arbol_errores_flowchart-v2-pointEnd" class="marker flowchart-v2" markerHeight="8" markerUnits="userSpaceOnUse" markerWidth="8" orient="auto" refX="5" refY="5" viewBox="0 0 10 10"><path d="m0 0 10 5-10 5z" class="arrowMarkerPath" style="stroke-width:1;stroke-dasharray:1,0"/></marker><marker id="dia-s01_d8_arbol_errores_flowchart-v2-pointStart" class="marker flowchart-v2" markerHeight="8" markerUnits="userSpaceOnUse" markerWidth="8" orient="auto" refX="4.5" refY="5" viewBox="0 0 10 10"><path d="m0 5 10 5V0z" class="arrowMarkerPath" style="stroke-width:1;stroke-dasharray:1,0"/></marker><marker id="dia-s01_d8_arbol_errores_flowchart-v2-pointEnd-margin" class="marker flowchart-v2" markerHeight="14" markerUnits="userSpaceOnUse" markerWidth="10.5" orient="auto" refX="11.5" refY="7" viewBox="0 0 11.5 14"><path d="m0 0 11.5 7L0 14z" class="arrowMarkerPath" style="stroke-width:0;stroke-dasharray:1,0"/></marker><marker id="dia-s01_d8_arbol_errores_flowchart-v2-pointStart-margin" class="marker flowchart-v2" markerHeight="14" markerUnits="userSpaceOnUse" markerWidth="11.5" orient="auto" refX="1" refY="7" viewBox="0 0 11.5 14"><polygon points="0,7 11.5,14 11.5,0" class="arrowMarkerPath" style="stroke-width:0;stroke-dasharray:1,0"/></marker><marker id="dia-s01_d8_arbol_errores_flowchart-v2-circleEnd" class="marker flowchart-v2" markerHeight="11" markerUnits="userSpaceOnUse" markerWidth="11" orient="auto" refX="11" refY="5" viewBox="0 0 10 10"><circle cx="5" cy="5" r="5" class="arrowMarkerPath" style="stroke-width:1;stroke-dasharray:1,0"/></marker><marker id="dia-s01_d8_arbol_errores_flowchart-v2-circleStart" class="marker flowchart-v2" markerHeight="11" markerUnits="userSpaceOnUse" markerWidth="11" orient="auto" refX="-1" refY="5" viewBox="0 0 10 10"><circle cx="5" cy="5" r="5" class="arrowMarkerPath" style="stroke-width:1;stroke-dasharray:1,0"/></marker><marker id="dia-s01_d8_arbol_errores_flowchart-v2-circleEnd-margin" class="marker flowchart-v2" markerHeight="14" markerUnits="userSpaceOnUse" markerWidth="14" orient="auto" refX="12.25" refY="5" viewBox="0 0 10 10"><circle cx="5" cy="5" r="5" class="arrowMarkerPath" style="stroke-width:0;stroke-dasharray:1,0"/></marker><marker id="dia-s01_d8_arbol_errores_flowchart-v2-circleStart-margin" class="marker flowchart-v2" markerHeight="14" markerUnits="userSpaceOnUse" markerWidth="14" orient="auto" refX="-2" refY="5" viewBox="0 0 10 10"><circle cx="5" cy="5" r="5" class="arrowMarkerPath" style="stroke-width:0;stroke-dasharray:1,0"/></marker><marker id="dia-s01_d8_arbol_errores_flowchart-v2-crossEnd" class="marker cross flowchart-v2" markerHeight="11" markerUnits="userSpaceOnUse" markerWidth="11" orient="auto" refX="12" refY="5.2" viewBox="0 0 11 11"><path d="m1 1 9 9m0-9-9 9" class="arrowMarkerPath" style="stroke-width:2;stroke-dasharray:1,0"/></marker><marker id="dia-s01_d8_arbol_errores_flowchart-v2-crossStart" class="marker cross flowchart-v2" markerHeight="11" markerUnits="userSpaceOnUse" markerWidth="11" orient="auto" refX="-1" refY="5.2" viewBox="0 0 11 11"><path d="m1 1 9 9m0-9-9 9" class="arrowMarkerPath" style="stroke-width:2;stroke-dasharray:1,0"/></marker><marker id="dia-s01_d8_arbol_errores_flowchart-v2-crossEnd-margin" class="marker cross flowchart-v2" markerHeight="12" markerUnits="userSpaceOnUse" markerWidth="12" orient="auto" refX="17.7" refY="7.5" viewBox="0 0 15 15"><path d="m1 1 13 13M1 14 14 1" class="arrowMarkerPath" style="stroke-width:2.5"/></marker><marker id="dia-s01_d8_arbol_errores_flowchart-v2-crossStart-margin" class="marker cross flowchart-v2" markerHeight="12" markerUnits="userSpaceOnUse" markerWidth="12" orient="auto" refX="-3.5" refY="7.5" viewBox="0 0 15 15"><path d="m1 1 13 13M1 14 14 1" class="arrowMarkerPath" style="stroke-width:2.5;stroke-dasharray:1,0"/></marker><g class="root"><g class="edgePaths"><path id="dia-s01_d8_arbol_errores-L_Q1_SIN_0" marker-end="url(#dia-s01_d8_arbol_errores_flowchart-v2-pointEnd)" d="m629.199 210.084 14.095 16.208c14.095 16.207 42.286 48.621 56.382 83.506s14.095 72.238 14.095 90.916v18.677" class="edge-thickness-normal edge-pattern-solid edge-thickness-normal edge-pattern-solid flowchart-link" data-edge="true" data-et="edge" data-id="L_Q1_SIN_0" data-look="classic" data-points="W3sieCI6NjI5LjE5ODUyMjg4NzExMDEsInkiOjIxMC4wODQxODA1MTI1NDgwN30seyJ4Ijo3MTMuNzcwOTg0NjQ5NjU4MiwieSI6MzA3LjMyODEyNX0seyJ4Ijo3MTMuNzcwOTg0NjQ5NjU4MiwieSI6NDIzLjM5MDYyNX1d"/><path id="dia-s01_d8_arbol_errores-L_Q1_Q2_0" marker-end="url(#dia-s01_d8_arbol_errores_flowchart-v2-pointEnd)" d="m506.711 210.084-14.096 16.208c-14.095 16.207-42.286 48.621-56.381 70.162-14.096 21.541-14.096 32.207-14.096 37.541v5.333" class="edge-thickness-normal edge-pattern-solid edge-thickness-normal edge-pattern-solid flowchart-link" data-edge="true" data-et="edge" data-id="L
g><g class="edgeLabels"><g class="edgeLabel"><g class="label" data-id="L_Q1_SIN_0" transform="translate(713.771 298.328)"><rect width="72.656" height="22" x="-36.328" y="-2" class="background"/><text y="-10.1" text-anchor="middle"><tspan x="0" y="-.1em" class="text-outer-tspan row" dy="1.1em" text-anchor="middle"><tspan class="text-inner-tspan" font-style="normal" font-weight="normal">No,</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> ni</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> una</tspan></tspan></text></g></g><g class="edgeLabel"><g class="label" data-id="L_Q1_Q2_0" transform="translate(422.138 298.328)"><rect width="78.203" height="22" x="-39.102" y="-2" class="background"/><text y="-10.1" text-anchor="middle"><tspan x="0" y="-.1em" class="text-outer-tspan row" dy="1.1em" text-anchor="middle"><tspan class="text-inner-tspan" font-style="normal" font-weight="normal">Sí,</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> algunas</tspan></tspan></text></g></g><g class="edgeLabel"><g class="label" data-id="L_Q2_EJE_0" transform="translate(564.525 594.953)"><rect width="149.141" height="38.5" x="-74.57" y="-2" class="background"/><text y="-10.1" text-anchor="middle"><tspan x="0" y="-.1em" class="text-outer-tspan row" dy="1.1em" text-anchor="middle"><tspan class="text-inner-tspan" font-style="normal" font-weight="normal">No,</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> se</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> detuvo</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> con</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> un</tspan></tspan><tspan x="0" y="1em" class="text-outer-tspan row" dy="1.1em" text-anchor="middle"><tspan class="text-inner-tspan" font-style="normal" font-weight="normal">mensaje</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> rojo</tspan></tspan></text></g></g><g class="edgeLabel"><g class="label" data-id="L_Q2_Q3_0" transform="translate(279.751 603.203)"><rect width="163.641" height="22" x="-81.82" y="-2" class="background"/><text y="-10.1" text-anchor="middle"><tspan x="0" y="-.1em" class="text-outer-tspan row" dy="1.1em" text-anchor="middle"><tspan class="text-inner-tspan" font-style="normal" font-weight="normal">Sí,</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> terminó</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> sin</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> quejarse</tspan></tspan></text></g></g><g class="edgeLabel"><g class="label" data-id="L_Q3_LOG_0" transform="translate(136.547 901.39)"><rect width="23.531" height="22" x="-11.766" y="-2" class="background"/><text y="-10.1" text-anchor="middle"><tspan x="0" y="-.1em" class="text-outer-tspan row" dy="1.1em" text-anchor="middle"><tspan class="text-inner-tspan" font-style="normal" font-weight="normal">No</tspan></tspan></text></g></g><g class="edgeLabel"><g class="label" data-id="L_Q3_OK_0" transform="translate(422.675 901.39)"><rect width="17.359" height="22" x="-8.398" y="-2" class="background"/><text y="-10.1" text-anchor="middle"><tspan x="0" y="-.1em" class="text-outer-tspan row" dy="1.1em" text-anchor="middle"><tspan class="text-inner-tspan" font-style="normal" font-weight="normal">Sí</tspan></tspan></text></g></g></g><g class="nodes"><g id="dia-s01_d8_arbol_errores-flowchart-Q1-0" class="node default" data-look="classic" transform="translate(567.955 139.664)"><polygon points="131.6640625,0 263.328125,-131.6640625 131.6640625,-263.328125 0,-131.6640625" class="label-container" transform="translate(-131.164 131.664)"/><g class="label" transform="translate(0 -17.25)"><rect/><rect class="background" style="stroke:none"/><text y="-10.1"><tspan x="0" y="-.1em" class="text-outer-tspan row" dy="1.1em"><tspan class="text-inner-tspan" font-style="normal" font-weight="normal">¿Alcanzó</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> a</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> ejecutarse</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> alguna</tspan></tspan><tspan x="0" y="1em" class="text-outer-tspan row" dy="1.1em"><tspan class="text-inner-tspan" font-style="normal" font-weight="normal">línea?</tspan></tspan></text></g></g><g id="dia-s01_d8_arbol_errores-flowchart-Q2-1" class="node default" data-look="classic" transform="translate(422.138 455.64)"><polygon points="112.3125,0 224.625,-112.3125 112.3125,-224.625 0,-112.3125" class="label-container" transform="translate(-111.813 112.313)"/><g class="label" transform="translate(0 -17.25)"><rect/><rect class="background" style="stroke:none"/><text y="-10.1"><tspan x="0" y="-.1em" class="text-outer-tspan row" dy="1.1em"><tspan class="text-inner-tspan" font-style="normal" font-weight="normal">¿Llegó</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> hasta</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> el</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> final</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> del</tspan></tspan><tspan x="0" y="1em" class="text-outer-tspan row" dy="1.1em"><tspan class="text-inner-tspan" font-style="normal" font-weight="normal">programa?</tspan></tspan></text></g></g><g id="dia-s01_d8_arbol_errores-flowchart-Q3-2" class="node default" data-look="classic" transform="translate(279.751 765.422)"><polygon points="108.96875,0 217.9375,-108.96875 108.96875,-217.9375 0,-108.96875" class="label-container" transform="translate(-108.469 108.969)"/><g class="label" transform="translate(0 -17.25)"><rect/><rect class="background" style="stroke:none"/><text y="-10.1"><tspan x="0" y="-.1em" class="text-outer-tspan row" dy="1.1em"><tspan class="text-inner-tspan" font-style="normal" font-weight="normal">¿El</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> resultado</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> es</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> el</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> que</tspan></tspan><tspan x="0" y="1em" class="text-outer-tspan row" dy="1.1em"><tspan class="text-inner-tspan" font-style="normal" font-weight="normal">esperabas?</tspan></tspan></text></g></g><g id="dia-s01_d8_arbol_errores-flowchart-SIN-3" class="node default error" data-look="classic" transform="translate(713.771 455.64)"><rect width="258.641" height="64.5" x="-129.32" y="-32.25" class="basic label-container" style="fill:#fdf1f1!important;stroke:#d03b3b!important"/><g class="label" style="color:#10294d!important" transform="translate(0 -17.25)"><rect/><rect class="background" style="stroke:none"/><text y="-10.1" style="fill:#10294d!important"><tspan x="0" y="-.1em" class="text-outer-tspan row" dy="1.1em"><tspan class="text-inner-tspan" font-style="normal" font-weight="normal">ERROR</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> DE</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> SINTAXIS</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> ·</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> mira</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> la</tspan></tspan><tspan x="0" y="1em" class="text-outer-tspan row" dy="1.1em"><tspan class="text-inner-tspan" font-style="normal" font-weight="normal">línea</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> señalada</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> y</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> el</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> signo</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> ^</tspan></tspan></text></g></g><g id="dia-s01_d8_arbol_errores-flowchart-EJE-4" class="node default error" data-look="classic" transform="translate(564.525 765.422)"><rect width="251.609" height="81" x="-125.805" y="-40.5" class="basic label-container" style="fill:#fdf1f1!important;stroke:#d03b3b!important"/><g class="label" style="color:#10294d!important" transform="translate(0 -25.5)"><rect/><rect class="background" style="stroke:none"/><text y="-10.1" style="fill:#10294d!important"><tspan x="0" y="-.1em" class="text-outer-tspan row" dy="1.1em"><tspan class="text-inner-tspan" font-style="normal" font-weight="normal">ERROR</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> DE</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> EJECUCIÓN</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> ·</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> lee</tspan></tspan><tspan x="0" y="1em" class="text-outer-tspan row" dy="1.1em"><tspan class="text-inner-tspan" font-style="normal" font-weight="normal">la</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> ÚLTIMA</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> línea</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> del</tspan></tspan><tspan x="0" y="2.1em" class="text-outer-tspan row" dy="1.1em"><tspan class="text-inner-tspan" font-style="normal" font-weight="normal">traceback</tspan></tspan></text></g></g><g id="dia-s01_d8_arbol_errores-flowchart-LOG-5" class="node default error" data-look="classic" transform="translate(136.547 978.64)"><rect width="257.094" height="64.5" x="-128.547" y="-32.25" class="basic label-container" style="fill:#fdf1f1!important;stroke:#d03b3b!important"/><g class="label" style="color:#10294d!important" transform="translate(0 -17.25)"><rect/><rect class="background" style="stroke:none"/><text y="-10.1" style="fill:#10294d!important"><tspan x="0" y="-.1em" class="text-outer-tspan row" dy="1.1em"><tspan class="text-inner-tspan" font-style="normal" font-weight="normal">ERROR</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> DE</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> LÓGICA</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> ·</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> nadie</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> te</tspan></tspan><tspan x="0" y="1em" class="text-outer-tspan row" dy="1.1em"><tspan class="text-inner-tspan" font-style="normal" font-weight="normal">avisa.</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> Se</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> caza</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"
33m0 0 .949-1.271m-.95 1.271.95-1.271m0 0 1.028-1.208m-1.028 1.208 1.028-1.208m0 0 1.104-1.14m-1.104 1.14 1.104-1.14m0 0 1.174-1.067m-1.174 1.067 1.174-1.067m0 0 1.24-.989m-1.24.99 1.24-.99m0 0 1.302-.908m-1.301.908 1.301-.908m0 0 1.357-.822m-1.357.822 1.357-.822m0 0 1.406-.734m-1.406.734 1.406-.734m0 0 1.451-.642m-1.45.642 1.45-.642m0 0 1.49-.548m-1.49.548 1.49-.548m0 0 1.52-.452m-1.52.452 1.52-.452m0 0 1.547-.353m-1.547.353 1.547-.353m0 0 1.566-.253m-1.566.253 1.566-.253m0 0 1.58-.152m-1.58.152 1.58-.152m0 0 1.585-.051m-1.586.05 1.586-.05m0 0" style="fill:#e9f7ee!important;stroke:#0ca30c!important" transform="translate(422.956 978.64)"/></g><g class="label" style="color:#10294d!important" transform="translate(422.956 961.39)"><rect/><rect class="background" style="stroke:none"/><text y="-10.1" style="fill:#10294d!important"><tspan x="0" y="-.1em" class="text-outer-tspan row" dy="1.1em"><tspan class="text-inner-tspan" font-style="normal" font-weight="normal">Sin</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> error</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> conocido</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> ·</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> escribe</tspan></tspan><tspan x="0" y="1em" class="text-outer-tspan row" dy="1.1em"><tspan class="text-inner-tspan" font-style="normal" font-weight="normal">un</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> assert</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> y</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> asegúrate</tspan></tspan></text></g></g></g></g><defs><filter id="dia-s01_d8_arbol_errores-drop-shadow" width="130%" height="130%"><feDropShadow dx="4" dy="4" flood-color="#000" flood-opacity=".06" stdDeviation="0"/></filter></defs><defs><filter id="dia-s01_d8_arbol_errores-drop-shadow-small" width="150%" height="150%"><feDropShadow dx="2" dy="2" flood-color="#000" flood-opacity=".06" stdDeviation="0"/></filter></defs><linearGradient id="dia-s01_d8_arbol_errores-gradient" x1="0%" x2="100%" y1="0%" y2="0%" gradientUnits="objectBoundingBox"><stop offset="0%" stop-color="hsl(0, 0%, 83.3333333333%)" stop-opacity="1"/><stop offset="100%" stop-color="hsl(0, 0%, 88.9215686275%)" stop-opacity="1"/></linearGradient></svg>', 'Cuatro preguntas y sabes con cuál de los tres estás peleando.')

# %% [markdown]
# #### Un error de lógica de 125 millones de dólares
#
# En 1999 la NASA perdió la sonda **Mars Climate Orbiter**. El software no falló:
# corrió perfecto, sin un solo mensaje de error, durante nueve meses de viaje. El
# problema fue que un equipo entregaba los datos de empuje en libras-fuerza y el
# otro los leía como si fueran newtons. La sonda entró demasiado bajo en la
# atmósfera de Marte y se desintegró.
#
# Ni sintaxis, ni ejecución. **Lógica.** Nadie avisó.
#
# Por eso, a partir de hoy, la pregunta que te vas a hacer siempre no es «¿corrió
# mi programa?» sino **«¿corrió, y además está bien?»**.

# %%
quiz(
    "Q5", 6,
    "Tu programa calcula el 15 % de descuento sobre $80.000 y muestra $79.985. "
    "No aparece ningún mensaje de error. ¿Qué tipo de error tienes?",
    ["De sintaxis", "De ejecución", "De lógica",
     "Ninguno: si no hay mensaje, no hay error"],
    "De lógica",
    "Corrió entero y sin quejarse, y entregó un número equivocado. Esa es la "
    "firma exacta del error de lógica.",
    pistas=["Haz la cuenta a mano: el 15 % de 80.000 son 12.000, así que el "
            "precio con descuento debería ser 68.000. El programa corrió sin "
            "quejarse… y entregó otra cosa."],
)

# %% [markdown]
# ---
#
# ## 5. Siete ejercicios · 35 min
#
# Aquí es donde se juega tu nota: **25 puntos** repartidos en siete ejercicios.
# Cada uno son dos celdas — la tuya y la de prueba — y la de prueba es solo un
# montón de `assert` como el que acabas de fabricar.
#
# Tres reglas de la casa:
#
# - **Los intentos no restan.** Ejecuta la celda de prueba tantas veces como
#   quieras.
# - **Las pistas tampoco.** Cada ejercicio trae tres, de la que hace pensar a la
#   que casi resuelve. Se piden con `pista("E1")`, `pista("E2")`…
# - Si ejecutas una celda de ejercicio sin haberla tocado, te va a salir
#   `NotImplementedError: ...`. No es un fallo del cuadernillo: es un error de
#   ejecución **puesto a propósito** que significa «aquí falta tu parte». Bórralo
#   cuando escribas tu respuesta.

# %% [markdown]
# ### Ejercicio 1 — Hardware, software, dato o proceso
#
# *Dificultad ★☆☆☆ · 3 puntos*
#
# Esta es la versión individual de la actividad que hicieron en clase. Abajo hay
# ocho cosas de la vida real de la UIS. Clasifica cada una escribiendo **una** de
# estas cuatro palabras, entre comillas:
#
# `"hardware"` · `"software"` · `"dato"` · `"proceso"`
#
# La primera ya está resuelta como ejemplo. Si dudas, vuelve a la tabla de la
# sección 3A: *el software es la receta, el dato es el ingrediente, el proceso es
# cocinar y el hardware es la olla.*
#
# > ¿Atascado? Ejecuta `pista("E1")` en una celda nueva. Hay 3, de la que hace pensar a la que casi resuelve. Pedirlas no resta puntos.

# %%
# Reemplaza cada  ...  por una de estas cuatro palabras, entre comillas:
#     "hardware"    "software"    "dato"    "proceso"
CLASIFICACION = {
    "el mouse del portátil":                    "hardware",   # resuelto, de ejemplo
    "WhatsApp":                                 ...,
    "la nota 4.3 de tu primer parcial":         ...,
    "ordenar la lista del curso por apellido":  ...,
    "la pantalla táctil del cajero automático": ...,
    "Windows 11":                               ...,
    "la foto de tu carné de la UIS":            ...,
    "calcular el promedio del semestre":        ...,
}
### INICIO SOLUCION
CLASIFICACION = {
    "el mouse del portátil":                    "hardware",
    "WhatsApp":                                 "software",
    "la nota 4.3 de tu primer parcial":         "dato",
    "ordenar la lista del curso por apellido":  "proceso",
    "la pantalla táctil del cajero automático": "hardware",
    "Windows 11":                               "software",
    "la foto de tu carné de la UIS":            "dato",
    "calcular el promedio del semestre":        "proceso",
}
### FIN SOLUCION

# %%
assert isinstance(CLASIFICACION, dict), "CLASIFICACION debe seguir siendo un diccionario"
assert len(CLASIFICACION) == 8, "No agregues ni borres filas: son ocho"
assert all(isinstance(v, str) for v in CLASIFICACION.values()), \
    "Cada respuesta va entre comillas, como texto"

corregir("ejercicio_1", CLASIFICACION)
print("Ejercicio 1 superado: distingues hardware, software, datos y procesos.")

# %% [markdown]
# ### Ejercicio 2 — La escalera de los lenguajes
#
# *Dificultad ★☆☆☆ · 3 puntos*
#
# Los cuatro fragmentos de abajo hacen **lo mismo**: sumar dos números. Lo que
# cambia es a qué altura están escritos.
#
# Ordénalos en la lista `NIVELES`, del **más cercano a la máquina** (posición 1)
# al **más cercano a una persona** (posición 4). Copia los textos tal cual, con
# sus comillas.
#
# ```
# A)  std::cout << a + b;
# B)  10110000 01100001
# C)  print(a + b)
# D)  MOV AL, 61h
# ```
#
# Pista conceptual, no técnica: pregúntate en cuál de los cuatro **no aparece
# ninguna palabra**, y en cuál se parece más a algo que dirías en voz alta.
#
# > ¿Atascado? Ejecuta `pista("E2")` en una celda nueva. Hay 3, de la que hace pensar a la que casi resuelve. Pedirlas no resta puntos.

# %%
NIVELES = [
    ...,   # 1 = lo más cerca de la máquina
    ...,
    ...,
    ...,   # 4 = lo más cerca de una persona
]
### INICIO SOLUCION
NIVELES = [
    "10110000 01100001",
    "MOV AL, 61h",
    "std::cout << a + b;",
    "print(a + b)",
]
### FIN SOLUCION

# %%
assert isinstance(NIVELES, list) and len(NIVELES) == 4, "NIVELES debe ser una lista de 4 textos"
assert all(isinstance(x, str) for x in NIVELES), "Copia los fragmentos como texto, entre comillas"
assert len(set(NIVELES)) == 4, "No repitas fragmentos: cada uno va una sola vez"

corregir("ejercicio_2", NIVELES)
print("Ejercicio 2 superado: ya sabes leer la altura de un lenguaje.")

# %% [markdown]
# *¿Por qué C++ va por debajo de Python?* Porque se compila directo a código de
# máquina y te obliga a declarar tipos y detalles que Python resuelve solo. Los
# dos son de alto nivel; uno está un escalón más abajo que el otro.

# %% [markdown]
# ### Ejercicio 3 — Escribe en lenguaje de máquina
#
# *Dificultad ★★☆☆ · 4 puntos*
#
# Tu turno de darle órdenes a la MiniMáquina en su propio idioma. Recuerda su
# repertorio completo:
#
# | Código | Instrucción | Qué hace |
# |---|---|---|
# | `1 n` | CARGAR n | pone `n` en la gaveta |
# | `2 n` | SUMAR n | le suma `n` a la gaveta |
# | `3 0` | MOSTRAR | muestra lo que hay en la gaveta |
# | `0 0` | PARAR | apaga la máquina |
#
# **Escribe el programa que calcule 4 + 9 + 7 y muestre el resultado.**
#
# Tres reglas que la máquina exige:
# - se CARGA **una sola vez** (el primer número); los demás se SUMAN
# - hay que MOSTRAR antes de PARAR, o nadie verá nada
# - todo programa termina con PARAR
#
# > ¿Atascado? Ejecuta `pista("E3")` en una celda nueva. Hay 3, de la que hace pensar a la que casi resuelve. Pedirlas no resta puntos.

# %%
# Escribe la lista completa. La primera instrucción va de regalo:
#   1, 4   significa  CARGAR 4
programa_suma = [
    1, 4,     # CARGAR 4
    # <- sigue tú: SUMAR 9, SUMAR 7, MOSTRAR y PARAR
]
### INICIO SOLUCION
programa_suma = [
    1, 4,     # CARGAR 4
    2, 9,     # SUMAR 9
    2, 7,     # SUMAR 7
    3, 0,     # MOSTRAR
    0, 0,     # PARAR
]
### FIN SOLUCION

# %%
assert isinstance(programa_suma, list), "programa_suma tiene que ser una lista"
assert all(isinstance(x, int) for x in programa_suma), "Todo en lenguaje de máquina son números enteros"
assert len(programa_suma) % 2 == 0, "Cada instrucción son DOS números: código y argumento"
assert set(programa_suma[0::2]) <= {0, 1, 2, 3}, \
    "Usaste un código de instrucción que la MiniMáquina no conoce (solo 0, 1, 2 y 3)"
assert programa_suma[0::2].count(1) == 1, \
    "Se CARGA una sola vez: los demás números se SUMAN"

_maquina = MiniMaquina(programa_suma)
_salidas = _maquina.ejecutar(traza=False)

assert _maquina.termino_con_parar, "Todo programa debe terminar con PARAR (0, 0)"
assert _salidas, "Tu programa no mostró nada: ¿le pusiste MOSTRAR (3, 0)?"
assert _salidas == [20], f"La MiniMáquina mostró {_salidas} y esperábamos [20]"

print("Ejercicio 3 superado: escribiste y ejecutaste un programa en lenguaje de máquina.")

# %% [markdown]
# ### Ejercicio 4 — Diagnostica los tres
#
# *Dificultad ★★☆☆ · 3 puntos*
#
# Tres programas, tres problemas distintos. **No los ejecutes**: diagnostícalos
# leyendo, que es lo que vas a tener que hacer toda tu vida profesional.
#
# **Programa A**
# ```python
# nota = 4.2
# if nota >= 3.0
#     print("Aprobado")
# ```
#
# **Programa B**
# ```python
# notas = [4.0, 3.5, 2.8]
# print("La cuarta nota del curso es:", notas[3])
# ```
#
# **Programa C**
# ```python
# precio = 80000
# descuento = 15          # el almacén da 15 % de descuento
# final = precio - descuento
# print("Precio final:", final)
# ```
#
# Escribe para cada uno **una** de estas tres palabras, entre comillas:
# `"sintaxis"` · `"ejecucion"` · `"logica"` (sin tildes, para no pelear con el
# teclado).
#
# > ¿Atascado? Ejecuta `pista("E4")` en una celda nueva. Hay 3, de la que hace pensar a la que casi resuelve. Pedirlas no resta puntos.

# %%
DIAGNOSTICO = {
    "A": ...,
    "B": ...,
    "C": ...,
}
### INICIO SOLUCION
DIAGNOSTICO = {
    "A": "sintaxis",
    "B": "ejecucion",
    "C": "logica",
}
### FIN SOLUCION

# %%
assert isinstance(DIAGNOSTICO, dict) and set(DIAGNOSTICO) == {"A", "B", "C"}, \
    "DIAGNOSTICO debe tener exactamente las llaves 'A', 'B' y 'C'"
assert all(v in {"sintaxis", "ejecucion", "logica"} for v in DIAGNOSTICO.values()), \
    "Usa solo estas tres palabras, sin tildes: sintaxis, ejecucion, logica"

corregir("ejercicio_4", DIAGNOSTICO)
print("Ejercicio 4 superado: sabes distinguir los tres errores sin ejecutarlos.")

# %% [markdown]
# ### Ejercicio 5 — Caza el error que nadie te va a señalar
#
# *Dificultad ★★★☆ · 4 puntos*
#
# Abajo hay una función que debería calcular el promedio de tres notas. Corre sin
# quejarse. Y está mal.
#
# Dos cosas que hacer:
#
# 1. **Arregla la línea del cálculo.** Recuerda el promedio de los tres cuatros.
# 2. **Escribe entre las comillas triples** —eso se llama *docstring*— qué hace
#    la función y cuál era el error. Una o dos frases tuyas, no copiadas.
#
# Sobre la primera línea, `def promedio_de_tres(n1, n2, n3):` — no te asustes:
# significa «receta que recibe tres notas». Te la damos hecha; en la semana 8
# aprenderás a escribirla tú. Hoy solo trabaja adentro.
#
# > ¿Atascado? Ejecuta `pista("E5")` en una celda nueva. Hay 3, de la que hace pensar a la que casi resuelve. Pedirlas no resta puntos.

# %%
def promedio_de_tres(n1, n2, n3):
    """ESCRIBE AQUÍ, con tus palabras, qué hace esta función y cuál era el error de lógica que arreglaste."""
    resultado = n1 + n2 + n3 / 3     # <- aquí está el error de lógica
    return resultado
### INICIO SOLUCION
def promedio_de_tres(n1, n2, n3):
    """Devuelve el promedio de tres notas.

    El error de lógica era de precedencia: sin paréntesis Python dividía solo la
    tercera nota antes de sumar, así que el resultado no era un promedio.
    """
    resultado = (n1 + n2 + n3) / 3
    return resultado
### FIN SOLUCION

# %%
# Cuatro casos de prueba: situaciones cuyo resultado correcto conocemos de antemano.
assert abs(promedio_de_tres(4.0, 4.0, 4.0) - 4.0) < 1e-9, \
    "Con tres notas de 4.0 el promedio TIENE que dar 4.0"
assert abs(promedio_de_tres(3.0, 4.0, 5.0) - 4.0) < 1e-9, \
    "Con 3.0, 4.0 y 5.0 el promedio es 4.0"
assert abs(promedio_de_tres(0.0, 0.0, 3.0) - 1.0) < 1e-9, \
    "Revisa: ¿estás dividiendo la SUMA de las tres, o solo la última?"
assert abs(promedio_de_tres(5.0, 5.0, 5.0) - 5.0) < 1e-9, \
    "Con tres cincos el promedio es 5.0"

_doc = (promedio_de_tres.__doc__ or "").strip()
assert "ESCRIBE AQUÍ" not in _doc, "Reemplaza el texto de ejemplo por tu propia explicación"
assert len(_doc) >= 40, "Tu explicación es muy corta: escribe al menos una frase completa"

print("Ejercicio 5 superado: cazaste y documentaste un error que Python nunca iba a señalar.")
### INICIO PRUEBAS OCULTAS
# Un caso más, que el estudiante no ve: con cuatro casos visibles todavía se
# podría intentar acertar de memoria; con este quinto hay que calcular de verdad.
assert abs(promedio_de_tres(1.0, 2.0, 4.5) - 2.5) < 1e-9
### FIN PRUEBAS OCULTAS

# %% [markdown]
# *¿Notaste que te probamos con cuatro casos distintos y no con uno?* Con un solo
# caso podrías haber escrito `resultado = 4.0` y pasar. Con cuatro, la única forma
# de pasar es calcular de verdad. Así se evita hacer trampa… y así se diseñan las
# pruebas en la vida real.

# %% [markdown]
# ### Ejercicio 6 — Crea un archivo con código
#
# *Dificultad ★★★☆ · 4 puntos*
#
# Hasta ahora todo lo que has hecho vive en la memoria y desaparece cuando se
# apaga el kernel. Vamos a dejar algo **escrito en el disco**.
#
# Completa la función para que:
#
# 1. **cree** el archivo `bitacora_semana1.txt` en tu carpeta de trabajo,
# 2. **escriba** exactamente tres líneas:
#    · la primera, el nombre que recibe la función
#    · la segunda, el texto `Semana 1: fundamentos computacionales`
#    · la tercera, lo que quieras contar sobre esta semana (mínimo una palabra),
# 3. **lo vuelva a leer** y devuelva su contenido completo.
#
# Las tres partes de trabajar con archivos: **abrir**, **hacer algo**, **cerrar**.
# El `with` de abajo cierra por ti aunque algo falle — por eso se usa siempre.
# Cada línea termina en `\n`, que es como se escribe «salto de línea».
#
# > ¿Atascado? Ejecuta `pista("E6")` en una celda nueva. Hay 3, de la que hace pensar a la que casi resuelve. Pedirlas no resta puntos.

# %%
def crear_bitacora(nombre_estudiante):
    """Crea bitacora_semana1.txt con tres líneas y devuelve su contenido."""
    # 1. Abre el archivo en modo "w" con un bloque  with open(...) as archivo:
    #    y escribe las tres líneas. Cada una termina en \n
    # 2. Vuelve a abrirlo, ahora en modo "r", y léelo entero con archivo.read()
    # 3. Devuelve lo leído con  return
### INICIO SOLUCION
def crear_bitacora(nombre_estudiante):
    """Crea bitacora_semana1.txt con tres líneas y devuelve su contenido."""
    with open("bitacora_semana1.txt", "w", encoding="utf-8") as archivo:
        archivo.write(nombre_estudiante + "\n")
        archivo.write("Semana 1: fundamentos computacionales\n")
        archivo.write("Lo que más me costó fue distinguir los tres errores.\n")

    with open("bitacora_semana1.txt", "r", encoding="utf-8") as archivo:
        contenido = archivo.read()

    return contenido
### FIN SOLUCION

# %%
import os

_contenido = crear_bitacora("Ana Gómez")

assert os.path.exists("bitacora_semana1.txt"), \
    "No encuentro bitacora_semana1.txt en la carpeta de trabajo. ¿Lo creaste con open(..., 'w')?"
assert isinstance(_contenido, str) and _contenido.strip(), \
    "La función debe DEVOLVER (return) lo que quedó escrito en el archivo"

_lineas = [l for l in _contenido.strip().split("\n") if l.strip()]
assert len(_lineas) == 3, f"El archivo debe tener 3 líneas y encontré {len(_lineas)}. ¿Pusiste el \\n al final de cada una?"
assert "Ana Gómez" in _lineas[0], "La primera línea debe ser el nombre que RECIBE la función"
assert "Semana 1: fundamentos computacionales" in _lineas[1], "La segunda línea debe ir tal cual el enunciado"

with open("bitacora_semana1.txt", "r", encoding="utf-8") as _f:
    assert _f.read() == _contenido, \
        "Lo que devuelves tiene que ser EXACTAMENTE lo que quedó guardado en el disco"

# Segunda llamada con otro nombre: el archivo debe reescribirse, no quedarse con el anterior.
_c2 = crear_bitacora("Luis Peña")
assert "Luis Peña" in _c2 and "Ana Gómez" not in _c2, \
    "Tu función debe usar el nombre que recibe, no uno fijo escrito a mano"

print("Ejercicio 6 superado: creaste, escribiste y leíste un archivo. Eso es gestión de archivos.")
### INICIO PRUEBAS OCULTAS
# Tercer nombre, con tilde y sin espacios, para descartar cualquier atajo.
_c3 = crear_bitacora("Zulma Ríos")
assert "Zulma Ríos" in _c3 and "Luis Peña" not in _c3
### FIN PRUEBAS OCULTAS

# %% [markdown]
# Ejecuta `!ls -l` y ahí está tu archivo, con su tamaño y su fecha. Ábrelo desde
# el explorador de archivos de Jupyter (la pestaña del principio) y verás el
# mismo texto. **Una sola cosa, vista desde tres lugares distintos**: tu código,
# la terminal y el explorador.

# %% [markdown]
# Antes del último ejercicio, ejecuta esta celda: es el vocabulario cerrado con el
# que se arma el mapa. Puedes volver a ella cuando quieras.

# %%
ver_vocabulario()

# %% [markdown]
# ### Ejercicio 7 — Arma tu mapa de la computación
#
# *Dificultad ★★★★ · 4 puntos*
#
# Último ejercicio, y el que más vale la pena. Vas a dibujar el mapa de todo lo
# que viste hoy — pero en vez de arrastrar cajitas con el mouse, lo vas a
# **escribir**, que es como se representan las ideas cuando una máquina tiene que
# entenderlas.
#
# Un mapa conceptual es una lista de **relaciones**, y cada relación es una frase
# de tres partes:
#
# ```
# ("intérprete",  "traduce",  "lenguaje de alto nivel")
#   ^ de qué        ^ qué hace     ^ con qué
# ```
#
# que se lee: *«el intérprete traduce el lenguaje de alto nivel»*.
#
# **Tu tarea:** agrega **al menos 6 relaciones tuyas** a las 3 de ejemplo, usando
# solo el vocabulario permitido. Ejecuta `ver_vocabulario()` para verlo cuando
# quieras.
#
# **Regla de oro:** cada relación tuya tiene que poder leerse en voz alta como una
# frase con sentido. Si suena rara al decirla, está mal.
#
# Y cuatro relaciones **no pueden faltar** — son el corazón de esta semana. Si
# repasaste la sección 3, ya sabes cuáles son.
#
# > ¿Atascado? Ejecuta `pista("E7")` en una celda nueva. Hay 3, de la que hace pensar a la que casi resuelve. Pedirlas no resta puntos.

# %%
MAPA = [
    ("computador", "se compone de", "hardware"),          # ejemplo
    ("computador", "se compone de", "software"),          # ejemplo
    ("Python", "es un", "lenguaje de alto nivel"),        # ejemplo
    # Agrega aquí abajo AL MENOS 6 relaciones tuyas, una por línea y con esta forma:
    #     ("concepto", "relación", "concepto"),
]
### INICIO SOLUCION
MAPA = [
    ("computador", "se compone de", "hardware"),
    ("computador", "se compone de", "software"),
    ("Python", "es un", "lenguaje de alto nivel"),
    ("procesador", "ejecuta", "lenguaje de máquina"),
    ("intérprete", "traduce", "lenguaje de alto nivel"),
    ("IDE", "se compone de", "editor"),
    ("proceso", "produce", "dato"),
    ("hardware", "se compone de", "procesador"),
    ("dato", "se guarda en", "archivo"),
    ("programa", "puede tener", "error de lógica"),
]
### FIN SOLUCION

# %%
assert isinstance(MAPA, list), "MAPA debe ser una lista"
assert len(MAPA) >= 9, f"Tu mapa tiene {len(MAPA)} relaciones y necesita al menos 9 (3 de ejemplo + 6 tuyas)"

for _t in MAPA:
    assert isinstance(_t, tuple) and len(_t) == 3, \
        f"Cada relación es una tupla de tres textos. Revisa esta: {_t}"
    assert _t[0] in VOCABULARIO, f"'{_t[0]}' no está en el vocabulario. Ejecuta ver_vocabulario()"
    assert _t[2] in VOCABULARIO, f"'{_t[2]}' no está en el vocabulario. Ejecuta ver_vocabulario()"
    assert _t[1] in RELACIONES, f"'{_t[1]}' no es una relación permitida. Ejecuta ver_vocabulario()"
    assert _t[0] != _t[2], f"Un concepto no se relaciona consigo mismo: {_t}"

_conceptos = {t[0] for t in MAPA} | {t[2] for t in MAPA}
assert len(_conceptos) >= 8, f"Usaste {len(_conceptos)} conceptos distintos y necesitas al menos 8"
assert len(set(MAPA)) == len(MAPA), "Hay una relación repetida: cada una va una sola vez"

corregir("ejercicio_7", MAPA)     # comprueba las 4 relaciones nucleares

dibujar_mapa(MAPA)
print("Ejercicio 7 superado. Tu mapa quedó dibujado arriba: revísalo con la rúbrica de abajo.")

# %% [markdown]
# #### Lo que la máquina NO puede corregirte
#
# El cuadernillo comprueba que tu mapa esté **bien armado**: que uses el
# vocabulario, que conectes al menos ocho conceptos y que no se te escapen las
# cuatro relaciones que son el corazón de esta semana. Lo que **no** puede
# comprobar es si tus otras relaciones son buenas ideas o disparates con buena
# ortografía. Eso lo miras tú con la rúbrica de abajo y lo mira el profesor en
# clase. Es honesto decírtelo: una máquina puede verificar la forma de una idea,
# no su valor.
#
# **Rúbrica de autoevaluación.** Mira tu mapa dibujado y contéstate:
#
# | Criterio | Sí / Todavía no |
# |---|---|
# | ¿Cada relación mía se puede leer en voz alta como una frase con sentido? | |
# | ¿Conecté las dos mitades del mapa (lo físico con lo abstracto), o quedaron dos islas? | |
# | ¿Hay algún concepto que quedó suelto, sin ninguna flecha? | |
# | ¿Podría explicarle mi mapa a alguien de mi casa en dos minutos? | |

# %%
# Diagrama: s01_d9_mapa_modelo
ava.figura('<svg xmlns="http://www.w3.org/2000/svg" id="dia-s01_d9_mapa_modelo" width="100%" aria-roledescription="flowchart-v2" class="flowchart" role="graphics-document document" style="max-width:2053.58px;background-color:transparent" viewBox="0 0 2053.578 604.5"><style>#dia-s01_d9_mapa_modelo{font-family:system-ui,-apple-system,&apos;Segoe UI&apos;,Roboto,sans-serif;font-size:15px;fill:#000000;}@keyframes edge-animation-frame{from{stroke-dashoffset:0;}}@keyframes dash{to{stroke-dashoffset:0;}}#dia-s01_d9_mapa_modelo .edge-animation-slow{stroke-dasharray:9,5!important;stroke-dashoffset:900;animation:dash 50s linear infinite;stroke-linecap:round;}#dia-s01_d9_mapa_modelo .edge-animation-fast{stroke-dasharray:9,5!important;stroke-dashoffset:900;animation:dash 20s linear infinite;stroke-linecap:round;}#dia-s01_d9_mapa_modelo .error-icon{fill:#552222;}#dia-s01_d9_mapa_modelo .error-text{fill:#552222;stroke:#552222;}#dia-s01_d9_mapa_modelo .edge-thickness-normal{stroke-width:1px;}#dia-s01_d9_mapa_modelo .edge-thickness-thick{stroke-width:3.5px;}#dia-s01_d9_mapa_modelo .edge-pattern-solid{stroke-dasharray:0;}#dia-s01_d9_mapa_modelo .edge-thickness-invisible{stroke-width:0;fill:none;}#dia-s01_d9_mapa_modelo .edge-pattern-dashed{stroke-dasharray:3;}#dia-s01_d9_mapa_modelo .edge-pattern-dotted{stroke-dasharray:2;}#dia-s01_d9_mapa_modelo .marker{fill:#52514e;stroke:#52514e;}#dia-s01_d9_mapa_modelo .marker.cross{stroke:#52514e;}#dia-s01_d9_mapa_modelo svg{font-family:system-ui,-apple-system,&apos;Segoe UI&apos;,Roboto,sans-serif;font-size:15px;}#dia-s01_d9_mapa_modelo p{margin:0;}#dia-s01_d9_mapa_modelo .label{font-family:system-ui,-apple-system,&apos;Segoe UI&apos;,Roboto,sans-serif;color:#000000;}#dia-s01_d9_mapa_modelo .cluster-label text{fill:#333;}#dia-s01_d9_mapa_modelo .cluster-label span{color:#333;}#dia-s01_d9_mapa_modelo .cluster-label span p{background-color:transparent;}#dia-s01_d9_mapa_modelo .label text,#dia-s01_d9_mapa_modelo span{fill:#000000;color:#000000;}#dia-s01_d9_mapa_modelo .node rect,#dia-s01_d9_mapa_modelo .node circle,#dia-s01_d9_mapa_modelo .node ellipse,#dia-s01_d9_mapa_modelo .node polygon,#dia-s01_d9_mapa_modelo .node path{fill:#eee;stroke:#999;stroke-width:1px;}#dia-s01_d9_mapa_modelo .rough-node .label text,#dia-s01_d9_mapa_modelo .node .label text,#dia-s01_d9_mapa_modelo .image-shape .label,#dia-s01_d9_mapa_modelo .icon-shape .label{text-anchor:middle;}#dia-s01_d9_mapa_modelo .node .katex path{fill:#000;stroke:#000;stroke-width:1px;}#dia-s01_d9_mapa_modelo .rough-node .label,#dia-s01_d9_mapa_modelo .node .label,#dia-s01_d9_mapa_modelo .image-shape .label,#dia-s01_d9_mapa_modelo .icon-shape .label{text-align:center;}#dia-s01_d9_mapa_modelo .node.clickable{cursor:pointer;}#dia-s01_d9_mapa_modelo .root .anchor path{fill:#52514e!important;stroke-width:0;stroke:#52514e;}#dia-s01_d9_mapa_modelo .arrowheadPath{fill:#333333;}#dia-s01_d9_mapa_modelo .edgePath .path{stroke:#52514e;stroke-width:1px;}#dia-s01_d9_mapa_modelo .flowchart-link{stroke:#52514e;fill:none;}#dia-s01_d9_mapa_modelo .edgeLabel{background-color:white;text-align:center;}#dia-s01_d9_mapa_modelo .edgeLabel p{background-color:white;}#dia-s01_d9_mapa_modelo .edgeLabel rect{opacity:0.5;background-color:white;fill:white;}#dia-s01_d9_mapa_modelo .labelBkg{background-color:rgba(255, 255, 255, 0.5);}#dia-s01_d9_mapa_modelo .cluster rect{fill:hsl(0, 0%, 98.9215686275%);stroke:#707070;stroke-width:1px;}#dia-s01_d9_mapa_modelo .cluster text{fill:#333;}#dia-s01_d9_mapa_modelo .cluster span{color:#333;}#dia-s01_d9_mapa_modelo div.mermaidTooltip{position:absolute;text-align:center;max-width:200px;padding:2px;font-family:system-ui,-apple-system,&apos;Segoe UI&apos;,Roboto,sans-serif;font-size:12px;background:#fdf6e3;border:1px solid #707070;border-radius:2px;pointer-events:none;z-index:100;}#dia-s01_d9_mapa_modelo .flowchartTitleText{text-anchor:middle;font-size:18px;fill:#000000;}#dia-s01_d9_mapa_modelo rect.text{fill:none;stroke-width:0;}#dia-s01_d9_mapa_modelo .icon-shape,#dia-s01_d9_mapa_modelo .image-shape{background-color:white;text-align:center;}#dia-s01_d9_mapa_modelo .icon-shape p,#dia-s01_d9_mapa_modelo .image-shape p{background-color:white;padding:2px;}#dia-s01_d9_mapa_modelo .icon-shape .label rect,#dia-s01_d9_mapa_modelo .image-shape .label rect{opacity:0.5;background-color:white;fill:white;}#dia-s01_d9_mapa_modelo .label-icon{display:inline-block;height:1em;overflow:visible;vertical-align:-0.125em;}#dia-s01_d9_mapa_modelo .node .label-icon path{fill:currentColor;stroke:revert;stroke-width:revert;}#dia-s01_d9_mapa_modelo .node .neo-node{stroke:#999;}#dia-s01_d9_mapa_modelo [data-look=&quot;neo&quot;].node rect,#dia-s01_d9_mapa_modelo [data-look=&quot;neo&quot;].cluster rect,#dia-s01_d9_mapa_modelo [data-look=&quot;neo&quot;].node polygon{stroke:url(#dia-s01_d9_mapa_modelo-gradient);filter:drop-shadow( 1px 2px 2px rgba(185,185,185,1));}#dia-s01_d9_mapa_modelo [data-look=&quot;neo&quot;].swimlane.cluster rect{filter:none;}#dia-s01_d9_mapa_modelo [data-look=&quot;neo&quot;].node path{stroke:url(#dia-s01_d9_mapa_modelo-gradient);stroke-width:1px;}#dia-s01_d9_mapa_modelo [data-look=&quot;neo&quot;].node .outer-path{filter:drop-shadow( 1px 2px 2px rgba(185,185,185,1));}#dia-s01_d9_mapa_modelo [data-look=&quot;neo&quot;].node .neo-line path{stroke:#999;filter:none;}#dia-s01_d9_mapa_modelo [data-look=&quot;neo&quot;].node circle{stroke:url(#dia-s01_d9_mapa_modelo-gradient);filter:drop-shadow( 1px 2px 2px rgba(185,185,185,1));}#dia-s01_d9_mapa_modelo [data-look=&quot;neo&quot;].node circle .state-start{fill:#000000;}#dia-s01_d9_mapa_modelo [data-look=&quot;neo&quot;].icon-shape .icon{fill:url(#dia-s01_d9_mapa_modelo-gradient);filter:drop-shadow( 1px 2px 2px rgba(185,185,185,1));}#dia-s01_d9_mapa_modelo [data-look=&quot;neo&quot;].icon-shape .icon-neo path{stroke:url(#dia-s01_d9_mapa_modelo-gradient);filter:drop-shadow( 1px 2px 2px rgba(185,185,185,1));}#dia-s01_d9_mapa_modelo :root{--mermaid-font-family:&quot;trebuchet ms&quot;,verdana,arial,sans-serif;}#dia-s01_d9_mapa_modelo .fisico rect{fill:rgb(232, 240, 251)!important;stroke:rgb(42, 120, 214)!important;color:rgb(16, 41, 77)!important;}#dia-s01_d9_mapa_modelo .fisico polygon{fill:rgb(232, 240, 251)!important;stroke:rgb(42, 120, 214)!important;color:rgb(16, 41, 77)!important;}#dia-s01_d9_mapa_modelo .fisico ellipse{fill:rgb(232, 240, 251)!important;stroke:rgb(42, 120, 214)!important;color:rgb(16, 41, 77)!important;}#dia-s01_d9_mapa_modelo .fisico circle{fill:rgb(232, 240, 251)!important;stroke:rgb(42, 120, 214)!important;color:rgb(16, 41, 77)!important;}#dia-s01_d9_mapa_modelo .fisico path{fill:rgb(232, 240, 251)!important;stroke:rgb(42, 120, 214)!important;color:rgb(16, 41, 77)!important;}#dia-s01_d9_mapa_modelo .fisico tspan{fill:rgb(16, 41, 77)!important;}#dia-s01_d9_mapa_modelo .logico rect{fill:rgb(243, 238, 254)!important;stroke:rgb(74, 58, 167)!important;color:rgb(46, 35, 119)!important;}#dia-s01_d9_mapa_modelo .logico polygon{fill:rgb(243, 238, 254)!important;stroke:rgb(74, 58, 167)!important;color:rgb(46, 35, 119)!important;}#dia-s01_d9_mapa_modelo .logico ellipse{fill:rgb(243, 238, 254)!important;stroke:rgb(74, 58, 167)!important;color:rgb(46, 35, 119)!important;}#dia-s01_d9_mapa_modelo .logico circle{fill:rgb(243, 238, 254)!important;stroke:rgb(74, 58, 167)!important;color:rgb(46, 35, 119)!important;}#dia-s01_d9_mapa_modelo .logico path{fill:rgb(243, 238, 254)!important;stroke:rgb(74, 58, 167)!important;color:rgb(46, 35, 119)!important;}#dia-s01_d9_mapa_modelo .logico tspan{fill:rgb(46, 35, 119)!important;}#dia-s01_d9_mapa_modelo .lenguaje rect{fill:rgb(233, 247, 238)!important;stroke:rgb(12, 163, 12)!important;color:rgb(16, 41, 77)!important;}#dia-s01_d9_mapa_modelo .lenguaje polygon{fill:rgb(233, 247, 238)!important;stroke:rgb(12, 163, 12)!important;color:rgb(16, 41, 77)!important;}#dia-s01_d9_mapa_modelo .lenguaje ellipse{fill:rgb(233, 247, 238)!important;stroke:rgb(12, 163, 12)!important;color:rgb(16, 41, 77)!important;}#dia-s01_d9_mapa_modelo .lenguaje circle{fill:rgb(233, 247, 238)!important;stroke:rgb(12, 163, 12)!important;color:rgb(16, 41, 77)!important;}#dia-s01_d9_mapa_modelo .lenguaje path{fill:rgb(233, 247, 238)!important;stroke:rgb(12, 163, 12)!important;color:rgb(16, 41, 77)!important;}#dia-s01_d9_mapa_modelo .lenguaje tspan{fill:rgb(16, 41, 77)!important;}#dia-s01_d9_mapa_modelo .entorno rect{fill:rgb(253, 246, 227)!important;stroke:rgb(237, 161, 0)!important;color:rgb(16, 41, 77)!important;}#dia-s01_d9_mapa_modelo .entorno polygon{fill:rgb(253, 246, 227)!important;stroke:rgb(237, 161, 0)!important;color:rgb(16, 41, 77)!important;}#dia-s01_d9_mapa_modelo .entorno ellipse{fill:rgb(253, 246, 227)!important;stroke:rgb(237, 161, 0)!important;color:rgb(16, 41, 77)!important;}#dia-s01_d9_mapa_modelo .entorno circle{fill:rgb(253, 246, 227)!important;stroke:rgb(237, 161, 0)!important;color:rgb(16, 41, 77)!important;}#dia-s01_d9_mapa_modelo .entorno path{fill:rgb(253, 246, 227)!important;stroke:rgb(237, 161, 0)!important;color:rgb(16, 41, 77)!important;}#dia-s01_d9_mapa_modelo .entorno tspan{fill:rgb(16, 41, 77)!important;}#dia-s01_d9_mapa_modelo .error rect{fill:rgb(253, 241, 241)!important;stroke:rgb(208, 59, 59)!important;color:rgb(16, 41, 77)!important;}#dia-s01_d9_mapa_modelo .error polygon{fill:rgb(253, 241, 241)!important;stroke:rgb(208, 59, 59)!important;color:rgb(16, 41, 77)!important;}#dia-s01_d9_mapa_modelo .error ellipse{fill:rgb(253, 241, 241)!important;stroke:rgb(208, 59, 59)!important;color:rgb(16, 41, 77)!important;}#dia-s01_d9_mapa_modelo .error circle{fill:rgb(253, 241, 241)!important;stroke:rgb(208, 59, 59)!important;color:rgb(16, 41, 77)!important;}#dia-s01_d9_mapa_modelo .error path{fill:rgb(253, 241, 241)!important;stroke:rgb(208, 59, 59)!important;color:rgb(16, 41, 77)!important;}#dia-s01_d9_mapa_modelo .error tspan{fill:rgb(16, 41, 77)!important;}</style><marker id="dia-s01_d9_mapa_modelo_flowchart-v2-pointEnd" class="marker flowchart-v2" markerHeight="8" markerUnits="userSpaceOnUse" markerWidth="8" orient="auto" refX="5" refY="5" viewBox="0 0 10 10"><path d="m0 0 10 5-10 5z" class="arrowMarkerPath" style="stroke-width:1;stroke-dasharray:1,0"/></marker><marker id="dia-s01_d9_mapa_modelo_flowchart-v2-pointStart" class="marker flowchart-v2" markerHeight="8" markerUnits="userSpaceOnUse" markerWidth="8" orient="auto" refX="4.5" refY="5" viewBox="0 0 10 10"><path d="m0 5 10 5V0z" class="arrowMarkerPath" style="stroke-width:1;stroke-dasharray:1,0"/></marker><marker id="dia-s01_d9_mapa_modelo_flowchart-v2-pointEnd-margin" class="marker flowchart-v2" markerHeight="14" markerUnits="userSpaceOnUse" markerWidth="10.5" orient="auto" refX="11.5" refY="7" viewBox="0 0 11.5 14"><path d="m0 0 11.5 7L0 14z" class="arrowMarkerPath" style="stroke-width:0;stroke-dasharray:1,0"/></marker><marker id="dia-s01_d9_mapa_modelo_flowchart-v2-pointStart-margin" class="marker flowchart-v2" markerHeight="14" markerUnits="userSpaceOnUse" markerWidth="11.5" orient="auto" refX="1" refY="7" viewBox="0 0 11.5 14"><polygon points="0,7 11.5,14 11.5,0" class="arrowMarkerPath" style="stroke-width:0;stroke-dasharray:1,0"/></marker><marker id="dia-s01_d9_mapa_modelo_flowchart-v2-circleEnd" class="marker flowchart-v2" markerHeight="11" markerUnits="userSpaceOnUse" markerWidth="11" orient="auto" refX="11" refY="5" viewBox="0 0 10 10"><circle cx="5" cy="5" r="5" class="arrowMarkerPath" style="stroke-width:1;stroke-dasharray:1,0"/></marker><marker id="dia-s01_d9_mapa_modelo_flowchart-v2-circleStart" class="marker flowchart-v2" markerHeight="11" markerUnits="userSpaceOnUse" markerWidth="11" orient="auto" refX="-1" refY="5" viewBox="0 0 10 10"><circle cx="5" cy="5" r="5" class="arrowMarkerPath" style="stroke-width:1;stroke-dasharray:1,0"/></marker><marker id="dia-s01_d9_mapa_modelo_flowchart-v2-circleEnd-margin" class="marker flowchart-v2" markerHeight="14" markerUnits="userSpaceOnUse" markerWidth="14" orient="auto" refX="12.25" refY="5" viewBox="0 0 10 10"><circle cx="5" cy="5" r="5" class="arrowMarkerPath" style="stroke-width:0;stroke-dasharray:1,0"/></marker><marker id="dia-s01_d9_mapa_modelo_flowchart-v2-circleStart-margin" class="marker flowchart-v2" markerHeight="14" markerUnits="userSpaceOnUse" markerWidth="14" orient="auto" refX="-2" refY="5" viewBox="0 0 10 10"><circle cx="5" cy="5" r="5" class="arrowMarkerPath" style="stroke-width:0;stroke-dasharray:1,0"/></marker><marker id="dia-s01_d9_mapa_modelo_flowchart-v2-crossEnd" class="marker cross flowchart-v2" markerHeight="11" markerUnits="userSpaceOnUse" markerWidth="11" orient="auto" refX="12" refY="5.2" viewBox="0 0 11 11"><path d="m1 1 9 9m0-9-9 9" class="arrowMarkerPath" style="stroke-width:2;stroke-dasharray:1,0"/></marker><marker id="dia-s01_d9_mapa_modelo_flowchart-v2-crossStart" class="marker cross flowchart-v2" markerHeight="11" markerUnits="userSpaceOnUse" markerWidth="11" orient="auto" refX="-1" refY="5.2" viewBox="0 0 11 11"><path d="m1 1 9 9m0-9-9 9" class="arrowMarkerPath" style="stroke-width:2;stroke-dasharray:1,0"/></marker><marker id="dia-s01_d9_mapa_modelo_flowchart-v2-crossEnd-margin" class="marker cross flowchart-v2" markerHeight="12" markerUnits="userSpaceOnUse" markerWidth="12" orient="auto" refX="17.7" refY="7.5" viewBox="0 0 15 15"><path d="m1 1 13 13M1 14 14 1" class="arrowMarkerPath" style="stroke-width:2.5"/></marker><marker id="dia-s01_d9_mapa_modelo_flowchart-v2-crossStart-margin" class="marker cross flowchart-v2
y="-2" class="background"/><text y="-10.1" text-anchor="middle"><tspan x="0" y="-.1em" class="text-outer-tspan row" dy="1.1em" text-anchor="middle"><tspan class="text-inner-tspan" font-style="normal" font-weight="normal">usa</tspan></tspan></text></g></g><g class="edgeLabel"><g class="label" data-id="L_PROG_ELOG_0" transform="translate(726.82 122.5)"><rect width="86.859" height="22" x="-43.43" y="-2" class="background"/><text y="-10.1" text-anchor="middle"><tspan x="0" y="-.1em" class="text-outer-tspan row" dy="1.1em" text-anchor="middle"><tspan class="text-inner-tspan" font-style="normal" font-weight="normal">puede</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> tener</tspan></tspan></text></g></g></g><g class="nodes"><g id="dia-s01_d9_mapa_modelo-flowchart-COMP-0" class="node default fisico" data-look="classic" transform="translate(79.695 131.5)"><rect width="143.391" height="48" x="-71.695" y="-24" class="basic label-container" style="fill:#e8f0fb!important;stroke:#2a78d6!important"/><g class="label" style="color:#10294d!important" transform="translate(0 -9)"><rect/><rect class="background" style="stroke:none"/><text y="-10.1" style="fill:#10294d!important"><tspan x="0" y="-.1em" class="text-outer-tspan row" dy="1.1em"><tspan class="text-inner-tspan" font-style="normal" font-weight="normal">computador</tspan></tspan></text></g></g><g id="dia-s01_d9_mapa_modelo-flowchart-HW-1" class="node default fisico" data-look="classic" transform="translate(1371.805 53)"><rect width="123.672" height="48" x="-61.836" y="-24" class="basic label-container" style="fill:#e8f0fb!important;stroke:#2a78d6!important"/><g class="label" style="color:#10294d!important" transform="translate(0 -9)"><rect/><rect class="background" style="stroke:none"/><text y="-10.1" style="fill:#10294d!important"><tspan x="0" y="-.1em" class="text-outer-tspan row" dy="1.1em"><tspan class="text-inner-tspan" font-style="normal" font-weight="normal">hardware</tspan></tspan></text></g></g><g id="dia-s01_d9_mapa_modelo-flowchart-SW-2" class="node default logico" data-look="classic" transform="translate(370.383 180.5)"><rect width="119.453" height="48" x="-59.727" y="-24" class="basic label-container" style="fill:#f3eefe!important;stroke:#4a3aa7!important"/><g class="label" style="color:#2e2377!important" transform="translate(0 -9)"><rect/><rect class="background" style="stroke:none"/><text y="-10.1" style="fill:#2e2377!important"><tspan x="0" y="-.1em" class="text-outer-tspan row" dy="1.1em"><tspan class="text-inner-tspan" font-style="normal" font-weight="normal">software</tspan></tspan></text></g></g><g id="dia-s01_d9_mapa_modelo-flowchart-PROC-3" class="node default fisico" data-look="classic" transform="translate(1661.93 32)"><rect width="138.047" height="48" x="-69.023" y="-24" class="basic label-container" style="fill:#e8f0fb!important;stroke:#2a78d6!important"/><g class="label" style="color:#10294d!important" transform="translate(0 -9)"><rect/><rect class="background" style="stroke:none"/><text y="-10.1" style="fill:#10294d!important"><tspan x="0" y="-.1em" class="text-outer-tspan row" dy="1.1em"><tspan class="text-inner-tspan" font-style="normal" font-weight="normal">procesador</tspan></tspan></text></g></g><g id="dia-s01_d9_mapa_modelo-flowchart-MEM-4" class="node default fisico" data-look="classic" transform="translate(1661.93 180.5)"><rect width="119.594" height="48" x="-59.797" y="-24" class="basic label-container" style="fill:#e8f0fb!important;stroke:#2a78d6!important"/><g class="label" style="color:#10294d!important" transform="translate(0 -9)"><rect/><rect class="background" style="stroke:none"/><text y="-10.1" style="fill:#10294d!important"><tspan x="0" y="-.1em" class="text-outer-tspan row" dy="1.1em"><tspan class="text-inner-tspan" font-style="normal" font-weight="normal">memoria</tspan></tspan></text></g></g><g id="dia-s01_d9_mapa_modelo-flowchart-PROG-5" class="node default logico" data-look="classic" transform="translate(584.14 180.5)"><rect width="126.094" height="48" x="-63.047" y="-24" class="basic label-container" style="fill:#f3eefe!important;stroke:#4a3aa7!important"/><g class="label" style="color:#2e2377!important" transform="translate(0 -9)"><rect/><rect class="background" style="stroke:none"/><text y="-10.1" style="fill:#2e2377!important"><tspan x="0" y="-.1em" class="text-outer-tspan row" dy="1.1em"><tspan class="text-inner-tspan" font-style="normal" font-weight="normal">programa</tspan></tspan></text></g></g><g id="dia-s01_d9_mapa_modelo-flowchart-PROCESO-6" class="node default logico" data-look="classic" transform="translate(886.156 229.5)"><rect width="115.547" height="48" x="-57.773" y="-24" class="basic label-container" style="fill:#f3eefe!important;stroke:#4a3aa7!important"/><g class="label" style="color:#2e2377!important" transform="translate(0 -9)"><rect/><rect class="background" style="stroke:none"/><text y="-10.1" style="fill:#2e2377!important"><tspan x="0" y="-.1em" class="text-outer-tspan row" dy="1.1em"><tspan class="text-inner-tspan" font-style="normal" font-weight="normal">proceso</tspan></tspan></text></g></g><g id="dia-s01_d9_mapa_modelo-flowchart-DATO-7" class="node default logico" data-look="classic" transform="translate(1122.055 229.5)"><rect width="90.766" height="48" x="-45.383" y="-24" class="basic label-container" style="fill:#f3eefe!important;stroke:#4a3aa7!important"/><g class="label" style="color:#2e2377!important" transform="translate(0 -9)"><rect/><rect class="background" style="stroke:none"/><text y="-10.1" style="fill:#2e2377!important"><tspan x="0" y="-.1em" class="text-outer-tspan row" dy="1.1em"><tspan class="text-inner-tspan" font-style="normal" font-weight="normal">dato</tspan></tspan></text></g></g><g id="dia-s01_d9_mapa_modelo-flowchart-ARCH-8" class="node default logico" data-look="classic" transform="translate(1371.805 229.5)"><rect width="109.766" height="48" x="-54.883" y="-24" class="basic label-container" style="fill:#f3eefe!important;stroke:#4a3aa7!important"/><g class="label" style="color:#2e2377!important" transform="translate(0 -9)"><rect/><rect class="background" style="stroke:none"/><text y="-10.1" style="fill:#2e2377!important"><tspan x="0" y="-.1em" class="text-outer-tspan row" dy="1.1em"><tspan class="text-inner-tspan" font-style="normal" font-weight="normal">archivo</tspan></tspan></text></g></g><g id="dia-s01_d9_mapa_modelo-flowchart-LM-9" class="node default lenguaje" data-look="classic" transform="translate(1943.672 53)"><rect width="201.313" height="48" x="-100.656" y="-24" class="basic label-container" style="fill:#e9f7ee!important;stroke:#0ca30c!important"/><g class="label" style="color:#10294d!important" transform="translate(0 -9)"><rect/><rect class="background" style="stroke:none"/><text y="-10.1" style="fill:#10294d!important"><tspan x="0" y="-.1em" class="text-outer-tspan row" dy="1.1em"><tspan class="text-inner-tspan" font-style="normal" font-weight="normal">lenguaje</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> de</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> máquina</tspan></tspan></text></g></g><g id="dia-s01_d9_mapa_modelo-flowchart-LAN-10" class="node default lenguaje" data-look="classic" transform="translate(1943.672 376.5)"><rect width="203.813" height="48" x="-101.906" y="-24" class="basic label-container" style="fill:#e9f7ee!important;stroke:#0ca30c!important"/><g class="label" style="color:#10294d!important" transform="translate(0 -9)"><rect/><rect class="background" style="stroke:none"/><text y="-10.1" style="fill:#10294d!important"><tspan x="0" y="-.1em" class="text-outer-tspan row" dy="1.1em"><tspan class="text-inner-tspan" font-style="normal" font-weight="normal">lenguaje</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> de</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> alto</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> nivel</tspan></tspan></text></g></g><g id="dia-s01_d9_mapa_modelo-flowchart-PY-11" class="node default lenguaje" data-look="classic" transform="translate(1661.93 278.5)"><rect width="108.453" height="48" x="-54.227" y="-24" class="basic label-container" style="fill:#e9f7ee!important;stroke:#0ca30c!important"/><g class="label" style="color:#10294d!important" transform="translate(0 -9)"><rect/><rect class="background" style="stroke:none"/><text y="-10.1" style="fill:#10294d!important"><tspan x="0" y="-.1em" class="text-outer-tspan row" dy="1.1em"><tspan class="text-inner-tspan" font-style="normal" font-weight="normal">Python</tspan></tspan></text></g></g><g id="dia-s01_d9_mapa_modelo-flowchart-INT-12" class="node default entorno" data-look="classic" transform="translate(1661.93 376.5)"><rect width="127.016" height="48" x="-63.508" y="-24" class="basic label-container" style="fill:#fdf6e3!important;stroke:#eda100!important"/><g class="label" style="color:#10294d!important" transform="translate(0 -9)"><rect/><rect class="background" style="stroke:none"/><text y="-10.1" style="fill:#10294d!important"><tspan x="0" y="-.1em" class="text-outer-tspan row" dy="1.1em"><tspan class="text-inner-tspan" font-style="normal" font-weight="normal">intérprete</tspan></tspan></text></g></g><g id="dia-s01_d9_mapa_modelo-flowchart-IDE-13" class="node default entorno" data-look="classic" transform="translate(1371.805 474.5)"><rect width="83.156" height="48" x="-41.578" y="-24" class="basic label-container" style="fill:#fdf6e3!important;stroke:#eda100!important"/><g class="label" style="color:#10294d!important" transform="translate(0 -9)"><rect/><rect class="background" style="stroke:none"/><text y="-10.1" style="fill:#10294d!important"><tspan x="0" y="-.1em" class="text-outer-tspan row" dy="1.1em"><tspan class="text-inner-tspan" font-style="normal" font-weight="normal">IDE</tspan></tspan></text></g></g><g id="dia-s01_d9_mapa_modelo-flowchart-ED-14" class="node default entorno" data-look="classic" transform="translate(1661.93 474.5)"><rect width="100" height="48" x="-50" y="-24" class="basic label-container" style="fill:#fdf6e3!important;stroke:#eda100!important"/><g class="label" style="color:#10294d!important" transform="translate(0 -9)"><rect/><rect class="background" style="stroke:none"/><text y="-10.1" style="fill:#10294d!important"><tspan x="0" y="-.1em" class="text-outer-tspan row" dy="1.1em"><tspan class="text-inner-tspan" font-style="normal" font-weight="normal">editor</tspan></tspan></text></g></g><g id="dia-s01_d9_mapa_modelo-flowchart-TERM-15" class="node default entorno" data-look="classic" transform="translate(1661.93 572.5)"><rect width="115.484" height="48" x="-57.742" y="-24" class="basic label-container" style="fill:#fdf6e3!important;stroke:#eda100!important"/><g class="label" style="color:#10294d!important" transform="translate(0 -9)"><rect/><rect class="background" style="stroke:none"/><text y="-10.1" style="fill:#10294d!important"><tspan x="0" y="-.1em" class="text-outer-tspan row" dy="1.1em"><tspan class="text-inner-tspan" font-style="normal" font-weight="normal">terminal</tspan></tspan></text></g></g><g id="dia-s01_d9_mapa_modelo-flowchart-ELOG-16" class="node default error" data-look="classic" transform="translate(886.156 131.5)"><rect width="159.406" height="48" x="-79.703" y="-24" class="basic label-container" style="fill:#fdf1f1!important;stroke:#d03b3b!important"/><g class="label" style="color:#10294d!important" transform="translate(0 -9)"><rect/><rect class="background" style="stroke:none"/><text y="-10.1" style="fill:#10294d!important"><tspan x="0" y="-.1em" class="text-outer-tspan row" dy="1.1em"><tspan class="text-inner-tspan" font-style="normal" font-weight="normal">error</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> de</tspan><tspan class="text-inner-tspan" font-style="normal" font-weight="normal"> lógica</tspan></tspan></text></g></g></g></g><defs><filter id="dia-s01_d9_mapa_modelo-drop-shadow" width="130%" height="130%"><feDropShadow dx="4" dy="4" flood-color="#000" flood-opacity=".06" stdDeviation="0"/></filter></defs><defs><filter id="dia-s01_d9_mapa_modelo-drop-shadow-small" width="150%" height="150%"><feDropShadow dx="2" dy="2" flood-color="#000" flood-opacity=".06" stdDeviation="0"/></filter></defs><linearGradient id="dia-s01_d9_mapa_modelo-gradient" x1="0%" x2="100%" y1="0%" y2="0%" gradientUnits="objectBoundingBox"><stop offset="0%" stop-color="hsl(0, 0%, 83.3333333333%)" stop-opacity="1"/><stop offset="100%" stop-color="hsl(0, 0%, 88.9215686275%)" stop-opacity="1"/></linearGradient></svg>', 'Un mapa posible. No es «el» mapa correcto: compara la forma, no las palabras.')

# %% [markdown]
# ---
#
# ## 6. El reto: MiniMáquina 2.0 · 10 min
#
# *(opcional, sin nota)*
#
# La MiniMáquina sabe cargar, sumar, mostrar y parar. Le falta **restar**.
#
# Abajo está su motor completo — el mismo que ejecutaste en la sección 3B, sin
# trucos. Léelo (vas a entender más de lo que crees), y **agrégale la instrucción
# `4 n` = RESTAR n**.
#
# No hay verificador ni puntos. Hay algo mejor: si funciona, acabas de ampliar el
# repertorio de instrucciones de un procesador. Eso es literalmente diseñar
# hardware.
#
# Si te sobran ganas: agrégale también `5 n` = MULTIPLICAR, y después intenta
# escribir un programa que calcule el promedio de tres notas usando solo tus
# instrucciones. Vas a descubrir por qué se inventaron los lenguajes de alto
# nivel.

# %%
def mi_minimaquina(programa):
    """La MiniMáquina entera. Léela de arriba abajo: es más simple de lo que parece."""
    acumulador = 0          # la única gaveta que tiene la máquina
    mostrados = []          # lo que fue mostrando por el camino
    i = 0                   # dónde va leyendo dentro de la lista

    while i + 1 < len(programa):        # mientras queden instrucciones completas
        codigo = programa[i]            # qué hay que hacer
        argumento = programa[i + 1]     # con qué número

        if codigo == 1:                 # CARGAR
            acumulador = argumento
        elif codigo == 2:               # SUMAR
            acumulador = acumulador + argumento
        elif codigo == 3:               # MOSTRAR
            print("La gaveta tiene:", acumulador)
            mostrados.append(acumulador)
        elif codigo == 0:               # PARAR
            break
        # <- AGREGA AQUÍ TU INSTRUCCIÓN
        #    elif codigo == 4:          # RESTAR
        #        ...

        i = i + 2                       # cada instrucción ocupa dos posiciones

    return mostrados


# 4 + 9 - 6 debería mostrar 7. Mientras RESTAR no exista, la máquina se salta
# esa instrucción y muestra 13. Ejecuta, mira el 13, y arréglalo.
mi_minimaquina([1, 4, 2, 9, 4, 6, 3, 0, 0, 0])

# %% [markdown]
# ---
#
# ## 7. Tus cinco preguntas · 5 min
#
# Abajo a la derecha de la pantalla hay un botón con un robot. Es **Ava**, el
# tutor de inteligencia artificial del curso. Tres cosas que tienes que saber
# antes de tocarlo:
#
# **1. Tienes cinco preguntas por cuadernillo. Cinco. No cinco por ejercicio.**
# El contador va abajo en el panel. Se gasta una pregunta solo cuando Ava
# alcanza a responder: si se cae la conexión, no pierdes nada.
#
# **2. Ava no te va a dar la respuesta, ni suplicándole.** Está configurado como
# tutor socrático: responde con preguntas y pistas. No es tacañería. En la
# evaluación escrita —que pesa el 30 %— Ava no entra contigo al salón. Cada vez
# que le pides la solución, el que aprende es él; cada vez que le pides una
# pregunta, el que aprende eres tú.
#
# **3. Ava ve tu pantalla, pero solo si le apuntas.** Antes de preguntar, **haz
# clic en la celda del ejercicio en el que estás atascado**. El panel toma
# automáticamente el enunciado, el código que llevas escrito y el último error
# que te salió. Si preguntas desde cualquier otra parte del cuadernillo, Ava
# responde a ciegas y gastas una pregunta en un «¿en qué ejercicio vas?».

# %% [markdown]
# ### Antes de gastar una pregunta, haz estas tres cosas
#
# Son gratis y resuelven, con mucho, la mayoría de los atascos:
#
# 1. **Lee la última línea del mensaje rojo.** Esa línea es la respuesta. Todo lo
#    de arriba es contexto.
# 2. **Usa las tres pistas del ejercicio** (`pista("E3")`). Van de lo
#    general a lo concreto y no cuestan nada.
# 3. **Explícale tu código en voz alta a la pared.** Suena ridículo y funciona:
#    la mitad de los errores aparecen solos al obligarte a decir qué hace cada
#    línea. Los programadores le dicen «depuración del patito de hule».
#
# ### Presupuesto sugerido para este cuadernillo
#
# | Ejercicio | Preguntas sugeridas | Por qué |
# |---|---|---|
# | 1 y 2 (clasificar, ordenar) | **0** | Son de concepto: la respuesta está en la sección 3. Si dudas, relee — es más rápido |
# | 3 (MiniMáquina) | **0–1** | Si el programa no muestra 20, tu pregunta ideal es sobre la tabla de traza |
# | 4 (tipos de error) | **0** | La tabla comparativa de la sección 4 lo resuelve |
# | 5 (arreglar la lógica) | **1** | Aquí sí vale la pena si no ves qué está mal |
# | 6 (archivos) | **1** | El manejo de `open` es nuevo y es normal atascarse |
# | 7 (mapa conceptual) | **1–2** | Guarda estas: es el ejercicio abierto |
#
# ### Cómo se pregunta bien
#
# | Pregunta que te va a servir | Pregunta que desperdicia el turno |
# |---|---|
# | «Me sale `TypeError: can only concatenate str to str` en el ejercicio 5. **No me des la solución: hazme una pregunta** que me ayude a ver qué tipo de dato tengo.» | «Hazme el ejercicio 5.» |
# | «Creo que mi error es de lógica porque no sale mensaje rojo pero el número está mal. ¿Cómo compruebo si tengo razón?» | «¿Está bien mi código?» *(sin decir cuál ni qué esperabas)* |
# | «Explícame con **otra analogía** la diferencia entre intérprete y compilador; la del traductor no me quedó clara.» | «Explícame todo el cuadernillo.» |
# | «Mi mapa conceptual tiene 9 relaciones y el test dice que falta conectar 'procesador'. ¿Qué preguntas debería hacerme sobre el procesador?» | «Dame las 9 relaciones del mapa.» |
# | «Voy a decirte lo que **creo** que hace mi código línea por línea. Dime en cuál me equivoco.» | «Corrige esto.» *(pegando el código sin más)* |
#
# Fíjate en el patrón de la columna buena: **dice dónde está, qué esperaba, qué
# pasó, y pide una pregunta en vez de una respuesta.**

# %%
quiz(
    "A1", 6,
    "Llevas 20 minutos atascado en el ejercicio 6 y te quedan 2 preguntas. "
    "¿Cuál es la mejor jugada?",
    ["Pedirle a Ava el código resuelto y copiarlo",
     "Hacer clic en la celda del ejercicio 6 y pedirle a Ava que me haga preguntas "
     "sobre lo que ya escribí",
     "Preguntarle a Ava desde donde esté, sin seleccionar nada",
     "Saltarme el ejercicio"],
    "Hacer clic en la celda del ejercicio 6 y pedirle a Ava que me haga preguntas "
    "sobre lo que ya escribí",
    "Le diste contexto (la celda) y le pediste el tipo de ayuda que sí te deja "
    "aprendiendo. Las dos cosas, en una sola pregunta.",
    pistas=["Dos cosas importan aquí: <b>dónde</b> haces clic antes de preguntar y "
            "<b>qué</b> le pides. Solo una opción acierta en las dos."],
)

# %% [markdown]
# ---
#
# ## 8. Cierre · 10 min
#
# Antes de reclamar tu insignia, tres preguntas que solo te interesan a ti:
#
# 1. **¿Qué puedes hacer hoy que no podías esta mañana?** (respóndete en voz
#    alta; si la respuesta es «nada», vuelve a la sección 3B)
# 2. **¿Cuál de los tres tipos de error te parece más peligroso, y por qué?**
# 3. **Si tuvieras que explicarle a alguien de tu casa qué es el software, ¿qué
#    ejemplo usarías?**

# %% [markdown]
# ## Tu entorno de trabajo
#
# Este cuadernillo corre en un computador de la universidad al que entras por el
# navegador. Alguien —nosotros— ya instaló ahí Python, Jupyter y todo lo demás,
# y por eso hoy pudiste programar a los diez minutos sin pelear con un instalador.
#
# Eso es deliberado: **en la semana 1 nadie debería perder su primera clase
# porque un `.exe` falló.**
#
# Pero también sería mentirte decir que ya tienes un entorno. El día que quieras
# programar sin internet, hacer tu proyecto final, o trabajar después de que este
# curso termine, vas a necesitar **tu propio Python**. Por eso la lista tiene dos
# columnas:
#
# | | **Columna A — El entorno del AVA** | **Columna B — Tu entorno local** |
# |---|---|---|
# | Dónde | En el navegador, servidor de la UIS | En tu computador |
# | Quién lo instaló | Nosotros | Tú, en la clase 2 |
# | Para qué sirve | Aprender y **ser calificado** | Trabajar por tu cuenta, sin internet |
# | ¿De aquí sale tu nota? | **Sí** | **No** |
# | ¿Es obligatorio? | Sí, y ya lo tienes | Sí para tu formación, **no para tu nota de hoy** |
#
# ### Columna B — la instalación local, con dos rutas honestas
#
# **Ruta 1 — Tengo computador y puedo instalar** *(en la clase 2 o en casa)*
#
# 1. Instala **Python** desde `python.org/downloads`. En Windows, marca la
#    casilla **«Add python.exe to PATH»** en la primera pantalla. Es la casilla
#    que, si no marcas, te va a costar media hora después.
# 2. Abre una **terminal** (en Windows: `cmd`; en Mac/Linux: Terminal) y escribe
#    `python --version`. Si contesta con un número, ganaste.
# 3. Instala **VS Code** desde `code.visualstudio.com` y, dentro, la extensión
#    **Python** de Microsoft.
# 4. Crea una carpeta `algoritmos-uis` y dentro un archivo `hola.py` con una
#    línea: `print("Hola desde mi propio computador")`.
# 5. Ejecútalo de **tres formas distintas**, que es el punto del ejercicio:
#    · desde la terminal, con `python hola.py`
#    · desde VS Code, con el botón de ejecutar
#    · desde Jupyter, instalándolo con `pip install notebook` y corriendo
#      `jupyter notebook`
# 6. Fíjate en lo que **no** cambia: las tres veces es el mismo intérprete
#    ejecutando el mismo archivo. Editor, terminal y cuaderno son tres puertas al
#    mismo cuarto.
#
# **Ruta 2 — No tengo computador propio, o no puedo instalar**
#
# Esto no te deja atrás y no te cuesta un punto. Tienes tres opciones, en orden:
#
# 1. **La sala de cómputo de la UIS**, en la franja de la clase 2: el profesor
#    reserva 20 minutos para hacer la ruta 1 en equipo. Es la opción oficial.
# 2. **Versión portátil**: WinPython y VS Code Portable caben en una USB y no
#    requieren permisos de administrador.
# 3. **Ninguna por ahora**: sigue con la columna A, que es la que califica, y
#    haz la ruta 1 cuando puedas. Avísale al profesor por Moodle para que lo
#    sepa; no es un problema, es información.

# %%
verificar_entorno()     # columna A, automática
lista_comprobacion()    # columna B, autodeclarada + texto para Moodle

# %%
reclamar_insignia()

# %% [markdown]
# ### Para profundizar — y para aprender a elegir fuentes
#
# Una competencia de este curso es **investigar en fuentes confiables**, no en el
# primer video que salga. Cuatro para empezar:
#
# - **Computer History Museum** (`computerhistory.org`) — la historia completa,
#   con documentos originales. Es un museo: no le paga nadie por convencerte.
# - **La documentación oficial de Python** (`docs.python.org/es/3/`) — en
#   español. Aburrida y exacta: la fuente definitiva cuando algo no funciona.
# - **How to Think Like a Computer Scientist**, edición Runestone — libro de CS1
#   abierto, gratuito e interactivo.
# - **Real Python** (`realpython.com`) — tutoriales serios, con autor firmado.
#
# **Cómo saber si una fuente es confiable**, en tres preguntas:
# *¿quién la publica y qué gana con eso?* · *¿dice de dónde saca lo que afirma?*
# · *¿de cuándo es?* (en informática, cinco años es una eternidad).
#
# Y una advertencia específica de 2026: **la IA generativa también es una fuente,
# y es una fuente que se equivoca con mucha seguridad.** Ava incluido. Todo lo
# que te diga sobre un dato concreto —una fecha, una función, un parámetro—
# verifícalo en la documentación oficial. Toma treinta segundos.

# %% [markdown]
# ---
# *Semana 1 · AVA Algoritmos y Programación 41333 · UIS 2026-2*
# *Puntos de este cuadernillo: 25. XP: 70. Tu nota viaja sola a Moodle.*
